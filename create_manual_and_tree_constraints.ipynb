# %% [markdown]
# # Create a constraint tree joining manual and antumated constraints
#
# In this notebook, we will create constraint statements for BEAST2 that will join soft constraints that we had produced before from published Diptera trees (see [create_constraint.ipynb](create_constraint.ipynb)) with hard constraints pulled from several literature sources, summarized in a text file.

# %% [markdown]
# ## Retrieve previous constraint tree

# %%
import dendropy, numpy as np, copy
from pathlib import Path
from collections import defaultdict, Counter

# %%
with open('./constraint_trees/result/partial_iqtree.tre', 'r') as f:
    tr = dendropy.Tree.get(file=f, schema="newick",preserve_underscores=True)
    for node in tr.internal_nodes():
        node.label = None
        node.taxon = None

tr.print_plot(show_internal_node_labels=True)
# Out:
# /----------------------------------------------------- Deuterophlebia_560719
# |
# |  /-------------------------------------------------- Nymphomyia_560766
# |  |
# |  |                                        /--------- Trichocera_52759
# |  |                                        |
# |  |  /-------------------------------------@     /--- Dicranota_700836
# |  |  |                                     |  /--@
# |  |  |                                     |  |  \--- Pedicia_472374
# |  |  |                                     \--@
# @  |  |                                        |  /--- Liogma_560731
# |  |  |                                        |  |
# |  |  |                                        \--@--- Phalacrocera_2203737
# |  |  |                                           |
# |  |  |                                           \--- Cylindrotoma_700834
# |  |  |
# |  |  |                                           /--- Liponeura_446516
# |  |  |                                        /--@
# |  |  |                                        |  \--- Blepharicera_547808
# |  |  |                               /--------@
# \--@  |                               |        |  /--- Mischoderus_560267
#    |  |                               |        |  |
#    |  |                               |        \--@--- Araucoderus_1549737
#    |  |                               |           |
#    |  |                               |           \--- Protoplasa_560776
#    |  |                               |
#    |  |                               |  /------------ Dixa_79309
#    |  |                               |  |
#    |  |                               |  |        /--- Sphaeromias_1874311
#    |  |                               |  |        |
#    |  |                               |  |        |--- Palpomyia_1525500
#    |  |                               |  |        |
#    |  |  /----------------------------@  |        |--- Austroconops_209696
#    |  |  |                            |  |        |
#    |  |  |                            |  |        |--- Culicoides_41820
#    |  |  |                            |  |     /--@
#    |  |  |                            |  |     |  |--- Serromyia_209716
#    |  |  |                            |  |     |  |
#    \--@  |                            |  |     |  |--- Forcipomyia_209700
#       |  |                            |  |     |  |
#       |  |                            |  |     |  |--- Dasyhelea_41822
#       |  |                            |  |     |  |
#       |  |                            |  |     |  \--- Atrichopogon_209702
#       |  |                            |  |     |
#       |  |                            |  |     |  /--- Ainuyusurika_1165747
#       |  |                            \--@     |  |
#       |  |                               |     |  |--- Pentaneura_891922
#       |  |                               |     |  |
#       |  |                               |  /--@  |--- Metriocnemus_137497
#       |  |                               |  |  |  |
#       |  |                               |  |  |  |--- Eukiefferiella_288843
#       |  |                               |  |  |  |
#       |  |                               |  |  |  |--- Parochlus_315560
#       |  |                               |  |  |  |
#       |  |                               |  |  |  |--- Pseudosmittia_611382
#       |  |                               |  |  |  |
#       |  |                               |  |  |  |--- Tvetenia_611398
#       |  |                               |  |  |  |
#       |  |                               |  |  |  |--- Paucispinigera_903463
#       |  |                               |  |  |  |
#       |  |                               |  |  |  |--- Paraborniella_903459
#       |  |                               |  |  \--@
#       |  |                               |  |     |--- Smittia_315559
#       |  |                               |  |     |
#       |  |                               |  |     |--- Monodiamesa_891905
#       |  |                               \--@     |
#       |  |                                  |     |--- Chironomus_7150
#       |  |                                  |     |
#       |  |                                  |     |--- Clunio_315556
#       |  |                                  |     |
#       |  |                                  |     |--- Aphroteniella_646259
#       \--@                                  |     |
#          |                                  |     |--- Gymnometriocnemus_611353
#          |                                  |     |
#          |                                  |     |--- Corynoneura_611344
#          |                                  |     |
#          |                                  |     |--- Ablabesmyia_46216
#          |                                  |     |
#          |                                  |     \--- Psectrotanypus_903467
#          |                                  |
#          |                                  |     /--- Androprosopa_41815
#          |                                  |     |
#          |                                  \-----@--- Austrothaumalea_1085085
#          |                                        |
#          |                                        \--- Thaumalea_61068
#          |
#          |                                        /--- Scatopse_1520324
#          |                        /---------------@
#          |                        |               \--- Coboldia_170624
#          |                        |
#          |                        |   /--------------- Axymyia_560715
#          |  /---------------------@   |
#          |  |                     |   |           /--- Dilophus_52733
#          |  |                     |   |           |
#          |  |                     |   |        /--@--- Plecia_1260898
#          |  |                     \---@        |  |
#          |  |                         |  /-----@  \--- Bibio_189978
#          |  |                         |  |     |
#          |  |                         |  |     |  /--- Pachyneura_1588165
#          |  |                         |  |     \--@
#          |  |                         \--@        \--- Cramptonomyia_209688
#          |  |                            |
#          |  |                            |  /--------- Diadocidia_560721
#          |  |                            |  |
#          |  |                            |  |     /--- Orfelia_270890
#          |  |                            \--@  /--@
#          |  |                               |  |  \--- Macrocera_608727
#          |  |                               |  |
#          |  |                               \--@  /--- Sciara_82677
#          |  |                                  |  |
#          |  |                                  |  |--- Pnyxia_1781626
#          \--@                                  \--@
#             |                                     |--- Corynoptera_1260849
#             |                                     |
#             |                                     \--- Bradysia_35571
#             |
#             |  /-------------------------------------- Oreoleptis_1262318
#             |  |
#             |  |                                  /--- Paraplatypeza_192442
#             |  |                                  |
#             |  |                                  |--- Bertamyia_1445832
#             |  |                                  |
#             |  |                                  |--- Callomyia_712098
#             |  |                                  |
#             |  |   /------------------------------@--- Kesselimyia_1445844
#             |  |   |                              |
#             |  |   |                              |--- Agathomyia_226141
#             |  |   |                              |
#             |  |   |                              |--- Polyporivora_1445854
#             |  |   |                              |
#             |  |   |                              \--- Platypeza_289241
#             |  |   |
#             \--@   |                              /--- Chamaemyia_305621
#                |   |                              |
#                |   |                     /--------@--- Leucopis_1728826
#                |   |                     |        |
#                |   |                     |        \--- Parochthiphila_1262282
#                |   |                     |
#                |   |                     |        /--- Coelopa_169466
#                |   |  /------------------@  /-----@
#                |   |  |                  |  |     \--- Helcomyza_169476
#                |   |  |                  |  |
#                |   |  |                  |  |     /--- Homoneura_1692452
#                |   |  |                  |  |     |
#                |   |  |                  |  |  /--@--- Tricholauxania_192459
#                |   |  |                  \--@  |  |
#                |   |  |                     |  |  \--- Aulogastromyia_1824990
#                |   |  |                     |  |
#                |   |  |                     |  |  /--- Pteromicra_1226622
#                \---@  |                     |  |  |
#                    |  |                     |  |  |--- Dictya_1096051
#                    |  |                     |  |  |
#                    |  |                     \--@  |--- Elgiva_320938
#                    |  |                        |  |
#                    |  |                        |  |--- Sepedon_320954
#                    |  |                        |  |
#                    |  |                        |  |--- Neolimnia_1262312
#                    |  |                        |  |
#                    |  |                        |  |--- Sciomyza_320936
#                    |  |                        |  |
#                    |  |                        \--@--- Ilione_1096072
#                    |  |                           |
#                    |  |                           |--- Psacadina_1096078
#                    |  |                           |
#                    |  |                           |--- Tetanocera_320959
#                    |  |                           |
#                    |  |                           |--- Hedria_320941
#                    |  |                           |
#                    |  |                           |--- Coremacera_1226614
#                    |  |                           |
#                    |  |                           |--- Anticheta_1096047
#                    |  |                           |
#                    |  |                           \--- Pelidnoptera_1096074
#                    |  |
#                    |  |                           /--- Copromyza_1217530
#                    \--@  /------------------------@
#                       |  |                        \--- Leptocera_1614654
#                       |  |
#                       |  |                        /--- Mimegralla_115300
#                       |  |                        |
#                       |  |                        |--- Compsobata_286452
#                       |  |                     /--@
#                       |  |                     |  |--- Calobata_1820059
#                       |  |                     |  |
#                       |  |            /--------@  \--- Micropeza_1572561
#                       |  |            |        |
#                       |  |            |        |  /--- Telostylinus_1262347
#                       |  |            |        \--@
#                       |  |            |           \--- Odontoloxozus_588320
#                       |  |            |
#                       |  |            |           /--- Lasiopiophila_1790233
#                       |  |            |           |
#                       |  |            |           |--- Piophila_53709
#                       |  |            |     /-----@
#                       |  |            |     |     |--- Centrophlebomyia_1603419
#                       |  |            |     |     |
#                       |  |            |     |     \--- Liopiophila_1603421
#                       |  |            |     |
#                       |  |            |     |     /--- Delphinia_43369
#                       |  |            |     |     |
#                       |  |            |     |     |--- Chaetopsis_240871
#                       |  |            |     |  /--@
#                       |  |            |  /--@  |  |--- Tetanops_454640
#                       |  |            |  |  |  |  |
#                       |  |  /---------@  |  |  |  \--- Euxesta_286468
#                       |  |  |         |  |  |  |
#                       |  |  |         |  |  |  |  /--- Eurosta_28593
#                       |  |  |         |  |  |  |  |
#                       |  |  |         |  |  |  |  |--- Anastrepha_28585
#                       |  |  |         |  |  |  |  |
#                       |  |  |         |  |  |  |  |--- Euleia_28591
#                       \--@  |         |  |  |  |  |
#                          |  |         |  |  \--@  |--- Terellia_28615
#                          |  |         |  |     |  |
#                          |  |         |  |     |  |--- Paracantha_164885
#                          |  |         |  |     |  |
#                          |  |         |  |     |  |--- Tephritis_43386
#                          |  |         |  |     |  |
#                          |  |         |  |     |  |--- Urophora_28620
#                          |  |         |  |     |  |
#                          |  |         |  |     |  |--- Gymnocarena_28597
#                          |  |         |  |     |  |
#                          |  |         |  |     |  |--- Jamesomyia_28601
#                          |  |         |  |     \--@
#                          |  |         |  |        |--- Oxyna_381365
#                          |  |         \--@        |
#                          |  |            |        |--- Trupanea_30060
#                          |  |            |        |
#                          |  |            |        |--- Rhagoletis_28609
#                          |  |            |        |
#                          |  |            |        |--- Noeeta_381362
#                          |  |            |        |
#                          |  |            |        |--- Ceratitis_7212
#                          |  |            |        |
#                          |  |            |        |--- Zonosemata_28622
#                          |  |            |        |
#                          |  |            |        |--- Bactrocera_27456
#                          |  |            |        |
#                          |  |            |        |--- Xyphosia_381372
#                          |  |            |        |
#                          |  |            |        \--- Icterica_28599
#                          |  |            |
#                          |  |            |        /--- Opomyza_716643
#                          |  |            |     /--@
#                          |  |            |     |  \--- Geomyza_305619
#                          |  |            |  /--@
#                          |  |            |  |  |  /--- Psila_305548
#                          \--@            |  |  |  |
#                             |            |  |  \--@--- Loxocera_34684
#                             |            \--@     |
#                             |               |     \--- Chyliza_716634
#                             |               |
#                             |               |     /--- Sepsis_137507
#                             |               \-----@
#                             |                     \--- Themira_292396
#                             |
#                             |                     /--- Diasemopsis_139652
#                             |                     |
#                             |               /-----@--- Sphyracephala_139674
#                             |               |     |
#                             |               |     \--- Diopsis_139667
#                             |  /------------@
#                             |  |            |  /------ Procanace_1262322
#                             |  |            |  |
#                             |  |            \--@  /--- Stiphrosoma_500293
#                             |  |               |  |
#                             |  |               \--@--- Paranthomyza_500298
#                             |  |                  |
#                             |  |                  \--- Quametopia_1603285
#                             |  |
#                             |  |                  /--- Thaumatomyia_333800
#                             |  |                  |
#                             |  |                  |--- Hippelates_540866
#                             |  |                  |
#                             |  |                  |--- Cetema_540891
#                             |  |                  |
#                             |  |                  |--- Gaurax_540862
#                             |  |                  |
#                             |  |                  |--- Lipara_540870
#                             |  |                  |
#                             |  |                  |--- Tricimba_540889
#                             |  |                  |
#                             |  |      /-----------@--- Elachiptera_540858
#                             |  |      |           |
#                             |  |      |           |--- Incertella_540867
#                             |  |      |           |
#                             |  |      |           |--- Aphanotrigonum_540849
#                             |  |      |           |
#                             |  |      |           |--- Calamoncosis_540852
#                             |  |      |           |
#                             \--@      |           |--- Chlorops_540892
#                                |      |           |
#                                |  /---@           |--- Cryptonevra_1616778
#                                |  |   |           |
#                                |  |   |           \--- Epichlorops_540897
#                                |  |   |
#                                |  |   |           /--- Stenomicra_716630
#                                |  |   |  /--------@
#                                |  |   |  |        \--- Periscelis_716628
#                                |  |   |  |
#                                |  |   |  |  /--------- Fergusonina_156411
#                                |  |   |  |  |
#                                |  |   \--@  |     /--- Liriomyza_127403
#                                |  |      |  |     |
#                                |  |      |  |     |--- Melanagromyza_286470
#                                |  |      |  |     |
#                                |  |      |  |     |--- Phytobia_414304
#                                |  |      \--@     |
#                                |  |         |     |--- Cerodontha_127401
#                                |  |         |     |
#                                |  |         |  /--@--- Ophiomyia_341050
#                                |  |         |  |  |
#                                |  |         |  |  |--- Japanagromyza_414298
#                                |  |         |  |  |
#                                |  |         |  |  |--- Agromyza_414290
#                                |  |         \--@  |
#                                |  |            |  |--- Calycomyza_414293
#                                |  |            |  |
#                                |  |            |  \--- Phytomyza_132616
#                                |  |            |
#                                \--@            \------ Odinia_414302
#                                   |
#                                   |               /--- Crataerina_452743
#                                   |               |
#                                   |               |--- Olfersia_1333310
#                                   |               |
#                                   |               |--- Melophagus_452748
#                                   |               |
#                                   |            /--@--- Ornithophila_1497392
#                                   |            |  |
#                                   |            |  |--- Hippobosca_452745
#                                   |            |  |
#                                   |         /--@  |--- Icosta_402409
#                                   |         |  |  |
#                                   |         |  |  \--- Lipoptena_170902
#                                   |         |  |
#                                   |         |  \------ Glossina_7393
#                                   |         |
#                                   |         |     /--- Muscina_57892
#                                   |         |     |
#                                   |         |     |--- Phaonia_253431
#                                   |         |     |
#                                   |         |     |--- Hebecnema_559682
#                                   |         |     |
#                                   |         |     |--- Potamia_559704
#                                   |         |     |
#                                   |         |     |--- Atherigona_305597
#                                   |         |     |
#                                   \---------@     |--- Musca_7369
#                                             |     |
#                                             |     |--- Passeromyia_1511687
#                                             |     |
#                                             |     |--- Myospila_520040
#                                             |     |
#                                             |  /--@--- Haematobosca_559680
#                                             |  |  |
#                                             |  |  |--- Neomyia_305607
#                                             |  |  |
#                                             |  |  |--- Mesembrina_116147
#                                             |  |  |
#                                             |  |  |--- Graphomya_1072499
#                                             |  |  |
#                                             |  |  |--- Morellia_253340
#                                             |  |  |
#                                             |  |  |--- Philornis_253427
#                                             \--@  |
#                                                |  |--- Polietes_559702
#                                                |  |
#                                                |  |--- Eginia_1511678
#                                                |  |
#                                                |  \--- Limnophora_307207
#                                                |
#                                                |  /--- Scathophaga_95462
#                                                |  |
#                                                |  |--- Hydromyza_113174
#                                                |  |
#                                                |  |--- Norellia_113119
#                                                \--@
#                                                   |--- Cordilura_113132
#                                                   |
#                                                   |--- Cleigastra_113167
#                                                   |
#                                                   \--- Orthacheta_113181

# %% [markdown]
# ## Retrieve hard monophyly statements

# %%
new_constraints = dict()
counts = Counter()
with open(Path('constraint_trees')/'final_constraints_info'/'hard_constraints.txt','r') as f:
    for l in f.readlines():
        k,v = l.strip().split('=')
        v=v.split(',')
        new_constraints[k]=v
        counts[k]=len(v)
counts.most_common()
# Out:
# [('first_split', 500),
#  ('Brachycera', 392),
#  ('Oestroidea', 76),
#  ('Bibionomorpha', 39),
#  ('Culicomorpha', 37),
#  ('Tephritoidea', 35),
#  ('Tachinidae', 33),
#  ('Sciaroidea', 30),
#  ('Syrphidae', 29),
#  ('Tabanomorpha', 20),
#  ('Chironomidae', 18),
#  ('Ephydroidea', 17),
#  ('Muscidae', 17),
#  ('Tipulomorpha', 16),
#  ('Tipuloidea', 15),
#  ('Tabanidae', 14),
#  ('Chloropidae', 13),
#  ('Anthomyiidae', 13),
#  ('Sciomyzidae', 13),
#  ('Hippoboscoidea', 11),
#  ('Cecidomyiidae', 11),
#  ('Mycetophilidae', 11),
#  ('Empidoidea', 10),
#  ('Lauxanioidea', 8),
#  ('Asilidae', 8),
#  ('Ceratopogonidae', 8),
#  ('Culicoidea', 7),
#  ('Empididae', 7),
#  ('Acroceridae', 7),
#  ('Hippoboscidae', 7),
#  ('Sarcophagidae', 7),
#  ('Platypezidae', 7),
#  ('Ephydridae', 6),
#  ('Scathophagidae', 6),
#  ('Rhinophoridae', 6),
#  ('Bombyliidae', 4),
#  ('Milichiidae', 4),
#  ('Conopidae', 4),
#  ('Micropezidae', 4),
#  ('Mesembrinellidae', 4),
#  ('Pipunculidae', 4),
#  ('Lonchaeidae', 4),
#  ('Piophilidae', 4),
#  ('Ulidiidae', 4),
#  ('Culicidae', 4),
#  ('Dolichopodidae', 3),
#  ('Psilidae', 3),
#  ('Nycteribiidae', 3),
#  ('Anthomyzidae', 3),
#  ('Clusiidae', 3),
#  ('Platystomatidae', 3),
#  ('Xylophagidae', 3),
#  ('Sciaridae', 3),
#  ('Celyphidae', 2),
#  ('Fanniidae', 2),
#  ('Neriidae', 2),
#  ('Rhiniidae', 2),
#  ('Sepsidae', 2),
#  ('Keroplatidae', 2)]

# %% [markdown]
# ## Retrive parent hard constraints

# %%
constraint_parent = dict()
with open(Path('constraint_trees')/'final_constraints_info'/'parent_nodes.txt','r') as f:
    for l in f.readlines():
        k,v = l.strip().split('=')
        constraint_parent[k]=v

# %% [markdown]
# ## Combine constraints
#
# Now we will go through the new constraints, from most to least inclusive
#
# For each new constraint, we will find in our tree the MRCA of all overlapping tips and name it with that constraint. We will also add a property that this is a hard constraint.
#
# If there are no overlapping tips, we will find the parent hard constraint node, and add a child node.
#
# We will then traverse constraints from least to most inclusive, and check if all child taxa are present, adding them if not.

# %% [markdown]
# ## overlap with tree

# %%
tree_taxa = set([t.label for t in tr.taxon_namespace])
print('constraint','n_tips','n_overlap')
for k,v in new_constraints.items():
    print(k,len(v),len(set(v).intersection(tree_taxa)))
# Out:
# constraint n_tips n_overlap
# first_split 500 190
# Tabanomorpha 20 1
# Bibionomorpha 39 13
# Culicomorpha 37 30
# Tipulomorpha 16 6
# Empidoidea 10 0
# Ephydroidea 17 0
# Hippoboscoidea 11 8
# Lauxanioidea 8 6
# Oestroidea 76 0
# Sciaroidea 30 6
# Tephritoidea 35 26
# Culicoidea 7 1
# Tipuloidea 15 5
# Asilidae 8 0
# Bombyliidae 4 0
# Dolichopodidae 3 0
# Empididae 7 0
# Acroceridae 7 0
# Chloropidae 13 13
# Milichiidae 4 0
# Conopidae 4 0
# Psilidae 3 3
# Ephydridae 6 0
# Hippoboscidae 7 7
# Nycteribiidae 3 0
# Celyphidae 2 0
# Anthomyiidae 13 0
# Fanniidae 2 0
# Muscidae 17 17
# Scathophagidae 6 6
# Micropezidae 4 4
# Neriidae 2 2
# Mesembrinellidae 4 0
# Rhiniidae 2 0
# Rhinophoridae 6 0
# Sarcophagidae 7 0
# Tachinidae 33 0
# Anthomyzidae 3 3
# Clusiidae 3 0
# Platypezidae 7 7
# Sciomyzidae 13 13
# Sepsidae 2 2
# Pipunculidae 4 0
# Syrphidae 29 0
# Lonchaeidae 4 0
# Piophilidae 4 4
# Platystomatidae 3 0
# Ulidiidae 4 4
# Tabanidae 14 0
# Xylophagidae 3 0
# Cecidomyiidae 11 0
# Keroplatidae 2 2
# Mycetophilidae 11 0
# Sciaridae 3 3
# Ceratopogonidae 8 8
# Chironomidae 18 18
# Culicidae 4 0
# Brachycera 392 135

# %% [markdown]
# ### Step 1 add constraints

# %%
with open('./constraint_trees/result/partial_iqtree.tre', 'r') as f:
    tr = dendropy.Tree.get(file=f, schema="newick",preserve_underscores=True)
    for node in tr.internal_nodes():
        node.label = None
        node.taxon = None

for c,_ in counts.most_common():
    tree_taxa = set([t.label for t in tr.taxon_namespace])
    common_taxa = set(new_constraints[c]).intersection(tree_taxa)
    if common_taxa:
        # Find the MRCA of the common taxa in the tree
        common_taxa_nodes = [tr.find_node_with_taxon_label(taxon) for taxon in common_taxa]
        mrca = tr.mrca(taxon_labels=common_taxa)
        if mrca.is_leaf():
            new_internal_node = tr.node_factory(label=c)
            new_internal_node.annotations.add_new("constraint_type", "hard")
            parent_node = mrca.parent_node
            parent_node.remove_child(mrca)
            parent_node.add_child(new_internal_node)
            new_internal_node.add_child(mrca)
        else:
            mrca.annotations.add_new("constraint_type", "hard")
            mrca.label = c   
    else:
        mrca = tr.find_node_with_label(constraint_parent[c])
        new_node = tr.node_factory(label=c)
        for taxon in new_constraints[c]:
            if taxon not in tree_taxa:
                new_taxon = tr.taxon_namespace.require_taxon(label=taxon)
                child_node = tr.node_factory(taxon=new_taxon)
                new_node.add_child(child_node)
        mrca.add_child(new_node)
    tr.update_bipartitions(suppress_unifurcations=False)
    tr.reconstruct_taxon_namespace()

# %% [markdown]
# ## Step 2 add missing taxa

# %%
for c,_ in reversed(counts.most_common()):
    tree_taxa = set([t.label for t in tr.taxon_namespace])
    included_taxa = set(new_constraints[c])
    common_taxa = included_taxa.intersection(tree_taxa)
    
    if common_taxa != included_taxa:
        missing_taxa = included_taxa - common_taxa
        mrca = tr.find_node_with_label(c)
        
        for taxon in missing_taxa:
            new_taxon = tr.taxon_namespace.require_taxon(label=taxon)
            new_leaf = tr.node_factory(taxon=new_taxon)
            mrca.add_child(new_leaf)

        # Update the taxon namespace and tree structure
        tr.reconstruct_taxon_namespace()
        tr.update_bipartitions()

# %%
tr.print_plot(show_internal_node_labels=True)
# Out:
# /---------------------------------------------------- Deuterophlebia_560719
# |
# |  /------------------------------------------------- Nymphomyia_560766
# |  |
# |  |                                       /--------- Trichocera_52759
# |  |                                       |
# |  |                                       |     /--- Dicranota_700836
# |  |                                       |  /--@
# |  |                                       |  |  \--- Pedicia_472374
# |  |                                       |  |
# |  |                                       |  |  /--- Liogma_560731
# |  |                                       |  |  |
# |  |  /------------------------------------Tipulomorphahalacrocera_2203737
# |  |  |                                    |  |  |
# |  |  |                                    |  |  \--- Cylindrotoma_700834
# |  |  |                                    |  |
# |  |  |                                    |  |------ Tipula_41043
# |  |  |                                    |  |
# |  |  |                                    |  |------ Dictenidia_2108369
# |  |  |                                    |  |
# |  |  |                                    \--Tipuloideamonia_52743
# |  |  |                                       |
# |  |  |                                       |------ Prionocera_1690388
# |  |  |                                       |
# |  |  |                                       |------ Gnophomyia_700845
# |  |  |                                       |
# |  |  |                                       |------ Ctenophora_516519
# |  |  |                                       |
# |  |  |                                       |------ Tanyptera_2108371
# |  |  |                                       |
# |  |  |                                       |------ Metalimnobia_700851
# |  |  |                                       |
# |  |  |                                       |------ Dactylolabis_560717
# |  |  |                                       |
# |  |  |                                       \------ Antocha_454619
# |  |  |
# |  |  |                                          /--- Liponeura_446516
# |  |  |                                       /--@
# |  |  |                                       |  \--- Blepharicera_547808
# |  |  |                              /--------@
# |  |  |                              |        |  /--- Mischoderus_560267
# |  |  |                              |        |  |
# |  |  |                              |        \--@--- Araucoderus_1549737
# |  |  |                              |           |
# |  |  |                              |           \--- Protoplasa_560776
# |  |  |                              |
# |  |  |                              |           /--- Sphaeromias_1874311
# |  |  |                              |           |
# |  |  |                              |           |--- Palpomyia_1525500
# |  |  |                              |           |
# |  |  |                              |           |--- Austroconops_209696
# |  |  |                              |           |
# |  |  |                              |           |--- Culicoides_41820
# |  |  |                              |        /--Ceratopogonidae
# |  |  |                              |        |  |--- Serromyia_209716
# |  |  |                              |        |  |
# |  |  |                              |        |  |--- Forcipomyia_209700
# |  |  |                              |        |  |
# |  |  |                              |        |  |--- Dasyhelea_41822
# |  |  |                              |        |  |
# |  |  |                              |        |  \--- Atrichopogon_209702
# |  |  |                              |        |
# |  |  |                              |        |  /--- Ainuyusurika_1165747
# |  |  |                              |        |  |
# |  |  |                              |        |  |--- Pentaneura_891922
# |  |  |                              |        |  |
# |  |  |                              |     /--@  |--- Metriocnemus_137497
# |  |  |                              |     |  |  |
# |  |  |                              |     |  |  |--- Eukiefferiella_288843
# |  |  |  /---------------------------@     |  |  |
# |  |  |  |                           |     |  |  |--- Parochlus_315560
# |  |  |  |                           |     |  |  |
# |  |  |  |                           |     |  |  |--- Pseudosmittia_611382
# |  |  |  |                           |     |  |  |
# |  |  |  |                           |     |  |  |--- Tvetenia_611398
# |  |  |  |                           |     |  |  |
# |  |  |  |                           |     |  |  |--- Paucispinigera_903463
# |  |  |  |                           |     |  |  |
# |  |  |  |                           |     |  |  |--- Paraborniella_903459
# |  |  |  |                           |     |  \--Chironomidae
# |  |  |  |                           |     |     |--- Smittia_315559
# |  |  |  |                           |     |     |
# |  |  |  |                           |     |     |--- Monodiamesa_891905
# |  |  |  |                           |  /--@     |
# |  |  |  |                           |  |  |     |--- Chironomus_7150
# |  |  |  |                           |  |  |     |
# |  |  |  |                           |  |  |     |--- Clunio_315556
# |  |  |  |                           |  |  |     |
# |  |  |  |                           |  |  |     |--- Aphroteniella_646259
# |  |  |  |                           |  |  |     |
# |  |  |  |                           |  |  |     |--- Gymnometriocnemus_611353
# |  |  |  |                           |  |  |     |
# |  |  |  |                           |  |  |     |--- Corynoneura_611344
# |  |  |  |                           |  |  |     |
# |  |  |  |                           |  |  |     |--- Ablabesmyia_46216
# |  |  |  |                           |  |  |     |
# |  |  |  |                           |  |  |     \--- Psectrotanypus_903467
# |  |  |  |                           |  |  |
# |  |  |  |                           |  |  |     /--- Androprosopa_41815
# |  |  |  |                           |  |  |     |
# |  |  |  |                           \--Culicomorpha- Austrothaumalea_1085085
# |  |  |  |                              |        |
# |  |  |  |                              |        \--- Thaumalea_61068
# |  |  |  |                              |
# |  |  |  |                              |        /--- Dixa_79309
# |  |  |  |                              |        |
# |  |  |  |                              |--------Culicoideaonyx_1577622
# |  |  |  |                              |        |
# |  |  |  |                              |        \--- Chaoborus_41812
# |  |  |  |                              |
# |  |  |  |                              |        /--- Anopheles_7164
# |  |  |  |                              |        |
# |  |  |  |                              |        |--- Culex_7174
# |  |  |  |                              |--------Culicidae
# |  |  |  |                              |        |--- Culiseta_174825
# |  |  |  |                              |        |
# |  |  |  |                              |        \--- Aedes_7158
# |  |  |  |                              |
# |  |  |  |                              \------------ Simulium_7191
# |  |  |  |
# |  |  |  |                                       /--- Scatopse_1520324
# |  |  |  |                        /--------------@
# |  |  |  |                        |              \--- Coboldia_170624
# |  |  |  |                        |
# |  |  |  |                        |  /--------------- Axymyia_560715
# |  |  |  |                        |  |
# |  |  |  |                        |  |           /--- Dilophus_52733
# |  |  |  |                        |  |           |
# |  |  |  |                        |  |        /--@--- Plecia_1260898
# |  |  |  |                        |  |        |  |
# |  |  |  |                        |  |  /-----@  \--- Bibio_189978
# |  |  |  |                        |  |  |     |
# |  |  |  |                        |  |  |     |  /--- Pachyneura_1588165
# |  |  |  |                        |  |  |     \--@
# |  |  |  |                        |  |  |        \--- Cramptonomyia_209688
# |  |  |  |                        |  |  |
# |  |  |  |                        |--@  |  /--------- Diadocidia_560721
# |  |  |  |                        |  |  |  |
# |  |  |  |                        |  |  |  |     /--- Orfelia_270890
# |  |  |  |                        |  |  |  |  /--Keroplatidae
# |  |  |  |                        |  |  |  |  |  \--- Macrocera_608727
# |  |  |  |                        |  |  |  |  |
# |  |  |  |                        |  |  |  |--@  /--- Sciara_82677
# |  |  |  |                        |  |  |  |  |  |
# |  |  |  |                        |  |  |  |  |  |--- Pnyxia_1781626
# |  |  |  |                        |  |  |  |  \--Sciaridae
# |  |  |  |                        |  |  |  |     |--- Corynoptera_1260849
# |  |  |  |                        |  |  |  |     |
# |  |  |  |                        |  \--@  |     \--- Bradysia_35571
# |  |  |  |                        |     |  |
# |  |  |  |                        |     |  |     /--- Contarinia_153220
# |  |  |  |                        |     |  |     |
# |  |  |  |                        |     |  |     |--- Sitodiplosis_263139
# |  |  |  |                        |     |  |     |
# |  |  |  |                        |     |  |     |--- Aprionus_1819779
# |  |  |  |                        |     |  |     |
# |  |  |  |                        |     |  |     |--- Piceacecis_2597495
# |  |  |  |                        |     |  |     |
# |  |  |  |                        |     |  |     |--- Lasioptera_201413
# |  |  |  |                        |     |  |     |
# |  |  |  |  /---------------------Bibionomorpha--Cecidomyiidae_1914937
# |  |  |  |  |                     |     |  |     |
# |  |  |  |  |                     |     |  |     |--- Cecidomyia_1543682
# |  |  |  |  |                     |     |  |     |
# |  |  |  |  |                     |     |  |     |--- Dasineura_240745
# |  |  |  |  |                     |     |  |     |
# |  |--@  |  |                     |     \--Sciaroidea Asphondylia_153012
# |  |  |  |  |                     |        |     |
# |  |  |  |  |                     |        |     |--- Winnertzia_2338641
# |  |  |  |  |                     |        |     |
# |  |  |  |  |                     |        |     \--- Aphidoletes_95971
# |  |  |  |  |                     |        |
# |  |  |  |  |                     |        |     /--- Brachypeza_2326774
# |  |  |  |  |                     |        |     |
# |  |  |  |  |                     |        |     |--- Trichonta_397122
# |  |  |  |  |                     |        |     |
# |  |  |  |  |                     |        |     |--- Mycetophila_397146
# |  |  |  |  |                     |        |     |
# |  |  |  |  |                     |        |     |--- Neoempheria_608686
# |  |  |  |  |                     |        |     |
# |  |  |  |  |                     |        |     |--- Symmerus_560780
# |  |  |  |  |                     |        |     |
# |  |  |  |  |                     |        |-----Mycetophilidae08706
# |  |  |  |  |                     |        |     |
# |  |  |  |  |                     |        |     |--- Sciophila_1085959
# |  |  |  |  |                     |        |     |
# |  |  |  |  |                     |        |     |--- Phronia_397119
# |  |  |  |  |                     |        |     |
# |  |  |  |  |                     |        |     |--- Exechia_397139
# |  |  |  |  |                     |        |     |
# |  |  |  |  |                     |        |     |--- Epicypta_397117
# |  |  |  |  |                     |        |     |
# |  |  |  |  |                     |        |     \--- Leptomorphus_560729
# |  |  |  |  |                     |        |
# |  |  |  |  |                     |        |--------- Ditomyia_1520322
# |  |  |  |  |                     |        |
# |  |  |  |  |                     |        \--------- Bolitophila_52718
# |  |  |  |  |                     |
# |  |  |  |  |                     |------------------ Hesperinus_1086788
# |  |  |  |  |                     |
# |  |  |  |  |                     \------------------ Penthetria_560770
# |  |  |  |  |
# |  |  |  |  |                                    /--- Paraplatypeza_192442
# |  |  |  |  |                                    |
# |  |  |  |  |                                    |--- Bertamyia_1445832
# |  |  |  |  |                                    |
# |  |  |  |  |                                    |--- Callomyia_712098
# |  |  |  |  |                                    |
# |  |  |  |  |     /------------------------------Platypezidaemyia_1445844
# |  |  |  |  |     |                              |
# |  |  |  |  |     |                              |--- Agathomyia_226141
# |  |  |  |  |     |                              |
# |  |  |  |  |     |                              |--- Polyporivora_1445854
# |  |  |  |  |     |                              |
# |  |  |  |  |     |                              \--- Platypeza_289241
# |  |  |  |  |     |
# |  |  |  |  |     |                              /--- Chamaemyia_305621
# |  |  |  |  |     |                              |
# |  |  |  |  |     |                     /--------@--- Leucopis_1728826
# |  |  |  |  |     |                     |        |
# |  |  |  |  |     |                     |        \--- Parochthiphila_1262282
# |  |  |  |  |     |                     |
# |  |  |  |  |     |                     |        /--- Coelopa_169466
# |  |  |  |  |     |                     |  /-----@
# |  |  |  |  |     |                     |  |     \--- Helcomyza_169476
# |  |  |  |  |     |                     |  |
# |  |  |  |  |     |                     |  |     /--- Homoneura_1692452
# |  |  |  |  |     |                     |  |     |
# |  |  |  |  |     |                     |  |  /--@--- Tricholauxania_192459
# |  |  |  |  |     |                     |--@  |  |
# |  |  |  |  |     |                     |  |  |  \--- Aulogastromyia_1824990
# |  |  |  |  |     |                     |  |  |
# |  |  |  |  |     |                     |  |  |  /--- Pteromicra_1226622
# |  |  |  |  |     |                     |  |  |  |
# |  |  |  |  |     |                     |  |  |  |--- Dictya_1096051
# |  |  |  |  |     |                     |  |  |  |
# |  |  |  |  |     |                     |  \--@  |--- Elgiva_320938
# |  |  |  |  |     |                     |     |  |
# |  |  |  |  |     |  /------------------Lauxanioidea- Sepedon_320954
# |  |  |  |  |     |  |                  |     |  |
# |  |  |  |  |  /--@  |                  |     |  |--- Neolimnia_1262312
# |  |  |  |  |  |  |  |                  |     |  |
# |  |  |  |  |  |  |  |                  |     |  |--- Sciomyza_320936
# |  |  |  |  |  |  |  |                  |     |  |
# |  |  |  |  |  |  |  |                  |     \--Sciomyzidae_1096072
# |  |  |  |  |  |  |  |                  |        |
# |  |  |  |  |  |  |  |                  |        |--- Psacadina_1096078
# |  |  |  |  |  |  |  |                  |        |
# |  |  |  |  |  |  |  |                  |        |--- Tetanocera_320959
# |  |  |  |  |  |  |  |                  |        |
# |  |  |  |  |  |  |  |                  |        |--- Hedria_320941
# @  |  |  |  |  |  |  |                  |        |
# |  |  |  |  |  |  |  |                  |        |--- Coremacera_1226614
# |  |  |  |  |  |  |  |                  |        |
# |  |  |  |  |  |  |  |                  |        |--- Anticheta_1096047
# |  |  |  |  |  |  |  |                  |        |
# |  |  |  |  |  |  |  |                  |        \--- Pelidnoptera_1096074
# |  |  |  |  |  |  |  |                  |
# |  |  |  |  |  |  |  |                  |        /--- Celyphus_1979294
# |  |  |  |  |  |  |  |                  \--------Celyphidae
# |  |  |  |  |  |  |  |                           \--- Spaniocelyphus_1262326
# |  |  |  |  |  |  |  |
# |  |  |  |  |  |  |  |                           /--- Copromyza_1217530
# |  |  |  |  |  |  |  |  /------------------------@
# |  |  |  |  |  |  |  |  |                        \--- Leptocera_1614654
# |  |  |  |  |  |  |  |  |
# |  |  |  |  |  |  |  |  |                        /--- Mimegralla_115300
# |  |  |  |  |  |  |  |  |                        |
# |  |  |  |  |  |  |  |  |                        |--- Compsobata_286452
# |  |  |  |  |  |  |  |  |                     /--Micropezidae
# |  |  |  |  |  |  |  |  |                     |  |--- Calobata_1820059
# |  |  |  |  |  |  |  |  |                     |  |
# |  |  |  |  |  |  \--@  |            /--------@  \--- Micropeza_1572561
# |  |  |  |  |  |     |  |            |        |
# |  |  |  |  |  |     |  |            |        |  /--- Telostylinus_1262347
# |  |  |  |  |  |     |  |            |        \--Neriidae
# |  |  |  |  |  |     |  |            |           \--- Odontoloxozus_588320
# |  |  |  |  |  |     |  |            |
# |  |  |  |  |  |     |  |            |           /--- Lasiopiophila_1790233
# |  |  |  |  |  |     |  |            |           |
# |  |  |  |  |  |     |  |            |           |--- Piophila_53709
# |  |  |  |  |  |     |  |            |     /-----Piophilidae
# |  |  |  |  |  |     |  |            |     |     |--- Centrophlebomyia_1603419
# |  |  |  |  |  |     |  |            |     |     |
# |  |  |  |  |  |     |  |            |     |     \--- Liopiophila_1603421
# |  |  |  |  |  |     |  |            |     |
# |  |  |  |  |  |     |  |            |     |     /--- Delphinia_43369
# |  |  |  |  |  |     |  |            |     |     |
# |  |  |  |  |  |     |  |            |     |     |--- Chaetopsis_240871
# |  |  |  |  |  |     |  |            |     |  /--Ulidiidae
# |  |  |  |  |  |     |  |            |     |  |  |--- Tetanops_454640
# |  |  |  |  |  |     |  |            |     |  |  |
# |  |  |  |  |  |     |  |            |     |  |  \--- Euxesta_286468
# |  |  |  |  |  |     |  |            |     |  |
# |  |  |  |  |  |     |  |            |     |  |  /--- Eurosta_28593
# |  |  |  |  |  |     |  |            |     |  |  |
# |  |  |  |  |  |     |  |            |     |  |  |--- Anastrepha_28585
# |  |  |  |  |  |     |  |            |     |  |  |
# |  |  |  |  |  |     |  |            |     |  |  |--- Euleia_28591
# |  |  |  |  |  |     |  |            |     |  |  |
# |  |  |  |  |  |     |  |            |     |--@  |--- Terellia_28615
# |  |  |  |  |  |     |  |            |     |  |  |
# |  |  |  |  |  |     |  |            |     |  |  |--- Paracantha_164885
# |  |  |  |  |  |     |  |   /--------@     |  |  |
# |  |  |  |  |  |     |  |   |        |     |  |  |--- Tephritis_43386
# |  |  |  |  |  |     |  |   |        |     |  |  |
# |  |  |  |  |  |     \--@   |        |     |  |  |--- Urophora_28620
# |  |  |  |  |  |        |   |        |     |  |  |
# |  |  |  |  |  |        |   |        |     |  |  |--- Gymnocarena_28597
# |  |  |  |  |  |        |   |        |     |  |  |
# |  |  |  |  |  |        |   |        |     |  |  |--- Jamesomyia_28601
# |  |  |  |  |  |        |   |        |     |  \--@
# |  |  |  |  |  |        |   |        |     |     |--- Oxyna_381365
# |  |  |  |  |  |        |   |        |  /--Tephritoidea
# |  |  |  |  |  |        |   |        |  |  |     |--- Trupanea_30060
# |  |  |  |  |  |        |   |        |  |  |     |
# |  |  |  |  |  |        |   |        |  |  |     |--- Rhagoletis_28609
# |  |  |  |  |  |        |   |        |  |  |     |
# |  |  |  |  |  |        |   |        |  |  |     |--- Noeeta_381362
# |  |  |  |  |  |        |   |        |  |  |     |
# |  |  \--@  |  |        |   |        |  |  |     |--- Ceratitis_7212
# |  |     |  |  |        |   |        |  |  |     |
# |  |     |  |  |        |   |        |  |  |     |--- Zonosemata_28622
# |  |     |  |  |        |   |        |  |  |     |
# |  |     |  |  |        |   |        |  |  |     |--- Bactrocera_27456
# |  |     |  |  |        |   |        |  |  |     |
# |  |     |  |  |        |   |        |  |  |     |--- Xyphosia_381372
# |  |     |  |  |        |   |        |  |  |     |
# |  |     |  |  |        |   |        |  |  |     \--- Icterica_28599
# |  |     |  |  |        |   |        |  |  |
# |  |     |  |  |        |   |        |  |  |     /--- Lamprolonchaea_907706
# |  |     |  |  |        |   |        |  |  |     |
# |  |     |  |  |        |   |        |  |  |     |--- Lonchaea_198649
# |  |     |  |  |        |   |        |  |  |-----Lonchaeidae
# |  |     |  |  |        |   |        \--@  |     |--- Dasiops_286456
# |  |     |  |  |        |   |           |  |     |
# |  |     |  |  |        |   |           |  |     \--- Silba_198646
# |  |     |  |  |        |   |           |  |
# |  |     |  |  |        |   |           |  |     /--- Rivellia_28633
# |  |     |  |  |        |   |           |  |     |
# |  |     |  |  |        |   |           |  |-----Platystomatidae_286504
# |  |     |  |  |        |   |           |  |     |
# |  |     |  |  |        |   |           |  |     \--- Scholastes_1902237
# |  |     |  |  |        |   |           |  |
# |  |     |  |  |        |   |           |  |--------- Palloptera_286498
# |  |     |  |  |        |   |           |  |
# |  |     |  |  |        |   |           |  \--------- Ctenostylidae
# |  |     |  |  |        |   |           |
# |  |     |  |  |        |   |           |        /--- Opomyza_716643
# |  |     |  |  |        |   |           |     /--@
# |  |     |  |  |        \---@           |     |  \--- Geomyza_305619
# |  |     |  |  |            |           |  /--@
# |  |     |  |  |            |           |  |  |  /--- Psila_305548
# |  |     |  |  |            |           |  |  |  |
# |  |     |  |  |            |           |  |  \--Psilidaeocera_34684
# |  |     |  |  |            |           \--@     |
# |  |     |  |  |            |              |     \--- Chyliza_716634
# |  |     |  |  |            |              |
# |  |     |  |  |            |              |     /--- Sepsis_137507
# |  |     |  |  |            |              \-----Sepsidae
# |  |     |  |  |            |                    \--- Themira_292396
# |  |     |  |  |            |
# |  |     |  |  |            |                    /--- Diasemopsis_139652
# |  |     |  |  |            |                    |
# |  |     |  |  |            |              /-----@--- Sphyracephala_139674
# |  |     |  |  |            |              |     |
# |  |     |  |  |            |              |     \--- Diopsis_139667
# |  |     |  |  |            |  /-----------@
# |  |     |  |  |            |  |           |  /------ Procanace_1262322
# |  |     |  |  |            |  |           |  |
# |  |     |  |  |            |  |           \--@  /--- Stiphrosoma_500293
# |  |     |  |  |            |  |              |  |
# |  |     |  |  |            |  |              \--Anthomyzidaeomyza_500298
# |  |     |  |  |            |  |                 |
# |  |     |  |  |            |  |                 \--- Quametopia_1603285
# |  |     |  |  |            |  |
# |  |     |  |  |            |  |                 /--- Thaumatomyia_333800
# |  |     |  |--@            |  |                 |
# |  |     |  |  |            |  |                 |--- Hippelates_540866
# |  |     |  |  |            |  |                 |
# |  |     |  |  |            |  |                 |--- Cetema_540891
# |  |     |  |  |            |  |                 |
# |  |     |  |  |            |  |                 |--- Gaurax_540862
# |  |     |  |  |            |  |                 |
# |  |     |  |  |            |  |                 |--- Lipara_540870
# |  |     |  |  |            |  |                 |
# |  |     |  |  |            |  |                 |--- Tricimba_540889
# |  |     |  |  |            |  |                 |
# |  |     |  |  |            |  |     /-----------Chloropidaeptera_540858
# |  |     |  |  |            |  |     |           |
# |  |     |  |  |            |  |     |           |--- Incertella_540867
# |  |     |  |  |            |  |     |           |
# |  |     |  |  |            |  |     |           |--- Aphanotrigonum_540849
# |  |     |  |  |            |  |     |           |
# |  |     |  |  |            |  |     |           |--- Calamoncosis_540852
# |  |     |  |  |            |  |     |           |
# |  |     |  |  |            |  |     |           |--- Chlorops_540892
# |  |     |  |  |            \--@     |           |
# |  |     |  |  |               |  /--@           |--- Cryptonevra_1616778
# |  |     |  |  |               |  |  |           |
# |  |     |  |  |               |  |  |           \--- Epichlorops_540897
# |  |     |  |  |               |  |  |
# |  |     |  |  |               |  |  |           /--- Stenomicra_716630
# |  |     |  |  |               |  |  |  /--------@
# |  |     |  |  |               |  |  |  |        \--- Periscelis_716628
# |  |     |  |  |               |  |  |  |
# |  |     |  |  |               |  |  |  |  /--------- Fergusonina_156411
# |  |     |  |  |               |  |  |  |  |
# |  |     |  |  |               |  |  \--@  |     /--- Liriomyza_127403
# |  |     |  |  |               |  |     |  |     |
# |  |     |  |  |               |  |     |  |     |--- Melanagromyza_286470
# |  |     |  |  |               |  |     |  |     |
# |  |     |  |  |               |  |     |  |     |--- Phytobia_414304
# |  |     |  |  |               |  |     \--@     |
# |  |     |  |  |               |  |        |     |--- Cerodontha_127401
# |  |     |  |  |               |  |        |     |
# |  |     |  |  |               |  |        |  /--@--- Ophiomyia_341050
# |  |     |  |  |               |  |        |  |  |
# |  |     |  |  |               |  |        |  |  |--- Japanagromyza_414298
# |  |     |  |  |               |  |        |  |  |
# |  |     |  |  |               |  |        |  |  |--- Agromyza_414290
# |  |     |  |  |               |  |        \--@  |
# |  |     |  |  |               |  |           |  |--- Calycomyza_414293
# |  |     |  |  |               |  |           |  |
# |  |     |  |  |               |  |           |  \--- Phytomyza_132616
# |  |     |  |  |               |  |           |
# |  |     |  |  |               |  |           \------ Odinia_414302
# |  |     |  |  |               |  |
# |  |     |  |  |               \--@              /--- Crataerina_452743
# |  |     |  |  |                  |              |
# |  |     |  |  |                  |              |--- Olfersia_1333310
# |  |     |  |  |                  |              |
# |  |     |  |  |                  |              |--- Melophagus_452748
# |  |     |  |  |                  |              |
# |  |     |  |  |                  |           /--Hippoboscidaehila_1497392
# |  |     |  |  |                  |           |  |
# |  |     |  |  |                  |           |  |--- Hippobosca_452745
# |  |     |  |  |                  |           |  |
# |  |     |  |  |                  |           |  |--- Icosta_402409
# |  |     |  |  |                  |           |  |
# |  |     |  |  |                  |        /--Hippoboscoideaena_170902
# |  |     |  |  |                  |        |  |
# |  |     |  |  |                  |        |  |------ Glossina_7393
# |  |     |  |  |                  |        |  |
# |  |     |  |  |                  |        |  |  /--- Basilia_170889
# |  |     |  |  |                  |        |  |  |
# |  |     |  |  |                  |        |  \--Nycteribiidaeidia_81721
# |  |     |  |  |                  |        |     |
# |  |     |  |  |                  |        |     \--- Nycteribia_633884
# |  |     |  |  |                  |        |
# |  |     |  |  |                  |        |     /--- Muscina_57892
# |  |     |  |  |                  |        |     |
# |  |     |  |  |                  |        |     |--- Phaonia_253431
# |  |     |  |  |                  |        |     |
# |  |     |  |  |                  |        |     |--- Hebecnema_559682
# |  |     |  |  |                  |        |     |
# |  |     |  |  |                  |        |     |--- Potamia_559704
# |  |     |  |  |                  |        |     |
# |  |     |  |  |                  \--------@     |--- Atherigona_305597
# |  |     |  |  |                           |     |
# |  |     |  |  |                           |     |--- Musca_7369
# |  |     |  |  |                           |     |
# |  |     |  |  |                           |     |--- Passeromyia_1511687
# |  |     |  |  |                           |     |
# |  |     |  |  |                           |     |--- Myospila_520040
# |  |     |  |  |                           |     |
# |  |     |  |  |                           |  /--Muscidaematobosca_559680
# |  |     |  |  |                           |  |  |
# |  |     |  |  |                           |  |  |--- Neomyia_305607
# |  |     |  |  |                           |  |  |
# |  |     |  |  |                           |  |  |--- Mesembrina_116147
# |  |     |  |  |                           |  |  |
# |  |     |  |  |                           |  |  |--- Graphomya_1072499
# |  |     |  |  |                           |  |  |
# |  |     |  |  |                           |  |  |--- Morellia_253340
# |  |     |  |  |                           |  |  |
# |  |     |  |  |                           |  |  |--- Philornis_253427
# |  |     |  |  |                           \--@  |
# |  |     |  |  |                              |  |--- Polietes_559702
# |  |     |  |  |                              |  |
# |  |     |  |  |                              |  |--- Eginia_1511678
# |  |     |  |  |                              |  |
# |  |     |  |  |                              |  \--- Limnophora_307207
# |  |     |  |  |                              |
# |  |     |  |  |                              |  /--- Scathophaga_95462
# |  |     |  |  |                              |  |
# |  |     |  |  |                              |  |--- Hydromyza_113174
# |  |     |  |  |                              |  |
# |  |     |  |  |                              |  |--- Norellia_113119
# |  |     |  |  |                              \--Scathophagidae
# |  |     |  |  |                                 |--- Cordilura_113132
# |  |     |  |  |                                 |
# |  |     |  |  |                                 |--- Cleigastra_113167
# |  |     |  |  |                                 |
# |  |     |  |  |                                 \--- Orthacheta_113181
# |  |     |  |  |
# |  |     |  |  |                              /------ Oreoleptis_1262318
# |  |     |  |  |                              |
# |  |     |  |  |                              |  /--- Esenbeckia_124297
# |  |     |  |  |                              |  |
# |  |     |  |  |                              |  |--- Hybomitra_124690
# |  |     |  |  |                              |  |
# \--first_split |                              |  |--- Fidena_1334907
#    |     |  |  |                              |  |
#    |     |  |  |                              |  |--- Apatolestes_428062
#    |     |  |  |                              |  |
#    |     |  |  |                              |  |--- Catachlorops_1547373
#    |     |  |  |                              |  |
#    |     |  |  |                              |  |--- Silvius_415257
#    |     |  |  |                              |  |
#    |     |  |  |                              |  |--- Atylotus_1310336
#    |     |  |  |                              |--Tabanidae
#    |     |  |  |                              |  |--- Haematopota_124311
#    |     |  |  |                              |  |
#    |     |  |  |                              |  |--- Stenotabanus_1547430
#    |     |  |  \------------------------------Tabanomorpha
#    |     |  |                                 |  |--- Leucotabanus_1969939
#    |     |  |                                 |  |
#    |     |  |                                 |  |--- Chrysops_27458
#    |     |  |                                 |  |
#    |     |  |                                 |  |--- Tabanus_7206
#    |     |  |                                 |  |
#    |     |  |                                 |  |--- Bolbodimyia_1547386
#    |     |  |                                 |  |
#    |     |  |                                 |  \--- Goniops_428065
#    |     |  |                                 |
#    |     |  |                                 |------ Vermileo_124333
#    |     |  |                                 |
#    |     |  |                                 |------ Ptiolina_124325
#    |     |  |                                 |
#    |     |  |                                 |------ Rhagio_124327
#    |     |  |                                 |
#    |     |  |                                 |------ Atherix_124299
#    |     |  |                                 |
#    |     |  |                                 \------ Glutops_124309
#    |     |  |
#    |     |  |                                    /--- Compsomyiops_142897
#    |     |  |                                    |
#    |     |  |                                    |--- Lucilia_7374
#    |     |  |                                    |
#    |     |  |                                    |--- Paralucilia_1042205
#    |     |  |                                    |
#    |     |  |                                    |--- Trypocalliphora_1042207
#    |     |  |                                    |
#    |     |  |                                    |--- Cordylobia_226131
#    |     |  |                                    |
#    |     |  |                                    |--- Calliphora_7372
#    |     |  |                                    |
#    |     |  |                                    |--- Chrysomya_45449
#    |     |  |                                    |
#    |     |  |                                    |--- Protocalliphora_142901
#    |     |  |                                    |
#    |     |  |                                    |--- Auchmeromyia_226129
#    |     |  |                                    |
#    |     |  |                                    |--- Hemilucilia_416848
#    |     |  |                                    |
#    |     |  |                                    |--- Sarconesia_670650
#    |     |  |                                    |
#    |     |  |                                    |--- Amenia_2086281
#    |     |  |                                    |
#    |     |  |                                    |--- Melinda_170907
#    |     |  |                                    |
#    |     |  |                                    |--- Hemigymnochaeta_1240433
#    |     |  |                                    |
#    |     |  |                                    |--- Laneella_1658054
#    |     |  |                                    |
#    |     |  |                                    |--- Eumesembrinella_672472
#    |     |  |                                    |
#    |     |  |                                    |--- Mesembrinella_460529
#    |     |  |                                    |
#    |     |  |                                    |--- Huascaromusca_1609532
#    |     \--Brachycera                           |
#    |        |                                    |--- Mystacinobia_81694
#    |        |                                    |
#    |        |                                    |--- Oestrus_123736
#    |        |                                    |
#    |        |                                    |--- Cuterebra_170896
#    |        |                                    |
#    |        |                                    |--- Dermatobia_115426
#    |        |                                    |
#    |        |                                    |--- Oestromyia_170913
#    |        |                                    |
#    |        |                                    |--- Przhevalskiana_123746
#    |        |                                    |
#    |        |                                    |--- Rhinoestrus_204922
#    |        |                                    |
#    |        |                                    |--- Cephenemyia_170894
#    |        |                                    |
#    |        |                                    |--- Hypoderma_7388
#    |        |                                    |
#    |        |                                    |--- Pollenia_229639
#    |        |                                    |
#    |        |                                    |--- Rhyncomya_670621
#    |        |                                    |
#    |        |                                    |--- Idiella_1902146
#    |        |                                    |
#    |        |                                    |--- Stevenia_670627
#    |        |                                    |
#    |        |                                    |--- Paykullia_559695
#    |        |                                    |
# ...
#    |        |                                    |
#    |        |                                    \--- Anthomyia_259845
#    |        |
#    |        |                                    /--- Dolichopus_192427
#    |        |                                    |
#    |        |                                    |--- Medetera_377527
#    |        |                                    |
#    |        |                                    |--- Rhaphium_377528
#    |        |                                    |
#    |        |                                    |--- Rhamphomyia_192612
#    |        |                                    |
#    |        |                                    |--- Neoplasta_192640
#    |        |------------------------------------Dolichopodidae
#    |        |                                    |--- Phyllodromia_1209097
#    |        |                                    |
#    |        |                                    |--- Chelifera_369889
#    |        |                                    |
#    |        |                                    |--- Wiedemannia_240904
#    |        |                                    |
#    |        |                                    |--- Clinocera_192484
#    |        |                                    |
#    |        |                                    \--- Metachela_369884
#    |        |
#    |        |                                    /--- Philonicus_247567
#    |        |                                    |
#    |        |                                    |--- Dioctria_468720
#    |        |                                    |
#    |        |                                    |--- Promachus_247552
#    |        |                                    |
#    |        |                                    |--- Machimus_247604
#    |        |------------------------------------Asilidae
#    |        |                                    |--- Lasiopogon_219536
#    |        |                                    |
#    |        |                                    |--- Pamponerus_1717601
#    |        |                                    |
#    |        |                                    |--- Laphria_50683
#    |        |                                    |
#    |        |                                    \--- Mallophora_270862
#    |        |
#    |        |                                    /--- Ocnaea_210271
#    |        |                                    |
#    |        |                                    |--- Ogcodes_188257
#    |        |                                    |
#    |        |                                    |--- Eulonchus_210230
#    |        |                                    |
#    |        |------------------------------------Acroceridaera_210245
#    |        |                                    |
#    |        |                                    |--- Astomella_210239
#    |        |                                    |
#    |        |                                    |--- Exetasis_1932988
#    |        |                                    |
#    |        |                                    \--- Pterodontia_210267
#    |        |
#    |        |                                    /--- Systoechus_1690390
#    |        |                                    |
#    |        |                                    |--- Bombylius_219362
#    |        |------------------------------------Bombyliidae
#    |        |                                    |--- Anthrax_117078
#    |        |                                    |
#    |        |                                    \--- Ligyra_117088
#    |        |
#    |        |                                    /--- Desmometopa_305587
#    |        |                                    |
#    |        |                                    |--- Leptometopa_1720790
#    |        |------------------------------------Milichiidae
#    |        |                                    |--- Pholeomyia_1720804
#    |        |                                    |
#    |        |                                    \--- Milichiella_1890919
#    |        |
#    |        |                                    /--- Physocephala_198643
#    |        |                                    |
#    |        |                                    |--- Thecophora_305546
#    |        |------------------------------------Conopidae
#    |        |                                    |--- Sicus_1219203
#    |        |                                    |
#    |        |                                    \--- Zodion_768804
#    |        |
#    |        |                                    /--- Verrallia_115333
#    |        |                                    |
#    |        |                                    |--- Nephrocerus_115303
#    |        |------------------------------------Pipunculidae
#    |        |                                    |--- Chalarus_115250
#    |        |                                    |
#    |        |                                    \--- Pipunculus_240898
#    |        |
#    |        |                                    /--- Sobarocephala_574054
#    |        |                                    |
#    |        |------------------------------------Clusiidaeia_574057
#    |        |                                    |
#    |        |                                    \--- Clusiodes_500306
#    |        |
#    |        |                                    /--- Xylophagus_219493
#    |        |                                    |
#    |        |------------------------------------Xylophagidaenevra_560723
#    |        |                                    |
#    |        |                                    \--- Coenomyia_124305
#    |        |
#    |        |                                    /--- Fannia_95468
#    |        |------------------------------------Fanniidae
#    |        |                                    \--- Euryomma_1650677
#    |        |
#    |        |---------------------------------------- Nemotelus_343582
#    |        |
#    |        |---------------------------------------- Oxycera_860348
#    |        |
#    |        |---------------------------------------- Pantophthalmus_124295
#    |        |
#    |        |---------------------------------------- Scoliocentra_1823605
#    |        |
#    |        |---------------------------------------- Neorhynchocephalus_259248
#    |        |
#    |        |---------------------------------------- Tanypeza_1692486
#    |        |
#    |        |---------------------------------------- Scenopinus_247599
#    |        |
#    |        |---------------------------------------- Triphleba_92553
#    |        |
#    |        |---------------------------------------- Cryptochetum_1262333
#    |        |
#    |        |---------------------------------------- Mydas_186100
#    |        |
#    |        |---------------------------------------- Hypocera_940227
#    |        |
#    |        |---------------------------------------- Megaselia_36165
#    |        |
#    |        |---------------------------------------- Helosciomyzidae
#    |        |
#    |        |---------------------------------------- Neurochaeta_716624
#    |        |
#    |        |---------------------------------------- Sargus_343647
#    |        |
#    |        |---------------------------------------- Odontomyia_343652
#    |        |
#    |        |---------------------------------------- Lonchoptera_92595
#    |        |
#    |        |---------------------------------------- Diplonevra_92534
#    |        |
#    |        |---------------------------------------- Zabrachia_1891525
#    |        |
#    |        |---------------------------------------- Apocephalus_117252
#    |        |
#    |        |---------------------------------------- Thereva_95078
#    |        |
#    |        |---------------------------------------- Oedoparena_1262316
#    |        |
#    |        |---------------------------------------- Dryomyza_169444
#    |        |
#    |        |---------------------------------------- Anevrina_92526
#    |        |
#    |        |---------------------------------------- Hirmoneura_388531
#    |        |
#    |        |---------------------------------------- Chloromyia_343649
#    |        |
#    |        |---------------------------------------- Oplodontha_446504
#    |        |
#    |        |---------------------------------------- Neopachygaster_1692469
#    |        |
#    |        |---------------------------------------- Borophaga_712093
#    |        |
#    |        |---------------------------------------- Sciadocera_192453
#    |        |
#    |        |---------------------------------------- Apiocera_160270
#    |        |
#    |        |---------------------------------------- Ptecticus_343648
#    |        |
#    |        |---------------------------------------- Heterocheila_169481
#    |        |
#    |        |---------------------------------------- Berkshiria_2061012
#    |        |
#    |        |---------------------------------------- Hermetia_343581
#    |        |
#    |        |---------------------------------------- Neossos_2268121
#    |        |
#    |        |---------------------------------------- Pachygaster_124321
#    |        |
#    |        |---------------------------------------- Microchrysa_931517
#    |        |
#    |        |---------------------------------------- Teratomyzidae
#    |        |
#    |        \---------------------------------------- Stratiomys_219520
#    |
#    |------------------------------------------------- Bittacomorpha_79307
#    |
#    |------------------------------------------------- Lutzomyia_7199
#    |
#    |------------------------------------------------- Sycorax_114592
#    |
#    |------------------------------------------------- Clogmia_85119
#    |
#    |------------------------------------------------- Maruina_1144738
#    |
#    |------------------------------------------------- Psychoda_7201
#    |
#    |------------------------------------------------- Trichomyia_560271
#    |
#    |------------------------------------------------- Ptychoptera_209691
#    |
#    |------------------------------------------------- Phlebotomus_13203
#    |
#    \------------------------------------------------- Pericoma_1148481

# %% [markdown]
# ### Save BEAST xml statements
#
# Since we have already an XML file, here we will just generate constraint statements to manually add to it. All nodes in our tree will be constraints, following these rules:
#
# 1. If the node is annotated as a hard constraint, it will be a monophyletic constraint for the children of the node
# 2. If the node is not annotated as a hard constraint, it will be a soft constraint: we will include all children of the node as the cosntraint, and we will look for parent nodes until we find a hard constraint. We will then include the ancestors from this node as rogues, so they can float freely within the hard constraint (unless a less inclusive hard constraint excludes them).

# %%
node_lab_idx = 0
tr.seed_node.label = 'Diptera'
constraint_statements = []
log_statements = []

rogues = dict()

for node in tr.preorder_internal_node_iter():
    if node == tr.seed_node: continue
    included_taxa = [leaf.taxon.label for leaf in node.leaf_nodes()]
    constraint_lines = []
    
    if not node.label:
        node.label = f'Node_{node_lab_idx}' 
        node_lab_idx += 1
        
    
    log_statements.append(f'            <log idref="{node.label}.prior"/>')   
    
    
    if not node.annotations.get_value("constraint_type") == "hard": #soft constraint
        parent = node.parent_node
        while True:
            if parent.annotations.get_value("constraint_type") == "hard" or parent == tr.seed_node:
                break
            else:
                parent = parent.parent_node
                
        rogues = set([leaf.taxon.label for leaf in parent.leaf_nodes()]) - set(included_taxa)
                
        constraint_lines.append(f'                <distribution id="{node.label}.prior" spec="beastlabs.math.distributions.MRCAPriorWithRogues" monophyletic="true" tree="@Tree.t:mito_nonprotcoding">')
        constraint_lines.append(f'                    <taxonset id="{node.label}" spec="TaxonSet">')
        for tx in included_taxa:
            constraint_lines.append(f'                        <taxon idref="{tx}" spec="Taxon"/>')
        constraint_lines.append(f'                    </taxonset>')
           
            
        constraint_lines.append(f'                    <rogues id="{node.label}_rogues" spec="TaxonSet">')
        for rogue_tx in rogues:
            constraint_lines.append(f'                        <taxon idref="{rogue_tx}" spec="Taxon"/>')
        constraint_lines.append(f'                    </rogues>')
        
         
    else: #hard constraint
        constraint_lines = []
        constraint_lines.append(f'                 <distribution id="{node.label}.prior" spec="beast.base.evolution.tree.MRCAPrior" monophyletic="true" tree="@Tree.t:mito_nonprotcoding">' )
        constraint_lines.append(f'                    <taxonset id="{node.label}" spec="TaxonSet">')
        for tx in included_taxa:
            constraint_lines.append(f'                        <taxon idref="{tx}" spec="Taxon"/>')
        constraint_lines.append(f'                    </taxonset>')
        
    constraint_lines.append(f'                </distribution>')
        
        
    constraint_statements.append('\n'.join(constraint_lines))

# %% [markdown]
# Let's now print these statements so we can copy and paste to the xml file:

# %% [markdown]
# ### Log statements

# %%
print('\n'.join(log_statements))
# Out:
#             <log idref="first_split.prior"/>
#             <log idref="Node_0.prior"/>
#             <log idref="Tipulomorpha.prior"/>
#             <log idref="Tipuloidea.prior"/>
#             <log idref="Node_1.prior"/>
#             <log idref="Node_2.prior"/>
#             <log idref="Node_3.prior"/>
#             <log idref="Node_4.prior"/>
#             <log idref="Node_5.prior"/>
#             <log idref="Node_6.prior"/>
#             <log idref="Node_7.prior"/>
#             <log idref="Culicomorpha.prior"/>
#             <log idref="Node_8.prior"/>
#             <log idref="Node_9.prior"/>
#             <log idref="Ceratopogonidae.prior"/>
#             <log idref="Chironomidae.prior"/>
#             <log idref="Node_10.prior"/>
#             <log idref="Culicoidea.prior"/>
#             <log idref="Culicidae.prior"/>
#             <log idref="Brachycera.prior"/>
#             <log idref="Bibionomorpha.prior"/>
#             <log idref="Node_11.prior"/>
#             <log idref="Node_12.prior"/>
#             <log idref="Node_13.prior"/>
#             <log idref="Node_14.prior"/>
#             <log idref="Node_15.prior"/>
#             <log idref="Node_16.prior"/>
#             <log idref="Sciaroidea.prior"/>
#             <log idref="Node_17.prior"/>
#             <log idref="Keroplatidae.prior"/>
#             <log idref="Sciaridae.prior"/>
#             <log idref="Cecidomyiidae.prior"/>
#             <log idref="Mycetophilidae.prior"/>
#             <log idref="Node_18.prior"/>
#             <log idref="Node_19.prior"/>
#             <log idref="Platypezidae.prior"/>
#             <log idref="Node_20.prior"/>
#             <log idref="Lauxanioidea.prior"/>
#             <log idref="Node_21.prior"/>
#             <log idref="Node_22.prior"/>
#             <log idref="Node_23.prior"/>
#             <log idref="Node_24.prior"/>
#             <log idref="Node_25.prior"/>
#             <log idref="Sciomyzidae.prior"/>
#             <log idref="Celyphidae.prior"/>
#             <log idref="Node_26.prior"/>
#             <log idref="Node_27.prior"/>
#             <log idref="Node_28.prior"/>
#             <log idref="Node_29.prior"/>
#             <log idref="Node_30.prior"/>
#             <log idref="Micropezidae.prior"/>
#             <log idref="Neriidae.prior"/>
#             <log idref="Node_31.prior"/>
#             <log idref="Tephritoidea.prior"/>
#             <log idref="Piophilidae.prior"/>
#             <log idref="Node_32.prior"/>
#             <log idref="Ulidiidae.prior"/>
#             <log idref="Node_33.prior"/>
#             <log idref="Lonchaeidae.prior"/>
#             <log idref="Platystomatidae.prior"/>
#             <log idref="Node_34.prior"/>
#             <log idref="Node_35.prior"/>
#             <log idref="Node_36.prior"/>
#             <log idref="Psilidae.prior"/>
#             <log idref="Sepsidae.prior"/>
#             <log idref="Node_37.prior"/>
#             <log idref="Node_38.prior"/>
#             <log idref="Node_39.prior"/>
#             <log idref="Node_40.prior"/>
#             <log idref="Anthomyzidae.prior"/>
#             <log idref="Node_41.prior"/>
#             <log idref="Node_42.prior"/>
#             <log idref="Chloropidae.prior"/>
#             <log idref="Node_43.prior"/>
#             <log idref="Node_44.prior"/>
#             <log idref="Node_45.prior"/>
#             <log idref="Node_46.prior"/>
#             <log idref="Node_47.prior"/>
#             <log idref="Node_48.prior"/>
#             <log idref="Hippoboscoidea.prior"/>
#             <log idref="Hippoboscidae.prior"/>
#             <log idref="Nycteribiidae.prior"/>
#             <log idref="Node_49.prior"/>
#             <log idref="Muscidae.prior"/>
#             <log idref="Scathophagidae.prior"/>
#             <log idref="Tabanomorpha.prior"/>
#             <log idref="Tabanidae.prior"/>
#             <log idref="Rhiniidae.prior"/>
#             <log idref="Syrphidae.prior"/>
#             <log idref="Ephydridae.prior"/>
#             <log idref="Anthomyiidae.prior"/>
#             <log idref="Dolichopodidae.prior"/>
#             <log idref="Asilidae.prior"/>
#             <log idref="Acroceridae.prior"/>
#             <log idref="Bombyliidae.prior"/>
#             <log idref="Milichiidae.prior"/>
#             <log idref="Conopidae.prior"/>
#             <log idref="Pipunculidae.prior"/>
#             <log idref="Clusiidae.prior"/>
#             <log idref="Xylophagidae.prior"/>
#             <log idref="Fanniidae.prior"/>

# %% [markdown]
# ### Constraint statements

# %%
print('\n'.join(constraint_statements))
# Out:
#                  <distribution id="first_split.prior" spec="beast.base.evolution.tree.MRCAPrior" monophyletic="true" tree="@Tree.t:mito_nonprotcoding">
#                     <taxonset id="first_split" spec="TaxonSet">
#                         <taxon idref="Nymphomyia_560766" spec="Taxon"/>
#                         <taxon idref="Trichocera_52759" spec="Taxon"/>
#                         <taxon idref="Dicranota_700836" spec="Taxon"/>
#                         <taxon idref="Pedicia_472374" spec="Taxon"/>
#                         <taxon idref="Liogma_560731" spec="Taxon"/>
#                         <taxon idref="Phalacrocera_2203737" spec="Taxon"/>
#                         <taxon idref="Cylindrotoma_700834" spec="Taxon"/>
#                         <taxon idref="Tipula_41043" spec="Taxon"/>
#                         <taxon idref="Dictenidia_2108369" spec="Taxon"/>
#                         <taxon idref="Limonia_52743" spec="Taxon"/>
#                         <taxon idref="Prionocera_1690388" spec="Taxon"/>
#                         <taxon idref="Gnophomyia_700845" spec="Taxon"/>
#                         <taxon idref="Ctenophora_516519" spec="Taxon"/>
#                         <taxon idref="Tanyptera_2108371" spec="Taxon"/>
#                         <taxon idref="Metalimnobia_700851" spec="Taxon"/>
#                         <taxon idref="Dactylolabis_560717" spec="Taxon"/>
#                         <taxon idref="Antocha_454619" spec="Taxon"/>
#                         <taxon idref="Liponeura_446516" spec="Taxon"/>
#                         <taxon idref="Blepharicera_547808" spec="Taxon"/>
#                         <taxon idref="Mischoderus_560267" spec="Taxon"/>
#                         <taxon idref="Araucoderus_1549737" spec="Taxon"/>
#                         <taxon idref="Protoplasa_560776" spec="Taxon"/>
#                         <taxon idref="Sphaeromias_1874311" spec="Taxon"/>
#                         <taxon idref="Palpomyia_1525500" spec="Taxon"/>
#                         <taxon idref="Austroconops_209696" spec="Taxon"/>
#                         <taxon idref="Culicoides_41820" spec="Taxon"/>
#                         <taxon idref="Serromyia_209716" spec="Taxon"/>
#                         <taxon idref="Forcipomyia_209700" spec="Taxon"/>
#                         <taxon idref="Dasyhelea_41822" spec="Taxon"/>
#                         <taxon idref="Atrichopogon_209702" spec="Taxon"/>
#                         <taxon idref="Ainuyusurika_1165747" spec="Taxon"/>
#                         <taxon idref="Pentaneura_891922" spec="Taxon"/>
#                         <taxon idref="Metriocnemus_137497" spec="Taxon"/>
#                         <taxon idref="Eukiefferiella_288843" spec="Taxon"/>
#                         <taxon idref="Parochlus_315560" spec="Taxon"/>
#                         <taxon idref="Pseudosmittia_611382" spec="Taxon"/>
#                         <taxon idref="Tvetenia_611398" spec="Taxon"/>
#                         <taxon idref="Paucispinigera_903463" spec="Taxon"/>
#                         <taxon idref="Paraborniella_903459" spec="Taxon"/>
#                         <taxon idref="Smittia_315559" spec="Taxon"/>
#                         <taxon idref="Monodiamesa_891905" spec="Taxon"/>
#                         <taxon idref="Chironomus_7150" spec="Taxon"/>
#                         <taxon idref="Clunio_315556" spec="Taxon"/>
#                         <taxon idref="Aphroteniella_646259" spec="Taxon"/>
#                         <taxon idref="Gymnometriocnemus_611353" spec="Taxon"/>
#                         <taxon idref="Corynoneura_611344" spec="Taxon"/>
#                         <taxon idref="Ablabesmyia_46216" spec="Taxon"/>
#                         <taxon idref="Psectrotanypus_903467" spec="Taxon"/>
#                         <taxon idref="Androprosopa_41815" spec="Taxon"/>
#                         <taxon idref="Austrothaumalea_1085085" spec="Taxon"/>
#                         <taxon idref="Thaumalea_61068" spec="Taxon"/>
#                         <taxon idref="Dixa_79309" spec="Taxon"/>
#                         <taxon idref="Mochlonyx_1577622" spec="Taxon"/>
#                         <taxon idref="Chaoborus_41812" spec="Taxon"/>
#                         <taxon idref="Anopheles_7164" spec="Taxon"/>
#                         <taxon idref="Culex_7174" spec="Taxon"/>
#                         <taxon idref="Culiseta_174825" spec="Taxon"/>
#                         <taxon idref="Aedes_7158" spec="Taxon"/>
#                         <taxon idref="Simulium_7191" spec="Taxon"/>
#                         <taxon idref="Scatopse_1520324" spec="Taxon"/>
#                         <taxon idref="Coboldia_170624" spec="Taxon"/>
#                         <taxon idref="Axymyia_560715" spec="Taxon"/>
#                         <taxon idref="Dilophus_52733" spec="Taxon"/>
#                         <taxon idref="Plecia_1260898" spec="Taxon"/>
#                         <taxon idref="Bibio_189978" spec="Taxon"/>
#                         <taxon idref="Pachyneura_1588165" spec="Taxon"/>
#                         <taxon idref="Cramptonomyia_209688" spec="Taxon"/>
#                         <taxon idref="Diadocidia_560721" spec="Taxon"/>
#                         <taxon idref="Orfelia_270890" spec="Taxon"/>
#                         <taxon idref="Macrocera_608727" spec="Taxon"/>
#                         <taxon idref="Sciara_82677" spec="Taxon"/>
#                         <taxon idref="Pnyxia_1781626" spec="Taxon"/>
#                         <taxon idref="Corynoptera_1260849" spec="Taxon"/>
#                         <taxon idref="Bradysia_35571" spec="Taxon"/>
#                         <taxon idref="Contarinia_153220" spec="Taxon"/>
#                         <taxon idref="Sitodiplosis_263139" spec="Taxon"/>
#                         <taxon idref="Aprionus_1819779" spec="Taxon"/>
#                         <taxon idref="Piceacecis_2597495" spec="Taxon"/>
#                         <taxon idref="Lasioptera_201413" spec="Taxon"/>
#                         <taxon idref="Peromyia_1914937" spec="Taxon"/>
#                         <taxon idref="Cecidomyia_1543682" spec="Taxon"/>
#                         <taxon idref="Dasineura_240745" spec="Taxon"/>
#                         <taxon idref="Asphondylia_153012" spec="Taxon"/>
#                         <taxon idref="Winnertzia_2338641" spec="Taxon"/>
#                         <taxon idref="Aphidoletes_95971" spec="Taxon"/>
#                         <taxon idref="Brachypeza_2326774" spec="Taxon"/>
#                         <taxon idref="Trichonta_397122" spec="Taxon"/>
#                         <taxon idref="Mycetophila_397146" spec="Taxon"/>
#                         <taxon idref="Neoempheria_608686" spec="Taxon"/>
#                         <taxon idref="Symmerus_560780" spec="Taxon"/>
#                         <taxon idref="Mycomya_608706" spec="Taxon"/>
#                         <taxon idref="Sciophila_1085959" spec="Taxon"/>
#                         <taxon idref="Phronia_397119" spec="Taxon"/>
#                         <taxon idref="Exechia_397139" spec="Taxon"/>
#                         <taxon idref="Epicypta_397117" spec="Taxon"/>
#                         <taxon idref="Leptomorphus_560729" spec="Taxon"/>
#                         <taxon idref="Ditomyia_1520322" spec="Taxon"/>
#                         <taxon idref="Bolitophila_52718" spec="Taxon"/>
#                         <taxon idref="Hesperinus_1086788" spec="Taxon"/>
#                         <taxon idref="Penthetria_560770" spec="Taxon"/>
#                         <taxon idref="Paraplatypeza_192442" spec="Taxon"/>
#                         <taxon idref="Bertamyia_1445832" spec="Taxon"/>
#                         <taxon idref="Callomyia_712098" spec="Taxon"/>
#                         <taxon idref="Kesselimyia_1445844" spec="Taxon"/>
#                         <taxon idref="Agathomyia_226141" spec="Taxon"/>
#                         <taxon idref="Polyporivora_1445854" spec="Taxon"/>
#                         <taxon idref="Platypeza_289241" spec="Taxon"/>
#                         <taxon idref="Chamaemyia_305621" spec="Taxon"/>
#                         <taxon idref="Leucopis_1728826" spec="Taxon"/>
#                         <taxon idref="Parochthiphila_1262282" spec="Taxon"/>
#                         <taxon idref="Coelopa_169466" spec="Taxon"/>
#                         <taxon idref="Helcomyza_169476" spec="Taxon"/>
#                         <taxon idref="Homoneura_1692452" spec="Taxon"/>
#                         <taxon idref="Tricholauxania_192459" spec="Taxon"/>
#                         <taxon idref="Aulogastromyia_1824990" spec="Taxon"/>
#                         <taxon idref="Pteromicra_1226622" spec="Taxon"/>
#                         <taxon idref="Dictya_1096051" spec="Taxon"/>
#                         <taxon idref="Elgiva_320938" spec="Taxon"/>
#                         <taxon idref="Sepedon_320954" spec="Taxon"/>
#                         <taxon idref="Neolimnia_1262312" spec="Taxon"/>
#                         <taxon idref="Sciomyza_320936" spec="Taxon"/>
#                         <taxon idref="Ilione_1096072" spec="Taxon"/>
#                         <taxon idref="Psacadina_1096078" spec="Taxon"/>
#                         <taxon idref="Tetanocera_320959" spec="Taxon"/>
#                         <taxon idref="Hedria_320941" spec="Taxon"/>
#                         <taxon idref="Coremacera_1226614" spec="Taxon"/>
#                         <taxon idref="Anticheta_1096047" spec="Taxon"/>
#                         <taxon idref="Pelidnoptera_1096074" spec="Taxon"/>
#                         <taxon idref="Celyphus_1979294" spec="Taxon"/>
#                         <taxon idref="Spaniocelyphus_1262326" spec="Taxon"/>
#                         <taxon idref="Copromyza_1217530" spec="Taxon"/>
#                         <taxon idref="Leptocera_1614654" spec="Taxon"/>
#                         <taxon idref="Mimegralla_115300" spec="Taxon"/>
#                         <taxon idref="Compsobata_286452" spec="Taxon"/>
#                         <taxon idref="Calobata_1820059" spec="Taxon"/>
#                         <taxon idref="Micropeza_1572561" spec="Taxon"/>
#                         <taxon idref="Telostylinus_1262347" spec="Taxon"/>
#                         <taxon idref="Odontoloxozus_588320" spec="Taxon"/>
#                         <taxon idref="Lasiopiophila_1790233" spec="Taxon"/>
#                         <taxon idref="Piophila_53709" spec="Taxon"/>
#                         <taxon idref="Centrophlebomyia_1603419" spec="Taxon"/>
#                         <taxon idref="Liopiophila_1603421" spec="Taxon"/>
#                         <taxon idref="Delphinia_43369" spec="Taxon"/>
#                         <taxon idref="Chaetopsis_240871" spec="Taxon"/>
#                         <taxon idref="Tetanops_454640" spec="Taxon"/>
#                         <taxon idref="Euxesta_286468" spec="Taxon"/>
#                         <taxon idref="Eurosta_28593" spec="Taxon"/>
#                         <taxon idref="Anastrepha_28585" spec="Taxon"/>
#                         <taxon idref="Euleia_28591" spec="Taxon"/>
#                         <taxon idref="Terellia_28615" spec="Taxon"/>
#                         <taxon idref="Paracantha_164885" spec="Taxon"/>
#                         <taxon idref="Tephritis_43386" spec="Taxon"/>
#                         <taxon idref="Urophora_28620" spec="Taxon"/>
#                         <taxon idref="Gymnocarena_28597" spec="Taxon"/>
#                         <taxon idref="Jamesomyia_28601" spec="Taxon"/>
#                         <taxon idref="Oxyna_381365" spec="Taxon"/>
#                         <taxon idref="Trupanea_30060" spec="Taxon"/>
#                         <taxon idref="Rhagoletis_28609" spec="Taxon"/>
#                         <taxon idref="Noeeta_381362" spec="Taxon"/>
#                         <taxon idref="Ceratitis_7212" spec="Taxon"/>
#                         <taxon idref="Zonosemata_28622" spec="Taxon"/>
#                         <taxon idref="Bactrocera_27456" spec="Taxon"/>
#                         <taxon idref="Xyphosia_381372" spec="Taxon"/>
#                         <taxon idref="Icterica_28599" spec="Taxon"/>
#                         <taxon idref="Lamprolonchaea_907706" spec="Taxon"/>
#                         <taxon idref="Lonchaea_198649" spec="Taxon"/>
#                         <taxon idref="Dasiops_286456" spec="Taxon"/>
#                         <taxon idref="Silba_198646" spec="Taxon"/>
#                         <taxon idref="Rivellia_28633" spec="Taxon"/>
#                         <taxon idref="Platystoma_286504" spec="Taxon"/>
#                         <taxon idref="Scholastes_1902237" spec="Taxon"/>
#                         <taxon idref="Palloptera_286498" spec="Taxon"/>
#                         <taxon idref="Ctenostylidae" spec="Taxon"/>
#                         <taxon idref="Opomyza_716643" spec="Taxon"/>
#                         <taxon idref="Geomyza_305619" spec="Taxon"/>
#                         <taxon idref="Psila_305548" spec="Taxon"/>
#                         <taxon idref="Loxocera_34684" spec="Taxon"/>
#                         <taxon idref="Chyliza_716634" spec="Taxon"/>
#                         <taxon idref="Sepsis_137507" spec="Taxon"/>
#                         <taxon idref="Themira_292396" spec="Taxon"/>
#                         <taxon idref="Diasemopsis_139652" spec="Taxon"/>
#                         <taxon idref="Sphyracephala_139674" spec="Taxon"/>
#                         <taxon idref="Diopsis_139667" spec="Taxon"/>
#                         <taxon idref="Procanace_1262322" spec="Taxon"/>
#                         <taxon idref="Stiphrosoma_500293" spec="Taxon"/>
#                         <taxon idref="Paranthomyza_500298" spec="Taxon"/>
#                         <taxon idref="Quametopia_1603285" spec="Taxon"/>
#                         <taxon idref="Thaumatomyia_333800" spec="Taxon"/>
#                         <taxon idref="Hippelates_540866" spec="Taxon"/>
#                         <taxon idref="Cetema_540891" spec="Taxon"/>
#                         <taxon idref="Gaurax_540862" spec="Taxon"/>
#                         <taxon idref="Lipara_540870" spec="Taxon"/>
#                         <taxon idref="Tricimba_540889" spec="Taxon"/>
#                         <taxon idref="Elachiptera_540858" spec="Taxon"/>
#                         <taxon idref="Incertella_540867" spec="Taxon"/>
#                         <taxon idref="Aphanotrigonum_540849" spec="Taxon"/>
#                         <taxon idref="Calamoncosis_540852" spec="Taxon"/>
#                         <taxon idref="Chlorops_540892" spec="Taxon"/>
#                         <taxon idref="Cryptonevra_1616778" spec="Taxon"/>
#                         <taxon idref="Epichlorops_540897" spec="Taxon"/>
#                         <taxon idref="Stenomicra_716630" spec="Taxon"/>
#                         <taxon idref="Periscelis_716628" spec="Taxon"/>
#                         <taxon idref="Fergusonina_156411" spec="Taxon"/>
#                         <taxon idref="Liriomyza_127403" spec="Taxon"/>
#                         <taxon idref="Melanagromyza_286470" spec="Taxon"/>
#                         <taxon idref="Phytobia_414304" spec="Taxon"/>
#                         <taxon idref="Cerodontha_127401" spec="Taxon"/>
#                         <taxon idref="Ophiomyia_341050" spec="Taxon"/>
#                         <taxon idref="Japanagromyza_414298" spec="Taxon"/>
#                         <taxon idref="Agromyza_414290" spec="Taxon"/>
#                         <taxon idref="Calycomyza_414293" spec="Taxon"/>
#                         <taxon idref="Phytomyza_132616" spec="Taxon"/>
#                         <taxon idref="Odinia_414302" spec="Taxon"/>
#                         <taxon idref="Crataerina_452743" spec="Taxon"/>
#                         <taxon idref="Olfersia_1333310" spec="Taxon"/>
#                         <taxon idref="Melophagus_452748" spec="Taxon"/>
#                         <taxon idref="Ornithophila_1497392" spec="Taxon"/>
#                         <taxon idref="Hippobosca_452745" spec="Taxon"/>
#                         <taxon idref="Icosta_402409" spec="Taxon"/>
#                         <taxon idref="Lipoptena_170902" spec="Taxon"/>
#                         <taxon idref="Glossina_7393" spec="Taxon"/>
#                         <taxon idref="Basilia_170889" spec="Taxon"/>
#                         <taxon idref="Penicillidia_81721" spec="Taxon"/>
#                         <taxon idref="Nycteribia_633884" spec="Taxon"/>
#                         <taxon idref="Muscina_57892" spec="Taxon"/>
#                         <taxon idref="Phaonia_253431" spec="Taxon"/>
#                         <taxon idref="Hebecnema_559682" spec="Taxon"/>
#                         <taxon idref="Potamia_559704" spec="Taxon"/>
#                         <taxon idref="Atherigona_305597" spec="Taxon"/>
#                         <taxon idref="Musca_7369" spec="Taxon"/>
#                         <taxon idref="Passeromyia_1511687" spec="Taxon"/>
#                         <taxon idref="Myospila_520040" spec="Taxon"/>
#                         <taxon idref="Haematobosca_559680" spec="Taxon"/>
#                         <taxon idref="Neomyia_305607" spec="Taxon"/>
#                         <taxon idref="Mesembrina_116147" spec="Taxon"/>
#                         <taxon idref="Graphomya_1072499" spec="Taxon"/>
#                         <taxon idref="Morellia_253340" spec="Taxon"/>
#                         <taxon idref="Philornis_253427" spec="Taxon"/>
#                         <taxon idref="Polietes_559702" spec="Taxon"/>
#                         <taxon idref="Eginia_1511678" spec="Taxon"/>
#                         <taxon idref="Limnophora_307207" spec="Taxon"/>
#                         <taxon idref="Scathophaga_95462" spec="Taxon"/>
#                         <taxon idref="Hydromyza_113174" spec="Taxon"/>
#                         <taxon idref="Norellia_113119" spec="Taxon"/>
#                         <taxon idref="Cordilura_113132" spec="Taxon"/>
#                         <taxon idref="Cleigastra_113167" spec="Taxon"/>
#                         <taxon idref="Orthacheta_113181" spec="Taxon"/>
#                         <taxon idref="Oreoleptis_1262318" spec="Taxon"/>
#                         <taxon idref="Esenbeckia_124297" spec="Taxon"/>
#                         <taxon idref="Hybomitra_124690" spec="Taxon"/>
#                         <taxon idref="Fidena_1334907" spec="Taxon"/>
#                         <taxon idref="Apatolestes_428062" spec="Taxon"/>
#                         <taxon idref="Catachlorops_1547373" spec="Taxon"/>
#                         <taxon idref="Silvius_415257" spec="Taxon"/>
#                         <taxon idref="Atylotus_1310336" spec="Taxon"/>
#                         <taxon idref="Haematopota_124311" spec="Taxon"/>
#                         <taxon idref="Stenotabanus_1547430" spec="Taxon"/>
#                         <taxon idref="Leucotabanus_1969939" spec="Taxon"/>
#                         <taxon idref="Chrysops_27458" spec="Taxon"/>
#                         <taxon idref="Tabanus_7206" spec="Taxon"/>
#                         <taxon idref="Bolbodimyia_1547386" spec="Taxon"/>
#                         <taxon idref="Goniops_428065" spec="Taxon"/>
#                         <taxon idref="Vermileo_124333" spec="Taxon"/>
#                         <taxon idref="Ptiolina_124325" spec="Taxon"/>
#                         <taxon idref="Rhagio_124327" spec="Taxon"/>
#                         <taxon idref="Atherix_124299" spec="Taxon"/>
#                         <taxon idref="Glutops_124309" spec="Taxon"/>
#                         <taxon idref="Compsomyiops_142897" spec="Taxon"/>
#                         <taxon idref="Lucilia_7374" spec="Taxon"/>
#                         <taxon idref="Paralucilia_1042205" spec="Taxon"/>
#                         <taxon idref="Trypocalliphora_1042207" spec="Taxon"/>
#                         <taxon idref="Cordylobia_226131" spec="Taxon"/>
#                         <taxon idref="Calliphora_7372" spec="Taxon"/>
#                         <taxon idref="Chrysomya_45449" spec="Taxon"/>
#                         <taxon idref="Protocalliphora_142901" spec="Taxon"/>
#                         <taxon idref="Auchmeromyia_226129" spec="Taxon"/>
#                         <taxon idref="Hemilucilia_416848" spec="Taxon"/>
#                         <taxon idref="Sarconesia_670650" spec="Taxon"/>
#                         <taxon idref="Amenia_2086281" spec="Taxon"/>
#                         <taxon idref="Melinda_170907" spec="Taxon"/>
#                         <taxon idref="Hemigymnochaeta_1240433" spec="Taxon"/>
#                         <taxon idref="Laneella_1658054" spec="Taxon"/>
#                         <taxon idref="Eumesembrinella_672472" spec="Taxon"/>
#                         <taxon idref="Mesembrinella_460529" spec="Taxon"/>
#                         <taxon idref="Huascaromusca_1609532" spec="Taxon"/>
#                         <taxon idref="Mystacinobia_81694" spec="Taxon"/>
#                         <taxon idref="Oestrus_123736" spec="Taxon"/>
#                         <taxon idref="Cuterebra_170896" spec="Taxon"/>
#                         <taxon idref="Dermatobia_115426" spec="Taxon"/>
#                         <taxon idref="Oestromyia_170913" spec="Taxon"/>
#                         <taxon idref="Przhevalskiana_123746" spec="Taxon"/>
#                         <taxon idref="Rhinoestrus_204922" spec="Taxon"/>
#                         <taxon idref="Cephenemyia_170894" spec="Taxon"/>
#                         <taxon idref="Hypoderma_7388" spec="Taxon"/>
#                         <taxon idref="Pollenia_229639" spec="Taxon"/>
#                         <taxon idref="Rhyncomya_670621" spec="Taxon"/>
#                         <taxon idref="Idiella_1902146" spec="Taxon"/>
#                         <taxon idref="Stevenia_670627" spec="Taxon"/>
#                         <taxon idref="Paykullia_559695" spec="Taxon"/>
#                         <taxon idref="Phyto_1262320" spec="Taxon"/>
#                         <taxon idref="Rhinophora_670625" spec="Taxon"/>
#                         <taxon idref="Tricogena_1606792" spec="Taxon"/>
#                         <taxon idref="Melanophora_1606787" spec="Taxon"/>
#                         <taxon idref="Sarcophaga_7384" spec="Taxon"/>
#                         <taxon idref="Sphecapatoclea_2021595" spec="Taxon"/>
#                         <taxon idref="Blaesoxipha_128953" spec="Taxon"/>
#                         <taxon idref="Craticulina_2021509" spec="Taxon"/>
#                         <taxon idref="Wohlfahrtia_128961" spec="Taxon"/>
#                         <taxon idref="Miltogramma_670602" spec="Taxon"/>
#                         <taxon idref="Sphecapatodes_2021536" spec="Taxon"/>
#                         <taxon idref="Phytomyptera_179785" spec="Taxon"/>
#                         <taxon idref="Neaera_695903" spec="Taxon"/>
#                         <taxon idref="Parasetigena_380521" spec="Taxon"/>
#                         <taxon idref="Leschenaultia_179486" spec="Taxon"/>
#                         <taxon idref="Estheria_1918238" spec="Taxon"/>
#                         <taxon idref="Exorista_113238" spec="Taxon"/>
#                         <taxon idref="Billaea_701468" spec="Taxon"/>
#                         <taxon idref="Blepharomyia_179434" spec="Taxon"/>
#                         <taxon idref="Prosena_1918293" spec="Taxon"/>
#                         <taxon idref="Elomyia_1562792" spec="Taxon"/>
#                         <taxon idref="Dinera_569035" spec="Taxon"/>
#                         <taxon idref="Clausicella_1718822" spec="Taxon"/>
#                         <taxon idref="Lydella_283929" spec="Taxon"/>
#                         <taxon idref="Blondelia_179437" spec="Taxon"/>
#                         <taxon idref="Mintho_1918277" spec="Taxon"/>
#                         <taxon idref="Ectophasia_569037" spec="Taxon"/>
#                         <taxon idref="Drino_179459" spec="Taxon"/>
#                         <taxon idref="Senotainia_179787" spec="Taxon"/>
#                         <taxon idref="Cyrtophleba_991141" spec="Taxon"/>
#                         <taxon idref="Archytas_198637" spec="Taxon"/>
#                         <taxon idref="Cleonice_1918224" spec="Taxon"/>
#                         <taxon idref="Zaira_179789" spec="Taxon"/>
#                         <taxon idref="Dexia_569033" spec="Taxon"/>
#                         <taxon idref="Glaurocara_2027854" spec="Taxon"/>
#                         <taxon idref="Ateloglossa_1890907" spec="Taxon"/>
#                         <taxon idref="Acemya_1677647" spec="Taxon"/>
#                         <taxon idref="Macquartia_1918266" spec="Taxon"/>
#                         <taxon idref="Phryxe_569079" spec="Taxon"/>
#                         <taxon idref="Sturmia_569089" spec="Taxon"/>
#                         <taxon idref="Vibrissina_179525" spec="Taxon"/>
#                         <taxon idref="Pseudoperichaeta_283931" spec="Taxon"/>
#                         <taxon idref="Anthomyiopsis_1918198" spec="Taxon"/>
#                         <taxon idref="Nemoraea_170911" spec="Taxon"/>
#                         <taxon idref="Hammerschmidtia_226171" spec="Taxon"/>
#                         <taxon idref="Paragus_115308" spec="Taxon"/>
#                         <taxon idref="Brachyopa_1637464" spec="Taxon"/>
#                         <taxon idref="Eupeodes_290403" spec="Taxon"/>
#                         <taxon idref="Blera_226146" spec="Taxon"/>
#                         <taxon idref="Copestylum_511142" spec="Taxon"/>
#                         <taxon idref="Scaeva_219538" spec="Taxon"/>
#                         <taxon idref="Eumerus_224220" spec="Taxon"/>
#                         <taxon idref="Syrphus_224255" spec="Taxon"/>
#                         <taxon idref="Ornidia_994473" spec="Taxon"/>
#                         <taxon idref="Volucella_226148" spec="Taxon"/>
#                         <taxon idref="Melangyna_414825" spec="Taxon"/>
#                         <taxon idref="Syritta_34681" spec="Taxon"/>
#                         <taxon idref="Ocyptamus_369855" spec="Taxon"/>
#                         <taxon idref="Cheilosia_173981" spec="Taxon"/>
#                         <taxon idref="Chrysogaster_224248" spec="Taxon"/>
#                         <taxon idref="Microdon_115291" spec="Taxon"/>
#                         <taxon idref="Toxomerus_115327" spec="Taxon"/>
#                         <taxon idref="Sphaerophoria_226179" spec="Taxon"/>
#                         <taxon idref="Merodon_224226" spec="Taxon"/>
#                         <taxon idref="Pipiza_221788" spec="Taxon"/>
#                         <taxon idref="Epistrophe_414810" spec="Taxon"/>
#                         <taxon idref="Temnostoma_226164" spec="Taxon"/>
#                         <taxon idref="Eriozona_414724" spec="Taxon"/>
#                         <taxon idref="Myolepta_1473716" spec="Taxon"/>
#                         <taxon idref="Neoascia_224222" spec="Taxon"/>
#                         <taxon idref="Callicera_228567" spec="Taxon"/>
#                         <taxon idref="Eristalis_198633" spec="Taxon"/>
#                         <taxon idref="Xanthogramma_414873" spec="Taxon"/>
#                         <taxon idref="Curtonotum_1262296" spec="Taxon"/>
#                         <taxon idref="Leucophenga_7329" spec="Taxon"/>
#                         <taxon idref="Drosophila_7215" spec="Taxon"/>
#                         <taxon idref="Zygothrica_504731" spec="Taxon"/>
#                         <taxon idref="Stegana_188292" spec="Taxon"/>
#                         <taxon idref="Scaptomyza_7298" spec="Taxon"/>
#                         <taxon idref="Chymomyza_7292" spec="Taxon"/>
#                         <taxon idref="Cacoxenus_462273" spec="Taxon"/>
#                         <taxon idref="Zaprionus_7296" spec="Taxon"/>
#                         <taxon idref="Acletoxenus_462271" spec="Taxon"/>
#                         <taxon idref="Scaptodrosophila_7354" spec="Taxon"/>
#                         <taxon idref="Hydrellia_92591" spec="Taxon"/>
#                         <taxon idref="Nostima_1473719" spec="Taxon"/>
#                         <taxon idref="Scatophila_1763968" spec="Taxon"/>
#                         <taxon idref="Pelina_1086796" spec="Taxon"/>
#                         <taxon idref="Ephydra_504564" spec="Taxon"/>
#                         <taxon idref="Scatella_305595" spec="Taxon"/>
#                         <taxon idref="Phorbia_1993534" spec="Taxon"/>
#                         <taxon idref="Egle_411076" spec="Taxon"/>
#                         <taxon idref="Lasiomma_95464" spec="Taxon"/>
#                         <taxon idref="Alliopsis_1692454" spec="Taxon"/>
#                         <taxon idref="Fucellia_205683" spec="Taxon"/>
#                         <taxon idref="Pegomya_559697" spec="Taxon"/>
#                         <taxon idref="Paregle_559693" spec="Taxon"/>
#                         <taxon idref="Chiastocheta_129251" spec="Taxon"/>
#                         <taxon idref="Chirosia_392044" spec="Taxon"/>
#                         <taxon idref="Pegohylemyia_1887308" spec="Taxon"/>
#                         <taxon idref="Delia_30063" spec="Taxon"/>
#                         <taxon idref="Hylemya_253328" spec="Taxon"/>
#                         <taxon idref="Anthomyia_259845" spec="Taxon"/>
#                         <taxon idref="Dolichopus_192427" spec="Taxon"/>
#                         <taxon idref="Medetera_377527" spec="Taxon"/>
#                         <taxon idref="Rhaphium_377528" spec="Taxon"/>
#                         <taxon idref="Rhamphomyia_192612" spec="Taxon"/>
#                         <taxon idref="Neoplasta_192640" spec="Taxon"/>
#                         <taxon idref="Phyllodromia_1209097" spec="Taxon"/>
#                         <taxon idref="Chelifera_369889" spec="Taxon"/>
#                         <taxon idref="Wiedemannia_240904" spec="Taxon"/>
#                         <taxon idref="Clinocera_192484" spec="Taxon"/>
#                         <taxon idref="Metachela_369884" spec="Taxon"/>
#                         <taxon idref="Philonicus_247567" spec="Taxon"/>
#                         <taxon idref="Dioctria_468720" spec="Taxon"/>
#                         <taxon idref="Promachus_247552" spec="Taxon"/>
#                         <taxon idref="Machimus_247604" spec="Taxon"/>
#                         <taxon idref="Lasiopogon_219536" spec="Taxon"/>
#                         <taxon idref="Pamponerus_1717601" spec="Taxon"/>
#                         <taxon idref="Laphria_50683" spec="Taxon"/>
#                         <taxon idref="Mallophora_270862" spec="Taxon"/>
#                         <taxon idref="Ocnaea_210271" spec="Taxon"/>
#                         <taxon idref="Ogcodes_188257" spec="Taxon"/>
#                         <taxon idref="Eulonchus_210230" spec="Taxon"/>
#                         <taxon idref="Acrocera_210245" spec="Taxon"/>
#                         <taxon idref="Astomella_210239" spec="Taxon"/>
#                         <taxon idref="Exetasis_1932988" spec="Taxon"/>
#                         <taxon idref="Pterodontia_210267" spec="Taxon"/>
#                         <taxon idref="Systoechus_1690390" spec="Taxon"/>
#                         <taxon idref="Bombylius_219362" spec="Taxon"/>
#                         <taxon idref="Anthrax_117078" spec="Taxon"/>
#                         <taxon idref="Ligyra_117088" spec="Taxon"/>
#                         <taxon idref="Desmometopa_305587" spec="Taxon"/>
#                         <taxon idref="Leptometopa_1720790" spec="Taxon"/>
#                         <taxon idref="Pholeomyia_1720804" spec="Taxon"/>
#                         <taxon idref="Milichiella_1890919" spec="Taxon"/>
#                         <taxon idref="Physocephala_198643" spec="Taxon"/>
#                         <taxon idref="Thecophora_305546" spec="Taxon"/>
#                         <taxon idref="Sicus_1219203" spec="Taxon"/>
#                         <taxon idref="Zodion_768804" spec="Taxon"/>
#                         <taxon idref="Verrallia_115333" spec="Taxon"/>
#                         <taxon idref="Nephrocerus_115303" spec="Taxon"/>
#                         <taxon idref="Chalarus_115250" spec="Taxon"/>
#                         <taxon idref="Pipunculus_240898" spec="Taxon"/>
#                         <taxon idref="Sobarocephala_574054" spec="Taxon"/>
#                         <taxon idref="Clusia_574057" spec="Taxon"/>
#                         <taxon idref="Clusiodes_500306" spec="Taxon"/>
#                         <taxon idref="Xylophagus_219493" spec="Taxon"/>
#                         <taxon idref="Exeretonevra_560723" spec="Taxon"/>
#                         <taxon idref="Coenomyia_124305" spec="Taxon"/>
#                         <taxon idref="Fannia_95468" spec="Taxon"/>
#                         <taxon idref="Euryomma_1650677" spec="Taxon"/>
#                         <taxon idref="Nemotelus_343582" spec="Taxon"/>
#                         <taxon idref="Oxycera_860348" spec="Taxon"/>
#                         <taxon idref="Pantophthalmus_124295" spec="Taxon"/>
#                         <taxon idref="Scoliocentra_1823605" spec="Taxon"/>
#                         <taxon idref="Neorhynchocephalus_259248" spec="Taxon"/>
#                         <taxon idref="Tanypeza_1692486" spec="Taxon"/>
#                         <taxon idref="Scenopinus_247599" spec="Taxon"/>
#                         <taxon idref="Triphleba_92553" spec="Taxon"/>
#                         <taxon idref="Cryptochetum_1262333" spec="Taxon"/>
#                         <taxon idref="Mydas_186100" spec="Taxon"/>
#                         <taxon idref="Hypocera_940227" spec="Taxon"/>
#                         <taxon idref="Megaselia_36165" spec="Taxon"/>
#                         <taxon idref="Helosciomyzidae" spec="Taxon"/>
#                         <taxon idref="Neurochaeta_716624" spec="Taxon"/>
#                         <taxon idref="Sargus_343647" spec="Taxon"/>
#                         <taxon idref="Odontomyia_343652" spec="Taxon"/>
#                         <taxon idref="Lonchoptera_92595" spec="Taxon"/>
#                         <taxon idref="Diplonevra_92534" spec="Taxon"/>
#                         <taxon idref="Zabrachia_1891525" spec="Taxon"/>
#                         <taxon idref="Apocephalus_117252" spec="Taxon"/>
#                         <taxon idref="Thereva_95078" spec="Taxon"/>
#                         <taxon idref="Oedoparena_1262316" spec="Taxon"/>
#                         <taxon idref="Dryomyza_169444" spec="Taxon"/>
#                         <taxon idref="Anevrina_92526" spec="Taxon"/>
#                         <taxon idref="Hirmoneura_388531" spec="Taxon"/>
#                         <taxon idref="Chloromyia_343649" spec="Taxon"/>
#                         <taxon idref="Oplodontha_446504" spec="Taxon"/>
#                         <taxon idref="Neopachygaster_1692469" spec="Taxon"/>
#                         <taxon idref="Borophaga_712093" spec="Taxon"/>
#                         <taxon idref="Sciadocera_192453" spec="Taxon"/>
#                         <taxon idref="Apiocera_160270" spec="Taxon"/>
#                         <taxon idref="Ptecticus_343648" spec="Taxon"/>
#                         <taxon idref="Heterocheila_169481" spec="Taxon"/>
#                         <taxon idref="Berkshiria_2061012" spec="Taxon"/>
#                         <taxon idref="Hermetia_343581" spec="Taxon"/>
#                         <taxon idref="Neossos_2268121" spec="Taxon"/>
#                         <taxon idref="Pachygaster_124321" spec="Taxon"/>
#                         <taxon idref="Microchrysa_931517" spec="Taxon"/>
#                         <taxon idref="Teratomyzidae" spec="Taxon"/>
#                         <taxon idref="Stratiomys_219520" spec="Taxon"/>
#                         <taxon idref="Bittacomorpha_79307" spec="Taxon"/>
#                         <taxon idref="Lutzomyia_7199" spec="Taxon"/>
#                         <taxon idref="Sycorax_114592" spec="Taxon"/>
#                         <taxon idref="Clogmia_85119" spec="Taxon"/>
#                         <taxon idref="Maruina_1144738" spec="Taxon"/>
#                         <taxon idref="Psychoda_7201" spec="Taxon"/>
#                         <taxon idref="Trichomyia_560271" spec="Taxon"/>
#                         <taxon idref="Ptychoptera_209691" spec="Taxon"/>
#                         <taxon idref="Phlebotomus_13203" spec="Taxon"/>
#                         <taxon idref="Pericoma_1148481" spec="Taxon"/>
#                     </taxonset>
#                 </distribution>
#                 <distribution id="Node_0.prior" spec="beastlabs.math.distributions.MRCAPriorWithRogues" monophyletic="true" tree="@Tree.t:mito_nonprotcoding">
#                     <taxonset id="Node_0" spec="TaxonSet">
#                         <taxon idref="Trichocera_52759" spec="Taxon"/>
#                         <taxon idref="Dicranota_700836" spec="Taxon"/>
#                         <taxon idref="Pedicia_472374" spec="Taxon"/>
#                         <taxon idref="Liogma_560731" spec="Taxon"/>
#                         <taxon idref="Phalacrocera_2203737" spec="Taxon"/>
#                         <taxon idref="Cylindrotoma_700834" spec="Taxon"/>
#                         <taxon idref="Tipula_41043" spec="Taxon"/>
#                         <taxon idref="Dictenidia_2108369" spec="Taxon"/>
#                         <taxon idref="Limonia_52743" spec="Taxon"/>
#                         <taxon idref="Prionocera_1690388" spec="Taxon"/>
#                         <taxon idref="Gnophomyia_700845" spec="Taxon"/>
#                         <taxon idref="Ctenophora_516519" spec="Taxon"/>
#                         <taxon idref="Tanyptera_2108371" spec="Taxon"/>
#                         <taxon idref="Metalimnobia_700851" spec="Taxon"/>
#                         <taxon idref="Dactylolabis_560717" spec="Taxon"/>
#                         <taxon idref="Antocha_454619" spec="Taxon"/>
#                         <taxon idref="Liponeura_446516" spec="Taxon"/>
#                         <taxon idref="Blepharicera_547808" spec="Taxon"/>
#                         <taxon idref="Mischoderus_560267" spec="Taxon"/>
#                         <taxon idref="Araucoderus_1549737" spec="Taxon"/>
#                         <taxon idref="Protoplasa_560776" spec="Taxon"/>
#                         <taxon idref="Sphaeromias_1874311" spec="Taxon"/>
#                         <taxon idref="Palpomyia_1525500" spec="Taxon"/>
#                         <taxon idref="Austroconops_209696" spec="Taxon"/>
#                         <taxon idref="Culicoides_41820" spec="Taxon"/>
#                         <taxon idref="Serromyia_209716" spec="Taxon"/>
#                         <taxon idref="Forcipomyia_209700" spec="Taxon"/>
#                         <taxon idref="Dasyhelea_41822" spec="Taxon"/>
#                         <taxon idref="Atrichopogon_209702" spec="Taxon"/>
#                         <taxon idref="Ainuyusurika_1165747" spec="Taxon"/>
#                         <taxon idref="Pentaneura_891922" spec="Taxon"/>
#                         <taxon idref="Metriocnemus_137497" spec="Taxon"/>
#                         <taxon idref="Eukiefferiella_288843" spec="Taxon"/>
#                         <taxon idref="Parochlus_315560" spec="Taxon"/>
#                         <taxon idref="Pseudosmittia_611382" spec="Taxon"/>
#                         <taxon idref="Tvetenia_611398" spec="Taxon"/>
#                         <taxon idref="Paucispinigera_903463" spec="Taxon"/>
#                         <taxon idref="Paraborniella_903459" spec="Taxon"/>
#                         <taxon idref="Smittia_315559" spec="Taxon"/>
#                         <taxon idref="Monodiamesa_891905" spec="Taxon"/>
#                         <taxon idref="Chironomus_7150" spec="Taxon"/>
#                         <taxon idref="Clunio_315556" spec="Taxon"/>
#                         <taxon idref="Aphroteniella_646259" spec="Taxon"/>
#                         <taxon idref="Gymnometriocnemus_611353" spec="Taxon"/>
#                         <taxon idref="Corynoneura_611344" spec="Taxon"/>
#                         <taxon idref="Ablabesmyia_46216" spec="Taxon"/>
#                         <taxon idref="Psectrotanypus_903467" spec="Taxon"/>
#                         <taxon idref="Androprosopa_41815" spec="Taxon"/>
#                         <taxon idref="Austrothaumalea_1085085" spec="Taxon"/>
#                         <taxon idref="Thaumalea_61068" spec="Taxon"/>
#                         <taxon idref="Dixa_79309" spec="Taxon"/>
#                         <taxon idref="Mochlonyx_1577622" spec="Taxon"/>
#                         <taxon idref="Chaoborus_41812" spec="Taxon"/>
#                         <taxon idref="Anopheles_7164" spec="Taxon"/>
#                         <taxon idref="Culex_7174" spec="Taxon"/>
#                         <taxon idref="Culiseta_174825" spec="Taxon"/>
#                         <taxon idref="Aedes_7158" spec="Taxon"/>
#                         <taxon idref="Simulium_7191" spec="Taxon"/>
#                         <taxon idref="Scatopse_1520324" spec="Taxon"/>
#                         <taxon idref="Coboldia_170624" spec="Taxon"/>
#                         <taxon idref="Axymyia_560715" spec="Taxon"/>
#                         <taxon idref="Dilophus_52733" spec="Taxon"/>
#                         <taxon idref="Plecia_1260898" spec="Taxon"/>
#                         <taxon idref="Bibio_189978" spec="Taxon"/>
#                         <taxon idref="Pachyneura_1588165" spec="Taxon"/>
#                         <taxon idref="Cramptonomyia_209688" spec="Taxon"/>
#                         <taxon idref="Diadocidia_560721" spec="Taxon"/>
#                         <taxon idref="Orfelia_270890" spec="Taxon"/>
#                         <taxon idref="Macrocera_608727" spec="Taxon"/>
#                         <taxon idref="Sciara_82677" spec="Taxon"/>
#                         <taxon idref="Pnyxia_1781626" spec="Taxon"/>
#                         <taxon idref="Corynoptera_1260849" spec="Taxon"/>
#                         <taxon idref="Bradysia_35571" spec="Taxon"/>
#                         <taxon idref="Contarinia_153220" spec="Taxon"/>
#                         <taxon idref="Sitodiplosis_263139" spec="Taxon"/>
#                         <taxon idref="Aprionus_1819779" spec="Taxon"/>
#                         <taxon idref="Piceacecis_2597495" spec="Taxon"/>
#                         <taxon idref="Lasioptera_201413" spec="Taxon"/>
#                         <taxon idref="Peromyia_1914937" spec="Taxon"/>
#                         <taxon idref="Cecidomyia_1543682" spec="Taxon"/>
#                         <taxon idref="Dasineura_240745" spec="Taxon"/>
#                         <taxon idref="Asphondylia_153012" spec="Taxon"/>
#                         <taxon idref="Winnertzia_2338641" spec="Taxon"/>
#                         <taxon idref="Aphidoletes_95971" spec="Taxon"/>
#                         <taxon idref="Brachypeza_2326774" spec="Taxon"/>
#                         <taxon idref="Trichonta_397122" spec="Taxon"/>
#                         <taxon idref="Mycetophila_397146" spec="Taxon"/>
#                         <taxon idref="Neoempheria_608686" spec="Taxon"/>
#                         <taxon idref="Symmerus_560780" spec="Taxon"/>
#                         <taxon idref="Mycomya_608706" spec="Taxon"/>
#                         <taxon idref="Sciophila_1085959" spec="Taxon"/>
#                         <taxon idref="Phronia_397119" spec="Taxon"/>
#                         <taxon idref="Exechia_397139" spec="Taxon"/>
#                         <taxon idref="Epicypta_397117" spec="Taxon"/>
#                         <taxon idref="Leptomorphus_560729" spec="Taxon"/>
#                         <taxon idref="Ditomyia_1520322" spec="Taxon"/>
#                         <taxon idref="Bolitophila_52718" spec="Taxon"/>
#                         <taxon idref="Hesperinus_1086788" spec="Taxon"/>
#                         <taxon idref="Penthetria_560770" spec="Taxon"/>
#                         <taxon idref="Paraplatypeza_192442" spec="Taxon"/>
#                         <taxon idref="Bertamyia_1445832" spec="Taxon"/>
#                         <taxon idref="Callomyia_712098" spec="Taxon"/>
#                         <taxon idref="Kesselimyia_1445844" spec="Taxon"/>
#                         <taxon idref="Agathomyia_226141" spec="Taxon"/>
#                         <taxon idref="Polyporivora_1445854" spec="Taxon"/>
#                         <taxon idref="Platypeza_289241" spec="Taxon"/>
#                         <taxon idref="Chamaemyia_305621" spec="Taxon"/>
#                         <taxon idref="Leucopis_1728826" spec="Taxon"/>
#                         <taxon idref="Parochthiphila_1262282" spec="Taxon"/>
#                         <taxon idref="Coelopa_169466" spec="Taxon"/>
#                         <taxon idref="Helcomyza_169476" spec="Taxon"/>
#                         <taxon idref="Homoneura_1692452" spec="Taxon"/>
#                         <taxon idref="Tricholauxania_192459" spec="Taxon"/>
#                         <taxon idref="Aulogastromyia_1824990" spec="Taxon"/>
#                         <taxon idref="Pteromicra_1226622" spec="Taxon"/>
#                         <taxon idref="Dictya_1096051" spec="Taxon"/>
#                         <taxon idref="Elgiva_320938" spec="Taxon"/>
#                         <taxon idref="Sepedon_320954" spec="Taxon"/>
#                         <taxon idref="Neolimnia_1262312" spec="Taxon"/>
#                         <taxon idref="Sciomyza_320936" spec="Taxon"/>
#                         <taxon idref="Ilione_1096072" spec="Taxon"/>
#                         <taxon idref="Psacadina_1096078" spec="Taxon"/>
#                         <taxon idref="Tetanocera_320959" spec="Taxon"/>
#                         <taxon idref="Hedria_320941" spec="Taxon"/>
#                         <taxon idref="Coremacera_1226614" spec="Taxon"/>
#                         <taxon idref="Anticheta_1096047" spec="Taxon"/>
#                         <taxon idref="Pelidnoptera_1096074" spec="Taxon"/>
#                         <taxon idref="Celyphus_1979294" spec="Taxon"/>
#                         <taxon idref="Spaniocelyphus_1262326" spec="Taxon"/>
#                         <taxon idref="Copromyza_1217530" spec="Taxon"/>
#                         <taxon idref="Leptocera_1614654" spec="Taxon"/>
#                         <taxon idref="Mimegralla_115300" spec="Taxon"/>
#                         <taxon idref="Compsobata_286452" spec="Taxon"/>
#                         <taxon idref="Calobata_1820059" spec="Taxon"/>
#                         <taxon idref="Micropeza_1572561" spec="Taxon"/>
#                         <taxon idref="Telostylinus_1262347" spec="Taxon"/>
#                         <taxon idref="Odontoloxozus_588320" spec="Taxon"/>
#                         <taxon idref="Lasiopiophila_1790233" spec="Taxon"/>
#                         <taxon idref="Piophila_53709" spec="Taxon"/>
#                         <taxon idref="Centrophlebomyia_1603419" spec="Taxon"/>
#                         <taxon idref="Liopiophila_1603421" spec="Taxon"/>
#                         <taxon idref="Delphinia_43369" spec="Taxon"/>
#                         <taxon idref="Chaetopsis_240871" spec="Taxon"/>
#                         <taxon idref="Tetanops_454640" spec="Taxon"/>
#                         <taxon idref="Euxesta_286468" spec="Taxon"/>
#                         <taxon idref="Eurosta_28593" spec="Taxon"/>
#                         <taxon idref="Anastrepha_28585" spec="Taxon"/>
#                         <taxon idref="Euleia_28591" spec="Taxon"/>
#                         <taxon idref="Terellia_28615" spec="Taxon"/>
#                         <taxon idref="Paracantha_164885" spec="Taxon"/>
#                         <taxon idref="Tephritis_43386" spec="Taxon"/>
#                         <taxon idref="Urophora_28620" spec="Taxon"/>
#                         <taxon idref="Gymnocarena_28597" spec="Taxon"/>
#                         <taxon idref="Jamesomyia_28601" spec="Taxon"/>
#                         <taxon idref="Oxyna_381365" spec="Taxon"/>
#                         <taxon idref="Trupanea_30060" spec="Taxon"/>
#                         <taxon idref="Rhagoletis_28609" spec="Taxon"/>
#                         <taxon idref="Noeeta_381362" spec="Taxon"/>
#                         <taxon idref="Ceratitis_7212" spec="Taxon"/>
#                         <taxon idref="Zonosemata_28622" spec="Taxon"/>
#                         <taxon idref="Bactrocera_27456" spec="Taxon"/>
#                         <taxon idref="Xyphosia_381372" spec="Taxon"/>
#                         <taxon idref="Icterica_28599" spec="Taxon"/>
#                         <taxon idref="Lamprolonchaea_907706" spec="Taxon"/>
# ...
#                         <taxon idref="Blondelia_179437" spec="Taxon"/>
#                         <taxon idref="Phronia_397119" spec="Taxon"/>
#                         <taxon idref="Incertella_540867" spec="Taxon"/>
#                         <taxon idref="Wiedemannia_240904" spec="Taxon"/>
#                         <taxon idref="Melanophora_1606787" spec="Taxon"/>
#                         <taxon idref="Hydromyza_113174" spec="Taxon"/>
#                         <taxon idref="Teratomyzidae" spec="Taxon"/>
#                         <taxon idref="Exeretonevra_560723" spec="Taxon"/>
#                         <taxon idref="Stratiomys_219520" spec="Taxon"/>
#                         <taxon idref="Syrphus_224255" spec="Taxon"/>
#                         <taxon idref="Nemotelus_343582" spec="Taxon"/>
#                         <taxon idref="Oxycera_860348" spec="Taxon"/>
#                         <taxon idref="Trupanea_30060" spec="Taxon"/>
#                         <taxon idref="Exechia_397139" spec="Taxon"/>
#                         <taxon idref="Penicillidia_81721" spec="Taxon"/>
#                         <taxon idref="Callicera_228567" spec="Taxon"/>
#                         <taxon idref="Homoneura_1692452" spec="Taxon"/>
#                         <taxon idref="Fergusonina_156411" spec="Taxon"/>
#                         <taxon idref="Aphanotrigonum_540849" spec="Taxon"/>
#                         <taxon idref="Hydrellia_92591" spec="Taxon"/>
#                         <taxon idref="Peromyia_1914937" spec="Taxon"/>
#                         <taxon idref="Piophila_53709" spec="Taxon"/>
#                         <taxon idref="Spaniocelyphus_1262326" spec="Taxon"/>
#                         <taxon idref="Temnostoma_226164" spec="Taxon"/>
#                         <taxon idref="Anticheta_1096047" spec="Taxon"/>
#                         <taxon idref="Dilophus_52733" spec="Taxon"/>
#                         <taxon idref="Parasetigena_380521" spec="Taxon"/>
#                         <taxon idref="Symmerus_560780" spec="Taxon"/>
#                         <taxon idref="Leucopis_1728826" spec="Taxon"/>
#                         <taxon idref="Bradysia_35571" spec="Taxon"/>
#                         <taxon idref="Tricimba_540889" spec="Taxon"/>
#                         <taxon idref="Copromyza_1217530" spec="Taxon"/>
#                         <taxon idref="Pipiza_221788" spec="Taxon"/>
#                         <taxon idref="Parochthiphila_1262282" spec="Taxon"/>
#                         <taxon idref="Aprionus_1819779" spec="Taxon"/>
#                         <taxon idref="Cordilura_113132" spec="Taxon"/>
#                         <taxon idref="Zabrachia_1891525" spec="Taxon"/>
#                         <taxon idref="Japanagromyza_414298" spec="Taxon"/>
#                         <taxon idref="Sarconesia_670650" spec="Taxon"/>
#                         <taxon idref="Hebecnema_559682" spec="Taxon"/>
#                         <taxon idref="Blaesoxipha_128953" spec="Taxon"/>
#                         <taxon idref="Pachyneura_1588165" spec="Taxon"/>
#                         <taxon idref="Cetema_540891" spec="Taxon"/>
#                         <taxon idref="Musca_7369" spec="Taxon"/>
#                         <taxon idref="Odontoloxozus_588320" spec="Taxon"/>
#                         <taxon idref="Ligyra_117088" spec="Taxon"/>
#                         <taxon idref="Tetanocera_320959" spec="Taxon"/>
#                         <taxon idref="Lonchaea_198649" spec="Taxon"/>
#                         <taxon idref="Contarinia_153220" spec="Taxon"/>
#                         <taxon idref="Epistrophe_414810" spec="Taxon"/>
#                         <taxon idref="Neopachygaster_1692469" spec="Taxon"/>
#                         <taxon idref="Fucellia_205683" spec="Taxon"/>
#                         <taxon idref="Noeeta_381362" spec="Taxon"/>
#                         <taxon idref="Ocyptamus_369855" spec="Taxon"/>
#                         <taxon idref="Clusia_574057" spec="Taxon"/>
#                         <taxon idref="Hermetia_343581" spec="Taxon"/>
#                         <taxon idref="Sphyracephala_139674" spec="Taxon"/>
#                         <taxon idref="Clusiodes_500306" spec="Taxon"/>
#                         <taxon idref="Elgiva_320938" spec="Taxon"/>
#                         <taxon idref="Euleia_28591" spec="Taxon"/>
#                         <taxon idref="Copestylum_511142" spec="Taxon"/>
#                         <taxon idref="Acemya_1677647" spec="Taxon"/>
#                         <taxon idref="Cheilosia_173981" spec="Taxon"/>
#                         <taxon idref="Haematopota_124311" spec="Taxon"/>
#                         <taxon idref="Agromyza_414290" spec="Taxon"/>
#                         <taxon idref="Hybomitra_124690" spec="Taxon"/>
#                         <taxon idref="Microdon_115291" spec="Taxon"/>
#                         <taxon idref="Esenbeckia_124297" spec="Taxon"/>
#                         <taxon idref="Tanypeza_1692486" spec="Taxon"/>
#                         <taxon idref="Ditomyia_1520322" spec="Taxon"/>
#                         <taxon idref="Billaea_701468" spec="Taxon"/>
#                         <taxon idref="Anastrepha_28585" spec="Taxon"/>
#                         <taxon idref="Pteromicra_1226622" spec="Taxon"/>
#                         <taxon idref="Atherix_124299" spec="Taxon"/>
#                         <taxon idref="Philornis_253427" spec="Taxon"/>
#                         <taxon idref="Sarcophaga_7384" spec="Taxon"/>
#                         <taxon idref="Winnertzia_2338641" spec="Taxon"/>
#                         <taxon idref="Lonchoptera_92595" spec="Taxon"/>
#                         <taxon idref="Chymomyza_7292" spec="Taxon"/>
#                         <taxon idref="Pseudoperichaeta_283931" spec="Taxon"/>
#                         <taxon idref="Stenotabanus_1547430" spec="Taxon"/>
#                         <taxon idref="Tephritis_43386" spec="Taxon"/>
#                         <taxon idref="Telostylinus_1262347" spec="Taxon"/>
#                         <taxon idref="Dictya_1096051" spec="Taxon"/>
#                         <taxon idref="Volucella_226148" spec="Taxon"/>
#                         <taxon idref="Eristalis_198633" spec="Taxon"/>
#                         <taxon idref="Rhaphium_377528" spec="Taxon"/>
#                         <taxon idref="Thereva_95078" spec="Taxon"/>
#                         <taxon idref="Xyphosia_381372" spec="Taxon"/>
#                         <taxon idref="Pnyxia_1781626" spec="Taxon"/>
#                         <taxon idref="Calliphora_7372" spec="Taxon"/>
#                         <taxon idref="Eumerus_224220" spec="Taxon"/>
#                         <taxon idref="Brachypeza_2326774" spec="Taxon"/>
#                         <taxon idref="Sepsis_137507" spec="Taxon"/>
#                         <taxon idref="Milichiella_1890919" spec="Taxon"/>
#                         <taxon idref="Syritta_34681" spec="Taxon"/>
#                         <taxon idref="Trichonta_397122" spec="Taxon"/>
#                         <taxon idref="Basilia_170889" spec="Taxon"/>
#                         <taxon idref="Morellia_253340" spec="Taxon"/>
#                         <taxon idref="Phaonia_253431" spec="Taxon"/>
#                         <taxon idref="Borophaga_712093" spec="Taxon"/>
#                         <taxon idref="Amenia_2086281" spec="Taxon"/>
#                         <taxon idref="Zonosemata_28622" spec="Taxon"/>
#                         <taxon idref="Metachela_369884" spec="Taxon"/>
#                         <taxon idref="Ornithophila_1497392" spec="Taxon"/>
#                         <taxon idref="Phryxe_569079" spec="Taxon"/>
#                         <taxon idref="Neomyia_305607" spec="Taxon"/>
#                         <taxon idref="Protocalliphora_142901" spec="Taxon"/>
#                         <taxon idref="Delphinia_43369" spec="Taxon"/>
#                         <taxon idref="Agathomyia_226141" spec="Taxon"/>
#                         <taxon idref="Neoplasta_192640" spec="Taxon"/>
#                         <taxon idref="Chiastocheta_129251" spec="Taxon"/>
#                         <taxon idref="Thecophora_305546" spec="Taxon"/>
#                         <taxon idref="Macquartia_1918266" spec="Taxon"/>
#                         <taxon idref="Periscelis_716628" spec="Taxon"/>
#                         <taxon idref="Neorhynchocephalus_259248" spec="Taxon"/>
#                         <taxon idref="Hedria_320941" spec="Taxon"/>
#                         <taxon idref="Pholeomyia_1720804" spec="Taxon"/>
#                         <taxon idref="Aphidoletes_95971" spec="Taxon"/>
#                         <taxon idref="Gaurax_540862" spec="Taxon"/>
#                         <taxon idref="Stegana_188292" spec="Taxon"/>
#                         <taxon idref="Leucotabanus_1969939" spec="Taxon"/>
#                         <taxon idref="Promachus_247552" spec="Taxon"/>
#                         <taxon idref="Exetasis_1932988" spec="Taxon"/>
#                         <taxon idref="Olfersia_1333310" spec="Taxon"/>
#                         <taxon idref="Zodion_768804" spec="Taxon"/>
#                         <taxon idref="Helosciomyzidae" spec="Taxon"/>
#                         <taxon idref="Rhamphomyia_192612" spec="Taxon"/>
#                         <taxon idref="Leschenaultia_179486" spec="Taxon"/>
#                         <taxon idref="Compsomyiops_142897" spec="Taxon"/>
#                         <taxon idref="Lasiomma_95464" spec="Taxon"/>
#                         <taxon idref="Dryomyza_169444" spec="Taxon"/>
#                         <taxon idref="Atylotus_1310336" spec="Taxon"/>
#                         <taxon idref="Scatella_305595" spec="Taxon"/>
#                         <taxon idref="Dioctria_468720" spec="Taxon"/>
#                         <taxon idref="Elachiptera_540858" spec="Taxon"/>
#                         <taxon idref="Verrallia_115333" spec="Taxon"/>
#                         <taxon idref="Mintho_1918277" spec="Taxon"/>
#                         <taxon idref="Tetanops_454640" spec="Taxon"/>
#                         <taxon idref="Chloromyia_343649" spec="Taxon"/>
#                         <taxon idref="Cryptonevra_1616778" spec="Taxon"/>
#                         <taxon idref="Leptocera_1614654" spec="Taxon"/>
#                         <taxon idref="Chaetopsis_240871" spec="Taxon"/>
#                         <taxon idref="Mycomya_608706" spec="Taxon"/>
#                         <taxon idref="Melophagus_452748" spec="Taxon"/>
#                         <taxon idref="Glaurocara_2027854" spec="Taxon"/>
#                         <taxon idref="Pelina_1086796" spec="Taxon"/>
#                         <taxon idref="Mycetophila_397146" spec="Taxon"/>
#                         <taxon idref="Ogcodes_188257" spec="Taxon"/>
#                         <taxon idref="Delia_30063" spec="Taxon"/>
#                         <taxon idref="Aulogastromyia_1824990" spec="Taxon"/>
#                         <taxon idref="Cacoxenus_462273" spec="Taxon"/>
#                         <taxon idref="Hylemya_253328" spec="Taxon"/>
#                         <taxon idref="Mimegralla_115300" spec="Taxon"/>
#                         <taxon idref="Heterocheila_169481" spec="Taxon"/>
#                         <taxon idref="Berkshiria_2061012" spec="Taxon"/>
#                         <taxon idref="Platypeza_289241" spec="Taxon"/>
#                         <taxon idref="Limnophora_307207" spec="Taxon"/>
#                         <taxon idref="Cephenemyia_170894" spec="Taxon"/>
#                         <taxon idref="Chalarus_115250" spec="Taxon"/>
#                         <taxon idref="Silba_198646" spec="Taxon"/>
#                         <taxon idref="Mesembrinella_460529" spec="Taxon"/>
#                         <taxon idref="Stenomicra_716630" spec="Taxon"/>
#                         <taxon idref="Pachygaster_124321" spec="Taxon"/>
#                         <taxon idref="Quametopia_1603285" spec="Taxon"/>
#                         <taxon idref="Chelifera_369889" spec="Taxon"/>
#                         <taxon idref="Trypocalliphora_1042207" spec="Taxon"/>
#                         <taxon idref="Jamesomyia_28601" spec="Taxon"/>
#                         <taxon idref="Bertamyia_1445832" spec="Taxon"/>
#                         <taxon idref="Mallophora_270862" spec="Taxon"/>
#                         <taxon idref="Leptometopa_1720790" spec="Taxon"/>
#                         <taxon idref="Apatolestes_428062" spec="Taxon"/>
#                         <taxon idref="Drino_179459" spec="Taxon"/>
#                         <taxon idref="Triphleba_92553" spec="Taxon"/>
#                         <taxon idref="Philonicus_247567" spec="Taxon"/>
#                         <taxon idref="Cecidomyia_1543682" spec="Taxon"/>
#                         <taxon idref="Melanagromyza_286470" spec="Taxon"/>
#                         <taxon idref="Anthrax_117078" spec="Taxon"/>
#                         <taxon idref="Clausicella_1718822" spec="Taxon"/>
#                         <taxon idref="Sobarocephala_574054" spec="Taxon"/>
#                         <taxon idref="Tricogena_1606792" spec="Taxon"/>
#                         <taxon idref="Desmometopa_305587" spec="Taxon"/>
#                         <taxon idref="Cryptochetum_1262333" spec="Taxon"/>
#                         <taxon idref="Euxesta_286468" spec="Taxon"/>
#                         <taxon idref="Huascaromusca_1609532" spec="Taxon"/>
#                         <taxon idref="Mydas_186100" spec="Taxon"/>
#                         <taxon idref="Fidena_1334907" spec="Taxon"/>
#                         <taxon idref="Paregle_559693" spec="Taxon"/>
#                         <taxon idref="Neolimnia_1262312" spec="Taxon"/>
#                         <taxon idref="Bolitophila_52718" spec="Taxon"/>
#                         <taxon idref="Vibrissina_179525" spec="Taxon"/>
#                         <taxon idref="Cerodontha_127401" spec="Taxon"/>
#                         <taxon idref="Axymyia_560715" spec="Taxon"/>
#                         <taxon idref="Sphecapatodes_2021536" spec="Taxon"/>
#                         <taxon idref="Atherigona_305597" spec="Taxon"/>
#                         <taxon idref="Rhinoestrus_204922" spec="Taxon"/>
#                         <taxon idref="Oxyna_381365" spec="Taxon"/>
#                         <taxon idref="Paykullia_559695" spec="Taxon"/>
#                         <taxon idref="Pollenia_229639" spec="Taxon"/>
#                         <taxon idref="Anevrina_92526" spec="Taxon"/>
#                         <taxon idref="Polietes_559702" spec="Taxon"/>
#                         <taxon idref="Hirmoneura_388531" spec="Taxon"/>
#                         <taxon idref="Crataerina_452743" spec="Taxon"/>
#                         <taxon idref="Chlorops_540892" spec="Taxon"/>
#                         <taxon idref="Goniops_428065" spec="Taxon"/>
#                         <taxon idref="Coenomyia_124305" spec="Taxon"/>
#                         <taxon idref="Cleigastra_113167" spec="Taxon"/>
#                         <taxon idref="Sicus_1219203" spec="Taxon"/>
#                         <taxon idref="Acletoxenus_462271" spec="Taxon"/>
#                         <taxon idref="Scaeva_219538" spec="Taxon"/>
#                         <taxon idref="Eginia_1511678" spec="Taxon"/>
#                         <taxon idref="Craticulina_2021509" spec="Taxon"/>
#                         <taxon idref="Scathophaga_95462" spec="Taxon"/>
#                         <taxon idref="Eulonchus_210230" spec="Taxon"/>
#                         <taxon idref="Icterica_28599" spec="Taxon"/>
#                         <taxon idref="Cordylobia_226131" spec="Taxon"/>
#                         <taxon idref="Apiocera_160270" spec="Taxon"/>
#                         <taxon idref="Archytas_198637" spec="Taxon"/>
#                         <taxon idref="Wohlfahrtia_128961" spec="Taxon"/>
#                         <taxon idref="Chrysogaster_224248" spec="Taxon"/>
#                         <taxon idref="Themira_292396" spec="Taxon"/>
#                         <taxon idref="Machimus_247604" spec="Taxon"/>
#                         <taxon idref="Eurosta_28593" spec="Taxon"/>
#                     </rogues>
#                 </distribution>
