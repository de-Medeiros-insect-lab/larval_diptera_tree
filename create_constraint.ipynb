# %% [markdown]
# # Create a constraint tree
#
# In this notebook, we will create a family-level constraint tree to use in a BEAST2 analysis of Diptera genera for which we have both molecular data and larval phenotypes scored.
#
# Previously, we obtained a dataset with several Diptera genus names with larval data, and used matrix condenser to parse these names and obtain NCBI IDs.
#
# We then used phylotaR to obtain a molecular dataset for these genera, finding that there are 6 genes with a good representation among them. Later we completed the phylotaR dataset with manually downloaded data for additional genera not present initially.
#
# We also downloaded constraint trees from supplementary data available in relevant publications. These encompass both an all-Diptera tree and several robust and more recent trees for less inclusive taxa.
#
# We now need to accomplish the following tasks to infer a phylogeny:
#
# 1. Obtain a constraint tree for all of the genera included in our alingments
#   * Use dendropy to extract tip names in all published phylogenies
#   * Create chatGPT prompts
#   * Use chatGPT to parse these tip names and extract structured taxonomic data
#   * Run TaxReformer to get additional information about these names
#   * Rename all tips to family level according to the most recent taxonomy
#   * Prune the large all-Diptera tree at higher levels (e. g. superfamily) when a better tree is available for those taxa
#   * Graft the better trees in place
#   * Collapse all familes to single tips
#   * Graft all genera tips to the correct family, making sure names match our alingments
#
# 2. Use this constraint tree to produce soft constraints for BEAST2. We will use this together with a list of hard monophyletic constraints including groups well-supported in the literature.

# %% [markdown]
# ## Get taxonomic data for tips
#
# ### Use dendropy yo extract tip names
#
# Here we will open all of our constraint tree sources and use dendropy to extract tip names.

# %%
import dendropy, numpy as np, copy
from pathlib import Path
from collections import defaultdict, Counter

# Initialize an empty list to store the tip names in their original order
tip_names = []

# Specify your directory
directory = Path("./constraint_trees")

# Define the list of schemas we'll try for each file
schemas = ['newick', 'nexus']

files = ['Bayless2022_Analysis6_64taxa1130aa_132mp_roguesremoved.tre',
         'Buenaventura2020_oest_50per_RAxML.tre',
         'Shin2018_RAxML_bipartitions.1000BT_data_v.tree',
         'Shin2018_RAxML_bipartitions.100BT_data_v.tree',
         'Winkler2022_ephy_aa.tre',
         'Wiegmann2011_pg_437.nex']

# Go through each file in the directory
for file in files:
    # Check if the file is a phylogenetic tree (e.g., in Newick or Nexus format)
    # Try to load the tree with each schema
    for schema in schemas:
        try:
            tree = dendropy.Tree.get(
                path=str(directory/file),
                schema=schema,
                preserve_underscores=True
            )

            # If we get here, it means the tree was loaded successfully.
            # We can break the loop over schemas.
            break
        except Exception as e:
            pass

    else:
        # If we get here, it means all schemas failed. We skip this file.
        print(f"Skipping {file} as no schema could load it.")
        continue

    # Replace spaces in taxon names with underscores
    for taxon in tree.taxon_namespace:
        taxon.label = taxon.label.replace(" ", "_")

    print(file)

    # Add the names of all the leaf nodes (tips) to the list, preserving original order
    # and avoiding duplicates
    tree.print_plot()
    for leaf in tree.leaf_node_iter():
        if leaf.taxon.label not in tip_names:
            tip_names.append(leaf.taxon.label)
# Out:
# Bayless2022_Analysis6_64taxa1130aa_132mp_roguesremoved.tre
# /--------------------------------------------------- Glossina_morsitans
# |
# |                                /------------------ Mesembrina_meridiana
# |                                |
# |  /-----------------------------+   /-------------- Cordilura
# |  |                             |   |
# |  |                             |   |          /--- Triarthria_setipennis
# |  |                             \---+      /---+
# |  |                                 |      |   \--- Pollenia
# |  |                                 |  /---+
# |  |                                 |  |   |   /--- Stomorhina_subapicalis
# |  |                                 \--+   \---+
# |  |                                    |       \--- Calliphora_vomitoria
# |  |                                    |
# |  |                                    \----------- Sarcophaga_bullata
# |  |
# |  |                                            /--- Derocephalus_angusticollis
# |  |                             /--------------+
# |  |                             |              \--- Micropeza_corrigiolata
# |  |                             |
# |  |                             |              /--- Ceratitis_capitata
# |  |              /--------------+          /---+
# |  |              |              |   /------+   \--- Zacompsia_fulva
# |  |              |              |   |      |
# |  |              |              |   |      \------- Piophila_australis
# |  |              |              |   |
# |  |              |              \---+      /------- Strongylophthalmyia
# |  |              |                  |  /---+
# |  |              |                  |  |   |   /--- Meroplius_fasciculatus
# |  |              |                  |  |   \---+
# |  |              |                  \--+       \--- Acartophthalmus_nigrinus
# |  |              |                     |
# |  |              |                     |       /--- Loxocera_cylindrica
# |  |              |                     \-------+
# |  |              |                             \--- Opomyza_germinationis
# |  |              |
# |  |              |                             /--- Archimicrodon_brachycerus
# |  |              |              /--------------+
# |  |              |              |              \--- Eristalis_pertinax
# |  |              |              |
# |  |              |          /---+          /------- Lonchoptera_bifurcata
# |  |          /---+          |   |   /------+
# |  |          |   |          |   |   |      |   /--- Megaselia_abdita
# |  |          |   |          |   |   |      \---+
# |  |          |   |          |   \---+          \--- Platypeza_anthrax
# |  |          |   |          |       |
# |  |          |   |          |       |  /----------- Meghyperus
# |--+          |   |       /--+       \--+
# |  |          |   |       |  |          |   /------- Hilarini
# |  |          |   |       |  |          \---+
# |  |          |   |       |  |              |   /--- Stilpon_pauciseta
# |  |          |   |       |  |              \---+
# |  |          |   |       |  |                  \--- Heteropsilopus_ingenuus
# |  |          |   |   /---+  |
# |  |          |   |   |   |  \---------------------- Nephrocerus_atrapilus
# |  |          |   |   |   |
# |  |          |   |   |   |                     /--- Pseudodinia_antennalis
# |  |          |   |   |   |          /----------+
# |  |          |   |   |   |          |          \--- Stylogaster
# |  |          |   |   |   |          |
# |  |       /--+   |   |   \----------+          /--- Helcomyza_mirabilis
# |  |       |  |   |   |              |  /-------+
# |  |       |  |   \---+              |  |       \--- Coelopa_frigida
# +  |       |  |       |              \--+
# |  |       |  |       |                 |   /------- Sapromyza_sciomyzina
# |  |       |  |       |                 \---+
# |  |       |  |       |                     |   /--- Limnia_unguicornis
# |  |       |  |       |                     \---+
# |  |       |  |       |                         \--- Myopa
# |  |       |  |       |
# |  |       |  |       |                         /--- Leptocera_erythrocera
# |  |       |  |       |                     /---+
# |  |       |  |       \---------------------+   \--- Diplogeomyza_tridens
# |  |       |  |                             |
# |  |       |  |                             \------- Tapeigaster_digitata
# |  |       |  |
# |  |   /---+  |                                 /--- Syringogaster_plesioterga
# |  |   |   |  |                         /-------+
# |  |   |   |  |                         |       \--- Teleopsis_dalmanni
# |  |   |   |  |                         |
# |  |   |   |  \-------------------------+       /--- Leiomyza_laevigata
# |  |   |   |                            |   /---+
# |  |   |   |                            |   |   \--- Mumetopia_occipitalis
# |  |   |   |                            \---+
# |  |   |   |                                |   /--- Australimyza_mcalpinei
# |  |   |   |                                \---+
# |  |   |   |                                    \--- Dasyrhicnoessa_insularis
# |  |   |   |
# |  |   |   |                                    /--- Nemo_dayi
# |  |   |   |                         /----------+
# |  |   |   |                         |          \--- Lipara_lucens
# |  \---+   |                         |
# |      |   \-------------------------+          /--- Scutops
# |      |                             |  /-------+
# |      |                             |  |       \--- Aulacigaster_mcalpinei
# |      |                             |  |
# |      |                             \--+       /--- Fergusonina_omlandi
# |      |                                |   /---+
# |      |                                |   |   \--- Carnus_hemapterus
# |      |                                \---+
# |      |                                    |   /--- Odinia_conspicua
# |      |                                    \---+
# |      |                                        \--- Melanagromyza
# |      |
# |      |                  /------------------------- Scatella_tenuicosta
# |      |                  |
# |      |                  |                     /--- Curtonotum
# |      \------------------+  /------------------+
# |                         |  |                  \--- Diastata_repleta
# |                         |  |
# |                         \--+   /------------------ Cryptochetum
# |                            |   |
# |                            |   |              /--- D_busckii
# |                            |   |          /---+
# |                            \---+      /---+   \--- D_virilis
# |                                |      |   |
# |                                |   /--+   \------- Drosophila_melanogaster
# |                                |   |  |
# |                                \---+  \----------- Chymomyza_costata
# |                                    |
# |                                    |      /------- Braula_coeca
# |                                    \------+
# |                                           |   /--- Phortica_variegata
# |                                           \---+
# |                                               \--- Stegana
# |
# \--------------------------------------------------- Ortholfersia_macleayi
#
#
# Buenaventura2020_oest_50per_RAxML.tre
#                               /- SAR_Sar_Sarcophaga_Mauritiella_cfrayssae
# /-----------------------------+
# |                             \- SAR_Sar_Sarcophaga_Asceloctella_australis
# |
# |/------------------------------ SAR_Sar_Sarcophaga_Bellieromima_subulata
# ||
# ||                            /- SAR_Sar_Sarcophaga_Stackelbergeola_mehadiensis
# ||  /-------------------------+
# ||  |                         \- SAR_Sar_Sarcophaga_Rohdendorfisca_forma
# ||  |
# ||  |  /------------------------ SAR_Sar_Helicobia_rapax
# ||  |  |
# ||  |  |/----------------------- SAR_Sar_Chrysagria_sp
# ||  |  ||
# ||  |  ||                    /-- OES_Cut_Dermatobia_hominis
# ||  |  ||      /-------------+
# ||  |  ||      |             |/- OES_Cut_Cuterebra_sp
# ||  |  ||      |             \+
# ||  |  ||      |              \- OES_Cut_Cuterebra_fontinella
# ||  |  ||      |
# ||  |  ||      |             /-- RHINO_Rhinomorinia_capensis
# ||  |  ||      |           /-+
# ||  |  ||      |           | |/- RHINO_Tricogena_rubicosa
# ||  |  ||      |           | \+
# ||  |  ||      |         /-+  \- RHINO_Rhinophora_lepida
# ||  |  ||      |         | |
# ||  |  ||      |         | |/--- RHINO_Tromodesia_angustifrons
# ||  |  ||      |         | \+
# ||  |  ||      |         |  |/-- RHINO_Bezzimyia_setifax
# ||  |  ||      |         |  \+
# ||  |  ||      |         |   |/- RHINO_Paykullia_maculata
# ||  |  ||      |         |   \+
# ||  |  ||      |         |    \- RHINO_Melanophora_roralis
# ||  |  ||      |   /-----+
# ||  |  ||      |   |     | /---- CAL_Tox_Sarconesia_versicolor
# ||  |  ||      |   |     | |
# ||  |  ||      |   |     | |  /- CAL_Cal_Pericallimyia_io
# ||  |  ||      |   |     |/+ /+
# ||  |  ||      |   |     |||/+\- CAL_Cal_Calliphora_sp
# ||  |  ||      |   |     |||||
# ||  |  ||      |   |     ||\+\-- CAL_Mel_Melanomya_nana
# ||  |  ||      |   |     || |
# ||  |  ||      |   |     \+ | /- CAL_Mel_Melinda_viridicyanea
# ||  |  ||      |   |      | \-+
# ||  |  ||      |   |      |   \- CAL_Cal_Bellardia_viarum
# ||  |  ||      |   |      |
# ||  |  ||      |   |      |   /- CAL_Luc_Lucilia_sp1
# ||  |  ||      |   |      \---+
# ||  |  ||      |   |          \- CAL_Luc_Lucilia_sp2
# ||  |  ||      |   |
# ||  |  ||      |   |    /------- CAL_Phu_Phumosia_sp
# ||  | /+|      |   |    |
# ||  | |||      |   |    |     /- CAL_Chr_Chrysomya_rufifacies
# ||  | |||      |   |    | /---+
# ||  | |||      |  /+    | |   \- CAL_Chr_Chrysomya_megacephala
# ||  | |||      |  ||    | |
# ||  | |||      |  ||/---+ | /--- CAL_Chr_Chloroprocta_idioidea
# ||  | |||      |  |||   |/+/+
# ||  | |||      |  |||   |||||/-- CAL_Chr_Compsomyiops_callipes
# ||  | |||      |  |||   ||||\+
# ||  | |||      |  |||   |||| |/- CAL_Chr_Cochliomyia_macellaria
# ||  | |||      |  |||   ||\+ \+
# ||  | |||      |  |||   || |  \- CAL_Chr_Paralucilia_sp
# ||  | |||      |  |||   \+ |
# ||  | |||      |  |||    | |  /- CAL_Chr_Hemilucilia_semidiaphana
# ||  | |||      |  |||    | \--+
# ||  | |||      |  |||    |    \- CAL_Chr_Hemilucilia_segmentaria
# ||  | |||      |  |||    |
# ||  | |||      |  |||    |    /- CAL_Chr_Phormia_regina
# ||  | |||      |  |||    \----+
# ||  | |||      |  |||         \- CAL_Chr_Protocalliphora_sp
# ||  | |||      |  |||
# ||  | |||      |  |||         /- RHINI_Cos_Sumatria_rufithorax
# ||  | |||      |  |||        /+
# ||  | |||     /+  |||  /-----+\- RHINI_Cos_Sumatria_vittigera
# ||  | |||     ||  |\+  |     |
# ||  | |||     ||  | |  |     \-- RHINI_Rhi_Genus_Unknown_sp
# ||  | |||     ||  | |  |
# ||  | |||     ||  | |  |      /- RHINI_Cos_Cosmina_sp
# ||  | |||     ||  | |  |  /---+
# || /+ |||     ||  | |  |  |   \- RHINI_Cos_Cosmina_fuscipennis
# || || |||     ||  | |  | /+
# || || |||     ||  | |  | ||/---- RHINI_Cos_Villeneuviella_seguyi
# || || |||     ||  | |  | |||
# |+ || |||     ||  | | /+ |\+ /-- RHINI_Cos_Rhyncomya_soyauxi
# || || |||     ||  | | || | |/+
# || || |||     ||  | | || | |||/- RHINI_Cos_Rhyncomya_dasyops
# || || |||     ||  | | ||/+ \+\+
# || || |||     ||  | | ||||  | \- RHINI_Cos_Rhyncomya_minutalis
# || || |||     || /+ | ||||  |
# || || |||     || || | ||||  \--- RHINI_Cos_Eurhyncomyia_diversicolor
# || || |||     || || | ||||
# || || |\+     || || | ||||   /-- RHINI_Cos_Isomyia_pubera
# || || | |     || || | |||\---+
# || || | |     || || | |\+    |/- RHINI_Cos_Isomyia_tristis
# || || | |     || || \-+ |    \+
# || || | |     || ||   | |     \- RHINI_Cos_Isomyia_nataliensis
# || || | |     || ||   | |
# || || | |     || ||   | |     /- RHINI_Rhi_Rhiniaa_apicalis
# +| || | |     || ||   | |    /+
# || || | |     || ||   | |    |\- RHINI_Rhi_Fainia_albitarsis
# || || | |     || ||   | \----+
# || || | |     || ||   |      |/- RHINI_Rhi_Stomorhina_cribata
# || || | |     || ||   |      \+
# || || | |     || ||   |       \- RHINI_Rhi_Stomorhina_lunata
# || || | |     || ||   |
# || || | |     || ||   \--------- CAL_Ben_Bengalia_sp
# || || | |     || ||
# || || | |     || ||           /- TAC_Exo_Blondelia_hyphantriae
# || || | |     || ||        /--+
# || || | |     || ||        |  \- TAC_Exo_Smidtia_fumiferanae
# || || | |     || ||       /+
# || || | |     || ||       ||/--- TAC_Tac_Epalpus_signifer
# || || | |     || ||       |\+
# || || | |     ||/+|       | |/-- TAC_Tac_Spilochaetosoma_californicum
# || || | |    /+||||       | \+
# || || | |    ||||||       |  |/- TAC_Tac_Nigrilypha_gnoma
# || || | |    ||||||       |  \+
# || || | |    ||||||      /+   \- TAC_Tac_Panzeria_nigricornea
# || ||/+ |    ||||||      ||
# || |||| |    ||||||      ||   /- TAC_Pha_Trichopoda_pennipes
# || |||| |    ||||||      ||  /+
# || |||| |    ||||||      ||  |\- TAC_Pha_Cylindromyia_binotata
# || |||| |    ||||||      || /+
# || |||| |    |||||\------+| ||/- TAC_Dex_Thelaira_americana
# || |||| |    |||||       |\-+\+
# || |||| |    |||||       |  | \- TAC_Dex_Ptilodexia_harpassa
# || |||| |    |||||       |  |
# || |||| |    |||||       |  \--- TAC_Mac_Cholomyia_inaequipes
# || |||| |    |||||       |
# || |||| |    |||||       \------ CAL_Pol_Pollenia_rudis
# || |||| |    |||||
# || |||| |    |||||          /--- MES_Laneella_sp
# || |||| |    |||||          |
# || |||| |    ||\+|         /+ /- MES_Mesembrinella_spicata
# || |||| |    || ||         ||/+
# ||/+||| |    || ||         |\+\- MES_Mesembrinella_flavicrura
# ||||||| |    || ||         | |
# ||||||| |    || ||         | \-- MES_Mesembrinella_batesi
# ||||||| |   /+| |\---------+
# ||||||| |   ||| |          | /-- FAN_Fannia_sp1
# ||||||| |   ||| |          |/+
# ||||||| |   ||| |          |||/- FAN_Euryomma_sp
# ||||||| |   ||| |          ||\+
# ||||||| |   ||| |          || \- FAN_Fannia_sp2
# ||||||| |   ||| |          \+
# ||||||| |   ||| |           | /- ANT_Hylemya_alcathoe
# ||||||| |   ||| |           |/+
# ||||||| |   ||| |           ||\- SCA_Scathophaga_stercolaria
# ||||||| |   ||| |           \+
# ||||||| |   ||| |            |/- ANT_Anthomyia_procellaris
# ||||||| |   ||| |            \+
# ||||||| |   ||| |             \- ANT_Leucophora_maculata
# ||||||| |   ||| |
# ||||\+| |   ||| \--------------- OES_Hyp_Hypoderma_tarandi
# |||| || |  /+||
# |||| || |  ||||               /- OES_Oes_Cephenemyia_sp
# |||| || |  |||\---------------+
# |||| || |  |||                \- OES_Oes_Oestrus_ovis
# |||| || |  |||
# |||| || |  |||                /- SAR_Par_Paramacronychia_flavipalpis
# |||| || |  |||               /+
# |||| || |  |||              /+\- SAR_Par_Brachicoma_setosa
# |||| || |  |||              ||
# |||| || |  ||\--------------+\-- SAR_Par_Dexagria_ushinskyi
# |\+| || |/-+|               |
# | || || || ||               |/-- SAR_Mil_Eumacronychia_sp
# | || || || ||               \+
# | || || || ||                |/- SAR_Mil_Amobia_signata
# | || || || ||                \+
# | || || || ||                 \- SAR_Mil_Sarcotachina_subcylindrica
# | || || || ||
# | || || \+ |\------------------- SAR_Sar_Emdenimyia_limai
# | || ||  | |
# | || ||  | |                  /- SAR_Sar_Ravinia_querula
# | || ||  | \------------------+
# | || ||  |                    \- SAR_Sar_Oxysarcodexia_ventricosa
# | || ||  |
# | || ||  |                  /--- SAR_Sar_Argoravinia_rufiventris
# | || ||  |                  |
# | || ||  \------------------+ /- SAR_Sar_Spirobolomyia_flavipalpis
# | || ||                     |/+
# | || ||                     ||\- SAR_Sar_Blaesoxipha_Gigantotheca_plinthopyga
# | || ||                     \+
# | || ||                      |/- SAR_Sar_Comasarcophaga_texana
# | || ||                      \+
# | || ||                       \- SAR_Sar_Fletcherimyia_folkertsi
# | || ||
# | || |\------------------------- SAR_Sar_Lipoptilocnema_koehleri
# | || |
# | || \-------------------------- SAR_Sar_Sarcophaga_Neobellieria_bullata
# | ||
# | |\---------------------------- SAR_Sar_Sarcophaga_Sarcorohdendorfia_furcata
# | |
# | |                           /- SAR_Sar_Sarcophaga_Sarcophaga_lehmanni
# | \---------------------------+
# |                             \- SAR_Sar_Sarcophaga_Thyrsocnema_incisilobata
# |
# \------------------------------- SAR_Sar_Sarcophaga_Hellicophagella_melanura
#
#
# Shin2018_RAxML_bipartitions.1000BT_data_v.tree
# /------------------- Chordonota_sp_CB0436_Stratiomyidae_S
# |
# |/------------------ Leucoptilum_sp_CB0326_Stratiomyidae_S
# ||
# ||                 / Ditylometopa_elegans_Stratiomyidae_S
# ||                /+
# ||                || Euryneura_propinqua_Stratiomyidae_S
# |/----------------++
# ||                |\ Diaphorostylus_nasica_Stratiomyidae_S
# ||                |
# ||                \- Cf__Euryneura_sp_CB0427_Stratiomyidae_S
# ||
# ||                /- Dieuryneura_stigma_Stratiomyidae_S
# ||                |
# |/----------------+/ Dysbiota_parvula_Stratiomyidae_S
# ||                |+
# ||                || Lagenosoma_sp_CB0403_Stratiomyidae_S
# ||                ++
# ||                |\ Auloceromyia_sp_CB0435_Stratiomyidae_S
# ||                |
# ||                \- Ampsalis_terminalis_CB0401_Stratiomyidae_S
# ||
# ||                /- Adoxomyia_bistriata_Stratiomyidae_S
# ||                |
# ||                |/ Nigritomyia_consobrina_Stratiomyidae_S
# ||               /++
# ||               ||\ Nigritomyia_loewii_Stratiomyidae_S
# ||               ||
# ||               |+/ Adoxomyia_regularis_CB0428_Stratiomyidae_S
# ||               ||+
# ||               ||+ Clitellaria_ephippium_Stratiomyidae_S
# ||               |||
# ||               |+\ Adoxomyia_rustica_CB0316_Stratiomyidae_S
# /+/--------------+|
# |||              |\- Adoxomyia_sp_CB0419_Stratiomyidae_S
# |||              |
# |||              |/- Hedriodiscus_binotatus_Stratiomyidae_S
# |||              ||
# |||              |+/ Stratiomyidae_S_sp_ESB_2006_Stratiomyidae_S
# |||              ||+
# |||              ||+ Stratiomys_laticeps_CB0319_Stratiomyidae_S
# |||              |||
# |||              \+\ Odontomyia_occidentalis_Stratiomyidae_S
# |||               |
# |||               |/ Euparyphus_pardalinus_Stratiomyidae_S
# |||               |+
# |||               |\ Euparyphus_sp_CB0429_Stratiomyidae_S
# |||               +
# |||               |/ Myxosargus_knowltoni_Stratiomyidae_S
# |||               \+
# |||                | Raphiocera_ornata_CB0406_Stratiomyidae_S
# |||                +
# |||                \ Histiodroma_sp_CB0301_Stratiomyidae_S
# |||
# ||/----------------- Lasiopa_balius_Stratiomyidae_S
# |||
# |||/---------------- Alopecuroceras_coloratum_Stratiomyidae_S
# ||||
# ||||               / Stratiomys_longicorni_Stratiomyidae_S
# ||||               +
# ||||              /+ Stratiomys_ruficornis_Stratiomyidae_S
# ||||              ||
# ||||              +\ Stratiomys_potamida_Stratiomyidae_S
# ||||              |
# |+||              |/ Odontomyia_flavissima_Stratiomyidae_S
# ||||              ++
# ||||              |\ Oplodontha_viridula_Stratiomyidae_S
# ||||              |
# ||||              |- Prosopochrysa_vitripennis_Stratiomyidae_S
# ||||             /+
# ||||             ||/ Oxycera_marginata_Stratiomyidae_S
# ||||             ||+
# ||||             ||| Oxycera_pardalina_Stratiomyidae_S
# |||/-------------+\+
# ||||             | | Hermionella_seguyi_Stratiomyidae_S
# ||||             | +
# ||||             | \ Oxycera_trilineata_Stratiomyidae_S
# ||||             |
# ||||             \-- Nemotelus_cingulatus_Stratiomyidae_S
# ||||
# ||||               / Antissa_sp_SLW_2002_Stratiomyidae_S
# ||||              /+
# ||||              |\ Exodontha_dubia_Stratiomyidae_S
# ||||             /+
# ||||             ||/ Beris_morrisii_Stratiomyidae_S
# ||||             |\+
# ||||             | | Actina_chalybea_Stratiomyidae_S
# ||||             | +
# ||||             | \ Chorisops_tunisiae_Stratiomyidae_S
# ||||             |
# ||||             | / Oplachantha_sp_CB0225_Stratiomyidae_S
# ||||             |/+
# ||||             ||\ Heteracanthia_sp_Stratiomyidae_S
# ||||/------------++
# |||||            ||/ Actina_viridis_Stratiomyidae_S
# |||||            ||+
# |||||            |++ Neoberis_brasiliana_Stratiomyidae_S
# |||||            |||
# |||||            ||\ Beridops_sp_CB0437_Stratiomyidae_S
# |||||            ||
# |||||            |+- Lecomyia_sp_CB0413_Stratiomyidae_S
# |||||            ||
# |||||            ||/ Cyanauges_ruficornis_CB0407_Stratiomyidae_S
# |||||            ||+
# |||||            +\+ Cyanauges_maculatus_CB0433_Stratiomyidae_S
# |||||            | |
# |||||            | \ Chiromyza_sp_CB0313_Stratiomyidae_S
# |||||            |
# |||||            \-- Parhadrestia_atava_Stratiomyidae_S
# |||||
# ||||| /------------- Hilarimorpha_sp_Hilarimorphidae_H
# ||||| |
# ||||| |         /--- Sylvicola_fenestralis_Anisopodoidea_B
# ||||| |         |
# ||||| |         |/-- Symmerus_annulatus_Mycetophilidae_O
# ||||| |         ||
# ||||| |         || / Manota_sp_DK_Mycetophilidae_O
# ||||| |         || +
# ||||| |         |+ | Manota_mazumbaiensis_Mycetophilidae_O
# ||||| |/--------+|/+
# ||||| ||        |||| Manota_mabokeensis_Mycetophilidae_O
# ||||| ||        |||+
# |+||| ||        ||+\ Manota_unifurcata_Mycetophilidae_O
# ||||| ||        |||
# ||||| ||        |||- Bibio_longipes_Bibionidae_O
# ||||| ||        |||
# ||||| ||        \++/ Manota_sp_BMW_Mycetophilidae_O
# ||||| ||         ||+
# ||||| ||         ||| Bolitophila_sp_BMW_Mycetophilidae_O
# ||||| ||         |++
# ||||| ||         ||\ Lygistorrhina_sanctaecatherina_Lygistorrhinidae_Oe
# ||||| ||         ||
# ||||| ||         |\- Arachnocampa_flava_Keroplatidae_O
# ||||| ||         |
# ||||| ||         | / Diadocidia_ferruginosa_Diadocidiidae_O
# ||||| ||         \-+
# ||||| ||           \ Bolitophila_sp_ER_009_Mycetophilidae_O
# ||||| ||
# ||||| ||          /- Heterotropus_sp_Bombyliidae_B
# ||||| ||          |
# ||||| ||     /----+/ Cyrtosiini_gen_sp_Bombyliidae_B
# ||||| ||     |    |+
# ||||| ||     |    || Mythicomyia_sp_Bombyliidae_B
# ||||| ||     |    ++
# ||||| ||     |    |\ Glabellula_sp_Bombyliidae_B
# ||||| ||     |    |
# ||||| ||     |    \- Mnemomyia_sp_Bombyliidae_B
# ||||| ||     |
# ||||| ||     |     / Pantarbes_sp_Bombyliidae_B
# ||||| ||     | /---+
# ||||| ||     | |   \ Eusurbus_sp_Bombyliidae_B
# ||||| ||     | |
# ||||| ||     | |  /- Marmasoma_sumptuosum_Bombyliidae_B
# ||||| ||     | |  |
# ||||| ||     | |  |/ Toxophora_compta_Bombyliidae_B
# ||||| ||     | | /++
# ||||| ||     | | ||+ Toxophora_sp_Bombyliidae_B
# ||||| ||     | | |||
# ||||| ||     | | ||\ Geron_sp_Bombyliidae_B
# ||||| ||     | | |+
# ||||| ||     | | ||- Zaclava_sp_Bombyliidae_B
# ||||| ||     | | ||
# ||||| ||     | | ++/ Systropus_sp_Bombyliidae_B
# ||||| ||     | | ||+
# ||||| ||     | | |\+ Systropus_flavoornatus_Bombyliidae_B
# ||||| ||     | | | |
# ||||| ||     | | | \ Dolichomyia_sp_Bombyliidae_B
# ||||| ||     | | |
# ||||| ||     |/+ | / Corsomyza_sp_Bombyliidae_B
# ||||| ||     ||| |-+
# ||||| ||     ||| | \ Apolysis_sp_Bombyliidae_B_1
# ||||| ||     ||| |
# ||||| ||     |||-+ / Tomomyza_sp_Bombyliidae_B
# ||||| ||     ||| |/+
# ||||| ||     ||| ||\ Paracosmus_sp_Bombyliidae_B
# ||||| ||     ||| |+
# ||||| ||     ||| ||- Lyophlaeba_sp_Bombyliidae_B
# ||||| ||     ||| ||
# ||||| ||     ||| ||/ Aleucosia_sp_Bombyliidae_B
# ||||| ||     ||| ||+
# ||||| ||     ||| ||| Comptosia_quadripennis_Bombyliidae_B
# ||||| ||     ||| ||+
# ||||| ||     ||| \+\ Comptosia_moretoni_Bombyliidae_B
# ||||| ||     |||  |
# ||||| ||     |||  |- Lordotus_sp_Bombyliidae_B
# ||||| ||     |||  |
# ||||| ||     |||  |/ Geminaria_sp_1_Bombyliidae_B
# ||||| ||     ||+  |+
# ||||| ||     |||  |+ Geminaria_sp_2_Bombyliidae_B
# ||||| ||     |||  +|
# ||||| ||     |||  |\ Amphicosmus_sp_Bombyliidae_B
# ||||| ||     |||  |
# ||||| ||     |||  |/ Conophorus_sp_Bombyliidae_B
# ||||| ||     |||  \+
# ||||| ||     |||   \ sparnopolius_sp_Bombyliidae_B
# ||||| ||     |||
# ||||| ||     |||---- Villa_sp_3_Bombyliidae_B
# ||||| |/-----+||
# ||||| ||     |||   / Anastoechus_sp_Bombyliidae_B
# ||||| ||     |||  /+
# ||||| ||     |||  || Heterostylum_sp_Bombyliidae_B
# ||||| ||     |||/-++
# ||||| ||     |||| |\ Meomyia_sp_Bombyliidae_B
# ||||| ||     ||+| |
# ||||| ||     |||| \- Bombylius_major_Bombyliidae_B
# ||||| ||     ||||
# ||||| ||     ||||  / Neosardus_sp_Bombyliidae_B
# ||||| ||     |||| /+
# ||||| ||     |||| |\ Neosardus_principus_Bombyliidae_B
# ||||| ||     |+|/-+
# ||||| ||     ||\+ |- Pteraulax_sp_Bombyliidae_B
# ||||| ||     || | +
# ||||| ||     || | |/ Aphoebantus_sp_2_Bombyliidae_B
# ||||| ||     || | \+
# ||||| ||     || |  | Aphoebantus_sp_1_Bombyliidae_B
# ||||| ||     || |  +
# ||||| ||     || |  \ Epacmus_sp_Bombyliidae_B
# ||||| ||     || |
# ||||| ||     || |  / Hemipenthes_jaennickeana_Bombyliidae_B
# ||||| ||     || |  +
# ||||| ||     || +  | Comptosia_sp_LRC2002_Bombyliidae_B
# ||||| ||     || |--+
# ||||| ||     || |  | Brachyanax_ater_Bombyliidae_B
# ||||| ||     || |  +
# ||||| ||     || |  \ Anthrax_proconcisus_Bombyliidae_B
# ||||| ||     || |
# ||||| ||     || |  / Ligyra_satyrus_Bombyliidae_B
# ||||| +|     || | /+
# ||||| ||     || | || Pseudopenthes_sp_Bombyliidae_B
# ||||| ||     || | |+
# ||||| ||     || | |\ Exoprosopa_sp_Bombyliidae_B
# |\+|| ||     || | |
# | ||| ||     || +/+/ Lepidanthrax_sp_Bombyliidae_B
# | ||| ||     |+ |||+
# | ||| ||     || |||+ Villa_sp_2_Bombyliidae_B
# | ||| ||     || ||||
# | ||| ||     || |||\ Villa_sp_1_Bombyliidae_B
# | ||| ||     || |||
# | ||| ||     || |++- Rynchanthrax_sp_Bombyliidae_B
# | ||| ||     || |||
# | ||| ||     || ||\- Hyperalonia_sp_Bombyliidae_B
# | ||| ||     || ||
# | ||| ||     || || / Anthrax_sp_Bombyliidae_B
# | ||| ||     || \+ +
# | ||| ||     ||  |-+ Xenox_tigrinus_Bombyliidae_B
# | ||| ||     ||  | |
# | ||| ||     ||  | \ Epacomoides_sp_Bombyliidae_B
# | ||| ||     ||  |
# | ||| ||     ||  \-- Antonia_sp_Bombyliidae_B
# | ||| ||     ||
# | ||| ||     ||   /- Thevenetimyia_sp_Bombyliidae_B
# | ||| ||     ||---+
# | ||| ||     ||   |/ Usia_sp_Bombyliidae_B
# | ||| ||     ||   \+
# | ||| ||     ||    | Apolysis_sp_Bombyliidae_B
# | ||| ||     +|    +
# | ||| ||     ||    \ Apolysis_sp_Bombyliidae_B_2
# | ||| ||     ||
# | ||| ||     |\----- Sericosoma_sp_Bombyliidae_B
# | ||| ||     |
# | ||| ||     |     / Lordotus_sp_Bombyliidae_B_MEI_90_26
# | ||| ||     |-----+
# | ||| ||     |     \ Lepidophora_sp_Bombyliidae_B
# | ||| ||     |
# | ||| ||     \------ Desmatomyia_sp_Bombyliidae_B
# | ||| ||
# | ||| ||           / Evocoa_chilensis_Evocoidae_A
# | ||| ||  /--------+
# ...
#                     | ||     ||         ||  \+
#                     | ||     ||         \+   \- Cryptochetum_sp
#                     | ||     ||          |
#                     \-+|     ||          |/---- Camilla_sp
#                       ||     ||          \+
#                       ||     \+           | /-- Curtonotum_helvum
#                       ||      |           \-+
#                       ||      |             |/- Campichoeta_punctum
#                       ||      |             \+
#                       ||      |              \- Diastata_fuscula
#                       ||      |
#                       ||      |/--------------- Paratrichobius_longicrus
#                       ||      ||
#                       ||      ||            /-- Glossina_morsitans
#                       ||      \+ /----------+
#                       ||       | |          |/- Crataerina_hirudinus
#                       ||       | |          \+
#                       ||       | |           \- Ornithomyia_avicularia
#                       ||       \-+
#                       ||         |/------------ Fannia_canicularis
#                       ||         ||
#                       ||         ||         /-- Drymeia_alpicola
#                       ||         \+/--------+
#                       ||          ||        |/- Musca_domestica
#                       ||          ||        \+
#                       ||          ||         \- Stomoxys_calcitrans
#                       ||          \+
#                       ||           |         /- Delia_radicum
#                       ||           | /-------+
#                       ||           | |       \- Scatophaga_stercoraria
#                       ||           | |
#                       \+           \-+      /-- Cephenemyia_phobifer
#                        |             |/-----+
#                        |             ||     |/- Sarcophaga_bullata
#                        |             ||     \+
#                        |             \+      \- Peckia_alvarengai
#                        |              |
#                        |              | /------ Phyto_melanocephala
#                        |              | |
#                        |              \-+/----- Cochliomyia_macellaria
#                        |                ||
#                        |                ||  /-- Gymnosoma_nudifrons
#                        |                \+/-+
#                        |                 || |/- Siphona_flavifrons
#                        |                 || \+
#                        |                 \+  \- Tachina_grossa
#                        |                  |
#                        |                  | /-- Exorista_larvarum
#                        |                  \-+
#                        |                    |/- Axinia_zentae
#                        |                    \+
#                        |                     \- Phania_funesta
#                        |
#                        |/---------------------- Megamerina_sp
#                        ||
#                        ||                 /---- Gymnochiromyia_sp
#                        ||                 |
#                        ||          /------+  /- Geomyza_tripunctata
#                        ||          |      | /+
#                        ||          |      | |\- Opomyza_florum
#                        ||          |      \-+
#                        ||          |        |/- Sepsis_cynipsea
#                        || /--------+        \+
#                        || |        |         \- Acartophthalmus_nigrinus
#                        || |        |
#                        || |        |         /- Richardia_teevani
#                        || |        | /-------+
#                        || |        | |       \- Lonchaea_polita
#                        || |        \-+
#                        || |          |/-------- Mycetaulus_sp
#                        || |          ||
#                        \+ |          \+      /- Melieria_omissa
#                         | |           | /----+
#                         | |           | |    \- Herina_palustris
#                         | |           \-+
#                         | |             |/----- Rivellia_syngenesiae
#                         | |             ||
#                         | |             \+/---- Nepaliseta_ashleyi
#                         | |              ||
#                         | |              \+  /- Tachinisca_cyaneiventris
#                         | |               | /+
#                         | |               | |\- Cardiacera_nr._miliacea
#                         | |               \-+
#                         | |                 |/- Ceratitis_capitata
#                         | |                 \+
#                         | |                  \- Trupanea_bullocki
#                         | |
#                         | |                  /- Inbiomyia_mcalpineorum
#                         | |              /---+
#                         | |              |   \- Nemula_longarista
#                         \-+              |
#                           |           /--+   /- Aulacigaster_sp
#                           |           |  |/--+
#                           |           |  ||  \- Cyamops_nebulosa
#                           |           |  ||
#                           |           |  \+  /- Telostylinus_sp
#                           |           |   | /+
#                           |           |   | |\- Rhinopomyzella_sp
#                           |           |   \-+
#                           |           |     |/- Compsobata_cibaria
#                           |/----------+     \+
#                           ||          |      \- Cnodacophora_sellata
#                           ||          |
#                           ||          |   /---- Somatia_aestiva
#                           ||          | /-+
#                           ||          | | | /-- Paramyia_nitens
#                           ||          | | \-+
#                           ||          | |   |/- Incertella_albipalpis
#                           ||          | |   \+
#                           ||          \-+    \- Thaumatomyia_notata
#                           ||            |
#                           ||            |   /-- Teloglabrus_sp
#                           ||            |/--+
#                           ||            ||  |/- Sphyracephala_brevicornis
#                           ||            ||  \+
#                           ||            \+   \- Cyrtodiopsis_dalmanni
#                           ||             |
#                           ||             |/---- Margo_sp
#                           \+             \+
#                            |              | /-- Azorastia_mediterranea
#                            |              \-+
#                            |                |/- Procanace_dianneae
#                            |                \+
#                            |                 \- Tethinosoma_fulvifrons
#                            |
#                            |                 /- Neotanypeza_sp
#                            | /---------------+
#                            | |               \- Strongylophthalmyia_pengellyi
#                            | |
#                            | |            /---- Willistoniella_pleuropunctata
#                            | |            |
#                            | |           /+  /- Fergusonina_turneri
#                            | |           || /+
#                            | |           || |\- Asteia_amoena
#                            | |           |\-+
#                            | |           |  |/- Xenasteia_shalam
#                            \-+/----------+  \+
#                              ||          |   \- Australimyza_sp
#                              ||          |
#                              ||          |   /- Chamaepsila_hennigi
#                              ||          |/--+
#                              ||          ||  \- Syringogaster_sp
#                              ||          \+
#                              ||           | /-- Clusia_lateralis
#                              ||           \-+
#                              ||             |/- Neurochaeta_sp
#                              \+             \+
#                               |              \- Palloptera_umbellatarum
#                               |
#                               |           /---- Teratomya_sp
#                               |/----------+
#                               ||          | /-- Trixoscelis_sp
#                               ||          \-+
#                               ||            |/- Suillia_variegata
#                               ||            \+
#                               ||             \- Anthomyza_gracilis
#                               \+
#                                | /------------- Heteromyza_atricornis
#                                | |
#                                | |           /- Parochthiphila_coronata
#                                | |        /--+
#                                | |        |  \- Cremifania_nearctica
#                                \-+/-------+
#                                  ||       | /-- Spaniocelyphus_umsinduzi
#                                  ||       \-+
#                                  ||         |/- Lyciella_decipiens
#                                  ||         \+
#                                  ||          \- Minettia_flaveola
#                                  \+
#                                   |          /- Natalimyza_sp
#                                   |/---------+
#                                   ||         \- Heterocheila_buccata
#                                   ||
#                                   || /--------- Stylogaster_sp
#                                   \+ |
#                                    | |       /- Huttonina_glabra
#                                    | |    /--+
#                                    | |    |  \- Helcomyza_mirabilis
#                                    \-+/---+
#                                      ||   | /-- Neosciomyza_luteipennis
#                                      ||   \-+
#                                      ||     |/- Lopa_convexa
#                                      ||     \+
#                                      \+      \- Coelopa_vanduzeei
#                                       |
#                                       |      /- Dryomyza_anilis
#                                       | /----+
#                                       | |    \- Oedoparena_glauca
#                                       \-+
#                                         |/----- Pelidnoptera_nigripennis
#                                         ||
#                                         \+   /- Physocephala_marginata
#                                          |/--+
#                                          ||  \- Myopa_sp
#                                          \+
#                                           | /-- Pherbellia_annulipes
#                                           \-+
#                                             |/- Neolimnia_obscura_
#                                             \+
#                                              \- Tetanocera_ferruginea_

# %% [markdown]
# ### Process tip names with chatGPT and parse results into table
# Now that we have the list, we can split it in sets of 35 and create chatGPT prompts to extract information from them.

# %%
chunk_size=35
lists_names = [tip_names[i:i + chunk_size] for i in range(0, len(tip_names), chunk_size)]

# %%
prompts = []
for l in lists_names:
    new_prompt = ('''The following list contains tip names extracted from a Diptera phylogenetic tree. Parse them to make a table including the following columns:
```tip_name,superfamily,family,subfamily,tribe,genus,species,additional_identifiers```
```
''' +
                  '\n'.join(l) +
                  '''
                  ```
Rules:
- Taxonomic ranks above genus may be abbreviated in the tip names (for example, SAR for Sarcophagidae). If there is an abbreviation, try your best guess to write athe full name. Consider family missing if there is no data about it in the original tip name, do not infer from genus name alone.
- Leave a cell empty if information is missing. "gen" usually means a genus is unknown, leave genus empty. "sp" usually means a species is unknown, leave species empty.
Output the table in csv format.

                  '''
                 )
    prompts.append(new_prompt)

# %% [markdown]
# Now let's loop through these prompts and copy them one by one with a GUI:

# %%
import ipywidgets as widgets

# Your list of strings
string_list = prompts
index = 0

# Create widgets
next_button = widgets.Button(description="Next")
back_button = widgets.Button(description="Back")
jump_button = widgets.Button(description="Jump")
index_input = widgets.BoundedIntText(min=1, max=len(string_list), description='Index:')
textarea = widgets.Textarea(rows=20, cols=200)
output = widgets.Output()
label = widgets.Label()

def update_label():
    label.value = f"Showing string {index+1} of {len(string_list)}"

def update_textarea():
    if index < len(string_list):
        textarea.value = string_list[index]
    else:
        textarea.value = ""

def on_next_button_clicked(b):
    global index
    with output:
        if index < len(string_list) - 1:
            index += 1
            update_label()
            update_textarea()
        else:
            print("End of list")

def on_back_button_clicked(b):
    global index
    with output:
        if index > 0:
            index -= 1
            update_label()
            update_textarea()
        else:
            print("Start of list")

def on_jump_button_clicked(b):
    global index
    with output:
        desired_index = index_input.value - 1  # Subtract 1 because our list is 0-indexed
        if 0 <= desired_index < len(string_list):
            index = desired_index
            update_label()
            update_textarea()
        else:
            print("Invalid index")

next_button.on_click(on_next_button_clicked)
back_button.on_click(on_back_button_clicked)
jump_button.on_click(on_jump_button_clicked)

button_box = widgets.HBox([back_button, next_button, jump_button, index_input])
display_area = widgets.VBox([button_box, label, textarea, output])

display(display_area)

# Update the textarea and label to start
update_textarea()
update_label()
# Out:
# VBox(children=(HBox(children=(Button(description='Back', style=ButtonStyle()), Button(description='Next', styl…

# %% [markdown]
# We will now loop through the prompts above, use them in chatGPT and paste the response in a csv table.
#
# The results can be found in this chat: https://chat.openai.com/share/13934687-d473-4eb6-8af3-4c7dedc836e5
#
# Now that we have done it, let's load the table and make sure everything looks all right.

# %%
import pandas as pd
gpt_table = pd.read_csv("./constraint_trees/taxonomy_parsing/parsed_gpt_tips.csv")
gpt_table
# Out:
#                                               tip_name superfamily family
# 0                    Liriomyza_sativae_AG1433_4372_308         NaN    NaN  \
# 1          Braula_coeca_Braula_coeca_GDDH01_1_5741_317         NaN    NaN
# 2                           Braula_coeca_I6794_507_280         NaN    NaN
# 3     Leucophenga_varia_L_varia_4359_279_assm.augustus         NaN    NaN
# 4                  Leucophenga_maculata_leucma_323_264         NaN    NaN
# ...                                                ...         ...    ...
# 2596                                 Chymomyza_costata         NaN    NaN
# 2597                                Eristalis_pertinax         NaN    NaN
# 2598                             Lonchoptera_bifurcata         NaN    NaN
# 2599                                  Megaselia_abdita         NaN    NaN
# 2600                                 Platypeza_anthrax         NaN    NaN
#
#      subfamily tribe        genus    species          additional_identifiers
# 0          NaN   NaN    Liriomyza    sativae                 AG1433_4372_308
# 1          NaN   NaN       Braula      coeca  Braula_coeca_GDDH01_1_5741_317
# 2          NaN   NaN       Braula      coeca                   I6794_507_280
# 3          NaN   NaN  Leucophenga      varia  L_varia_4359_279_assm.augustus
# 4          NaN   NaN  Leucophenga   maculata                  leucma_323_264
# ...        ...   ...          ...        ...                             ...
# 2596       NaN   NaN    Chymomyza    costata                             NaN
# 2597       NaN   NaN    Eristalis   pertinax                             NaN
# 2598       NaN   NaN  Lonchoptera  bifurcata                             NaN
# 2599       NaN   NaN    Megaselia     abdita                             NaN
# 2600       NaN   NaN    Platypeza    anthrax                             NaN
#
# [2601 rows x 8 columns]

# %% [markdown]
# Let's check if any row has made-up tip names, or any missing, and then check for duplicated tip names

# %%
gpt_table.loc[~gpt_table['tip_name'].isin(tip_names)]
# Out:
# Empty DataFrame
# Columns: [tip_name, superfamily, family, subfamily, tribe, genus, species, additional_identifiers]
# Index: []

# %%
[t for t in tip_names if t not in gpt_table['tip_name'].tolist()]
# Out:
# []

# %%
gpt_table['tip_name'].loc[gpt_table['tip_name'].duplicated()]
# Out:
# Series([], Name: tip_name, dtype: object)

# %% [markdown]
# Great, now each entry in the table is unique and we have correspondences to all tip names, let's update the table to use [TaxReformer](https://github.com/brunoasm/TaxReformer/blob/master/README.md)

# %%
def create_name(row):
    if pd.notnull(row['genus']) and pd.notnull(row['species']):
        return row['genus'] + ' ' + row['species']
    else:
        for column in ['species', 'genus', 'tribe', 'subfamily', 'family', 'superfamily']:
            if pd.notnull(row[column]):
                return row[column]

gpt_table['name'] = gpt_table.apply(create_name, axis=1)

gpt_table
# Out:
#                                               tip_name superfamily family
# 0                    Liriomyza_sativae_AG1433_4372_308         NaN    NaN  \
# 1          Braula_coeca_Braula_coeca_GDDH01_1_5741_317         NaN    NaN
# 2                           Braula_coeca_I6794_507_280         NaN    NaN
# 3     Leucophenga_varia_L_varia_4359_279_assm.augustus         NaN    NaN
# 4                  Leucophenga_maculata_leucma_323_264         NaN    NaN
# ...                                                ...         ...    ...
# 2596                                 Chymomyza_costata         NaN    NaN
# 2597                                Eristalis_pertinax         NaN    NaN
# 2598                             Lonchoptera_bifurcata         NaN    NaN
# 2599                                  Megaselia_abdita         NaN    NaN
# 2600                                 Platypeza_anthrax         NaN    NaN
#
#      subfamily tribe        genus    species          additional_identifiers
# 0          NaN   NaN    Liriomyza    sativae                 AG1433_4372_308  \
# 1          NaN   NaN       Braula      coeca  Braula_coeca_GDDH01_1_5741_317
# 2          NaN   NaN       Braula      coeca                   I6794_507_280
# 3          NaN   NaN  Leucophenga      varia  L_varia_4359_279_assm.augustus
# 4          NaN   NaN  Leucophenga   maculata                  leucma_323_264
# ...        ...   ...          ...        ...                             ...
# 2596       NaN   NaN    Chymomyza    costata                             NaN
# 2597       NaN   NaN    Eristalis   pertinax                             NaN
# 2598       NaN   NaN  Lonchoptera  bifurcata                             NaN
# 2599       NaN   NaN    Megaselia     abdita                             NaN
# 2600       NaN   NaN    Platypeza    anthrax                             NaN
#
#                        name
# 0         Liriomyza sativae
# 1              Braula coeca
# 2              Braula coeca
# 3         Leucophenga varia
# 4      Leucophenga maculata
# ...                     ...
# 2596      Chymomyza costata
# 2597     Eristalis pertinax
# 2598  Lonchoptera bifurcata
# 2599       Megaselia abdita
# 2600      Platypeza anthrax
#
# [2601 rows x 9 columns]

# %% [markdown]
# Let's save the table to run TaxReformer. Commented out since we did this already.

# %%
#gpt_table.to_csv("../constraint_trees/taxonomy_parsing/parsed_gpt_tips_for_taxreformer.csv")

# %% [markdown]
# ### Obtain taxonomic information with TaxReformer
#
# Now let's run TaxReformer. We run it using docker, so it is easier to do outside this notebook. We ran TaxReformer and saved an edited version of the table (with original columns other than tip name removed). Let's now open it an merge with our table.

# %%
taxref_df = pd.read_csv("./constraint_trees/taxonomy_parsing/output_matched_all_edited.csv",index_col=0)
taxref_df
# Out:
#                                                                   name
# tip_name
# Liriomyza_sativae_AG1433_4372_308                    Liriomyza sativae  \
# Braula_coeca_Braula_coeca_GDDH01_1_5741_317               Braula coeca
# Braula_coeca_I6794_507_280                                Braula coeca
# Leucophenga_varia_L_varia_4359_279_assm.augustus     Leucophenga varia
# Leucophenga_maculata_leucma_323_264               Leucophenga maculata
# ...                                                                ...
# Ruppellia_multisetosis_Therevidae                            Ruppellia
# Propebrevitrichia_patersonensi_Scenopinidaes              Scenopinidae
# CerdistusLRC_Asilidae                                        Cerdistus
# Hilarini                                                     Empidinae
# Syringogaster_plesioterga                                Syringogaster
#
#                                                       updated_fullname
# tip_name
# Liriomyza_sativae_AG1433_4372_308                    Liriomyza sativae  \
# Braula_coeca_Braula_coeca_GDDH01_1_5741_317               Braula coeca
# Braula_coeca_I6794_507_280                                Braula coeca
# Leucophenga_varia_L_varia_4359_279_assm.augustus     Leucophenga varia
# Leucophenga_maculata_leucma_323_264               Leucophenga maculata
# ...                                                                ...
# Ruppellia_multisetosis_Therevidae                            Ruppellia
# Propebrevitrichia_patersonensi_Scenopinidaes              Scenopinidae
# CerdistusLRC_Asilidae                                        Cerdistus
# Hilarini                                                     Empidinae
# Syringogaster_plesioterga                                Syringogaster
#
#                                                  taxonomy_source rank_matched
# tip_name
# Liriomyza_sativae_AG1433_4372_308                            OTT      species  \
# Braula_coeca_Braula_coeca_GDDH01_1_5741_317                  OTT      species
# Braula_coeca_I6794_507_280                                   OTT          NaN
# Leucophenga_varia_L_varia_4359_279_assm.augustus             OTT      species
# Leucophenga_maculata_leucma_323_264                          OTT      species
# ...                                                          ...          ...
# Ruppellia_multisetosis_Therevidae                            OTT        genus
# Propebrevitrichia_patersonensi_Scenopinidaes                 OTT       family
# CerdistusLRC_Asilidae                                        OTT        genus
# Hilarini                                                     OTT    subfamily
# Syringogaster_plesioterga                                    OTT        genus
#
#                                                                matched  score
# tip_name
# Liriomyza_sativae_AG1433_4372_308                    Liriomyza sativae    100  \
# Braula_coeca_Braula_coeca_GDDH01_1_5741_317               Braula coeca    100
# Braula_coeca_I6794_507_280                                Braula coeca    100
# Leucophenga_varia_L_varia_4359_279_assm.augustus     Leucophenga varia    100
# Leucophenga_maculata_leucma_323_264               Leucophenga maculata    100
# ...                                                                ...    ...
# Ruppellia_multisetosis_Therevidae                            Ruppellia    100
# Propebrevitrichia_patersonensi_Scenopinidaes              Scenopinidae    100
# CerdistusLRC_Asilidae                                        Cerdistus    100
# Hilarini                                                     Empidinae    100
# Syringogaster_plesioterga                                Syringogaster    100
#
#                                                   ott_id   ncbi_id
# tip_name
# Liriomyza_sativae_AG1433_4372_308                 246452  127406.0  \
# Braula_coeca_Braula_coeca_GDDH01_1_5741_317        26327  305562.0
# Braula_coeca_I6794_507_280                         26327  305562.0
# Leucophenga_varia_L_varia_4359_279_assm.augustus  765416  745178.0
# Leucophenga_maculata_leucma_323_264               742404   30051.0
# ...                                                  ...       ...
# Ruppellia_multisetosis_Therevidae                 545287   95102.0
# Propebrevitrichia_patersonensi_Scenopinidaes      653872   50675.0
# CerdistusLRC_Asilidae                             919308  188249.0
# Hilarini                                          235209   92562.0
# Syringogaster_plesioterga                         248409  553364.0
#
#                                                  name_source
# tip_name
# Liriomyza_sativae_AG1433_4372_308                        OTT  \
# Braula_coeca_Braula_coeca_GDDH01_1_5741_317              OTT
# Braula_coeca_I6794_507_280                               OTT
# Leucophenga_varia_L_varia_4359_279_assm.augustus         OTT
# Leucophenga_maculata_leucma_323_264                      OTT
# ...                                                      ...
# Ruppellia_multisetosis_Therevidae                        OTT
# Propebrevitrichia_patersonensi_Scenopinidaes             OTT
# CerdistusLRC_Asilidae                                    OTT
# Hilarini                                                 OTT
# Syringogaster_plesioterga                                OTT
#
#                                                   matched_id_in_source  ...
# tip_name                                                                ...
# Liriomyza_sativae_AG1433_4372_308                               246452  ...  \
# Braula_coeca_Braula_coeca_GDDH01_1_5741_317                      26327  ...
# Braula_coeca_I6794_507_280                                       26327  ...
# Leucophenga_varia_L_varia_4359_279_assm.augustus                765416  ...
# Leucophenga_maculata_leucma_323_264                             742404  ...
# ...                                                                ...  ...
# Ruppellia_multisetosis_Therevidae                               545287  ...
# Propebrevitrichia_patersonensi_Scenopinidaes                    653872  ...
# CerdistusLRC_Asilidae                                           919308  ...
# Hilarini                                                        235209  ...
# Syringogaster_plesioterga                                       248409  ...
#
#                                                       section  superfamily
# tip_name
# Liriomyza_sativae_AG1433_4372_308                 Schizophora  Opomyzoidea  \
# Braula_coeca_Braula_coeca_GDDH01_1_5741_317       Schizophora  Ephydroidea
# Braula_coeca_I6794_507_280                        Schizophora  Ephydroidea
# Leucophenga_varia_L_varia_4359_279_assm.augustus  Schizophora  Ephydroidea
# Leucophenga_maculata_leucma_323_264               Schizophora  Ephydroidea
# ...                                                       ...          ...
# Ruppellia_multisetosis_Therevidae                   Asiloidea          NaN
# Propebrevitrichia_patersonensi_Scenopinidaes        Asiloidea          NaN
# CerdistusLRC_Asilidae                               Asiloidea          NaN
# Hilarini                                           Empidoidea          NaN
# Syringogaster_plesioterga                          Diopsoidea          NaN
#
#                                                             family
# tip_name
# Liriomyza_sativae_AG1433_4372_308                      Agromyzidae  \
# Braula_coeca_Braula_coeca_GDDH01_1_5741_317              Braulidae
# Braula_coeca_I6794_507_280                               Braulidae
# Leucophenga_varia_L_varia_4359_279_assm.augustus     Drosophilidae
# Leucophenga_maculata_leucma_323_264                  Drosophilidae
# ...                                                            ...
# Ruppellia_multisetosis_Therevidae                       Therevidae
# Propebrevitrichia_patersonensi_Scenopinidaes          Scenopinidae
# CerdistusLRC_Asilidae                                     Asilidae
# Hilarini                                                 Empididae
# Syringogaster_plesioterga                         Syringogastridae
#
#                                                      subfamily      tribe
# tip_name
# Liriomyza_sativae_AG1433_4372_308                 Phytomyzinae        NaN  \
# Braula_coeca_Braula_coeca_GDDH01_1_5741_317                NaN        NaN
# Braula_coeca_I6794_507_280                                 NaN        NaN
# Leucophenga_varia_L_varia_4359_279_assm.augustus    Steganinae  Steganini
# Leucophenga_maculata_leucma_323_264                 Steganinae  Steganini
# ...                                                        ...        ...
# Ruppellia_multisetosis_Therevidae                     Phycinae        NaN
# Propebrevitrichia_patersonensi_Scenopinidaes               NaN        NaN
# CerdistusLRC_Asilidae                                 Asilinae        NaN
# Hilarini                                                   NaN        NaN
# Syringogaster_plesioterga                                  NaN        NaN
#
#                                                        subtribe
# tip_name
# Liriomyza_sativae_AG1433_4372_308                           NaN  \
# Braula_coeca_Braula_coeca_GDDH01_1_5741_317                 NaN
# Braula_coeca_I6794_507_280                                  NaN
# Leucophenga_varia_L_varia_4359_279_assm.augustus  Leucophengina
# Leucophenga_maculata_leucma_323_264               Leucophengina
# ...                                                         ...
# Ruppellia_multisetosis_Therevidae                           NaN
# Propebrevitrichia_patersonensi_Scenopinidaes                NaN
# CerdistusLRC_Asilidae                                       NaN
# Hilarini                                                    NaN
# Syringogaster_plesioterga                                   NaN
#
#                                                    species group subgenus
# tip_name
# Liriomyza_sativae_AG1433_4372_308                            NaN      NaN  \
# Braula_coeca_Braula_coeca_GDDH01_1_5741_317                  NaN      NaN
# Braula_coeca_I6794_507_280                                   NaN      NaN
# Leucophenga_varia_L_varia_4359_279_assm.augustus             NaN      NaN
# Leucophenga_maculata_leucma_323_264               maculata group      NaN
# ...                                                          ...      ...
# Ruppellia_multisetosis_Therevidae                            NaN      NaN
# Propebrevitrichia_patersonensi_Scenopinidaes                 NaN      NaN
# CerdistusLRC_Asilidae                                        NaN      NaN
# Hilarini                                                     NaN      NaN
# Syringogaster_plesioterga                                    NaN      NaN
#
#                                                  species subgroup
# tip_name
# Liriomyza_sativae_AG1433_4372_308                             NaN  \
# Braula_coeca_Braula_coeca_GDDH01_1_5741_317                   NaN
# Braula_coeca_I6794_507_280                                    NaN
# Leucophenga_varia_L_varia_4359_279_assm.augustus              NaN
# Leucophenga_maculata_leucma_323_264                           NaN
# ...                                                           ...
# Ruppellia_multisetosis_Therevidae                             NaN
# Propebrevitrichia_patersonensi_Scenopinidaes                  NaN
# CerdistusLRC_Asilidae                                         NaN
# Hilarini                                                      NaN
# Syringogaster_plesioterga                                     NaN
#
#                                                                          notes
# tip_name
# Liriomyza_sativae_AG1433_4372_308                                          NaN
# Braula_coeca_Braula_coeca_GDDH01_1_5741_317       superfamily manually updated
# Braula_coeca_I6794_507_280                        superfamily manually updated
# Leucophenga_varia_L_varia_4359_279_assm.augustus                           NaN
# Leucophenga_maculata_leucma_323_264                                        NaN
# ...                                                                        ...
# Ruppellia_multisetosis_Therevidae                                          NaN
# Propebrevitrichia_patersonensi_Scenopinidaes                               NaN
# CerdistusLRC_Asilidae                                                      NaN
# Hilarini                                                                   NaN
# Syringogaster_plesioterga                                                  NaN
#
# [2601 rows x 41 columns]

# %%
tipnames2tax = (gpt_table[["name","tip_name"]].
                merge(taxref_df, on = ["name","tip_name"], how = "left").
                set_index("tip_name").
                rename(columns={'updated_genus': 'genus', 'updated_species': 'species'})
               )

cols = list(tipnames2tax   .columns)
cols.remove('genus')
cols.remove('subgenus')
cols.remove('species')
cols.remove('species group')
cols.remove('species subgroup')
tipnames2tax    = tipnames2tax[cols+['genus', 'subgenus', 'species group','species subgroup', 'species']]

tipnames2tax.loc[tipnames2tax['species'].notna(), 'species'] = tipnames2tax['genus'] + ' ' + tipnames2tax['species']
                
tipnames2tax
# Out:
#                                                                    name
# tip_name
# Liriomyza_sativae_AG1433_4372_308                     Liriomyza sativae  \
# Braula_coeca_Braula_coeca_GDDH01_1_5741_317                Braula coeca
# Braula_coeca_I6794_507_280                                 Braula coeca
# Leucophenga_varia_L_varia_4359_279_assm.augustus      Leucophenga varia
# Leucophenga_maculata_leucma_323_264                Leucophenga maculata
# ...                                                                 ...
# Chymomyza_costata                                     Chymomyza costata
# Eristalis_pertinax                                   Eristalis pertinax
# Lonchoptera_bifurcata                             Lonchoptera bifurcata
# Megaselia_abdita                                       Megaselia abdita
# Platypeza_anthrax                                     Platypeza anthrax
#
#                                                        updated_fullname
# tip_name
# Liriomyza_sativae_AG1433_4372_308                     Liriomyza sativae  \
# Braula_coeca_Braula_coeca_GDDH01_1_5741_317                Braula coeca
# Braula_coeca_I6794_507_280                                 Braula coeca
# Leucophenga_varia_L_varia_4359_279_assm.augustus      Leucophenga varia
# Leucophenga_maculata_leucma_323_264                Leucophenga maculata
# ...                                                                 ...
# Chymomyza_costata                                     Chymomyza costata
# Eristalis_pertinax                                   Eristalis pertinax
# Lonchoptera_bifurcata                             Lonchoptera bifurcata
# Megaselia_abdita                                       Megaselia abdita
# Platypeza_anthrax                                     Platypeza anthrax
#
#                                                  taxonomy_source rank_matched
# tip_name
# Liriomyza_sativae_AG1433_4372_308                            OTT      species  \
# Braula_coeca_Braula_coeca_GDDH01_1_5741_317                  OTT      species
# Braula_coeca_I6794_507_280                                   OTT          NaN
# Leucophenga_varia_L_varia_4359_279_assm.augustus             OTT      species
# Leucophenga_maculata_leucma_323_264                          OTT      species
# ...                                                          ...          ...
# Chymomyza_costata                                            OTT          NaN
# Eristalis_pertinax                                           OTT      species
# Lonchoptera_bifurcata                                        OTT      species
# Megaselia_abdita                                             OTT      species
# Platypeza_anthrax                                            OTT      species
#
#                                                                 matched
# tip_name
# Liriomyza_sativae_AG1433_4372_308                     Liriomyza sativae  \
# Braula_coeca_Braula_coeca_GDDH01_1_5741_317                Braula coeca
# Braula_coeca_I6794_507_280                                 Braula coeca
# Leucophenga_varia_L_varia_4359_279_assm.augustus      Leucophenga varia
# Leucophenga_maculata_leucma_323_264                Leucophenga maculata
# ...                                                                 ...
# Chymomyza_costata                                     Chymomyza costata
# Eristalis_pertinax                                   Eristalis pertinax
# Lonchoptera_bifurcata                             Lonchoptera bifurcata
# Megaselia_abdita                                       Megaselia abdita
# Platypeza_anthrax                                     Platypeza anthrax
#
#                                                   score     ott_id    ncbi_id
# tip_name
# Liriomyza_sativae_AG1433_4372_308                 100.0   246452.0   127406.0  \
# Braula_coeca_Braula_coeca_GDDH01_1_5741_317       100.0    26327.0   305562.0
# Braula_coeca_I6794_507_280                        100.0    26327.0   305562.0
# Leucophenga_varia_L_varia_4359_279_assm.augustus  100.0   765416.0   745178.0
# Leucophenga_maculata_leucma_323_264               100.0   742404.0    30051.0
# ...                                                 ...        ...        ...
# Chymomyza_costata                                 100.0   305192.0    76946.0
# Eristalis_pertinax                                100.0  4354572.0  1572519.0
# Lonchoptera_bifurcata                             100.0   170799.0   385268.0
# Megaselia_abdita                                  100.0  1062936.0    88686.0
# Platypeza_anthrax                                 100.0  4350208.0  1572536.0
#
#                                                  name_source
# tip_name
# Liriomyza_sativae_AG1433_4372_308                        OTT  \
# Braula_coeca_Braula_coeca_GDDH01_1_5741_317              OTT
# Braula_coeca_I6794_507_280                               OTT
# Leucophenga_varia_L_varia_4359_279_assm.augustus         OTT
# Leucophenga_maculata_leucma_323_264                      OTT
# ...                                                      ...
# Chymomyza_costata                                        OTT
# Eristalis_pertinax                                       OTT
# Lonchoptera_bifurcata                                    OTT
# Megaselia_abdita                                         OTT
# Platypeza_anthrax                                        OTT
#
#                                                   matched_id_in_source  ...
# tip_name                                                                ...
# Liriomyza_sativae_AG1433_4372_308                             246452.0  ...  \
# Braula_coeca_Braula_coeca_GDDH01_1_5741_317                    26327.0  ...
# Braula_coeca_I6794_507_280                                     26327.0  ...
# Leucophenga_varia_L_varia_4359_279_assm.augustus              765416.0  ...
# Leucophenga_maculata_leucma_323_264                           742404.0  ...
# ...                                                                ...  ...
# Chymomyza_costata                                             305192.0  ...
# Eristalis_pertinax                                           4354572.0  ...
# Lonchoptera_bifurcata                                         170799.0  ...
# Megaselia_abdita                                             1062936.0  ...
# Platypeza_anthrax                                            4350208.0  ...
#
#                                                           family
# tip_name
# Liriomyza_sativae_AG1433_4372_308                    Agromyzidae  \
# Braula_coeca_Braula_coeca_GDDH01_1_5741_317            Braulidae
# Braula_coeca_I6794_507_280                             Braulidae
# Leucophenga_varia_L_varia_4359_279_assm.augustus   Drosophilidae
# Leucophenga_maculata_leucma_323_264                Drosophilidae
# ...                                                          ...
# Chymomyza_costata                                  Drosophilidae
# Eristalis_pertinax                                     Syrphidae
# Lonchoptera_bifurcata                             Lonchopteridae
# Megaselia_abdita                                        Phoridae
# Platypeza_anthrax                                   Platypezidae
#
#                                                       subfamily
# tip_name
# Liriomyza_sativae_AG1433_4372_308                  Phytomyzinae  \
# Braula_coeca_Braula_coeca_GDDH01_1_5741_317                 NaN
# Braula_coeca_I6794_507_280                                  NaN
# Leucophenga_varia_L_varia_4359_279_assm.augustus     Steganinae
# Leucophenga_maculata_leucma_323_264                  Steganinae
# ...                                                         ...
# Chymomyza_costata                                 Drosophilinae
# Eristalis_pertinax                                  Eristalinae
# Lonchoptera_bifurcata                                       NaN
# Megaselia_abdita                                    Metopininae
# Platypeza_anthrax                                  Platypezinae
#
#                                                            tribe
# tip_name
# Liriomyza_sativae_AG1433_4372_308                            NaN  \
# Braula_coeca_Braula_coeca_GDDH01_1_5741_317                  NaN
# Braula_coeca_I6794_507_280                                   NaN
# Leucophenga_varia_L_varia_4359_279_assm.augustus       Steganini
# Leucophenga_maculata_leucma_323_264                    Steganini
# ...                                                          ...
# Chymomyza_costata                                 Colocasiomyini
# Eristalis_pertinax                                    Eristalini
# Lonchoptera_bifurcata                                        NaN
# Megaselia_abdita                                     Megaseliini
# Platypeza_anthrax                                            NaN
#
#                                                        subtribe
# tip_name
# Liriomyza_sativae_AG1433_4372_308                           NaN  \
# Braula_coeca_Braula_coeca_GDDH01_1_5741_317                 NaN
# Braula_coeca_I6794_507_280                                  NaN
# Leucophenga_varia_L_varia_4359_279_assm.augustus  Leucophengina
# Leucophenga_maculata_leucma_323_264               Leucophengina
# ...                                                         ...
# Chymomyza_costata                                           NaN
# Eristalis_pertinax                                          NaN
# Lonchoptera_bifurcata                                       NaN
# Megaselia_abdita                                            NaN
# Platypeza_anthrax                                           NaN
#
#                                                                          notes
# tip_name
# Liriomyza_sativae_AG1433_4372_308                                          NaN  \
# Braula_coeca_Braula_coeca_GDDH01_1_5741_317       superfamily manually updated
# Braula_coeca_I6794_507_280                        superfamily manually updated
# Leucophenga_varia_L_varia_4359_279_assm.augustus                           NaN
# Leucophenga_maculata_leucma_323_264                                        NaN
# ...                                                                        ...
# Chymomyza_costata                                                          NaN
# Eristalis_pertinax                                                         NaN
# Lonchoptera_bifurcata                                                      NaN
# Megaselia_abdita                                                           NaN
# Platypeza_anthrax                                                          NaN
#
#                                                         genus subgenus
# tip_name
# Liriomyza_sativae_AG1433_4372_308                   Liriomyza      NaN  \
# Braula_coeca_Braula_coeca_GDDH01_1_5741_317            Braula      NaN
# Braula_coeca_I6794_507_280                                NaN      NaN
# Leucophenga_varia_L_varia_4359_279_assm.augustus  Leucophenga      NaN
# Leucophenga_maculata_leucma_323_264               Leucophenga      NaN
# ...                                                       ...      ...
# Chymomyza_costata                                         NaN      NaN
# Eristalis_pertinax                                  Eristalis      NaN
# Lonchoptera_bifurcata                             Lonchoptera      NaN
# Megaselia_abdita                                    Megaselia      NaN
# Platypeza_anthrax                                   Platypeza      NaN
#
#                                                    species group
# tip_name
# Liriomyza_sativae_AG1433_4372_308                            NaN  \
# Braula_coeca_Braula_coeca_GDDH01_1_5741_317                  NaN
# Braula_coeca_I6794_507_280                                   NaN
# Leucophenga_varia_L_varia_4359_279_assm.augustus             NaN
# Leucophenga_maculata_leucma_323_264               maculata group
# ...                                                          ...
# Chymomyza_costata                                  costata group
# Eristalis_pertinax                                           NaN
# Lonchoptera_bifurcata                                        NaN
# Megaselia_abdita                                             NaN
# Platypeza_anthrax                                            NaN
#
#                                                  species subgroup
# tip_name
# Liriomyza_sativae_AG1433_4372_308                             NaN  \
# Braula_coeca_Braula_coeca_GDDH01_1_5741_317                   NaN
# Braula_coeca_I6794_507_280                                    NaN
# Leucophenga_varia_L_varia_4359_279_assm.augustus              NaN
# Leucophenga_maculata_leucma_323_264                           NaN
# ...                                                           ...
# Chymomyza_costata                                             NaN
# Eristalis_pertinax                                            NaN
# Lonchoptera_bifurcata                                         NaN
# Megaselia_abdita                                              NaN
# Platypeza_anthrax                                             NaN
#
#                                                                 species
# tip_name
# Liriomyza_sativae_AG1433_4372_308                     Liriomyza sativae
# Braula_coeca_Braula_coeca_GDDH01_1_5741_317                Braula coeca
# Braula_coeca_I6794_507_280                                          NaN
# Leucophenga_varia_L_varia_4359_279_assm.augustus      Leucophenga varia
# Leucophenga_maculata_leucma_323_264                Leucophenga maculata
# ...                                                                 ...
# Chymomyza_costata                                                   NaN
# Eristalis_pertinax                                   Eristalis pertinax
# Lonchoptera_bifurcata                             Lonchoptera bifurcata
# Megaselia_abdita                                       Megaselia abdita
# Platypeza_anthrax                                     Platypeza anthrax
#
# [2601 rows x 41 columns]

# %%
ordered_ranks = ['domain',
       'kingdom', 'phylum', 'subphylum', 'class', 'subclass', 'infraclass',
       'cohort', 'superorder', 'order', 'suborder', 'infraorder', 'section',
       'superfamily', 'family', 'subfamily', 'tribe', 'subtribe', 'genus',
       'subgenus', 'species group', 'species subgroup', 'species']

tipnames2tax.columns
# Out:
# Index(['name', 'updated_fullname', 'taxonomy_source', 'rank_matched',
#        'matched', 'score', 'ott_id', 'ncbi_id', 'name_source',
#        'matched_id_in_source', 'updated_genus_ott_id', 'updated_genus_ncbi_id',
#        'updated_species_ott_id', 'updated_species_ncbi_id',
#        'ott_accepted_name', 'ott_version', 'higher_source', 'domain',
#        'kingdom', 'phylum', 'subphylum', 'class', 'subclass', 'cohort',
#        'infraclass', 'superorder', 'order', 'suborder', 'infraorder',
#        'section', 'superfamily', 'family', 'subfamily', 'tribe', 'subtribe',
#        'notes', 'genus', 'subgenus', 'species group', 'species subgroup',
#        'species'],
#       dtype='object')

# %% [markdown]
# ## Join trees
# ### Load constraint trees and add metadata to tips
#
# Now let's load our constraint trees and add taxonomic information as metadata.

# %%
#tns = dendropy.TaxonNamespace()

def load_tree(file):
    # Try to load the tree with each schema
    for schema in schemas:
        try:
            tree = dendropy.Tree.get(
                path=str(file),
                schema=schema,
                preserve_underscores=True,
                rooting="default-rooted"#,
                #taxon_namespace = tns
            )
    
            # If we get here, it means the tree was loaded successfully.
            # We can break the loop over schemas.
            break
        except Exception as e:
            pass
    else:
        # If we get here, it means all schemas failed. We skip this file.
        print(f"Skipping {file} as no schema could load it.")
        
    for leaf in tree.leaf_node_iter():
        leaf.taxon.label = leaf.taxon.label.replace(" ","_")
        
        taxon_info = tipnames2tax.loc[leaf.taxon.label]

        # Add the taxonomic information as metadata to the tip
        for column in ['taxonomy_source', 'ott_id', 'ncbi_id', 'ott_version', 'updated_fullname'] + ordered_ranks:
            if taxon_info[column] is not np.nan:
                leaf.annotations.add_new(column, taxon_info[column])
        
        
    return(tree)
                
    

    

directory = Path("./constraint_trees")
schemas = ['newick', 'nexus']
files = {'Diptera':directory/'Wiegmann2011_pg_437.nex',
         'Brachycera':directory/'Shin2018_RAxML_bipartitions.100BT_data_v.rerooted.tree',
         'Schizophora':directory/'Bayless2022_Analysis6_64taxa1130aa_132mp_roguesremoved.rerooted.tre',
         'Oestroidea':directory/'Buenaventura2020_oest_50per_RAxML.rerooted.tre',
         'Ephydroidea':directory/'Winkler2022_ephy_aa.rerooted.tre'
        }


original_trees = {focal_taxon:load_tree(file) for focal_taxon, file in files.items()}

# %% [markdown]
# ### Create synthetic constraint tree
#
# Now let's add names to nodes in our trees. For each higher taxon, we will search for the MRCA of all tips containing that taxon, and we will add the taxon as property to the MRCA. While we do it, we will check for conflicts (i. e. non-monophyletic higher taxa) for the focal taxa in our trees.

# %%
for tree_key in original_trees:
    tree = original_trees[tree_key]
    unique_taxa_tree = dict()

    # Iterate over each rank
    for rank in ordered_ranks:

        unique_taxa_tree[rank] = set()
        taxon_tips = dict()

        for leaf in tree.leaf_node_iter():
            annotation = leaf.annotations.get_value(rank)
            if annotation:
                unique_taxa_tree[rank].add(annotation)

                if annotation not in taxon_tips:
                    taxon_tips[annotation] = []
                taxon_tips[annotation].append(leaf)

        for taxon, tips in taxon_tips.items():
            # Get the MRCA of these tips
            mrca = tree.mrca(taxon_labels=[tip.taxon.label for tip in tips])

            # Verify that all descendants of the MRCA are not associated with any other taxon of the same rank
            conflict_count = 0
            total_descendants = 0
            conflict_tips = []

            for descendant in mrca.leaf_iter():
                total_descendants += 1
                descendant_taxon = descendant.annotations.get_value(rank)
                if descendant_taxon and descendant_taxon != taxon:
                    conflict_count += 1
                    conflict_tips.append(descendant.taxon.label)

            annotated_tips = len(tips)
            
            if taxon in original_trees.keys():
                if conflict_count == 0:
                    # If no conflict was found, add the taxon as a property of the MRCA
                    mrca.annotations.add_new(rank, taxon)
                    print(f"Tree {tree_key}, Rank {rank}, Taxon {taxon} annotated. {annotated_tips} tips annotated, {total_descendants} tips descending from MRCA.")
                else:
                    #print(f"Tree {tree_key}, Rank {rank}, Taxon {taxon} has conflicts. {annotated_tips} tips annotated, {total_descendants} tips descending from MRCA, {conflict_count} conflicts at tips: {conflict_tips}")
                    print(f"Tree {tree_key}, Rank {rank}, Taxon {taxon} has conflicts. {annotated_tips} tips annotated, {total_descendants} tips descending from MRCA, {conflict_count}")
# Out:
# Tree Diptera, Rank order, Taxon Diptera annotated. 203 tips annotated, 206 tips descending from MRCA.
# Tree Diptera, Rank suborder, Taxon Brachycera annotated. 157 tips annotated, 160 tips descending from MRCA.
# Tree Diptera, Rank section, Taxon Schizophora annotated. 110 tips annotated, 112 tips descending from MRCA.
# Tree Diptera, Rank superfamily, Taxon Ephydroidea has conflicts. 8 tips annotated, 10 tips descending from MRCA, 2
# Tree Diptera, Rank superfamily, Taxon Oestroidea annotated. 11 tips annotated, 11 tips descending from MRCA.
# Tree Brachycera, Rank order, Taxon Diptera has conflicts. 1076 tips annotated, 1095 tips descending from MRCA, 1
# Tree Brachycera, Rank suborder, Taxon Brachycera annotated. 1063 tips annotated, 1082 tips descending from MRCA.
# Tree Brachycera, Rank section, Taxon Schizophora annotated. 1 tips annotated, 1 tips descending from MRCA.
# Tree Schizophora, Rank order, Taxon Diptera annotated. 62 tips annotated, 64 tips descending from MRCA.
# Tree Schizophora, Rank suborder, Taxon Brachycera annotated. 62 tips annotated, 64 tips descending from MRCA.
# Tree Schizophora, Rank section, Taxon Schizophora annotated. 53 tips annotated, 54 tips descending from MRCA.
# Tree Schizophora, Rank superfamily, Taxon Oestroidea annotated. 5 tips annotated, 5 tips descending from MRCA.
# Tree Schizophora, Rank superfamily, Taxon Ephydroidea has conflicts. 9 tips annotated, 11 tips descending from MRCA, 2
# Tree Oestroidea, Rank order, Taxon Diptera annotated. 92 tips annotated, 100 tips descending from MRCA.
# Tree Oestroidea, Rank suborder, Taxon Brachycera annotated. 92 tips annotated, 100 tips descending from MRCA.
# Tree Oestroidea, Rank section, Taxon Schizophora annotated. 92 tips annotated, 100 tips descending from MRCA.
# Tree Oestroidea, Rank superfamily, Taxon Oestroidea annotated. 85 tips annotated, 93 tips descending from MRCA.
# Tree Ephydroidea, Rank order, Taxon Diptera annotated. 42 tips annotated, 43 tips descending from MRCA.
# Tree Ephydroidea, Rank suborder, Taxon Brachycera annotated. 42 tips annotated, 43 tips descending from MRCA.
# Tree Ephydroidea, Rank section, Taxon Schizophora annotated. 42 tips annotated, 43 tips descending from MRCA.
# Tree Ephydroidea, Rank superfamily, Taxon Oestroidea annotated. 3 tips annotated, 3 tips descending from MRCA.
# Tree Ephydroidea, Rank superfamily, Taxon Ephydroidea annotated. 31 tips annotated, 32 tips descending from MRCA.

# %% [markdown]
# We had to manually reroot some trees and update taxonomy in Ephydroidea, and now we are free from conflicts. Let's combine these trees into one. We will do this by replacing the focal node in each tree as follows:
#
# - For each tree, we will remove outgroups
# - We will use the Diptera tree as base
# - We will then replace Brachycera in this tree
# - We will then replace Schizophora in this tree
# - We will then replace Oestroidea and Ephydroidea

# %% [markdown]
# ### Prune outgroups

# %%
# To store the pruned trees
pruned_trees = {k:v.clone() for k,v in original_trees.items()}

for ingroup_taxon, tree in pruned_trees.items():
    # Find the ingroup node.
    ingroup_node = None
    for node in tree.postorder_node_iter():
        # Skip leaf nodes
        if node.is_leaf():
            continue
        
        # Infer the ranks from the node's annotations
        ranks = list(node.annotations.values_as_dict().keys())

        for rank in ranks:
            if node.annotations.get_value(rank) == ingroup_taxon:
                ingroup_node = node
                break
        if ingroup_node is not None:
            break

    # If ingroup_node is not found, skip this iteration.
    if ingroup_node is None:
        print('fail')
        continue

    # Infer the ingroup taxa from the descendant nodes of the ingroup node.
    ingroup_taxa = set(leaf.taxon for leaf in ingroup_node.leaf_iter())

    # Remove outgroup taxa from the tree's taxon namespace.
    tree.prune_taxa([taxon for taxon in tree.taxon_namespace if taxon not in ingroup_taxa])

# %% [markdown]
# ### Replace Brachycera in the Diptera tree

# %%
# Step 2.1: In both the 'Brachycera' and 'Diptera' trees, find all annotations of rank "family"
brachycera_tree = pruned_trees['Brachycera'].clone()
diptera_tree = pruned_trees['Diptera'].clone()

brachycera_families = set()
diptera_families = set()

for node in brachycera_tree.postorder_node_iter():
    annotations_dict = node.annotations.values_as_dict()
    if "family" in annotations_dict:
        brachycera_families.add(annotations_dict["family"])

for node in diptera_tree.postorder_node_iter():
    if node.is_leaf():
        annotations_dict = node.annotations.values_as_dict()
        if "family" in annotations_dict:
            diptera_families.add(annotations_dict["family"])

# Step 2.2: Consider only the family names in common between both trees
common_families = brachycera_families.intersection(diptera_families)

# Step 2.3: In the 'Diptera' tree, search for the MRCA of all tips containing these family annotations
tips_with_common_families = []

for node in diptera_tree.postorder_node_iter():
    if node.is_leaf():
        annotations_dict = node.annotations.values_as_dict()
        if "family" in annotations_dict and annotations_dict["family"] in common_families:
            tips_with_common_families.append(node)

# Step 2.4: Find the MRCA of these tips
if tips_with_common_families:
    mrca_node_in_diptera = diptera_tree.mrca(taxa=[tip.taxon for tip in tips_with_common_families])

    # Print out the MRCA node for verification (optional)
    if mrca_node_in_diptera is not None:
        print("MRCA found: ", mrca_node_in_diptera.annotations.values_as_dict())
        # Extract the subtree rooted at MRCA and print it
        subtree = dendropy.Tree(seed_node=copy.deepcopy(mrca_node_in_diptera))
        print("Subtree rooted at MRCA: ")
        print(subtree.print_plot())

        # Step 2.5: Replace the subtree starting at the MRCA in the 'Diptera' tree with the entire 'Brachycera' tree
        # Getting the parent of the MRCA
        parent_node = mrca_node_in_diptera.parent_node

        # Removing the MRCA node from the Diptera tree
        parent_node.remove_child(mrca_node_in_diptera)

        # Adding the Brachycera tree in place of the MRCA in Diptera tree
        parent_node.add_child(brachycera_tree.seed_node)

        print("Subtree replaced successfully.")
    else:
        print("No MRCA found for the given tips.")
else:
    print("No tips found with common families.")
    

# Step 2.7: Encode splits and update namespace
diptera_tree.update_taxon_namespace()
diptera_tree.update_bipartitions()
# Out:
# MRCA found:  {'suborder': 'Brachycera'}
# Subtree rooted at MRCA:
#                                             /---- Trichophthalma_sp
#                                   /---------+
#                                   |         | /-- Xylophagus_abdominalis
#                                   |         \-+
#                                   |           \-- Exeretonevra_angustifrons
#                                /--+
#                                |  |           /-- Rhagio_hirtis
#                                |  | /---------+
#                                |  | |         \-- Vermileo_opacus
#                                |  | |
#                                |  \-+         /-- Chrysopilus_thoracicus
#                                |    | /-------+
#                                |    | |       \-- Bolbomyia_nana
#                                |    \-+
#                                |      | /-------- Glutops_singularis
#                                |      \-+
#                                |        | /------ Oreoleptis_torrenticola
#                                |        \-+
#                                |          | /---- Atherix_variegata
# /------------------------------+          \-+
# |                              |            | /-- Tabanus_atratus
# |                              |            \-+
# |                              |              \-- Haematopota_pluvialis
# |                              |
# |                              |              /-- Hilarimorpha_mentata
# |                              |        /-----+
# |                              |        |     \-- Ogcodes_basalis
# |                              |    /---+
# |                              |    |   | /------ Pantophthalmus_bellardii
# |                              |    |   \-+
# |                              |    |     | /---- Xylomya_parens
# |                              |    |     \-+
# |                              |    |       | /-- Actina_viridis
# |                              |    |       \-+
# |                              \----+         \-- Hermetia_illucens
# |                                   |
# |                                   |       /---- Mythicomyia_sp
# |                                   | /-----+
# |                                   | |     | /-- Paracosmus_sp
# |                                   | |     \-+
# |                                   | |       \-- Bombylius_major
# |                                   | |
# |                                   \-+     /---- Asilus_crabroniformis
# |                                     | /---+
# |                                     | |   | /-- Mydas_clavatus
# +                                     | |   \-+
# |                                     | |     \-- Apiocera_haruspex
# |                                     \-+
# |                                       |     /-- Evocoa_chilensis
# |                                       | /---+
# |                                       | |   \-- Apsilocephala_sp
# |                                       \-+
# |                                         | /---- Prorates_sp
# |                                         \-+
# |                                           | /-- Acrosathe_novella
# |                                           \-+
# |                                             \-- Phycus_kroeberi
# |
# |                                       /-------- Atelestus_pulicarius
# |                                       |
# |                                       |     /-- Parathalassius_candidatus
# | /-------------------------------------+ /---+
# | |                                     | |   \-- Neurigona_quadrifasciata
# | |                                     | |
# | |                                     \-+   /-- Ocydromia_glabricula
# | |                                       | /-+
# | |                                       | | \-- Hybos_culiciformis
# | |                                       \-+
# | |                                         | /-- Clinocera_caerulea
# | |                                         \-+
# | |                                           \-- Oreogeton_scopifer
# \-+
#   | /-------------------------------------------- Apystomyia_elinguis
#   | |
#   | |                               /------------ Lonchoptera_uniseta
#   | | /-----------------------------+
#   | | |                             | /---------- Opetia_nigra
#   | | |                             \-+
#   | | |                               | /-------- Paraplatypeza_velutina
#   | | |                               \-+
#   | | |                                 | /------ Ironomyia_nigromaculata
#   \-+ |                                 \-+
#     | |                                   | /---- Sciadocera_rufomaculata
#     | |                                   \-+
#     | |                                     | /-- Phora_sp
#     | |                                     \-+
#     | |                                       \-- Megaselia_scalaris
#     | |
#     | |                                     /---- Microdon_tristis
#     | | /-----------------------------------+
#     \-+ |                                   | /-- Episyrphus_balteatus
#       | |                                   \-+
#       | |                                     \-- Rhingia_nasica
#       | |
#       | | /-------------------------------------- Cephalops_longistylis
#       | | |
#       | | |                             /-------- Neoalticomerus_seamansi
#       | | |                             |
#       | | |                             |     /-- Periscelis_sp
#       | | |          /------------------+ /---+
#       | | |          |                  | |   \-- Meoneura_sp
#       | | |          |                  | |
#       | | |          |                  \-+   /-- Cerodontha_dorsalis
#       | | |          |                    | /-+
#       | | |          |                    | | \-- Phytomyza_ilicicola
#       \-+ |          |                    \-+
#         | |          |                      | /-- Spelobia_bifrons
#         | |          |                      \-+
#         | |          |                        \-- Pseudocollinella_humida
#         | |          |
#         | |          |                      /---- Coenia_palustris
#         | | /--------+                /-----+
#         | | |        |                |     | /-- Psilopa_polita
#         | | |        |                |     \-+
#         | | |        |                |       \-- Hydrellia_griseola
#         | | |        | /--------------+
#         | | |        | |              |     /---- Drosophila_melanogaster
#         | | |        | |              | /---+
#         | | |        | |              | |   | /-- Braula_coeca
#         | | |        | |              | |   \-+
#         | | |        | |              \-+     \-- Cryptochetum_sp
#         | | |        | |                |
#         \-+ |        | |                | /------ Camilla_sp
#           | |        | |                \-+
#           | |        \-+                  | /---- Curtonotum_helvum
#           | |          |                  \-+
#           | |          |                    | /-- Campichoeta_punctum
#           | |          |                    \-+
#           | |          |                      \-- Diastata_fuscula
#           | |          |
#           | |          | /----------------------- Paratrichobius_longicrus
#           | |          | |
#           | |          | |                  /---- Glossina_morsitans
#           | |          \-+ /----------------+
#           | |            | |                | /-- Crataerina_hirudinus
#           | |            | |                \-+
#           | |            | |                  \-- Ornithomyia_avicularia
#           | |            \-+
#           | |              | /------------------- Fannia_canicularis
#           | |              | |
#           | |              | |              /---- Drymeia_alpicola
#           | |              \-+ /------------+
#           | |                | |            | /-- Musca_domestica
#           | |                | |            \-+
#           | |                | |              \-- Stomoxys_calcitrans
#           | |                \-+
#           | |                  |              /-- Delia_radicum
#           | |                  |  /-----------+
#           | |                  |  |           \-- Scatophaga_stercoraria
#           | |                  |  |
#           \-+                  \--+         /---- Cephenemyia_phobifer
#             |                     | /-------+
#             |                     | |       | /-- Sarcophaga_bullata
#             |                     | |       \-+
#             |                     \-+         \-- Peckia_alvarengai
#             |                       |
#             |                       | /---------- Phyto_melanocephala
#             |                       | |
#             |                       \-+ /-------- Cochliomyia_macellaria
#             |                         | |
#             |                         | |   /---- Gymnosoma_nudifrons
#             |                         \-+ /-+
#             |                           | | | /-- Siphona_flavifrons
#             |                           | | \-+
#             |                           \-+   \-- Tachina_grossa
#             |                             |
#             |                             | /---- Exorista_larvarum
#             |                             \-+
#             |                               | /-- Axinia_zentae
#             |                               \-+
#             |                                 \-- Phania_funesta
#             |
#             | /---------------------------------- Megamerina_sp
#             | |
#             | |                           /------ Gymnochiromyia_sp
#             | |                           |
#             | |                /----------+   /-- Geomyza_tripunctata
#             | |                |          | /-+
#             | |                |          | | \-- Opomyza_florum
#             | |                |          \-+
#             | |                |            | /-- Sepsis_cynipsea
#             | |  /-------------+            \-+
#             | |  |             |              \-- Acartophthalmus_nigrinus
#             | |  |             |
#             | |  |             |              /-- Richardia_teevani
#             | |  |             |  /-----------+
#             | |  |             |  |           \-- Lonchaea_polita
#             | |  |             \--+
#             | |  |                | /------------ Mycetaulus_sp
#             | |  |                | |
#             \-+  |                \-+         /-- Melieria_omissa
#               |  |                  | /-------+
#               |  |                  | |       \-- Herina_palustris
#               |  |                  \-+
#               |  |                    | /-------- Rivellia_syngenesiae
#               |  |                    | |
#               |  |                    \-+ /------ Nepaliseta_ashleyi
#               |  |                      | |
#               |  |                      \-+   /-- Tachinisca_cyaneiventris
#               |  |                        | /-+
#               |  |                        | | \-- Cardiacera_nr._miliacea
#               |  |                        \-+
#               |  |                          | /-- Ceratitis_capitata
#               |  |                          \-+
#               |  |                            \-- Trupanea_bullocki
#               |  |
#               |  |                            /-- Inbiomyia_mcalpineorum
#               |  |                      /-----+
#               |  |                      |     \-- Nemula_longarista
#               \--+                      |
#                  |                  /---+     /-- Aulacigaster_sp
#                  |                  |   | /---+
#                  |                  |   | |   \-- Cyamops_nebulosa
#                  |                  |   | |
#                  |                  |   \-+   /-- Telostylinus_sp
#                  |                  |     | /-+
#                  |                  |     | | \-- Rhinopomyzella_sp
#                  |                  |     \-+
#                  |                  |       | /-- Compsobata_cibaria
#                  | /----------------+       \-+
#                  | |                |         \-- Cnodacophora_sellata
#                  | |                |
#                  | |                |     /------ Somatia_aestiva
#                  | |                | /---+
#                  | |                | |   | /---- Paramyia_nitens
#                  | |                | |   \-+
#                  | |                | |     | /-- Incertella_albipalpis
#                  | |                | |     \-+
#                  | |                \-+       \-- Thaumatomyia_notata
#                  | |                  |
#                  | |                  |     /---- Teloglabrus_sp
#                  | |                  | /---+
#                  | |                  | |   | /-- Sphyracephala_brevicornis
#                  | |                  | |   \-+
#                  | |                  \-+     \-- Cyrtodiopsis_dalmanni
#                  | |                    |
#                  | |                    | /------ Margo_sp
#                  \-+                    \-+
#                    |                      | /---- Azorastia_mediterranea
#                    |                      \-+
#                    |                        | /-- Procanace_dianneae
#                    |                        \-+
#                    |                          \-- Tethinosoma_fulvifrons
#                    |
#                    |                          /-- Neotanypeza_sp
#                    | /------------------------+
#                    | |                        \-- Strongylophthalmyia_pengellyi
#                    | |
#                    | |                    /------ Willistoniella_pleuropunctata
#                    | |                    |
#                    | |                  /-+   /-- Fergusonina_turneri
#                    | |                  | | /-+
#                    | |                  | | | \-- Asteia_amoena
#                    | |                  | \-+
#                    | |                  |   | /-- Xenasteia_shalam
#                    \-+ /----------------+   \-+
#                      | |                |     \-- Australimyza_sp
#                      | |                |
#                      | |                |     /-- Chamaepsila_hennigi
#                      | |                | /---+
#                      | |                | |   \-- Syringogaster_sp
#                      | |                \-+
#                      | |                  | /---- Clusia_lateralis
#                      | |                  \-+
#                      | |                    | /-- Neurochaeta_sp
#                      \-+                    \-+
#                        |                      \-- Palloptera_umbellatarum
#                        |
#                        |                  /------ Teratomya_sp
#                        | /----------------+
#                        | |                | /---- Trixoscelis_sp
#                        | |                \-+
#                        | |                  | /-- Suillia_variegata
#                        | |                  \-+
#                        | |                    \-- Anthomyza_gracilis
#                        \-+
#                          | /--------------------- Heteromyza_atricornis
#                          | |
#                          | |                  /-- Parochthiphila_coronata
#                          | |              /---+
#                          | |              |   \-- Cremifania_nearctica
#                          \-+ /------------+
#                            | |            | /---- Spaniocelyphus_umsinduzi
#                            | |            \-+
#                            | |              | /-- Lyciella_decipiens
#                            | |              \-+
#                            | |                \-- Minettia_flaveola
#                            \-+
#                              |                /-- Natalimyza_sp
#                              | /--------------+
#                              | |              \-- Heterocheila_buccata
#                              | |
#                              | |  /-------------- Stylogaster_sp
#                              \-+  |
#                                |  |           /-- Huttonina_glabra
#                                |  |       /---+
#                                |  |       |   \-- Helcomyza_mirabilis
#                                \--+ /-----+
#                                   | |     | /---- Neosciomyza_luteipennis
#                                   | |     \-+
#                                   | |       | /-- Lopa_convexa
#                                   | |       \-+
#                                   \-+         \-- Coelopa_vanduzeei
#                                     |
#                                     |         /-- Dryomyza_anilis
#                                     | /-------+
#                                     | |       \-- Oedoparena_glauca
#                                     \-+
#                                       | /-------- Pelidnoptera_nigripennis
#                                       | |
#                                       \-+     /-- Physocephala_marginata
#                                         | /---+
#                                         | |   \-- Myopa_sp
#                                         \-+
#                                           | /---- Pherbellia_annulipes
#                                           \-+
#                                             | /-- Neolimnia_obscura_
#                                             \-+
#                                               \-- Tetanocera_ferruginea_
#
#
# None
# Subtree replaced successfully.

# %% [markdown]
# ### Replace Schizophora in the resulting tree

# %%
schizophora_tree = pruned_trees['Schizophora'].clone()

schizophora_families = set()
diptera_families = set()

for node in schizophora_tree.postorder_node_iter():
    annotations_dict = node.annotations.values_as_dict()
    if "family" in annotations_dict:
        schizophora_families.add(annotations_dict["family"])

for node in diptera_tree.postorder_node_iter():
    if node.is_leaf():
        annotations_dict = node.annotations.values_as_dict()
        if "family" in annotations_dict:
            diptera_families.add(annotations_dict["family"])

# Step 2.2: Consider only the family names in common between both trees
common_families = schizophora_families.intersection(diptera_families)

# Step 2.3: In the 'Diptera' tree, search for the MRCA of all tips containing these family annotations
tips_with_common_families = []

for node in diptera_tree.postorder_node_iter():
    if node.is_leaf():
        annotations_dict = node.annotations.values_as_dict()
        if "family" in annotations_dict and annotations_dict["family"] in common_families:
            tips_with_common_families.append(node)

# Step 2.4: Find the MRCA of these tips
if tips_with_common_families:
    mrca_node_in_diptera = diptera_tree.mrca(taxa=[tip.taxon for tip in tips_with_common_families])

    # Print out the MRCA node for verification (optional)
    if mrca_node_in_diptera is not None:
        print("MRCA found: ", mrca_node_in_diptera.annotations.values_as_dict())

        # Step 2.5: Replace the subtree starting at the MRCA in the 'Diptera' tree with the entire 'Schizophora' tree
        # Getting the parent of the MRCA
        parent_node = mrca_node_in_diptera.parent_node

        # Removing the MRCA node from the Diptera tree
        parent_node.remove_child(mrca_node_in_diptera)

        # Adding the Schizophora tree in place of the MRCA in Diptera tree
        parent_node.add_child(schizophora_tree.seed_node)

        print("Subtree replaced successfully.")
    else:
        print("No MRCA found for the given tips.")
else:
    print("No tips found with common families.")
    

# Step 2.7: Encode splits and update namespace
diptera_tree.update_taxon_namespace()
diptera_tree.update_bipartitions()
# Out:
# MRCA found:  {'taxonomy_source': 'OTT', 'ott_id': 693712.0, 'ncbi_id': 385270.0, 'ott_version': 'ott3.5draft1', 'updated_fullname': 'Pherbellia cinerella', 'domain': 'Eukaryota', 'kingdom': 'Metazoa', 'phylum': 'Arthropoda', 'subphylum': 'Hexapoda', 'class': 'Insecta', 'subclass': 'Pterygota', 'infraclass': 'Neoptera', 'cohort': 'Holometabola', 'order': 'Diptera', 'suborder': 'Brachycera', 'infraorder': 'Muscomorpha', 'section': 'Schizophora', 'superfamily': 'Sciomyzoidea', 'family': 'Sciomyzidae'}
# Subtree replaced successfully.

# %% [markdown]
# ### Replace Oestroidea in the resulting tree

# %%
oestroidea_tree = pruned_trees['Oestroidea'].clone()

oestroidea_families = set()
diptera_families = set()

for node in oestroidea_tree.postorder_node_iter():
    annotations_dict = node.annotations.values_as_dict()
    if "family" in annotations_dict:
        oestroidea_families.add(annotations_dict["family"])

for node in diptera_tree.postorder_node_iter():
    if node.is_leaf():
        annotations_dict = node.annotations.values_as_dict()
        if "family" in annotations_dict:
            diptera_families.add(annotations_dict["family"])

# Step 2.2: Consider only the family names in common between both trees
common_families = oestroidea_families.intersection(diptera_families)

# Step 2.3: In the 'Diptera' tree, search for the MRCA of all tips containing these family annotations
tips_with_common_families = []

for node in diptera_tree.postorder_node_iter():
    if node.is_leaf():
        annotations_dict = node.annotations.values_as_dict()
        if "family" in annotations_dict and annotations_dict["family"] in common_families:
            tips_with_common_families.append(node)

# Step 2.4: Find the MRCA of these tips
if tips_with_common_families:
    mrca_node_in_diptera = diptera_tree.mrca(taxa=[tip.taxon for tip in tips_with_common_families])

    # Print out the MRCA node for verification (optional)
    if mrca_node_in_diptera is not None:
        print("MRCA found: ", mrca_node_in_diptera.annotations.values_as_dict())
        
        # Extract the subtree rooted at MRCA and print it
        subtree = dendropy.Tree(seed_node=copy.deepcopy(mrca_node_in_diptera))
        print("Subtree rooted at MRCA: ")
        print(subtree.print_plot())


        # Step 2.5: Replace the subtree starting at the MRCA in the 'Diptera' tree with the entire 'Oestroidea' tree
        # Getting the parent of the MRCA
        parent_node = mrca_node_in_diptera.parent_node

        # Removing the MRCA node from the Diptera tree
        parent_node.remove_child(mrca_node_in_diptera)

        # Adding the Oestroidea tree in place of the MRCA in Diptera tree
        parent_node.add_child(oestroidea_tree.seed_node)

        print("Subtree replaced successfully.")
    else:
        print("No MRCA found for the given tips.")
else:
    print("No tips found with common families.")
    

# Step 2.7: Encode splits and update namespace
diptera_tree.update_taxon_namespace()
diptera_tree.update_bipartitions()
# Out:
# MRCA found:  {'superfamily': 'Oestroidea'}
# Subtree rooted at MRCA:
# /------------------------------------------------------- Sarcophaga_bullata
# |
# +                                    /------------------ Pollenia
# |                 /------------------+
# |                 |                  \------------------ Triarthria_setipennis
# \-----------------+
#                   |                  /------------------ Calliphora_vomitoria
#                   \------------------+
#                                      \------------------ Stomorhina_subapicalis
#
#
# None
# Subtree replaced successfully.

# %% [markdown]
# ### Replace Ephydroidea in the resulting tree

# %%
ephydroidea_tree = pruned_trees['Ephydroidea'].clone()

ephydroidea_families = set()
diptera_families = set()

for node in ephydroidea_tree.postorder_node_iter():
    annotations_dict = node.annotations.values_as_dict()
    if "family" in annotations_dict:
        ephydroidea_families.add(annotations_dict["family"])

for node in diptera_tree.postorder_node_iter():
    if node.is_leaf():
        annotations_dict = node.annotations.values_as_dict()
        if "family" in annotations_dict:
            diptera_families.add(annotations_dict["family"])

# Step 2.2: Consider only the family names in common between both trees
common_families = ephydroidea_families.intersection(diptera_families)

# Step 2.3: In the 'Diptera' tree, search for the MRCA of all tips containing these family annotations
tips_with_common_families = []

for node in diptera_tree.postorder_node_iter():
    if node.is_leaf():
        annotations_dict = node.annotations.values_as_dict()
        if "family" in annotations_dict and annotations_dict["family"] in common_families:
            tips_with_common_families.append(node)

# Step 2.4: Find the MRCA of these tips
if tips_with_common_families:
    mrca_node_in_diptera = diptera_tree.mrca(taxa=[tip.taxon for tip in tips_with_common_families])

    # Print out the MRCA node for verification (optional)
    if mrca_node_in_diptera is not None:
        print("MRCA found: ", mrca_node_in_diptera.annotations.values_as_dict())
        
        # Extract the subtree rooted at MRCA and print it
        subtree = dendropy.Tree(seed_node=copy.deepcopy(mrca_node_in_diptera))
        print("Subtree rooted at MRCA: ")
        print(subtree.print_plot())


        # Step 2.5: Replace the subtree starting at the MRCA in the 'Diptera' tree with the entire 'Ephydroidea' tree
        # Getting the parent of the MRCA
        parent_node = mrca_node_in_diptera.parent_node

        # Removing the MRCA node from the Diptera tree
        parent_node.remove_child(mrca_node_in_diptera)

        # Adding the Ephydroidea tree in place of the MRCA in Diptera tree
        parent_node.add_child(ephydroidea_tree.seed_node)

        print("Subtree replaced successfully.")
    else:
        print("No MRCA found for the given tips.")
else:
    print("No tips found with common families.")
    

# Step 2.7: Encode splits and update namespace
diptera_tree.update_taxon_namespace()
diptera_tree.update_bipartitions()
# Out:
# MRCA found:  {}
# Subtree rooted at MRCA:
# /------------------------------------------------------ Scatella_tenuicosta
# |
# |                                              /------- Diastata_repleta
# +      /---------------------------------------+
# |      |                                       \------- Curtonotum
# |      |
# \------+       /--------------------------------------- Cryptochetum
#        |       |
#        |       |                       /--------------- Braula_coeca
#        \-------+       /---------------+
#                |       |               |       /------- Stegana
#                |       |               \-------+
#                \-------+                       \------- Phortica_variegata
#                        |
#                        |       /----------------------- Chymomyza_costata
#                        \-------+
#                                |       /--------------- Drosophila_melanogaster
#                                \-------+
#                                        |       /------- D_virilis
#                                        \-------+
#                                                \------- D_busckii
#
#
# None
# Subtree replaced successfully.

# %% [markdown]
# ### Plot the resulting synthetic tree

# %%
diptera_tree.print_plot()
# Out:
# /-------------------- Deuterophlebia_coloradensis
# |
# /-------------------- Nymphomyia_dolichopeza
# |
# |                /--- Trichocera_brevicornis
# |                |
# |/---------------+/-- Ula_elegans
# ||               ||
# ||               ||/- Dactylolabis_montana
# ||               \++
# ||                ||/ Hexatoma_longicornis
# ||                |\+
# ||                + \ Hoplolabis_armata
# ||                |
# ||                |/- Liogma_nodicornis
# +|                \+
# ||                 |- Antocha_obtusa
# ||                 +
# ||                 |/ Dolichopeza_americana
# ||                 \+
# ||                  \ Tipula_abdominalis
# ||
# ||                  / Bittacomorpha_sp
# ||               /--+
# ||               |  \ Ptychoptera_sp
# ||               |
# ||               |/-- Edwardsina_gigantea
# ||               |+
# ||               ||/- Protoplasa_fitchii
# |/---------------+|+
# ||               |||- Clogmia_albipunctata
# +|               ||+
# ||               |||/ Lutzomyia_longipalpis
# ||               ||\+
# ||               || \ Phlebotomus_duboscqui
# ||               \+
# ||                |/- Dixa_submaculata
# ||                ||
# ||                |+/ Corethrella_amazonica
# ||                ||+
# ||                ||\ Chaoborus_americana
# ||                |+
# ||                ||/ Toxorhynchites_amboinensis
# ||                +\+
# ||                | \ Anopheles_gambiae
# ||                |
# ||                | / Stilobezzia_antennalis
# ||                |/+
# ||                ||\ Chironomus_tepperi
# ||                \+
# ||                 |- Androprosopa_americana
# ||                 +
# ||                 |/ Simulium_paynei
# ||                 \+
# ||                  \ Parasimulium_crosskeyi
# ||
# ||/------------------ Perissomma_mcalpinei
# |||
# |||                 / Olbiogaster_sackeni
# |||            /----+
# |||            |    \ Sylvicola_fenestralis
# \+|            |
#  |/------------+    / Synneuron_decipiens
#  ||            |/---+
#  ||            ||   \ Coboldia_fuscipes
#  ||            ||
#  ||            \+---- Axymyia_furcata
#  ||             |
#  ||             |   / Bibio_longipes
#  ||             +/--+
#  ||             ||  \ Cramptonomyia_spenceri
#  ||             ||
#  ||             \+  / Manota_sp
#  ||              |--+
#  ||              |  \ Symmerus_annulatus
#  ||              |
#  ||              +/-- Diadocidia_ferruginosa
#  ||              ||
#  ||              ||/- Pseudobrachypeza_bulbosa
#  ||              \++
#  ||               ||/ Bolitophila_sp
#  ||               |\+
#  ||               + \ Arachnocampa_flava
#  ||               |
#  ||               |/- Bradysia_tilicola
#  ||               \+
#  ||                |- Lygistorrhina_sanctaecatharinae
#  ||                +
#  ||                |/ Mayetiola_destructor
#  ||                \+
#  ||                 \ Lestremiinae_sp
#  ||
#  ||  /--------------- Hilarimorpha_sp_Hilarimorphidae
#  ||  |
#  ||  |             /- Hirmoneura_sp_SLW_2006c_Nemestrinidae
#  ||  |             +
#  ||  |             |/ Nemestrinidae_gen_sp_Nemestrinidae
#  ||  |             |+
#  ||  |             |\ Hirmoneura_sp_MDT_2010_Nemestrinidae
#  ||  |         /---+
#  ||  |         |   |/ Nemestrinus_aegyptiacus_Nemestrinidae
#  ||  |         |   |+
#  ||  |         |   |\ Neorhynchocephalus_volaticus_Nemestrinidae
#  ||  |         |   +
#  ||  |         |   |/ Trichophthalma_sp_SLW_2002_Nemestrinidae
#  ||  |         |   \+
#  ||  |         |    \ Trichophthalma_sp_LRC_2002_Nemestrinidae
#  ||  |         |
#  ||  |         |  /-- Acrocera_bulla_Acroceridae
#  ||  |         /--+
#  ||  |/--------+  |/- sphaerops_sp_SLW_2002_Acroceridae
#  ||  ||        |  \+
#  ||  ||        |   |- Acrocera_orbicula_Acroceridae
#  ||  ||        |   +
#  ||  ||        |   |/ Acrocera_sp_SLW_2002b_Acroceridae
#  ||  ||        |   \+
#  +|  ||        |    \ Acrocera_sp_SLW_2002a_Acroceridae
#  ||  ||        |
#  ||  ||        |    / Acroceridae_sp_New_Caledonia_Acroceridae
#  ||  ||        |  /-+
#  ||  ||        |  | \ Helle_longirostris_Acroceridae
#  ||  ||        |  |
#  ||  ||        +/-+/- Megalybus_nr__pictus_SLW_2002_Acroceridae
#  ||  ||        || |+
#  ||  ||        || ||/ Philopota_sp_SLW_2002b_Acroceridae
#  ||  ||        || |\+
#  ||  ||        || + \ Terphis_sp_SLW_2002_Acroceridae
#  ||  ||        || |
#  ||  ||        || |/- Parahelle_sp_SLW_2002_Acroceridae
#  ||  ||        || ||
#  ||  ||        || \+/ Thyllis_sp_SLW_2002a_Acroceridae
#  ||  ||        ||  |+
#  ||  ||        ||  |\ Thyllis_crassa_Acroceridae
#  ||  ||        ||  +
#  ||  ||        ||  |/ Thyllis_splendens_Acroceridae
#  ||  ||        ||  \+
#  ||  ||        \+   \ Thyllis_philopotoides_Acroceridae
#  ||  ||         |
#  ||  ||         |   / Turbopsebius_sp_SLW_2002_Acroceridae
#  ||  ||         |  /+
#  ||  ||         |  |\ Turbopsebius_diligens_Acroceridae
#  ||  ||         |--+
#  ||  ||         |  |/ Paracyrtus_sp_SLW_2002_Acroceridae
#  ||  ||         |  \+
#  ||  ||         |   \ Turbopsebius_sp_SLW_2006_Acroceridae
#  ||  ||         |
#  ||  ||         |/--- Holops_sp_SLW_2002_Acroceridae
#  ||  ||         ||
#  ||  ||         ||  / Pterodontia_sp_SLW_2002_Acroceridae
#  ||  ||         |+/-+
#  ||  ||         ||| \ Psilodera_affinis_Acroceridae
#  ||  ||         +||
#  ||/-+|         ||+ / Ogcodes_fumatus_Acroceridae
#  ||| ||         |||-+
#  ||| ||         ||| \ Ogcodes_canadensis_Acroceridae
#  ||| ||         ||+
#  ||| ||         |||/- Ogcodes_basalis_Acroceridae
#  ||| ||         ||\+
#  ||| ||         || |- Ogcodes_leptisoma_Acroceridae
#  ||| ||         || +
#  ||| ||         || |/ Ogcodes_sp_SLW_2002_Acroceridae
#  ||| ||         \+ \+
#  ||| ||          |  \ Ogcodes_sp_LRC_2002_Acroceridae
#  ||| ||          |
#  ||| ||          | /- Arrhynchus_nr_vittatus_SLW_200_Acroceridae2
#  ||| ||          | +
#  ||| ||          | |/ Arrhynchus_penai_Acroceridae
#  ||| ||          | |+
#  ||| ||          |-+\ Archipialea_sp_SLW_2002_Acroceridae
#  ||| ||          | |
#  ||| ||          | |- Ocnaea_sp_SLW_2002a_Acroceridae
#  ||| ||          | +
#  ||| ||          | |/ Ocnaea_sp_SLW_2002b_Acroceridae
#  ||| ||          | \+
#  ||| ||          +  \ Ocnaea_sp_SLW_2002c_Acroceridae
#  ||| ||          |
#  ||| ||          |  / Astomella_sp_SLW2002_Acroceridae
#  ||| ||          |/-+
#  ||| ||          || \ Apsona_muscaria_Acroceridae
#  ||| ||          ||
#  ||| ||          \+/- Eulonchus_smaragdinus_Acroceridae
#  ||| ||           |+
#  ||| ||           ||/ Eulonchus_marialiciae_Acroceridae
#  ||| ||           |\+
#  ||| ||           + \ Eulonchus_sp_SLW2002c_Acroceridae
#  ||| ||           |
#  ||| ||           |/- Lasia_sp_SLW_2002c_Acroceridae
#  ||| ||           \+
#  ||| ||            |- Lasia_sp_SLW_2002a_Acroceridae
#  ||| ||            +
#  ||| ||            |/ Lasia_carbonanicus_Acroceridae
#  ||| ||            \+
#  ||| ||             \ Lasia_sp_SLW_2002d_Acroceridae
#  ||| ||
#  ||| ||            /- Pantophthalmus_sp_Pantophthalmidae
#  ||| ||   /--------+
#  ||| ||   |        |/ Pantophthalmus_sp_Pantophthalmidae_MDT_2010
#  ||| ||   |        \+
#  ||| ||   |         \ Pantophthalmus_sp_Pantophthalmidae_BW_2000
#  ||| ||   |
#  ||| ||   |         / Xylomya_parens_Xylomyidae
#  ||| ||   /---------+
#  ||| ||   |         \ Solva_sp_CB0434_Xylomyidae
#  ||| ||   |
#  \+| ||   |         / Exodontha_dubia_Stratiomyidae
#   || |/---+        /+
#   || ||   |        |\ Antissa_sp_SLW_2002_Stratiomyidae
#   || ||   |      /-+
#   || ||   |      | |- Beris_morrisii_Stratiomyidae
#   || ||   |      | +
#   || ||   |      | |/ Chorisops_tunisiae_Stratiomyidae
#   || ||   |      | \+
#   || \+   |/-----+  \ Actina_chalybea_Stratiomyidae
#   ||  |   ||     |
#   ||  |   ||     |--- Parhadrestia_atava_Stratiomyidae
#   ||  |   +|     |
#   ||  |   ||     | /- Chiromyza_sp_CB0313_Stratiomyidae
#   ||  |   ||     +/+
#   ||  |   ||     |||/ Cyanauges_maculatus_CB0433_Stratiomyidae
#   ||  |   ||     ||\+
#   ||  |   ||     \+ \ Cyanauges_ruficornis_CB0407_Stratiomyidae
#   ||  |   ||      |
#   ||  |   ||      |-- Lecomyia_sp_CB0413_Stratiomyidae
#   ||  |   ||      |
#   ||  |   ||      + / Heteracanthia_sp_Stratiomyidae
#   ||  |   ||      |/+
#   ||  |   ||      ||\ Oplachantha_sp_CB0225_Stratiomyidae
#   ||  |   ||      \+
#   ||  |   ||       |- Beridops_sp_CB0437_Stratiomyidae
#   ||  |   \+       +
#   ||  |    |       |/ Neoberis_brasiliana_Stratiomyidae
#   ||  |    |       \+
#   ||  |    |        \ Actina_viridis_Stratiomyidae
#   ||  |    |
#   ||  |    |       /- Artemita_aurata_CB0303_Stratiomyidae
#   ||  |    |-------+
#   ||  |    |       |- Platylobium_zurstrasseni_Stratiomyidae
#   ||  |    |       +
#   ||  |    |       |/ Pseudocyphomyia_mimetica_Stratiomyidae
#   ||  |    |       \+
#   ||  |    |        \ Proegmenomyia_metallica_Stratiomyidae
#   ||  |    |
#   ||  |    |        / Pachygaster_atra_Stratiomyidae
#   ||  |    |       /+
#   ||  |    |       |\ Tinda_javana_Stratiomyidae
#   ||  |    |/------+
#   ||  |    ||      |/ Culcua_kolibaci_Stratiomyidae
#   ||  |    +|      \+
#   ||  |    ||       \ Culcua_nigra_Stratiomyidae
#   ||  |    ||
#   ||  |    ||    /--- Nemotelus_cingulatus_Stratiomyidae
#   ||  |    ||    |
#   ||  |    ||    |  / Oxycera_trilineata_Stratiomyidae
#   ||  |    ||    | /+
#   ||  |    |/----+ |\ Hermionella_seguyi_Stratiomyidae
#   ||  |    ||    |/+
#   ||  |    ||    |||/ Oxycera_pardalina_Stratiomyidae
#   ||  |    ||    ||\+
#   ||  |    ||    \+ \ Oxycera_marginata_Stratiomyidae
#   ||  |    ||     |
#   ||  |    \+     |-- Prosopochrysa_vitripennis_Stratiomyidae
#   ||  |     |     |
#   ||  |     |     + / Oplodontha_viridula_Stratiomyidae
#   ||  |     |     |/+
#   ||  |     |     ||\ Odontomyia_flavissima_Stratiomyidae
#   ||  |     |     \+
#   ||  |     |      |- Stratiomys_potamida_Stratiomyidae
#   ||  |     |      +
#   ||  |     |      |/ Stratiomys_ruficornis_Stratiomyidae
#   ||  |     |      \+
#   ||  |     |       \ Stratiomys_longicorni_Stratiomyidae
#   ||  |     |
#   ||  |     |      /- Ruba_opponens_Stratiomyidae
#   ||  |     |  /---+
#   ||  |     |  |   |- Chrysochlorina_sp_CB0410_Stratiomyidae
#   ||  |     +  |   +
#   ||  |     |  |   |/ Hermetia_melanderi_Stratiomyidae
#   ||  |     |  |   \+
#   ||  |     |/-+    \ Hermetia_illucens_Stratiomyidae
#   ||  |     || |
#   ||  |     || |    / Abavus_sp_Stratiomyidae
#   ||  |     || |/---+
#   ||  |     || ||   \ Acropeltates_sp_CB0311_Stratiomyidae
#   ||  |     || ||
#   ||  |     || \+  /- Nemotelus_sp_CB0506_Stratiomyidae
#   ||  |     ||  |--+
#   ||  |     ||  |  |/ Nemotelus_sp_CB0430_Stratiomyidae
#   ||  |     ||  |  \+
#   ||  |     ||  +   \ Nemotelus_nigrinus_Stratiomyidae
#   ||  |     ||  |
#   ||  |     ||  |/--- Eudmeta_marginata_Stratiomyidae
#   ||  |     ||  ||
#   ||  |     ||  \+--- Solva_marginata_Xylomyidae
#   ||  |     ||   |
#   ||  |     ||   +/-- Microchrysa_polita_Stratiomyidae
#   ||  |     ||   ||
#   ||  |     \+   \+ / Sargus_bipunctatus_Stratiomyidae
#   ||  |      |    |-+
#   ||  |      |    | \ Ptecticus_brevipennis_Stratiomyidae
#   ||  |      |    +
#   ||  |      |    |/- Chloromyia_formosa_CB0502_Stratiomyidae
#   ||  |      |    \+
#   ||  |      |     |- Sargus_thoracicus_Stratiomyidae
#   ||  |      |     +
#   ||  |      |     |/ Ptecticus_sp_CB0409_Stratiomyidae
#   ||  |      |     \+
#   ||  |      |      \ Merosargus_pictipes_Stratiomyidae
#   ||  |      |
#   ||  |      |------- Alopecuroceras_coloratum_Stratiomyidae
#   ||  |      |
#   ||  |      |/------ Lasiopa_balius_Stratiomyidae
#   ||  |      ||
#   ||  |      ||   /-- Adoxomyia_bistriata_Stratiomyidae
#   ||  |      ||   |
#   ||  +      ||  /+ / Nigritomyia_loewii_Stratiomyidae
#   ||  |      +|  ||-+
#   ||  |      ||  || \ Nigritomyia_consobrina_Stratiomyidae
#   ||  |      ||  |+
#   ||  |      ||  ||/- Adoxomyia_sp_CB0419_Stratiomyidae
#   ||  |      ||  |\+
#   ||  |      ||  | |- Adoxomyia_rustica_CB0316_Stratiomyidae
#   ||  |      ||  | +
#   ||  |      ||  | |/ Clitellaria_ephippium_Stratiomyidae
#   ||  |      \+--+ \+
#   ||  |       |  |  \ Adoxomyia_regularis_CB0428_Stratiomyidae
#   ||  |       |  |
#   ||  |       |  | /- Hedriodiscus_binotatus_Stratiomyidae
#   ||  |       |  |/+
#   ||  |       |  |||- Odontomyia_occidentalis_Stratiomyidae
#   ||  |       |  ||+
#   ||  |       |  |||/ Stratiomys_laticeps_CB0319_Stratiomyidae
#   ||  |       |  ||\+
#   ||  |       |  \+ \ Stratiomyidae_sp_ESB_2006_Stratiomyidae
#   ||  |       |   |
#   ||  |       |   | / Euparyphus_sp_CB0429_Stratiomyidae
#   ||  |       |   |/+
#   ||  |       |   ||\ Euparyphus_pardalinus_Stratiomyidae
#   ||  |       +   \+
#   ||  |       |    |- Myxosargus_knowltoni_Stratiomyidae
#   ||  |       |    +
#   ||  |       |    |/ Histiodroma_sp_CB0301_Stratiomyidae
#   ||  |       |    \+
#   ||  |       |     \ Raphiocera_ornata_CB0406_Stratiomyidae
#   ||  |       |
#   ||  |       |   /-- Dieuryneura_stigma_Stratiomyidae
#   ||  |       |/--+
#   ||  |       ||  |/- Ampsalis_terminalis_CB0401_Stratiomyidae
#   ||  |       ||  \+
#   ||  |       ||   |- Dysbiota_parvula_Stratiomyidae
#   ||  |       ||   +
#   ||  |       ||   |/ Auloceromyia_sp_CB0435_Stratiomyidae
#   ||  |       ||   \+
#   ||  |       \+    \ Lagenosoma_sp_CB0403_Stratiomyidae
#   +|  |        |
#   ||  |        |   /- Cf__Euryneura_sp_CB0427_Stratiomyidae
#   ||  |        |---+
#   ||  |        |   |- Ditylometopa_elegans_Stratiomyidae
#   ||  |        |   +
#   ||  |        |   |/ Diaphorostylus_nasica_Stratiomyidae
#   ||  |        |   \+
#   ||  |        +    \ Euryneura_propinqua_Stratiomyidae
#   ||  |        |
#   ||  |        |/---- Leucoptilum_sp_CB0326_Stratiomyidae
#   ||  |        ||
#   ||  |        ||   / Labocerina_atrata_Stratiomyidae
#   ||  |        ||  /+
#   ||  |        \+  |\ Abasanistus_rubricornis_Stratiomyidae
#   ||  |         |--+
#   ||  |         |  |/ Chordonota_inermis_CB0324_Stratiomyidae
#   ||  |         |  \+
#   ||  |         +   \ Chordonota_sp_CB0436_Stratiomyidae
#   ||  |         |
#   ||  |         |/--- Dicyphoma_schaefferi_Stratiomyidae
#   ||  |         ||
#   ||  |         \+--- Cyphomyia_dispar_CB0109_Stratiomyidae
#   ||  |          |
#   ||  |          +  / Cyphomyia_erecta_CB0426_Stratiomyidae
#   ||  |          |/-+
#   ||  |          || \ Cyphomyia_altifrons_CB0105_Stratiomyidae
#   ||  |          \+
#   ||  |           |-- Cyphomyia_nr_androgyna_CB0201_Stratiomyidae
#   ||  |           +
#   ||  |           |/- Cyphomyia_souzalopesi_CB0102_Stratiomyidae
#   ||  |           \+
#   ||  |            |- Cyphomyia_n_sp_1_CAB2005_Stratiomyidae
#   ||  |            +
#   ||  |            |/ Cyphomyia_pulchella_CB0212_Stratiomyidae
#   ||  |            \+
#   ||  |             \ Cyphomyia_cyanea_CB0203_Stratiomyidae
#   ||  |
#   ||  |            /- Rachicerus_obscuripennis_Xylophagidae
#   ||  |           /+
#   ||  |           ||- Heterostomus_curvipalpis_Xylophagidae
#   ||  |           |+
#   ||  |           ||/ Exeretonevra_angustifrons_Xylophagidae
#   ||  |/----------+\+
#   ||  ||          | \ Xylophagus_cinctus_Xylophagidae
#   ||  ||          |
#   ||  ||          |/- Heterostomus_sp_PHK2011_Xylophagidae
#   ||  ||          \+
#   ||  ||           |- Dialysis_elongata_Xylophagidae
#   ||  ||           +
#   ||  ||           |/ Coenomyia_ferruginea_Xylophagidae
#   ||  ||           \+
#   ||  ||            \ Arthropeas_magnum_Xylophagidae
#   ||  ||
#   ||  ||          /-- Ptiolina_sp_PHK_2011_Rhagionidae
#   ||  ||          |
#   ||  ||          + / spaniopsis_longicornis_Rhagionidae
#   ||  ||          |/+
#   ||  ||          ||\ spaniopsis_clelandi_Rhagionidae
#   ||  ||          |+
#   ||  ||          ||- Symphoromyia_sp_PHK_2006_Rhagionidae
#   ||  ||          |+
#   ||  ||        /-+|/ Symphoromyia_sp_SLB_2003_Rhagionidae
#   ||  ||        | |\+
#   ||  ||        | | \ Symphoromyia_hirta_Rhagionidae
#   ||  ||        | |
#   ||  ||        | |-- Ptiolina_fasciata_Rhagionidae
#   ||  ||        | |
#   ||  ||        | +/- Arthroceras_fulvicorne_Rhagionidae
#   ||  ||        | ||
#   ||  ||        | \+/ Chrysopilus_quadratus_Rhagionidae
#   ||  \+        |  |+
#   ||   |        |  |\ Chrysopilus_rhagiodes_Rhagionidae
#   ||   |--------+  +
#   ||   |        |  |/ Chrysopilus_sp_2_PHK_2006_Rhagionidae
#   ||   |        |  \+
#   ||   |        |   \ Chrysopilus_sp_3_PHK_2006_Rhagionidae
#   ||   |        |
#   ||   |        |/--- Bolbomyia_nana_Bolbomyiidae
#   ||   |        ||
#   ||   |        ||  / Rhagio_hirtus_Rhagionidae
#   ||   |        || /+
#   ||   |        || |\ Rhagio_mystaceus_Rhagionidae
#   ||   |        || |
#   ||   |        \+-+/ Vermileo_sp_PHK_2006_Vermileonidae
#   ||   |         | |+
#   ||   |         | |\ Leptynoma_hessei_Vermileonidae
#   ||   |         | +
#   ||   |         | |/ Vermileo_opacus_Vermileonidae
#   ||   |         | \+
#   ||   |         +  \ Vermilio_opacus_Vermileonidae
#   ||   |         |
#   ||   |         | /- Austroleptis_rhyphoides_Austroleptidae
#   ||   |         |/+
#   ||   |         |||/ Austroleptis_multimaculatus_Austroleptidae
#   ||   |         ||\+
#   ||   |         \+ \ Austroleptis_collessi_Austroleptidae
#   ||   |          |
#   ||   |          |-- Arthroteles_cinerea_Rhagionidae
#   ||   |          |
#   ||   +          + / Atherimorpha_atrifemur_Rhagionidae
#   ||   |          |/+
#   ||   |          ||\ Atherimorpha_nemoralis_Rhagionidae
#   ||   |          \+
#   ||   |           |- Atherimorpha_sp_3_PHK_Rhagionidae
#   ||   |           +
#   ||   |           |/ Atherimorpha_vernalis_Rhagionidae
#   ||   |           \+
#   ||   |            \ Atherimorpha_sp_2_PHK_Rhagionidae
#   ||   |
#   ||   |           /- Pseudoerinna_jonesi_Pelecorhynchidae
#   ||   |/----------+
#   ||   ||          |- Pelecorhynchus_personatus_Pelecorhynchidae
#   ||   ||          +
#   ||   ||          |/ Glutops_rossi_Pelecorhynchidae
#   ||   ||          \+
#   ||   ||           \ Glutops_singularis_Pelecorhynchidae
#   ||   ||
#   ||   |/------------ Oreoleptis_torrenticola_Oreoleptidae
#   ||   ||
#   ||   ||          /- Atherix_variegata_Athericidae
#   ||   ||          +
#   ||   ||          |/ Suragina_longipes_Athericidae
#   ||   ||          |+
#   ||   ||/---------+\ Atherix_marginata_Athericidae
#   ||   |||         |
#   ||   |||         |- Dasyomma_sp_Athericidae
#   ||   |||         +
#   ||   \+|         |/ Dasyomma_vittatum_Athericidae
#   ||    ||         \+
#   ||    ||          \ Dasyomma_caeruleum_Athericidae
#   ||    ||
#   ||    ||/---------- Phibalomyia_carteri_Tabanidae
#   ||    |||
#   ||    ||/---------- Lilaea_Lilaea_fuliginosa_Tabanidae
#   ||    |||
#   ||    |||        /- Silvius_Griseosilvius_quadrivi_Tabanidaettatus
#   ||    |||     /--+
#   ||    |||     |  |- Adersia_oestroides_Tabanidae
#   ||    |/+     |  +
#   ||    |||     |  |/ Silvius_Silvius_variegatus_Tabanidae
#   ||    |||     |  \+
#   ||    |||/----+   \ Silvius_Silvius_gigantulus_Tabanidae
#   ||    ||||    |
#   ||    ||||    |---- Chrysops_coquilletti_Tabanidae
#   ||    ||||    |
#   ||    +|+|    |  /- Chrysops_caecutiens_Tabanidae
#   ||    ||||    +/-+
#   ||    ||||    || |/ Chrysops_dispar_Tabanidae
#   ||    ||||    || \+
#   ||    ||||    \+  \ Chrysops_madagascariensis_Tabanidae
#   ||    ||||     |
#   ||    ||||     |--- Chrysops_flavidus_Tabanidae
#   ||    ||||     +
#   ||    ||||     |/-- Chrysops_sp_20_bighindtibia_Tabanidae
#   ||    ||||     \+
#   ||    ||||      |-- Chrysops_upsilon_Tabanidae
#   ||    ||||      +
#   ||    ||\+      |/- Chrysops_viduatus_Tabanidae
#   ||    || |      \+
#   ||    || |       |- Chrysopilus_thoracicus_Rhagionidae
#   ||    || |       +
#   ||    || |       |/ Chrysops_vittatus_Tabanidae
#   ||    || |       \+
#   ||    || |        \ Chrysops_carbonarius_Tabanidae
#   ||    || |
#   ||    || |        / Aegophagamyia_Triclida_variega_Tabanidaeta
#   ||    || |       /+
#   ||    || |       |\ Aegophagamyia_Triclida_sp_1_n_Tabanidaer_brunnea
#   ||    || |-------+
#   ||    || |       |/ Rhigioglossa_sp_2_RSA_Tabanidae
#   ||    || |       \+
#   ||    || |        \ Rhigioglossa_edentula_Tabanidae
#   ||    || |
#   ||    || |       /- Thaumastocera_akwa_Tabanidae
#   ||    \+ +/------+
#   ||     | ||      |- Tabanocella_Tabanocella_dentic_Tabanidaeornis
#   ||     | ||      +
#   ||     | ||      |/ Tabanocella_Tabanocella_sp_3_Tabanidae
#   ||     | ||      \+
#   ||     | ||       \ Orgizomyia_zigzag_Tabanidae
#   ||     | ||
#   ||     | \+-------- Agelanius_lanei_Tabanidae
#   ||     |  |
#   ||     |  |       / Limata_sp_1_SIM_was_Diachlori_Tabanidaeni_sp_RSA
#   ||     |  |    /--+
#   ||     |  |    |  \ Limata_sp_2_MEI_was_Limata_or_Tabanidae_Amanella
#   ||     |  |/---+
#   ||     |  ||   |/-- Cydistomyia_victoriensis_Tabanidae
#   ||     |  +|   \+
#   ||     |  ||    |-- Dasybasis_Protodasyommia_trans_Tabanidaeversa_sp_2
#   ||     |  ||    +
#   ||     |  ||    |/- Dasybasis_Protodasyommia_batra_Tabanidaenkii_sp_1
#   ||     |  ||    \+
#   ||     |  ||     |- Dasybasis_sp_11_Tabanidae
#   ||     |  ||     +
#   ||     |  ||     |/ Dasybasis_neobasalis_Tabanidae
#   ||     |  \+     \+
#   ||     |   |      \ Dasybasis_gentilis_Tabanidae
#   ||     |   |
#   ||     |   |------- Stenotabanus_Stenotabanus_sp__Tabanidae1
#   ||     |   |
#   ||     |   |   /--- Dasybasis_sp_3_Tabanidae
#   ||     |   |   |
#   ||     |   |/--+--- Chlorotabanus_inanis_Tabanidae
#   ||     |   ||  |
#   ||     |   ||  |  / Stypommisa_captiroptera_sp_2__TabanidaeFRGY
#   ||     |   ||  +/-+
#   ||     |   +|  || \ Stypommisa_sp_4_Tabanidae
#   ||     |   ||  ||
#   ||     |   ||  \+/- Dicladocera_macula_nr_Tabanidae
#   ||     |   ||   |+
#   ||     |   ||   ||/ Philipotabanus_pterographicus_Tabanidae
#   ||     |   ||   |\+
#   ||     |   ||   + \ Philipotabanus_stigmaticalis_Tabanidae
#   ||     |   ||   |
#   ||     |   \+   |/- Catachlorops_Psalidia_fulmineu_Tabanidaes
#   ||     |    |   \+
#   ||     |    |    |- Dasychela_Triceratomyia_macint_Tabanidaeyrei
#   ||     |    |    +
#   ||     |    |    |/ Acanthocera_sp_1_Tabanidae
#   ||     |    |    \+
#   ||     |    |     \ Dichelacera_regina_Tabanidae
#   ||     |    |
#   ||     |    |------ Diachlorus_nr_curvipes_sp_2_Tabanidae
#   ||     |    |
#   ||     +    |/----- Tabanus_pellucidus_sp_15_Tabanidae
#   ||     |    ||
#   ||     |    +|  /-- Tabanus_rufofrater_Tabanidae
#   ||     |    |/--+
#   ||     |    ||  |/- Tabanus_hirtitibia_or_discus_Tabanidae
#   ||     |    ||  \+
#   ||     |    \+   |- Tabanus_aegrotus_Tabanidae
#   ||     |     |   +
#   ||     |     |   |/ Tabanus_sulcifrons_Tabanidae
#   ||     |     |   \+
#   ||     |     |    \ Tabanus_atratus_Tabanidae?
#   ||     |     |
#   ||     |     |  /-- Hybomitra_rhombica_Tabanidae
#   ||     |     +/-+
#   ||     |     || |/- Hybomitra_bimaculata_Tabanidae
#   ||     |     || \+
#   ||     |     ||  |- Hybomitra_cincta_Tabanidae
#   ||     |     ||  +
#   ||     |     ||  |/ Hybomitra_illota_Tabanidae
#   ||     |     ||  \+
#   ||     |     ||   \ Hybomitra_epistates_Tabanidae
#   ||     |     ||
# ...
#             |   |  +
#             |   |  |/ Hydrophorus_borealis_Dolichopodidae
#             |   |  \+
#             |   |   \ Hydrophorus_rogenhoferi_Dolichopodidae
#             |   |
#             |   |/--- Aphrosylus_celtiber_Dolichopodidae
#             |   ||
#             |   \+--- Argyra_vestita_Dolichopodidae
#             |    |
#             |    |  / Argyra_elongata_Dolichopodidae
#             |    +/-+
#             |    || \ Argyra_diaphana_Dolichopodidae
#             |    ||
#             |    \+/- Argyra_atriceps_Dolichopodidae
#             |     |+
#             |     ||/ Argyra_ilonae_Dolichopodidae
#             +     |\+
#             |     + \ Argyra_grata_Dolichopodidae
#             |     |
#             |     |/- Argyra_perplexa_Dolichopodidae
#             |     \+
#             |      |- Argyra_argentina_Dolichopodidae
#             |      +
#             |      |/ Argyra_leucocephala_Dolichopodidae
#             |      \+
#             |       \ Argyra_argyria_Dolichopodidae
#             |
#             |       / Peloropeodes_sp_Pollet_0306_Dolichopodidae
#             |    /--+
#             |    |  \ Peloropeodes_sp_Pollet_0301_Dolichopodidae
#             |    |
#             |/---+  / Nepalomyia_sp_2_SNK_2009_Dolichopodidae
#             ||   |/-+
#             ||   || \ Nepalomyia_sp_1_SNK_2009_Dolichopodidae
#             ||   ||
#             ||   \+ / Scotiomyia_sp_SNK_2009_Dolichopodidae
#             ||    |-+
#             ||    | \ Scotiomyia_cf_singaporensis_SN_DolichopodidaeK_2009
#             ||    +
#             ||    |/- Acropsilus_sp_1_SNK_2009_Dolichopodidae
#             ||    \+
#             ||     |- Acropsilus_niger_Dolichopodidae
#             \+     +
#              |     |/ Acropsilus_sp_3_SNK_2009_Dolichopodidae
#              |     \+
#              |      \ Acropsilus_sp_2_SNK_2009_Dolichopodidae
#              |
#              |------- Pelastoneurus_sp_Pollet_0309_Dolichopodidae
#              |
#              |      / Hercostomus_meieri_Dolichopodidae
#              |/-----+
#              ||     \ Hercostomus_brevidigitalis_Dolichopodidae
#              ||
#              +|    /- Tachytrechus_tessellatus_Dolichopodidae
#              |/----+
#              ||    |/ Tachytrechus_transitorius_Dolichopodidae
#              ||    \+
#              ||     \ Tachytrechus_notatus_Dolichopodidae
#              ||
#              \+     / Hercostomus_plagiatus_Dolichopodidae
#               |/----+
#               ||    \ Hercostomus_verbekei_Dolichopodidae
#               ||
#               ||  /-- Dolichopus_campestris_Dolichopodidae
#               ||  |
#               ||  |/- Dolichopus_ungulatus_Dolichopodidae
#               ||/-++
#               ||| ||/ Dolichopus_claviger_Dolichopodidae
#               ||| |\+
#               +|| + \ Dolichopus_brevipennis_Dolichopodidae
#               ||| |
#               ||| |/- Dolichopus_arbustorum_Dolichopodidae
#               ||| \+
#               |||  |- Dolichopus_trivialis_Dolichopodidae
#               |||  +
#               |||  |/ Dolichopus_festivus_Dolichopodidae
#               |||  \+
#               |/+   \ Dolichopus_cilifemoratus_Dolichopodidae
#               |||
#               |||  /- Dolichopus_longicornis_Dolichopodidae
#               |||--+
#               |||  |/ Dolichopus_linearis_Dolichopodidae
#               |||  \+
#               |||   \ Dolichopus_acuticornis_Dolichopodidae
#               |||
#               \+| /-- Dolichopus_lepidus_Dolichopodidae
#                ||/+
#                ||||-- Dolichopus_longitarsis_Dolichopodidae
#                |+|+
#                ||||/- Dolichopus_nigricornis_Dolichopodidae
#                |||\+
#                ||| |- Dolichopus_atripes_Dolichopodidae
#                ||| +
#                ||| |/ Dolichopus_planitarsis_Dolichopodidae
#                ||| \+
#                |||  \ Dolichopus_genicupallidus_Dolichopodidae
#                |\+
#                | |  / Dolichopus_bigeniculatus_Dolichopodidae
#                | | /+
#                | | |\ Dolichopus_tanythrix_Dolichopodidae
#                | |-+
#                | | |- Dolichopus_clavipes_Dolichopodidae
#                | | +
#                | | |/ Dolichopus_nitidus_Dolichopodidae
#                | | \+
#                | |  \ Dolichopus_griseipennis_Dolichopodidae
#                | +
#                | | /- Dolichopus_latilimbatus_Dolichopodidae
#                | |/+
#                | |||/ Dolichopus_nubilus_Dolichopodidae
#                + ||\+
#                | || \ Dolichopus_excisus_Dolichopodidae
#                | \+
#                |  | / Dolichopus_urbanus_Dolichopodidae
#                |  |-+
#                |  | \ Dolichopus_popularis_Dolichopodidae
#                |  +
#                |  |/- Dolichopus_signatus_Dolichopodidae
#                |  \+
#                |   |- Dolichopus_subpennatus_Dolichopodidae
#                |   +
#                |   |/ Dolichopus_argyrotarsis_Dolichopodidae
#                |   \+
#                |    \ Dolichopus_pennatus_Dolichopodidae
#                |
#                |    / Paraclius_digitatus_Dolichopodidae
#                | /--+
#                | |  \ Argyrochlamys_impudicus_Dolichopodidae
#                | |
#                |/+  / Hercostomus_praeceps_Dolichopodidae
#                |||/-+
#                |||| \ Hercostomus_fulvicaudis_Dolichopodidae
#                ||||
#                ||\+ / Hercostomus_longiventris_Dolichopodidae
#                || |-+
#                || | \ Hercostomus_chetifer_Dolichopodidae
#                || |
#                || +/- Sybistroma_discipes_Dolichopodidae
#                || |+
#                || ||/ Sybistroma_obscurellum_Dolichopodidae
#                || ||+
#                || \+\ Sybistroma_crinipes_Dolichopodidae
#                ||  |
#                \+  |- Nodicornis_nodicornis_Dolichopodidae
#                 |  +
#                 |  |/ Hercostomus_parvilamellatus_Dolichopodidae
#                 |  \+
#                 |   \ Hercostomus_nanus_Dolichopodidae
#                 |
#                 |   / Hercostomus_vivax_Dolichopodidae
#                 |---+
#                 |   \ Hercostomus_fugax_Dolichopodidae
#                 |
#                 |/--- Gymnopternus_helveticus_Dolichopodidae
#                 ||
#                 || /- Gymnopternus_blankaartensis_Dolichopodidae
#                 |+/+
#                 ||||/ Gymnopternus_assimilis_Dolichopodidae
#                 +||\+
#                 ||| \ Gymnopternus_cupreus_Dolichopodidae
#                 ||+
#                 ||| / Gymnopternus_angustifrons_Dolichopodidae
#                 |||-+
#                 ||| \ Gymnopternus_aerosus_Dolichopodidae
#                 ||+
#                 |||/- Gymnopternus_metallicus_Dolichopodidae
#                 ||\+
#                 \+ |- Gymnopternus_silvestris_Dolichopodidae
#                  | +
#                  | |/ Gymnopternus_celer_Dolichopodidae
#                  | \+
#                  |  \ Gymnopternus_brevicornis_Dolichopodidae
#                  |
#                  | /- Hercostomus_nigriplantis_Dolichopodidae
#                  |-+
#                  | |/ Hercostomus_vockerothi_Dolichopodidae
#                  | \+
#                  |  \ Hercostomus_nigrilamellatus_Dolichopodidae
#                  |
#                  +/-- Hercostomus_pilifer_Dolichopodidae
#                  ||
#                  || / Poecilobothrus_chrysozygos_Dolichopodidae
#                  ||/+
#                  |||\ Poecilobothrus_nobilitatus_Dolichopodidae
#                  \++
#                   ||- Dolichopus_sp_Dolichopodidae_NCSU_97010378
#                   |+
#                   ||/ Poecilobothrus_regalis_Dolichopodidae
#                   |\+
#                   + \ Poecilobothrus_principalis_Dolichopodidae
#                   |
#                   | / Dolichopus_sp_Dolichopodidae_NCSU_99071924
#                   |/+
#                   ||\ Dolichopus_sp_Dolichopodidae
#                   \+
#                    |- Hercostomus_germanus_Dolichopodidae
#                    +
#                    |/ Hercostomus_chaerophylli_Dolichopodidae
#                    \+
#                     \ Hercostomus_nigripennis_Dolichopodidae

# %% [markdown]
# ### List non-mophyletic genera

# %%
# create a dictionary to store all leaf nodes in the same genus
genus_dict = defaultdict(list)

# iterate over the leaf nodes in the tree
for leaf in diptera_tree.leaf_node_iter():
    genus = leaf.annotations.get_value("genus")
    genus_dict[genus].append(leaf.taxon)

# list to store non-monophyletic genera
non_monophyletic = []

# iterate over each genus
for genus, taxa in genus_dict.items():
    # get the MRCA of all taxa in the genus
    mrca = diptera_tree.mrca(taxa=taxa)
    descendants = set(mrca.leaf_nodes())
    # if all descendants of the MRCA are in the genus, then it's monophyletic
    if not all([leaf.taxon in taxa for leaf in descendants]) and genus is not None:
        non_monophyletic.append(genus)

# print all non-monophyletic genera
print("Non-monophyletic genera:", non_monophyletic)

# print tree plot for each non-monophyletic genus
for genus in non_monophyletic:
    taxa = genus_dict[genus]
    mrca = diptera_tree.mrca(taxa=taxa)
    print("MRCA for genus", genus, ":")
    subtree = dendropy.Tree(seed_node=copy.deepcopy(mrca))
    print("Subtree rooted at MRCA: ")
    print(subtree.print_plot())
# Out:
# Non-monophyletic genera: ['Esenbeckia', 'Mesembrinella']
# MRCA for genus Esenbeckia :
# Subtree rooted at MRCA:
#                  /---- Esenbeckia_Palassomyia_fascipe_Tabanidaennis
# /----------------+
# |                \---- Mycteromyia_sp_1_Tabanidae
# +
# |   /----------------- Pegasomyia_abaureus_Tabanidae
# \---+
#     |   /------------- Esenbeckia_Esenbeckia_prasiniv_Tabanidaeentris
#     \---+
#         |    /-------- Esenbeckia_nr_lugubris_Fidena__TabanidaeLaphriomyia_sp_4
#         \----+
#              |   /---- Esenbeckia_Ricardoa_delta_Tabanidae
#              \---+
#                  \---- Esenbeckia_Ricardoa_sp_3_Tabanidae
#
#
# None
# MRCA for genus Mesembrinella :
# Subtree rooted at MRCA:
# /------------------------------------------------- MES_Mesembrinella_batesi
# +
# |                        /------------------------ MES_Mesembrinella_flavicrura
# \------------------------+
#                          \------------------------ MES_Mesembrinella_spicata
#
#
# None

# %% [markdown]
# ### Fix non-monophyletic genera
#
# There are only two non-mophyletic genera. Mesembrinella is made non-monophyletic because Mesembrinella spicata was updated to Henriquella spicata in Open Tree Taxonomy. However, a recent taxonomic treatment shows that it is currently considered Mesembrinella (https://www.biotaxa.org/Zootaxa/article/view/zootaxa.4659.1.1), and so says the phylogenetic tree. In this case, we will update the node information.
#
# The other conflict is Esenbeckia. It seems the subgenus Palassomyia renders it non-monophyletic. In this case, we will remove this node from the tree.
#
# Let's start by updating Mesembrinella spicata:

# %%
# Find the corresponding node in the tree
specific_node = diptera_tree.find_node_with_taxon_label("MES_Mesembrinella_spicata")

# Annotations to be updated
annotations_to_update = {
    "taxonomy_source": "OTT+manual",
    "updated_fullname": "Mesembrinella spicata",
    "genus": "Mesembrinella",
    "species": "Mesembrinella spicata"
}

# Update annotations for the specific node
for annotation in specific_node.annotations:
    if annotation.name in annotations_to_update:
        annotation.value = annotations_to_update[annotation.name]

# Print all annotations for the specific node to confirm the updates
for annotation in specific_node.annotations:
    print(f"{annotation.name}: {annotation.value}")
# Out:
# taxonomy_source: OTT+manual
# ott_id: 4389190.0
# ncbi_id: nan
# ott_version: ott3.5draft1
# updated_fullname: Mesembrinella spicata
# domain: Eukaryota
# kingdom: Metazoa
# phylum: Arthropoda
# subphylum: Hexapoda
# class: Insecta
# subclass: Pterygota
# infraclass: Neoptera
# cohort: Holometabola
# order: Diptera
# suborder: Brachycera
# infraorder: Muscomorpha
# section: Schizophora
# superfamily: Oestroidea
# family: Calliphoridae
# subfamily: Mesembrinellinae
# genus: Mesembrinella
# species: Mesembrinella spicata

# %% [markdown]
# Now let's remove Esenbeckia_Palassomyia_fascipe_Tabanidaennis

# %%
# Remove the taxon from the tree
diptera_tree.prune_taxa_with_labels(["Esenbeckia_Palassomyia_fascipe_Tabanidaennis"])

# %% [markdown]
# Now let's check again

# %%
# create a dictionary to store all leaf nodes in the same genus
genus_dict = defaultdict(list)

# iterate over the leaf nodes in the tree
for leaf in diptera_tree.leaf_node_iter():
    genus = leaf.annotations.get_value("genus")
    genus_dict[genus].append(leaf.taxon)

# list to store non-monophyletic genera
non_monophyletic = []

# iterate over each genus
for genus, taxa in genus_dict.items():
    # get the MRCA of all taxa in the genus
    mrca = diptera_tree.mrca(taxa=taxa)
    descendants = set(mrca.leaf_nodes())
    # if all descendants of the MRCA are in the genus, then it's monophyletic
    if not all([leaf.taxon in taxa for leaf in descendants]) and genus is not None:
        non_monophyletic.append(genus)

# print all non-monophyletic genera
print("Non-monophyletic genera:", non_monophyletic)

# print tree plot for each non-monophyletic genus
for genus in non_monophyletic:
    taxa = genus_dict[genus]
    mrca = diptera_tree.mrca(taxa=taxa)
    print("MRCA for genus", genus, ":")
    subtree = dendropy.Tree(seed_node=copy.deepcopy(mrca))
    print("Subtree rooted at MRCA: ")
    print(subtree.print_plot())
# Out:
# Non-monophyletic genera: []

# %% [markdown]
# ### List non-monophyletic families
#
# Now let's do the same for families

# %%
# create a function that returns a label combining the family name and the taxon label
def label_with_family(node):
    family = node.annotations.get_value("family")
    return f"{family}_{node.taxon.label}"

# create a dictionary to store all leaf nodes in the same family
family_dict = defaultdict(list)

# iterate over the leaf nodes in the tree
for leaf in diptera_tree.leaf_node_iter():
    family = leaf.annotations.get_value("family")
    family_dict[family].append(leaf.taxon)

# list to store non-monophyletic families
non_monophyletic = []
monophyletic = []

# iterate over each family
for family, taxa in family_dict.items():
    # get the MRCA of all taxa in the family
    mrca = diptera_tree.mrca(taxa=taxa)
    descendants = set(mrca.leaf_nodes())
    # if all descendants of the MRCA are in the family, then it's monophyletic
    if not all([leaf.taxon in taxa for leaf in descendants]) and family is not None:
        non_monophyletic.append(family)
    else:
        monophyletic.append(family)

# print all non-monophyletic families
print("Non-monophyletic families:", non_monophyletic)
print("Monophyletic families:", monophyletic)
# Out:
# Non-monophyletic families: ['Limoniidae', 'Mycetophilidae', 'Hilarimorphidae', 'Nemestrinidae', 'Acroceridae', 'Xylomyidae', 'Stratiomyidae', 'Rhagionidae', 'Tabanidae', 'Bombyliidae', 'Mydidae', 'Asilidae', 'Scenopinidae', 'Therevidae', 'Conopidae', 'Heleomyzidae', 'Calliphoridae', 'Oestridae', 'Rhiniidae', 'Ephydridae', 'Drosophilidae', 'Empididae', 'Hybotidae', 'Dolichopodidae']
# Monophyletic families: ['Deuterophlebiidae', 'Nymphomyiidae', 'Trichoceridae', 'Pediciidae', 'Cylindrotomidae', 'Tipulidae', 'Ptychopteridae', 'Blephariceridae', 'Tanyderidae', 'Psychodidae', 'Dixidae', 'Chaoboridae', 'Culicidae', 'Ceratopogonidae', 'Chironomidae', 'Thaumaleidae', 'Simuliidae', 'Perissommatidae', 'Anisopodidae', 'Synneuridae', 'Scatopsidae', 'Axymyiidae', 'Bibionidae', 'Pachyneuridae', 'Diadocidiidae', 'Keroplatidae', 'Sciaridae', 'Lygistorrhinidae', 'Cecidomyiidae', None, 'Pantophthalmidae', 'Xylophagaidae', 'Vermileonidae', 'Austroleptidae', 'Pelecorhynchidae', 'Oreoleptidae', 'Athericidae', 'Mythicomyiidae', 'Apioceridae', 'Evocoidae', 'Apsilocephalidae', 'Platypezidae', 'Pipunculidae', 'Chamaemyiidae', 'Coelopidae', 'Helcomyzidae', 'Lauxaniidae', 'Sciomyzidae', 'Sphaeroceridae', 'Micropezidae', 'Neriidae', 'Piophilidae', 'Ulidiidae', 'Tephritidae', 'Opomyzidae', 'Psilidae', 'Strongylophthalmyiidae', 'Acartophthalmidae', 'Sepsidae', 'Diopsidae', 'Canacidae', 'Australimyzidae', 'Anthomyzidae', 'Asteiidae', 'Chloropidae', 'Neminidae', 'Aulacigastridae', 'Periscelididae', 'Fergusoninidae', 'Carnidae', 'Agromyzidae', 'Odiniidae', 'Hippoboscidae', 'Glossinidae', 'Muscidae', 'Scathophagidae', 'Sarcophagidae', 'Tachinidae', 'Rhinophoridae', 'Mormotomyiidae', 'Camillidae', 'Campichoetidae', 'Diastatidae', 'Curtonotidae', 'Cryptochetidae', 'Braulidae', 'Atelestidae']

# %% [markdown]
# Several families are non-monophyletic. We will NOT fix this now. Let's just keep this in mind when building constraints

# %% [markdown]
# ### Save tree as NEXML
#
# Commented out since we did this already.

# %%
#with open('./constraint_trees/result/all_taxa_merged.nexml', 'w') as output_file:
#    diptera_tree.write(file=output_file, schema="nexml")

# %% [markdown]
# ## Prepare a genus-level constraint tree
#
# As a first attempt, we will try to build a genus-level constraint tree. If there is enough overlap between this and our genetic data, we may be able to use this tree as backbone while leaving genera not included floating.
#
# Since genus will be our unit of analysis, let's collapse all genera and rename tips to just their genus names and ncbi IDs. We will also remove genera without NCBI IDS

# %%
# Clone the original tree
cloned_tree = copy.deepcopy(diptera_tree)

# Iterate over the leaf nodes of the cloned tree
for leaf in cloned_tree.leaf_node_iter():
    # Get the genus annotation for the leaf node
    genus = leaf.annotations.get_value("genus")
    # If the genus annotation does not exist or is None, prune the leaf node
    if genus is None:
        cloned_tree.prune_subtree(leaf)

# Now, the cloned_tree should only contain leaves that have a non-null genus annotation

# %%
# Function to check if all elements in a list are equal
def all_equal(iterable):
    iterator = iter(iterable)
    try:
        first = next(iterator)
    except StopIteration:
        return True
    return all(first == rest for rest in iterator)

# Step 1: create a list of all genera listed in the "genus" attribute of leaves in the tree.
genus_list = list(set([leaf.annotations.get_value("genus") for leaf in cloned_tree.leaf_node_iter() if leaf.annotations.get_value("genus") is not None]))

# Step 2: Loop through genera
for genus in genus_list:
    # Step 3: Find leaves with this genus
    leaves = [leaf for leaf in cloned_tree.leaf_node_iter() if leaf.annotations.get_value("genus") == genus]
    
    
    if len(leaves) == 1:
        leaf = leaves[0]
        leaf.annotations.drop(name="species")
        continue
    

    else:
        mrca = cloned_tree.mrca(taxon_labels=[leaf.taxon.label for leaf in leaves])
        
        # Clear all annotations of this MRCA
        mrca.annotations.clear()

        # Get the unique set of annotations across all leaves for the current genus
        annotation_keys = set().union(*[leaf.annotations for leaf in leaves])

        # For each unique annotation, replace it at the MRCA only if it has the same value in all tips
        for key in annotation_keys:
            # Get the values of the current annotation for all leaves
            annotation_values = [leaf.annotations.get_value(key) for leaf in leaves]

            # If the annotation has the same value in all leaves, set it for the MRCA
            if all_equal(annotation_values):
                mrca.annotations.add_new(key, annotation_values[0])

        # Prune all leaves under the MRCA, making it a new leaf
        for leaf in leaves:
            cloned_tree.prune_subtree(leaf)

# %%
to_keep = []
for leaf in cloned_tree.leaf_node_iter():
    if not np.isnan(leaf.annotations.get_value("ncbi_id")):
        leaf.taxon.label = leaf.annotations.get_value("genus") + "_" + str(int(leaf.annotations.get_value("ncbi_id")))
        to_keep.append(leaf.taxon.label)
        
genus_tree = cloned_tree.extract_tree_with_taxa_labels(to_keep)

# %%
genus_tree.print_plot()
# Out:
# /--------------------------------------------------- Deuterophlebia_560720
# |
# |/-------------------------------------------------- Nymphomyia_560767
# ||
# ||                                       /---------- Trichocera_560761
# ||                                       |
# || /-------------------------------------+ /-------- Ula_560789
# +| |                                     | |
# || |                                     | |    /--- Dactylolabis_560718
# || |                                     \-+/---+
# || |                                       ||   | /- Hexatoma_560713
# || |                                       ||   \-+
# || |                                       \+     \- Hoplolabis_560726
# || |                                        |
# \+ |                                        | /----- Liogma_560732
#  | |                                        \-+
#  | |                                          | /--- Antocha_560706
#  | |                                          \-+
#  | |                                            | /- Dolichopeza_560711
#  | |                                            \-+
#  | |                                              \- Tipula_560804
#  | |
#  | |                                              /- Bittacomorpha_79307
#  | |                                     /--------+
#  | |                                     |        \- Ptychoptera_209691
#  | |                                     |
#  | |                                     |    /----- Edwardsina_560712
#  \-+                                     | /--+
#    | /-----------------------------------+ |  | /--- Protoplasa_560777
#    | |                                   | |  \-+
#    | |                                   | |    | /- Clogmia_85120
#    | |                                   | |    \-+
#    | |                                   | |      \- Lutzomyia_7200
#    | |                                   | |
#    | |                                   \-+  /----- Dixa_560710
#    | |                                     |  |
#    | |                                     |/-+   /- Corethrella_1262235
#    | |                                     || | /-+
#    | |                                     || | | \- Chaoborus_204565
#    | |                                     || \-+
#    | |                                     ||   | /- Toxorhynchites_46208
#    | |                                     \+   \-+
#    | |                                      |     \- Anopheles_7165
#    | |                                      |
#    | |                                      |     /- Stilobezzia_209713
#    | |                                      | /---+
#    | |                                      | |   \- Chironomus_113505
#    | |                                      \-+
#    \-+                                        | /--- Androprosopa_560705
#      |                                        \-+
#      |                                          | /- Simulium_560802
#      |                                          \-+
#      |                                            \- Parasimulium_61060
#      |
#      | /-------------------------------------------- Perissomma_560775
#      | |
#      | |                               /------------ Olbiogaster_560769
#      | |                               |
#      | |/------------------------------+          /- Synneuron_560783
#      | ||                              | /--------+
#      | ||                              | |        \- Coboldia_170625
#      | ||                              \-+
#      | ||                                | /-------- Axymyia_560716
#      | ||                                \-+
#      | ||                                  |/------- Cramptonomyia_209689
#      | ||                                  \+
#      | ||                                   | /----- Pseudobrachypeza_560779
#      | ||                                   \-+
#      \-+|                                     | /--- Bradysia_1262229
#        ||                                     \-+
#        ||                                       | /- Lygistorrhina_560763
#        ||                                       \-+
#        ||                                         \- Mayetiola_39758
#        ||
#        ||                                  /-------- Carvalhoa_1933013
#        ||                                  |
#        ||                                  |  /----- Aegophagamyia_1547371
#        || /--------------------------------+/-+
#        || |                                || | /--- Tabanocella_415259
#        || |                                || \-+
#        || |                                ||   | /- Dicladocera_1547391
#        || |                                \+   \-+
#        \+ |                                 |     \- Dasychela_1547376
#         | |                                 |
#         | |                                 |     /- Esenbeckia_124297
#         | |                                 \-----+
#         | |                                       \- Copidapha_1334959
#         | |
#         | | /--------------------------------------- Actenomeros_240478
#         | | |
#         | | |                                 /----- Pseudodinia_1572572
#         | | |                                 |
#         | | |   /-----------------------------+   /- Coelopa_169498
#         | | |   |                             | /-+
#         | | |   |                             | | \- Helcomyza_169477
#         | | |   |                             \-+
#         | | |   |                               | /- Sapromyza_1572539
#         | | |   |                               \-+
#         | | |   |                                 \- Limnia_1226590
#         | | |   |
#         | | |   |                                 /- Tapeigaster_1572574
#         | | |   |/--------------------------------+
#         | | | /-+|                                \- Leptocera_1614655
#         | | | | ||
#         | | | | ||                                /- Micropeza_1572562
#         | | | | ||                         /------+
#         \-+ | | ||                         |      \- Derocephalus_1335465
#           | | | ||                         |
#           | | | || /-----------------------+      /- Piophila_1572535
#           | | | || |                       |/-----+
#           | | | || |                       ||     \- Zacompsia_1572576
#           | | | || |                       ||
#           | | | \+ |                       \+     /- Opomyza_1298491
#           | | |  | |                        | /---+
#           | | |  | |                        | |   \- Loxocera_1572522
#           | | |  | |                        \-+
#           | | |  | |                          | /--- Strongylophthalmyia_768797
#           | | |  | |                          \-+
#           | | |  | |                            | /- Acartophthalmus_1262227
#           | | |  | |                            \-+
#           | | |  | |                              \- Meroplius_1572525
#           | | |  | |
#           | | |  | |                              /- Teleopsis_139649
#           | | |  | | /----------------------------+
#           | | |  \-+ |                            \- Mumetopia_1572527
#           | | |    | |
#           | | |    | |                        /----- Lipara_1323540
#           | | |    | | /----------------------+
#           | | |    | | |                      | /--- Aulacigaster_1473611
#           | | |    | | |                      \-+
#           | | |    | | |                        | /- Fergusonina_1230336
#           | | |    | | |                        \-+
#           | | |    | | |                          \- Melanagromyza_286470
#           | | |    | | |
#           | | |    | | |                          /- Ortholfersia_1572531
#           \-+ |    | | |  /-----------------------+
#             | |    | | |  |                       \- Glossina_7394
#             | |    | | |  |
#             | |    | | |  | /----------------------- Mesembrina_116148
#             | |    | | | /+ |
#             | |    \-+ | || | /--------------------- Cordilura_113132
#             | |      | | || | |
#             | |      | | || | | /------------------- Laneella_1658054
#             | |      | | |\-+ | |
#             | |      | | |  | | |  /---------------- Hypoderma_204921
#             | |      | | |  | | |  |
#             | |      | | |  | | |  | /-------------- Dermatobia_115427
#             | |      | | |  | | | /+ |
#             | |      | | |  \-+ | || |            /- Oestrus_123737
#             | |      | | |    | | || | /----------+
#             | |      | | |    | | |\-+ |          \- Cephenemyia_170894
#             | |      | | |    | | |  | |
#             | |      | | |    | | |  | |        /--- Eumacronychia_2021517
#             | |      | | |    | | |  | |      /-+
#             | |      | | |    | | |  | |      | | /- Sarcotachina_2021535
#             | |      | | |    | | |  \-+      | \-+
#             | |      | | |    | | |    | /----+   \- Amobia_1935040
#             | |      | | |    \-+ |    | |    |
#             | |      \-+ |      | |    | |    |   /- Dexagria_2021514
#             | |        | |      | |    | |    \---+
#             | |        | |      | |    | |        \- Paramacronychia_2021525
#             | |        | |      | |    \-+
#             | |        | |      | |      |        /- Oxysarcodexia_657617
#             | |        | |      | |      | /------+
#             | |        | |      | |      | |      \- Ravinia_543378
#             | |        | |      | |      | |
#             | |        | |      | |      | |  /----- Argoravinia_657623
#             | |        | |      | |      \-+/-+
#             | |        | |      | |        || | /--- Comasarcophaga_2173404
#             | |        | |      | |        || \-+
#             | |        | |      | |        ||   | /- Blaesoxipha_128954
#             | |        | |      | |        \+   \-+
#             | |        | |      | |         |     \- Spirobolomyia_670655
#             | |        | |      \-+         |
#             | |        | |        |         |   /--- Chrysagria_2173395
#             | |        | |        |         \---+
#             | |        | |        |             | /- Helicobia_657631
#             | |        | |        |             \-+
#             | |        | |        |               \- Lipoptilocnema_1935044
#             | |        | |        |
#             | |        | |        |        /-------- Pollenia_229640
#             | |        | |        |        |
#             \-+        | |        |        |  /----- Cholomyia_2500594
#               |        | |        |        |  |
#               |        | |        |    /---+/-+   /- Ptilodexia_2171783
#               |        | |        |    |   || | /-+
#               |        | |        |    |   || | | \- Thelaira_1640960
#               |        | |        |    |   || \-+
#               |        | |        |    |   ||   | /- Cylindromyia_1640937
#               |        \-+        |    |   \+   \-+
#               |          |        |    |    |     \- Trichopoda_1640944
#               |          |        |    |    |
#               |          |        |    |    |     /- Smidtia_880986
#               |          |        |    |    | /---+
#               |          |        |    |    | |   \- Blondelia_1036589
#               |          |        |    |    \-+
#               |          |        |    |      | /--- Epalpus_240881
#               |          |        |    |      \-+
#               |          |        |    |        | /- Panzeria_2176050
#               |          |        \----+        \-+
#               |          |             |          \- Nigrilypha_2500705
#               |          |             |
#               |          |             |          /- Melanophora_1606788
#               |          |             |   /------+
#               |          |             |   |      \- Paykullia_559696
#               |          |             | /-+
#               |          |             | | |/------- Lucilia_7374
#               |          |             | | ||
#               |          |             | | \+ /----- Sarconesia_670599
#               |          |             | |  | |
#               |          |             | |  \-+   /- Bellardia_2173236
#               |          |             | |    | /-+
#               |          |             | |    | | \- Melinda_170908
#               |          |             | |    \-+
#               |          |             \-+      | /- Melanomya_2173294
#               |          |               |      \-+
#               |          |               |        \- Calliphora_7372
#               |          |               |
#               |          |               |        /- Protocalliphora_142901
#               |          |               |    /---+
#               |          |               |    |   \- Phormia_7380
#               |          |               |  /-+
#               |          |               |  | | /--- Chloroprocta_447473
#               |          |               |  | \-+
#               |          |               \--+   | /- Compsomyiops_142898
#               |          |                  |   \-+
#               |          |                  |     \- Paralucilia_1042205
#               |          |                  |
#               |          |                  \------- Bengalia_367287
#               |          |
#               |          |                    /----- Philygria_1473725
#               |          |                  /-+
#               |          |                  | | /--- Coenia_1262293
#               |          |                  | \-+
#               |          |                  |   | /- Scatella_1473685
#               |          |           /------+   \-+
#               |          |           |      |     \- Cirrula_1929280
#               |          |           |      |
#               |          |           |      |     /- Athyroglossa_1720778
#               |          \-----------+      \-----+
#               |                      |            \- Psilopa_1262249
#               |                      |
#               |                      | /------------ Mormotomyia_1155705
#               |                      | |
#               |                      \-+ /---------- Camilla_1262331
#               |                        | |
#               |                        \-+ /-------- Campichoeta_1262281
#               |                          | |
#               |                          \-+/------- Cryptochetum_1262333
#               |                            ||
#               |                            ||   /--- Chymomyza_76946
#               |                            \+ /-+
#               |                             | | | /- Mycodrosophila_7338
#               |                             | | \-+
#               |                             \-+   \- Drosophila_7227
#               |                               |
#               |                               | /--- Braula_305562
#               |                               \-+
#               |                                 | /- Stegana_188292
#               |                                 \-+
#               |                                   \- Phortica_462259
#               |
#               |                                   /- Ngirhaphium_626743
#               \-----------------------------------+
#                                                   \- Pseudosympycnus_1003953

# %% [markdown]
# Now let's check the names in this tree against our alignments. How much overlap is there?

# %%
# define the path
path = Path('./') / 'alignments' / 'aligned_trimmed_cleaned'

# get all files
all_files = list(path.glob("*"))

# filter out the files that include "updated" in the name
files_without_updated = [file for file in all_files if "updated" not in file.name]

# Create an empty set to store sequence names
sequence_names = set()

# Loop over each file
for file in files_without_updated:
    with open(file, 'r') as f:
        for line in f:
            # If the line starts with '>', it's a sequence name
            if line.startswith('>'):
                # Add sequence name to the set (remove '>' and newline character)
                sequence_names.add(line[1:].strip())

# %%
# Get leaf labels from the tree
tree_labels = {leaf.taxon.label for leaf in genus_tree.leaf_node_iter()}

# Compute the overlap
overlap_seq_tree = sequence_names & tree_labels
overlap_tree_seq = tree_labels & sequence_names

# Calculate the percentage
percentage_seq_in_tree = len(overlap_seq_tree) / len(sequence_names) * 100
percentage_tree_in_seq = len(overlap_tree_seq) / len(tree_labels) * 100

print(f"{percentage_seq_in_tree}% of the {len(sequence_names)} sequence names are in the tree.")
print(f"{percentage_tree_in_seq}% of the {len(tree_labels)} tree labels are in the sequence names.")
# Out:
# 2.589641434262948% of the 502 sequence names are in the tree.
# 9.774436090225564% of the 133 tree labels are in the sequence names.

# %% [markdown]
# It seems the overlap is too small, let's save this tree and try a different strategy based on families, which will probably have a better overlap with our data. Commented out since we did this already.

# %%
#with open('./constraint_trees/result/genus_level.nexml', 'w') as output_file:
#    genus_tree.write(file=output_file, schema="nexml")

# %% [markdown]
# ## Prepare a family-level constraint tree
#
# Since there is not a lot of overlap at the genus level, let's try a different strategy based on family-level constraints:
#
# 1. Remove non-monophyletic families
# 2. Prune the tree so that families are tips
# 3. Get our sequence names and associated family names
# 4. Graft sequence names as polytomies in the corresponding families
# 5. Export as a tree for IQTREE (see http://www.iqtree.org/doc/Advanced-Tutorial)
# 6. Export as NEXUS monophyletic statements for BEAST2. Also export taxa not included in the tree as a rogues XML block (see https://www.beast2.org/2021/04/12/constraining-trees.html)

# %% [markdown]
# ### Remove non-monophyletic families

# %%
family_constraint = copy.deepcopy(diptera_tree)

for leaf in family_constraint.leaf_node_iter():
    this_family = leaf.annotations.get_value("family")
    if this_family is None or this_family in non_monophyletic:
        family_constraint.prune_subtree(leaf)

# %% [markdown]
# ### Prune tree so families are tips

# %%
# Step 1: create a list of all genera listed in the "genus" attribute of leaves in the tree.
family_list = list(set([leaf.annotations.get_value("family") for leaf in family_constraint.leaf_node_iter() if leaf.annotations.get_value("family") is not None]))

# Step 2: Loop through families
for fam in family_list:
    # Step 3: Find leaves with this family
    leaves = [leaf for leaf in family_constraint.leaf_node_iter() if leaf.annotations.get_value("family") == fam]
    
    
    if len(leaves) == 1:
        leaf = leaves[0]
        leaf.annotations.drop(name="species")
        leaf.annotations.drop(name="genus")
        leaf.annotations.drop(name="ncbi_id")
        leaf.annotations.drop(name="updated_fullname")
        leaf.annotations.drop(name="subfamily")
        leaf.annotations.drop(name="tribe")
        leaf.annotations.drop(name="subgenus")
        leaf.annotations.drop(name="species_group")
        leaf.annotations.drop(name="species_subgroup")
        leaf.annotations.drop(name="ott_id")
        continue
    

    else:
        mrca = family_constraint.mrca(taxon_labels=[leaf.taxon.label for leaf in leaves])
        
        # Clear all annotations of this MRCA
        mrca.annotations.clear()

        # Get the unique set of annotations across all leaves for the current genus
        annotation_keys = set().union(*[leaf.annotations for leaf in leaves])

        # For each unique annotation, replace it at the MRCA only if it has the same value in all tips
        for key in annotation_keys:
            # Get the values of the current annotation for all leaves
            annotation_values = [leaf.annotations.get_value(key.name) for leaf in leaves]

            # If the annotation has the same value in all leaves, set it for the MRCA
            if all_equal(annotation_values):
                mrca.annotations.add_new(key.name, annotation_values[0])
                

        # Prune all leaves under the MRCA
        mrca.clear_child_nodes()

# %%
for leaf in family_constraint.leaf_node_iter():
    leaf.taxon = dendropy.Taxon(label = leaf.annotations.get_value('family'))
family_constraint.update_taxon_namespace()
family_constraint.update_bipartitions()
family_constraint.print_plot()
# Out:
# /------------------------------------------------------- Deuterophlebiidae
# |
# | /----------------------------------------------------- Nymphomyiidae
# | |
# + |                                             /------- Trichoceridae
# | | /-------------------------------------------+
# | | |                                           |  /---- Pediciidae
# | | |                                           \--+
# | | |                                              | /-- Cylindrotomidae
# \-+ |                                              \-+
#   | |                                                \-- Tipulidae
#   | |
#   | |                                      /------------ Ptychopteridae
#   | |                                      |
#   | |                                      |       /---- Blephariceridae
#   | |                                      |  /----+
#   | |  /-----------------------------------+  |    | /-- Tanyderidae
#   \-+  |                                   |  |    \-+
#     |  |                                   |  |      \-- Psychodidae
#     |  |                                   |  |
#     |  |                                   \--+    /---- Dixidae
#     |  |                                      | /--+
#     |  |                                      | |  | /-- Chaoboridae
#     |  |                                      | |  \-+
#     |  |                                      | |    \-- Culicidae
#     |  |                                      \-+
#     |  |                                        |    /-- Ceratopogonidae
#     |  |                                        |  /-+
#     |  |                                        |  | \-- Chironomidae
#     |  |                                        \--+
#     \--+                                           | /-- Thaumaleidae
#        |                                           \-+
#        |                                             \-- Simuliidae
#        |
#        | /---------------------------------------------- Perissommatidae
#        | |
#        | |                          /------------------- Anisopodidae
#        | |                          |
#        | |  /-----------------------+                /-- Synneuridae
#        | |  |                       | /--------------+
#        | |  |                       | |              \-- Scatopsidae
#        | |  |                       \-+
#        | |  |                         |  /-------------- Axymyiidae
#        | |  |                         |  |
#        \-+  |                         \--+           /-- Bibionidae
#          |  |                            | /---------+
#          |  |                            | |         \-- Pachyneuridae
#          |  |                            \-+
#          |  |                              |  /--------- Diadocidiidae
#          |  |                              \--+
#          |  |                                 | /------- Keroplatidae
#          |  |                                 \-+
#          |  |                                   |  /---- Sciaridae
#          |  |                                   \--+
#          |  |                                      | /-- Lygistorrhinidae
#          \--+                                      \-+
#             |                                        \-- Cecidomyiidae
#             |
#             |                              /------------ Pantophthalmidae
#             |                              |
#             | /----------------------------+  /--------- Xylophagaidae
#             | |                            |  |
#             | |                            \--+      /-- Vermileonidae
#             | |                               | /----+
#             | |                               | |    \-- Austroleptidae
#             | |                               \-+
#             | |                                 |  /---- Pelecorhynchidae
#             | |                                 \--+
#             | |                                    | /-- Oreoleptidae
#             | |                                    \-+
#             | |                                      \-- Athericidae
#             | |
#             | |  /-------------------------------------- Mythicomyiidae
#             \-+  |
#               |  |                                 /---- Apioceridae
#               |  | /-------------------------------+
#               |  | |                               | /-- Evocoidae
#               |  | |                               \-+
#               |  | |                                 \-- Apsilocephalidae
#               |  | |
#               |  | |    /------------------------------- Platypezidae
#               |  | |    |
#               |  | |    | /----------------------------- Pipunculidae
#               |  | |    | |
#               |  | | /--+ |                     /------- Chamaemyiidae
#               |  | | |  | |                     |
#               \--+ | |  | |  /------------------+    /-- Coelopidae
#                  | | |  | |  |                  |  /-+
#                  | | |  \-+  |                  |  | \-- Helcomyzidae
#                  | | |    |  |                  \--+
#                  | | |    |  |                     | /-- Lauxaniidae
#                  | | |    |  |                     \-+
#                  | | |    |  |                       \-- Sciomyzidae
#                  | | |    |  |
#                  | | |    |  | /------------------------ Sphaeroceridae
#                  | | |    \--+ |
#                  | | |       | |                     /-- Micropezidae
#                  | | |       | |           /---------+
#                  | | |       | |           |         \-- Neriidae
#                  | | |       | |           |
#                  | | |       | |           |       /---- Piophilidae
#                  \-+ |       | |  /--------+  /----+
#                    | |       | |  |        |  |    | /-- Ulidiidae
#                    | |       | |  |        |  |    \-+
#                    | |       \-+  |        |  |      \-- Tephritidae
#                    | |         |  |        \--+
#                    | |         |  |           |      /-- Opomyzidae
#                    | |         |  |           | /----+
#                    | |         |  |           | |    \-- Psilidae
#                    | |         |  |           \-+
#                    | |         |  |             |  /---- Strongylophthalmyiidae
#                    | |         |  |             \--+
#                    | |         |  |                | /-- Acartophthalmidae
#                    | |         |  |                \-+
#                    | |         |  |                  \-- Sepsidae
#                    | |         \--+
#                    | |            |             /------- Diopsidae
#                    | |            |             |
#                    | |            | /-----------+    /-- Canacidae
#                    | |            | |           |  /-+
#                    | |            | |           |  | \-- Australimyzidae
#                    | |            | |           \--+
#                    | |            | |              | /-- Anthomyzidae
#                    | |            | |              \-+
#                    | |            | |                \-- Asteiidae
#                    | |            | |
#                    | |            | |                /-- Chloropidae
#                    \-+            | |         /------+
#                      |            | |         |      \-- Neminidae
#                      |            \-+         |
#                      |              | /-------+      /-- Aulacigastridae
#                      |              | |       | /----+
#                      |              | |       | |    \-- Periscelididae
#                      |              | |       | |
#                      |              | |       \-+    /-- Fergusoninidae
#                      |              | |         |  /-+
#                      |              | |         |  | \-- Carnidae
#                      |              | |         \--+
#                      |              | |            | /-- Agromyzidae
#                      |              | |            \-+
#                      |              \-+              \-- Odiniidae
#                      |                |
#                      |                |              /-- Hippoboscidae
#                      |                |    /---------+
#                      |                |    |         \-- Glossinidae
#                      |                |  /-+
#                      |                |  | |  /--------- Muscidae
#                      |                |  | \--+
#                      |                |  |    | /------- Scathophagidae
#                      |                |  |    \-+
#                      |                |  |      |  /---- Sarcophagidae
#                      |                \--+      \--+
#                      |                   |         | /-- Tachinidae
#                      |                   |         \-+
#                      |                   |           \-- Rhinophoridae
#                      |                   |
#                      |                   | /------------ Mormotomyiidae
#                      |                   | |
#                      |                   \-+  /--------- Camillidae
#                      |                     |  |
#                      |                     |  |      /-- Campichoetidae
#                      |                     \--+    /-+
#                      |                        | /--+ \-- Diastatidae
#                      |                        | |  |
#                      |                        \-+  \---- Curtonotidae
#                      |                          |
#                      |                          |    /-- Cryptochetidae
#                      |                          \----+
#                      |                               \-- Braulidae
#                      |
#                      \---------------------------------- Atelestidae

# %% [markdown]
# ### Get sequence names and associated taxonomic information
#
# Since our final sequences were obtained with a mixture of phylotaR and manual updating, the easiest way is to retrieve all sequence names and then use TaxReformer to get their families. Let's create a table for TaxReformer. Commented out since we did this already.

# %%
#(pd.DataFrame([{'name':x.split('_')[0], 'seqname':x} for x in sequence_names]).
# to_csv('./alignments/aligned_trimmed_cleaned/all_seqnames.csv')
#)

# %% [markdown]
# Now let's run TaxReformer externally. Results were saved in a csv table that we will open now:

# %%
seq_data = pd.read_csv('./alignments/aligned_trimmed_cleaned/all_seqnames_taxreformer.csv',index_col=0)
seq_data
# Out:
#                      name updated_fullname taxonomy_source rank_matched
# Unnamed: 0
# 0                 Muscina          Muscina             OTT        genus  \
# 1            Ainuyusurika     Ainuyusurika             OTT        genus
# 2               Clusiodes        Clusiodes             OTT        genus
# 3              Chamaemyia       Chamaemyia             OTT        genus
# 4           Paraplatypeza    Paraplatypeza             OTT        genus
# ...                   ...              ...             ...          ...
# 532             Leptocera        Leptocera             OTT        genus
# 533           Apocephalus      Apocephalus             OTT        genus
# 534                  Egle             Egle             OTT        genus
# 535             Anthomyia        Anthomyia             OTT        genus
# 537              Icterica         Icterica             OTT        genus
#
#                   matched  score   ott_id  ncbi_id name_source
# Unnamed: 0
# 0                 Muscina    100   573702    57892         OTT  \
# 1            Ainuyusurika    100   606050  1165747         OTT
# 2               Clusiodes    100   133900   500306         OTT
# 3              Chamaemyia    100   267777   305621         OTT
# 4           Paraplatypeza    100   652770   192442         OTT
# ...                   ...    ...      ...      ...         ...
# 532             Leptocera    100  4398843  1614654         OTT
# 533           Apocephalus    100   293294   117252         OTT
# 534                  Egle    100   675509   411076         OTT
# 535             Anthomyia    100   388244   259845         OTT
# 537              Icterica    100   801865    28599         OTT
#
#             matched_id_in_source  ...    suborder    infraorder
# Unnamed: 0                        ...
# 0                         573702  ...  Brachycera   Muscomorpha  \
# 1                         606050  ...  Nematocera  Culicomorpha
# 2                         133900  ...  Brachycera   Muscomorpha
# 3                         267777  ...  Brachycera   Muscomorpha
# 4                         652770  ...  Brachycera   Muscomorpha
# ...                          ...  ...         ...           ...
# 532                      4398843  ...  Brachycera   Muscomorpha
# 533                       293294  ...  Brachycera   Muscomorpha
# 534                       675509  ...  Brachycera   Muscomorpha
# 535                       388244  ...  Brachycera   Muscomorpha
# 537                       801865  ...  Brachycera   Muscomorpha
#
#                 superfamily          family     subfamily          tribe
# Unnamed: 0
# 0                 Muscoidea        Muscidae     Azeliinae  Reinwardtiini  \
# 1             Chironomoidea    Chironomidae  Chironominae    Chironomini
# 2               Opomyzoidea       Clusiidae           NaN            NaN
# 3              Lauxanioidea   Chamaemyiidae           NaN            NaN
# 4             Platypezoidea    Platypezidae  Platypezinae            NaN
# ...                     ...             ...           ...            ...
# 532         Sphaeroceroidea  Sphaeroceridae   Limosininae            NaN
# 533           Platypezoidea        Phoridae   Metopininae    Megaseliini
# 534               Muscoidea    Anthomyiidae  Anthomyiinae            NaN
# 535               Muscoidea    Anthomyiidae  Anthomyiinae            NaN
# 537            Tephritoidea     Tephritidae   Tephritinae     Xyphosiini
#
#            subtribe               seqname      section        cohort
# Unnamed: 0
# 0               NaN         Muscina_57892  Schizophora  Holometabola
# 1               NaN  Ainuyusurika_1165747          NaN  Holometabola
# 2               NaN      Clusiodes_500306  Schizophora  Holometabola
# 3               NaN     Chamaemyia_305621  Schizophora  Holometabola
# 4               NaN  Paraplatypeza_192442      Aschiza  Holometabola
# ...             ...                   ...          ...           ...
# 532             NaN     Leptocera_1614654  Schizophora  Holometabola
# 533             NaN    Apocephalus_117252      Aschiza  Holometabola
# 534             NaN           Egle_411076  Schizophora  Holometabola
# 535             NaN      Anthomyia_259845  Schizophora  Holometabola
# 537             NaN        Icterica_28599  Schizophora  Holometabola
#
# [502 rows x 33 columns]

# %% [markdown]
# Let's now see how many of our sequences can be placed in the families in the constraint tree

# %%
seq_data['family'].drop_duplicates().isin([leaf.taxon.label for leaf in family_constraint.leaf_nodes()]).value_counts()
# Out:
# family
# True     66
# False    43
# Name: count, dtype: int64

# %% [markdown]
# So it seems a little more than half of the families are represented in the tree. How about the number of tips?

# %%
seq_data['family'].isin([leaf.taxon.label for leaf in family_constraint.leaf_nodes()]).value_counts()
# Out:
# family
# True     285
# False    217
# Name: count, dtype: int64

# %% [markdown]
# A little over half of the tips are in the constraint. We definitely need to use soft constraints, then, since we can only constrain part of our tree.

# %% [markdown]
# ### Graft sequence names to the tree
# Now we will loop through all of our sequences and graft them into the tree if their family is represented. At the end, we will remove leaf nodes that do not correspond to our sequences. We will manually remove Pnyxia_1781626 since we removed this species from the alignment since the sequence was uninformative and causign a rogue taxon problem.

# %%
families_in_tree = [leaf.taxon.label for leaf in family_constraint.leaf_nodes()]
for i, x in seq_data.iterrows():
    if x['family'] in families_in_tree:
        # Find the node (internal or leaf) with a taxon label equal to the family
        target_node = family_constraint.find_node_with_taxon_label(x['family'])
        
        # Create a new taxon with the given label
        new_taxon = dendropy.Taxon(label=x['seqname'])
        
        # Create a new node with this taxon and add it as a child of the target node
        new_node = dendropy.Node(taxon=new_taxon)
        target_node.add_child(new_node)

family_constraint.update_taxon_namespace()
family_constraint.update_bipartitions()
family

labels_to_remove = [leaf.taxon.label for leaf in family_constraint.leaf_node_iter() 
                  if leaf.taxon.label not in seq_data['seqname'].tolist()]

partial_constraint = family_constraint.extract_tree_without_taxa_labels(labels=labels_to_remove + ["Pnyxia_1781626"])

# %%
partial_constraint.print_plot()
# Out:
# /----------------------------------------------------- Deuterophlebia_560719
# |
# | /--------------------------------------------------- Nymphomyia_560766
# | |
# | |                                        /---------- Trichocera_52759
# | |                                        |
# | |                                        |       /-- Dicranota_700836
# | |  /-------------------------------------+  /----+
# | |  |                                     |  |    \-- Pedicia_472374
# | |  |                                     |  |
# | |  |                                     |  |    /-- Liogma_560731
# | |  |                                     \--+    |
# | |  |                                        | /--+-- Phalacrocera_2203737
# | |  |                                        | |  |
# + |  |                                        | |  \-- Cylindrotoma_700834
# | |  |                                        | |
# | |  |                                        \-+  /-- Ctenophora_516519
# | |  |                                          |  |
# | |  |                                          |  |-- Tanyptera_2108371
# | |  |                                          |  |
# | |  |                                          \--+-- Dictenidia_2108369
# | |  |                                             |
# | |  |                                             |-- Prionocera_1690388
# | |  |                                             |
# | |  |                                             \-- Tipula_41043
# | |  |
# | |  |                                             /-- Ptychoptera_209691
# | |  |                                /------------+
# \-+  |                                |            \-- Bittacomorpha_79307
#   |  |                                |
#   |  |                                |            /-- Liponeura_446516
#   |  |                                |       /----+
#   |  |                                |       |    \-- Blepharicera_547808
#   |  |                                |       |
#   |  |                                |       |    /-- Mischoderus_560267
#   |  |                                |       |    |
#   |  |                                |  /----+ /--+-- Araucoderus_1549737
#   |  |                                |  |    | |  |
#   |  |                                |  |    | |  \-- Protoplasa_560776
#   |  |                                |  |    | |
#   |  |                                |  |    | |  /-- Trichomyia_560271
#   |  |                                |  |    \-+  |
#   |  |                                |  |      |  |-- Maruina_1144738
#   |  | /------------------------------+  |      |  |
#   |  | |                              |  |      |  |-- Clogmia_85119
#   |  | |                              |  |      |  |
#   |  | |                              |  |      |  |-- Lutzomyia_7199
#   |  | |                              |  |      \--+
#   |  | |                              |  |         |-- Pericoma_1148481
#   |  | |                              |  |         |
#   |  | |                              |  |         |-- Psychoda_7201
#   |  | |                              |  |         |
#   |  | |                              |  |         |-- Phlebotomus_13203
#   |  | |                              |  |         |
#   |  | |                              |  |         \-- Sycorax_114592
#   \--+ |                              |  |
#      | |                              |  |    /------- Dixa_79309
#      | |                              |  |    |
#      | |                              |  |    |    /-- Mochlonyx_1577622
#      | |                              \--+ /--+ /--+
#      | |                                 | |  | |  \-- Chaoborus_41812
#      | |                                 | |  | |
#      | |                                 | |  \-+  /-- Anopheles_7164
#      | |                                 | |    |  |
#      | |                                 | |    |  |-- Culex_7174
#      | |                                 | |    \--+
#      | |                                 | |       |-- Aedes_7158
#      | |                                 | |       |
#      | |                                 | |       \-- Culiseta_174825
#      | |                                 | |
#      | |                                 | |       /-- Sphaeromias_1874311
#      | |                                 | |       |
#      | |                                 | |       |-- Palpomyia_1525500
#      | |                                 | |       |
#      | |                                 | |       |-- Austroconops_209696
#      | |                                 | |       |
#      | |                                 | |       |-- Culicoides_41820
#      | |                                 | |    /--+
#      | |                                 | |    |  |-- Serromyia_209716
#      | |                                 | |    |  |
#      | |                                 | |    |  |-- Forcipomyia_209700
#      | |                                 | |    |  |
#      | |                                 | |    |  |-- Dasyhelea_41822
#      | |                                 \-+    |  |
#      | |                                   |    |  \-- Atrichopogon_209702
#      | |                                   |    |
#      | |                                   |    |  /-- Ainuyusurika_1165747
#      | |                                   |    |  |
#      | |                                   |    |  |-- Pentaneura_891922
#      | |                                   |    |  |
#      | |                                   |  /-+  |-- Metriocnemus_137497
#      | |                                   |  | |  |
#      | |                                   |  | |  |-- Eukiefferiella_288843
#      | |                                   |  | |  |
#      | |                                   |  | |  |-- Parochlus_315560
#      | |                                   |  | |  |
#      | |                                   |  | |  |-- Pseudosmittia_611382
#      | |                                   |  | |  |
#      | |                                   |  | |  |-- Tvetenia_611398
#      | |                                   |  | |  |
#      | |                                   |  | |  |-- Paucispinigera_903463
#      | |                                   |  | |  |
#      | |                                   |  | |  |-- Paraborniella_903459
#      | |                                   |  | \--+
#      \-+                                   |  |    |-- Smittia_315559
#        |                                   |  |    |
#        |                                   |  |    |-- Monodiamesa_891905
#        |                                   |  |    |
#        |                                   \--+    |-- Chironomus_7150
#        |                                      |    |
#        |                                      |    |-- Clunio_315556
#        |                                      |    |
#        |                                      |    |-- Aphroteniella_646259
#        |                                      |    |
#        |                                      |    |-- Gymnometriocnemus_611353
#        |                                      |    |
#        |                                      |    |-- Corynoneura_611344
#        |                                      |    |
#        |                                      |    |-- Ablabesmyia_46216
#        |                                      |    |
#        |                                      |    \-- Psectrotanypus_903467
#        |                                      |
#        |                                      |    /-- Androprosopa_41815
#        |                                      |    |
#        |                                      | /--+-- Austrothaumalea_1085085
#        |                                      | |  |
#        |                                      \-+  \-- Thaumalea_61068
#        |                                        |
#        |                                        \----- Simulium_7191
#        |
#        |                                           /-- Scatopse_1520324
#        |                            /--------------+
#        |                            |              \-- Coboldia_170624
#        |                            |
#        |                            | /--------------- Axymyia_560715
#        |  /-------------------------+ |
#        |  |                         | |            /-- Dilophus_52733
#        |  |                         | |            |
#        |  |                         | |         /--+-- Plecia_1260898
#        |  |                         \-+         |  |
#        |  |                           |  /------+  \-- Bibio_189978
#        |  |                           |  |      |
#        |  |                           |  |      |  /-- Pachyneura_1588165
#        |  |                           |  |      \--+
#        |  |                           |  |         \-- Cramptonomyia_209688
#        |  |                           \--+
#        |  |                              | /---------- Diadocidia_560721
#        |  |                              | |
#        |  |                              | |       /-- Orfelia_270890
#        |  |                              | |  /----+
#        |  |                              \-+  |    \-- Macrocera_608727
#        |  |                                |  |
#        |  |                                |  |    /-- Sciara_82677
#        |  |                                |  |    |
#        |  |                                |  | /--+-- Corynoptera_1260849
#        |  |                                \--+ |  |
#        |  |                                   | |  \-- Bradysia_35571
#        |  |                                   | |
#        |  |                                   | |  /-- Cecidomyia_1543682
#        |  |                                   | |  |
#        |  |                                   | |  |-- Aphidoletes_95971
#        |  |                                   \-+  |
#        |  |                                     |  |-- Piceacecis_2597495
#        |  |                                     |  |
#        |  |                                     |  |-- Lasioptera_201413
#        \--+                                     |  |
#           |                                     |  |-- Peromyia_1914937
#           |                                     |  |
#           |                                     \--+-- Winnertzia_2338641
#           |                                        |
#           |                                        |-- Asphondylia_153012
#           |                                        |
#           |                                        |-- Aprionus_1819779
#           |                                        |
#           |                                        |-- Dasineura_240745
#           |                                        |
#           |                                        |-- Sitodiplosis_263139
#           |                                        |
#           |                                        \-- Contarinia_153220
#           |
#           |                              /------------ Pantophthalmus_124295
#           |                              |
#           |                              |         /-- Exeretonevra_560723
#           | /----------------------------+         |
#           | |                            | /-------+-- Xylophagus_219493
#           | |                            | |       |
#           | |                            \-+       \-- Coenomyia_124305
#           | |                              |
#           | |                              |  /------- Vermileo_124333
#           | |                              \--+
#           | |                                 | /----- Glutops_124309
#           | |                                 \-+
#           | |                                   |  /-- Oreoleptis_1262318
#           | |                                   \--+
#           | |                                      \-- Atherix_124299
#           | |
#           \-+  /-------------------------------------- Apiocera_160270
#             |  |
#             |  |                                   /-- Paraplatypeza_192442
#             |  |                                   |
#             |  |                                   |-- Bertamyia_1445832
#             |  |                                   |
#             |  |                                   |-- Callomyia_712098
#             |  |                                   |
#             |  |  /--------------------------------+-- Kesselimyia_1445844
#             |  |  |                                |
#             |  |  |                                |-- Agathomyia_226141
#             |  |  |                                |
#             |  |  |                                |-- Polyporivora_1445854
#             \--+  |                                |
#                |  |                                \-- Platypeza_289241
#                |  |
#                |  |                                /-- Pipunculus_240898
#                |  |                                |
#                |  |                                |-- Chalarus_115250
#                |  | /------------------------------+
#                |  | |                              |-- Nephrocerus_115303
#                |  | |                              |
#                |  | |                              \-- Verrallia_115333
#                |  | |
#                |  | |                              /-- Chamaemyia_305621
#                |  | |                              |
#                \--+ |                      /-------+-- Leucopis_1728826
#                   | |                      |       |
#                   | |                      |       \-- Parochthiphila_1262282
#                   | |                      |
#                   | |                      |       /-- Coelopa_169466
#                   | |  /-------------------+  /----+
#                   | |  |                   |  |    \-- Helcomyza_169476
#                   | |  |                   |  |
#                   | |  |                   |  |    /-- Homoneura_1692452
#                   | |  |                   |  |    |
#                   | |  |                   |  | /--+-- Tricholauxania_192459
#                   | |  |                   \--+ |  |
#                   | |  |                      | |  \-- Aulogastromyia_1824990
#                   | |  |                      | |
#                   | |  |                      | |  /-- Pteromicra_1226622
#                   | |  |                      | |  |
#                   | |  |                      | |  |-- Dictya_1096051
#                   | |  |                      | |  |
#                   \-+  |                      \-+  |-- Elgiva_320938
#                     |  |                        |  |
#                     |  |                        |  |-- Sepedon_320954
#                     |  |                        |  |
#                     |  |                        |  |-- Neolimnia_1262312
#                     |  |                        |  |
#                     |  |                        |  |-- Sciomyza_320936
#                     |  |                        |  |
#                     |  |                        \--+-- Ilione_1096072
#                     |  |                           |
#                     |  |                           |-- Psacadina_1096078
#                     |  |                           |
#                     |  |                           |-- Tetanocera_320959
#                     |  |                           |
#                     |  |                           |-- Hedria_320941
#                     |  |                           |
#                     |  |                           |-- Coremacera_1226614
#                     |  |                           |
#                     |  |                           |-- Anticheta_1096047
#                     |  |                           |
#                     |  |                           \-- Pelidnoptera_1096074
#                     |  |
#                     |  |                           /-- Copromyza_1217530
#                     |  | /-------------------------+
#                     |  | |                         \-- Leptocera_1614654
#                     \--+ |
#                        | |                         /-- Mimegralla_115300
#                        | |                         |
#                        | |                         |-- Compsobata_286452
#                        | |                      /--+
#                        | |                      |  |-- Calobata_1820059
#                        | |                      |  |
#                        | |               /------+  \-- Micropeza_1572561
#                        | |               |      |
#                        | |               |      |  /-- Telostylinus_1262347
#                        | |               |      \--+
#                        | |               |         \-- Odontoloxozus_588320
#                        | |               |
#                        | |               |         /-- Lasiopiophila_1790233
#                        | |               |         |
#                        | |               |         |-- Piophila_53709
#                        | |               |    /----+
#                        | |               |    |    |-- Centrophlebomyia_1603419
#                        | |               |    |    |
#                        | |               |    |    \-- Liopiophila_1603421
#                        | |               |    |
#                        | |               |    |    /-- Delphinia_43369
#                        | |               |    |    |
#                        | |               |    |    |-- Chaetopsis_240871
#                        | |               |    | /--+
#                        | |               | /--+ |  |-- Tetanops_454640
#                        | |               | |  | |  |
#                        | |  /------------+ |  | |  \-- Euxesta_286468
#                        | |  |            | |  | |
#                        | |  |            | |  | |  /-- Eurosta_28593
#                        | |  |            | |  | |  |
#                        | |  |            | |  | |  |-- Anastrepha_28585
#                        | |  |            | |  | |  |
#                        | |  |            | |  | |  |-- Euleia_28591
#                        | |  |            | |  | |  |
#                        | |  |            | |  \-+  |-- Terellia_28615
#                        | |  |            | |    |  |
#                        | |  |            | |    |  |-- Paracantha_164885
#                        \-+  |            | |    |  |
#                          |  |            | |    |  |-- Tephritis_43386
#                          |  |            | |    |  |
#                          |  |            | |    |  |-- Urophora_28620
#                          |  |            | |    |  |
#                          |  |            | |    |  |-- Gymnocarena_28597
#                          |  |            | |    |  |
#                          |  |            | |    |  |-- Jamesomyia_28601
#                          |  |            | |    \--+
#                          |  |            | |       |-- Oxyna_381365
#                          |  |            \-+       |
#                          |  |              |       |-- Trupanea_30060
#                          |  |              |       |
#                          |  |              |       |-- Rhagoletis_28609
#                          |  |              |       |
#                          |  |              |       |-- Noeeta_381362
#                          |  |              |       |
#                          |  |              |       |-- Ceratitis_7212
#                          |  |              |       |
#                          |  |              |       |-- Zonosemata_28622
#                          |  |              |       |
#                          |  |              |       |-- Bactrocera_27456
#                          |  |              |       |
#                          |  |              |       |-- Xyphosia_381372
#                          |  |              |       |
#                          |  |              |       \-- Icterica_28599
#                          |  |              |
#                          |  |              |       /-- Opomyza_716643
#                          |  |              |    /--+
#                          |  |              |    |  \-- Geomyza_305619
#                          |  |              |  /-+
#                          |  |              |  | |  /-- Psila_305548
#                          |  |              |  | |  |
#                          |  |              |  | \--+-- Loxocera_34684
#                          |  |              \--+    |
#                          |  |                 |    \-- Chyliza_716634
#                          |  |                 |
#                          |  |                 |    /-- Sepsis_137507
#                          |  |                 \----+
#                          |  |                      \-- Themira_292396
#                          \--+
#                             |                      /-- Diasemopsis_139652
#                             |                      |
#                             |                 /----+-- Sphyracephala_139674
#                             |                 |    |
#                             |                 |    \-- Diopsis_139667
#                             | /---------------+
#                             | |               | /----- Procanace_1262322
#                             | |               | |
#                             | |               \-+  /-- Stiphrosoma_500293
#                             | |                 |  |
#                             | |                 \--+-- Paranthomyza_500298
#                             | |                    |
#                             | |                    \-- Quametopia_1603285
#                             | |
#                             | |                    /-- Thaumatomyia_333800
#                             | |                    |
#                             | |                    |-- Hippelates_540866
#                             | |                    |
#                             | |                    |-- Cetema_540891
#                             | |                    |
#                             | |                    |-- Gaurax_540862
#                             | |                    |
#                             | |                    |-- Lipara_540870
#                             | |                    |
#                             | |                    |-- Tricimba_540889
#                             | |                    |
#                             | |          /---------+-- Elachiptera_540858
#                             | |          |         |
#                             | |          |         |-- Incertella_540867
#                             | |          |         |
#                             | |          |         |-- Aphanotrigonum_540849
#                             | |          |         |
#                             | |          |         |-- Calamoncosis_540852
#                             | |          |         |
#                             | |          |         |-- Chlorops_540892
#                             | |          |         |
#                             | |  /-------+         |-- Cryptonevra_1616778
#                             | |  |       |         |
#                             | |  |       |         \-- Epichlorops_540897
#                             | |  |       |
#                             | |  |       |         /-- Stenomicra_716630
#                             | |  |       | /-------+
#                             | |  |       | |       \-- Periscelis_716628
#                             | |  |       | |
#                             | |  |       | |  /------- Fergusonina_156411
#                             | |  |       | |  |
#                             | |  |       \-+  |    /-- Liriomyza_127403
#                             | |  |         |  |    |
#                             | |  |         |  |    |-- Melanagromyza_286470
#                             | |  |         |  |    |
#                             | |  |         |  |    |-- Phytobia_414304
#                             \-+  |         \--+    |
#                               |  |            |    |-- Cerodontha_127401
#                               |  |            |    |
#                               |  |            | /--+-- Ophiomyia_341050
#                               |  |            | |  |
#                               |  |            | |  |-- Japanagromyza_414298
#                               |  |            | |  |
#                               |  |            | |  |-- Agromyza_414290
#                               |  |            \-+  |
#                               |  |              |  |-- Calycomyza_414293
#                               |  |              |  |
#                               |  |              |  \-- Phytomyza_132616
#                               |  |              |
#                               |  |              \----- Odinia_414302
#                               |  |
#                               |  |                 /-- Crataerina_452743
#                               |  |                 |
#                               |  |                 |-- Olfersia_1333310
#                               |  |                 |
#                               |  |                 |-- Melophagus_452748
#                               |  |                 |
#                               |  |              /--+-- Ornithophila_1497392
#                               |  |              |  |
#                               |  |              |  |-- Hippobosca_452745
#                               |  |              |  |
#                               |  |    /---------+  |-- Icosta_402409
#                               |  |    |         |  |
#                               |  |    |         |  \-- Lipoptena_170902
#                               |  |    |         |
#                               |  |    |         \----- Glossina_7393
#                               |  |    |
#                               |  |    |            /-- Muscina_57892
#                               |  |    |            |
#                               |  |    |            |-- Phaonia_253431
#                               |  |    |            |
#                               |  |    |            |-- Hebecnema_559682
#                               |  |    |            |
#                               |  |    |            |-- Potamia_559704
#                               |  |    |            |
#                               |  |    |            |-- Atherigona_305597
#                               |  |    |            |
#                               |  |    |            |-- Musca_7369
#                               |  |    |            |
#                               |  |    |            |-- Passeromyia_1511687
#                               |  |    |            |
#                               |  |    |            |-- Myospila_520040
#                               \--+    |            |
#                                  |  /-+  /---------+-- Haematobosca_559680
#                                  |  | |  |         |
#                                  |  | |  |         |-- Neomyia_305607
#                                  |  | |  |         |
#                                  |  | |  |         |-- Mesembrina_116147
#                                  |  | |  |         |
#                                  |  | |  |         |-- Graphomya_1072499
#                                  |  | |  |         |
#                                  |  | |  |         |-- Morellia_253340
#                                  |  | |  |         |
#                                  |  | |  |         |-- Philornis_253427
#                                  |  | |  |         |
#                                  |  | |  |         |-- Polietes_559702
#                                  |  | |  |         |
#                                  |  | |  |         |-- Eginia_1511678
#                                  |  | |  |         |
#                                  |  | |  |         \-- Limnophora_307207
#                                  |  | |  |
#                                  |  | |  |         /-- Scathophaga_95462
#                                  |  | |  |         |
#                                  |  | |  |         |-- Hydromyza_113174
#                                  |  | |  |         |
#                                  |  | \--+         |-- Norellia_113119
#                                  |  |    | /-------+
#                                  |  |    | |       |-- Cordilura_113132
#                                  |  |    | |       |
#                                  |  |    | |       |-- Cleigastra_113167
#                                  |  |    | |       |
#                                  |  |    | |       \-- Orthacheta_113181
#                                  |  |    | |
#                                  |  |    | |       /-- Sphecapatoclea_2021595
#                                  |  |    | |       |
#                                  |  |    | |       |-- Sphecapatodes_2021536
#                                  |  |    | |       |
#                                  |  |    | |       |-- Miltogramma_670602
#                                  |  |    | |       |
#                                  |  |    | |  /----+-- Blaesoxipha_128953
#                                  |  |    | |  |    |
#                                  |  |    | |  |    |-- Craticulina_2021509
#                                  |  |    | |  |    |
#                                  |  |    | |  |    |-- Sarcophaga_7384
#                                  |  |    | |  |    |
#                                  |  |    | |  |    \-- Wohlfahrtia_128961
#                                  |  |    | |  |
#                                  |  |    \-+  |    /-- Ectophasia_569037
#                                  |  |      |  |    |
#                                  |  |      |  |    |-- Sturmia_569089
#                                  |  |      |  |    |
#                                  |  |      |  |    |-- Phytomyptera_179785
#                                  |  |      |  |    |
#                                  |  |      |  |    |-- Nemoraea_170911
#                                  |  |      |  |    |
#                                  |  |      |  |    |-- Billaea_701468
#                                  |  |      |  |    |
#                                  |  |      |  |    |-- Ateloglossa_1890907
#                                  |  |      |  |    |
#                                  |  |      |  |    |-- Senotainia_179787
#                                  |  |      |  |    |
#                                  |  |      |  |    |-- Elomyia_1562792
#                                  |  |      |  |    |
#                                  |  |      |  |    |-- Blondelia_179437
#                                  \--+      |  |    |
#                                     |      |  |    |-- Prosena_1918293
#                                     |      |  |    |
#                                     |      |  |    |-- Glaurocara_2027854
#                                     |      \--+    |
#                                     |         |    |-- Drino_179459
#                                     |         |    |
#                                     |         |    |-- Phryxe_569079
#                                     |         |    |
#                                     |         |    |-- Acemya_1677647
#                                     |         |    |
#                                     |         |    |-- Blepharomyia_179434
#                                     |         |    |
#                                     |         |    |-- Cleonice_1918224
#                                     |         |    |
#                                     |         | /--+-- Cyrtophleba_991141
#                                     |         | |  |
#                                     |         | |  |-- Dinera_569035
#                                     |         | |  |
#                                     |         | |  |-- Anthomyiopsis_1918198
#                                     |         | |  |
#                                     |         | |  |-- Neaera_695903
#                                     |         | |  |
#                                     |         | |  |-- Parasetigena_380521
#                                     |         | |  |
#                                     |         | |  |-- Mintho_1918277
#                                     |         | |  |
#                                     |         | |  |-- Lydella_283929
#                                     |         | |  |
#                                     |         | |  |-- Clausicella_1718822
#                                     |         | |  |
#                                     |         | |  |-- Archytas_198637
#                                     |         | |  |
#                                     |         | |  |-- Dexia_569033
#                                     |         \-+  |
#                                     |           |  |-- Pseudoperichaeta_283931
#                                     |           |  |
#                                     |           |  |-- Estheria_1918238
#                                     |           |  |
#                                     |           |  |-- Exorista_113238
#                                     |           |  |
#                                     |           |  |-- Leschenaultia_179486
#                                     |           |  |
#                                     |           |  |-- Vibrissina_179525
#                                     |           |  |
#                                     |           |  |-- Zaira_179789
#                                     |           |  |
#                                     |           |  \-- Macquartia_1918266
#                                     |           |
#                                     |           |  /-- Stevenia_670627
#                                     |           |  |
#                                     |           |  |-- Rhinophora_670625
#                                     |           |  |
#                                     |           |  |-- Tricogena_1606792
#                                     |           \--+
#                                     |              |-- Phyto_1262320
#                                     |              |
#                                     |              |-- Paykullia_559695
#                                     |              |
#                                     |              \-- Melanophora_1606787
#                                     |
#                                     |              /-- Curtonotum_1262296
#                                     \--------------+
#                                                    \-- Cryptochetum_1262333

# %% [markdown]
# ### Create BEAST xml constraints
# For BEAST, we will need these kinds of constraints:
# 1. A hard monophyletic constraint for all Diptera including calibration for the root of the tree.
# 1. Hard monophyletic constraints derived from literature sources for very well-supported groups.
# 2. Soft constraints based on our constraint tree, but with rogues being able to be placed anywhere allowed by the hard monophyletic constraints.
#
# To accomplish that, we will reconcile a list of hard monophyletic constraints with the tree detailing soft constraints, by finding the nodes in the constraint tree that correspond to our hard constraints. Before we do it, let's find the mean and standard deviation we will use to calibrate the base of the tree (i. e. all Diptera).

# %%
Diptera_ages = pd.read_csv('./constraint_trees/timetree_pairwise_search_Deuterophlebia-Drosophila.csv')
Diptera_ages
average_time = Diptera_ages['Time'].mean()
sd_time = Diptera_ages['Time'].std()

print(average_time, sd_time)
# Out:
# 260.125 32.06861134089428

# %% [markdown]
# Now we will reconcile our partial and hard constraints to create constraint an log statements to add to our xml file

# %%
tr = copy.deepcopy(partial_constraint)

# %%
new_constraints = dict()
counts = Counter()
with open(Path('constraint_trees')/'hard_constraint_info'/'hard_constraints.txt','r') as f:
    for l in f.readlines():
        k,v = l.strip().split('=')
        v=v.split(',')
        new_constraints[k]=v
        counts[k]=len(v)
counts.most_common()
# Out:
# [('Diptera', 501),
#  ('first_split', 500),
#  ('Brachycera', 391),
#  ('Ephydroidea_Calyptratae', 143),
#  ('Calyptratae', 125),
#  ('Oestroidea', 76),
#  ('Bibionomorpha', 39),
#  ('Culicomorpha', 37),
#  ('Tephritoidea', 35),
#  ('Tachinidae', 33),
#  ('Sciaroidea', 30),
#  ('Syrphidae', 29),
#  ('Tabanomorpha', 20),
#  ('Ephydroidea', 18),
#  ('Chironomidae', 18),
#  ('Muscidae', 17),
#  ('Tipulomorpha', 16),
#  ('Tipuloidea', 15),
#  ('Tabanidae', 14),
#  ('Chloropidae', 13),
#  ('Anthomyiidae', 13),
#  ('Sciomyzidae', 13),
#  ('Hippoboscoidea', 11),
#  ('Cecidomyiidae', 11),
#  ('Mycetophilidae', 11),
#  ('Empidoidea', 10),
#  ('Lauxanioidea', 8),
#  ('Asilidae', 8),
#  ('Ceratopogonidae', 8),
#  ('Culicoidea', 7),
#  ('Empididae', 7),
#  ('Acroceridae', 7),
#  ('Hippoboscidae', 7),
#  ('Sarcophagidae', 7),
#  ('Platypezidae', 7),
#  ('Ephydridae', 6),
#  ('Scathophagidae', 6),
#  ('Rhinophoridae', 6),
#  ('Bombyliidae', 4),
#  ('Milichiidae', 4),
#  ('Conopidae', 4),
#  ('Micropezidae', 4),
#  ('Mesembrinellidae', 4),
#  ('Pipunculidae', 4),
#  ('Lonchaeidae', 4),
#  ('Piophilidae', 4),
#  ('Ulidiidae', 4),
#  ('Culicidae', 4),
#  ('Dolichopodidae', 3),
#  ('Psilidae', 3),
#  ('Nycteribiidae', 3),
#  ('Anthomyzidae', 3),
#  ('Clusiidae', 3),
#  ('Platystomatidae', 3),
#  ('Xylophagidae', 3),
#  ('Sciaridae', 3),
#  ('Celyphidae', 2),
#  ('Fanniidae', 2),
#  ('Neriidae', 2),
#  ('Rhiniidae', 2),
#  ('Sepsidae', 2),
#  ('Keroplatidae', 2)]

# %% [markdown]
# #### Retrive parent hard constraints
# Now let's read the file that shows parent-offspring relationships between hard constraints (i. e. which hard constraints are contained within each other)

# %%
constraint_parent = dict()
with open(Path('constraint_trees')/'hard_constraint_info'/'parent_nodes.txt','r') as f:
    for l in f.readlines():
        k,v = l.strip().split('=')
        constraint_parent[k]=v
print(constraint_parent)
# Out:
# {'first_split': 'Diptera', 'Empidoidea': 'Brachycera', 'Ephydroidea_Calyptratae': 'Brachycera', 'Calyptratae': 'Ephydroidea_Calyptratae', 'Ephydroidea': 'Ephydroidea_Calyptratae', 'Hippoboscoidea': 'Calyptratae', 'Oestroidea': 'Calyptratae', 'Anthomyiidae': 'Calyptratae', 'Fanniidae': 'Calyptratae', 'Muscidae': 'Calyptratae', 'Scathophagidae': 'Calyptratae', 'Mesembrinellidae': 'Oestroidea', 'Rhiniidae': 'Oestroidea', 'Rhinophoridae': 'Oestroidea', 'Sarcophagidae': 'Oestroidea', 'Tachinidae': 'Oestroidea', 'Lauxanioidea': 'Brachycera', 'Sciaroidea': 'Bibionomorpha', 'Tephritoidea': 'Brachycera', 'Culicoidea': 'Culicomorpha', 'Tipuloidea': 'Tipulomorpha', 'Asilidae': 'Brachycera', 'Bombyliidae': 'Brachycera', 'Dolichopodidae': 'Brachycera', 'Empididae': 'Brachycera', 'Acroceridae': 'Brachycera', 'Chloropidae': 'Brachycera', 'Milichiidae': 'Brachycera', 'Conopidae': 'Brachycera', 'Psilidae': 'Brachycera', 'Ephydridae': 'Ephydroidea', 'Hippoboscidae': 'Hippoboscoidea', 'Nycteribiidae': 'Hippoboscoidea', 'Celyphidae': 'Lauxanioidea', 'Micropezidae': 'Brachycera', 'Neriidae': 'Brachycera', 'Anthomyzidae': 'Brachycera', 'Clusiidae': 'Brachycera', 'Platypezidae': 'Brachycera', 'Sciomyzidae': 'Brachycera', 'Sepsidae': 'Brachycera', 'Syrphidae': 'Brachycera', 'Lonchaeidae': 'Tephritoidea', 'Piophilidae': 'Tephritoidea', 'Platystomatidae': 'Tephritoidea', 'Ulidiidae': 'Tephritoidea', 'Tabanidae': 'Tabanomorpha', 'Xylophagidae': 'Brachycera', 'Cecidomyiidae': 'Sciaroidea', 'Keroplatidae': 'Sciaroidea', 'Mycetophilidae': 'Sciaroidea', 'Sciaridae': 'Sciaroidea', 'Ceratopogonidae': 'Culicomorpha', 'Chironomidae': 'Culicomorpha', 'Culicidae': 'Culicomorpha', 'Brachycera': 'first_split', 'Tabanomorpha': 'Brachycera', 'Bibionomorpha': 'first_split', 'Culicomorpha': 'first_split', 'Tipulomorpha': 'first_split', 'Pipunculidae': 'Brachycera'}

# %% [markdown]
# #### Combine constraints
#
# Now we will go through the hard constraints, from most to least inclusive
#
# For each hard constraint, we will find in our tree the MRCA of all overlapping tips and name it with that constraint. We will also add a property that this is a hard constraint.
#
# If there are no overlapping tips, we will find the parent hard constraint node, and add a child node.
#
# We will then traverse constraints from least to most inclusive, and check if all child taxa are present, adding them if not.

# %% [markdown]
# ##### overlap with tree

# %%
tree_taxa = set([t.label for t in tr.taxon_namespace])
print('constraint','n_tips','n_overlap')
for k,v in new_constraints.items():
    print(k,len(v),len(set(v).intersection(tree_taxa)))
# Out:
# constraint n_tips n_overlap
# Diptera 501 284
# first_split 500 283
# Brachycera 391 194
# Tabanomorpha 20 4
# Bibionomorpha 39 24
# Culicomorpha 37 37
# Tipulomorpha 16 11
# Ephydroidea_Calyptratae 143 79
# Calyptratae 125 77
# Empidoidea 10 0
# Ephydroidea 18 2
# Hippoboscoidea 11 8
# Lauxanioidea 8 6
# Oestroidea 76 46
# Sciaroidea 30 17
# Tephritoidea 35 26
# Culicoidea 7 7
# Tipuloidea 15 10
# Asilidae 8 0
# Bombyliidae 4 0
# Dolichopodidae 3 0
# Empididae 7 0
# Acroceridae 7 0
# Chloropidae 13 13
# Milichiidae 4 0
# Conopidae 4 0
# Psilidae 3 3
# Ephydridae 6 0
# Hippoboscidae 7 7
# Nycteribiidae 3 0
# Celyphidae 2 0
# Anthomyiidae 13 0
# Fanniidae 2 0
# Muscidae 17 17
# Scathophagidae 6 6
# Micropezidae 4 4
# Neriidae 2 2
# Mesembrinellidae 4 0
# Rhiniidae 2 0
# Rhinophoridae 6 6
# Sarcophagidae 7 7
# Tachinidae 33 33
# Anthomyzidae 3 3
# Clusiidae 3 0
# Platypezidae 7 7
# Sciomyzidae 13 13
# Sepsidae 2 2
# Pipunculidae 4 4
# Syrphidae 29 0
# Lonchaeidae 4 0
# Piophilidae 4 4
# Platystomatidae 3 0
# Ulidiidae 4 4
# Tabanidae 14 0
# Xylophagidae 3 3
# Cecidomyiidae 11 11
# Keroplatidae 2 2
# Mycetophilidae 11 0
# Sciaridae 3 3
# Ceratopogonidae 8 8
# Chironomidae 18 18
# Culicidae 4 4

# %% [markdown]
# ##### Step 1 add constraints to existing nodes
#
# Here we will start from the most inclusive constraints. If there is a node in our tree that corresponds to it, we will name that node as the taxon to be constrained. If it is a leaf node, we will create an intermediate node. If there is no overlap with our tree, we will add a node that corresponds to these taxa.

# %%
for node in tr.internal_nodes():
    node.label = None
    node.taxon = None

for c,_ in counts.most_common():
    tree_taxa = set([t.label for t in tr.taxon_namespace])
    common_taxa = set(new_constraints[c]).intersection(tree_taxa)
    if common_taxa:
        # Find the MRCA of the common taxa in the tree
        common_taxa_nodes = [tr.find_node_with_taxon_label(taxon) for taxon in common_taxa]
        mrca = tr.mrca(taxon_labels=common_taxa)
        if mrca.is_leaf():
            new_internal_node = tr.node_factory(label=c)
            new_internal_node.annotations.add_new("constraint_type", "hard")
            parent_node = mrca.parent_node
            parent_node.remove_child(mrca)
            parent_node.add_child(new_internal_node)
            new_internal_node.add_child(mrca)
        else:
            mrca.annotations.add_new("constraint_type", "hard")
            mrca.label = c   
    else:
        mrca = tr.find_node_with_label(constraint_parent[c])
        new_node = tr.node_factory(label=c)
        for taxon in new_constraints[c]:
            if taxon not in tree_taxa:
                new_taxon = tr.taxon_namespace.require_taxon(label=taxon)
                child_node = tr.node_factory(taxon=new_taxon)
                new_node.add_child(child_node)
        mrca.add_child(new_node)
        new_node.annotations.add_new("constraint_type", "hard")
    tr.update_bipartitions(suppress_unifurcations=False)
    tr.reconstruct_taxon_namespace()

# %% [markdown]
# ##### Step 2 add missing taxa
# Now we will go from more to less inclusive taxa and add any remaining tips that were not added in the first step. This may have happened when we had some overlap between prior constraints and the new constraints, but not complete overlap.

# %%
for c,_ in reversed(counts.most_common()):
    tree_taxa = set([t.label for t in tr.taxon_namespace])
    included_taxa = set(new_constraints[c])
    common_taxa = included_taxa.intersection(tree_taxa)
    
    if common_taxa != included_taxa:
        missing_taxa = included_taxa - common_taxa
        mrca = tr.find_node_with_label(c)
        
        for taxon in missing_taxa:
            new_taxon = tr.taxon_namespace.require_taxon(label=taxon)
            new_leaf = tr.node_factory(taxon=new_taxon)
            mrca.add_child(new_leaf)

        # Update the taxon namespace and tree structure
        tr.reconstruct_taxon_namespace()
        tr.update_bipartitions()

# %%
tr.print_plot(show_internal_node_labels=True)
# Out:
# /---------------------------------------------------- Deuterophlebia_560719
# |
# | /-------------------------------------------------- Nymphomyia_560766
# | |
# | |                                       /---------- Trichocera_52759
# | |                                       |
# | |                                       |       /-- Dicranota_700836
# | |                                       |  /----@
# | |                                       |  |    \-- Pedicia_472374
# | |                                       |  |
# | |                                       |  |    /-- Liogma_560731
# | |                                       |  |    |
# | |  /------------------------------------TipulomorphaPhalacrocera_2203737
# | |  |                                    |  | |  |
# | |  |                                    |  | |  \-- Cylindrotoma_700834
# | |  |                                    |  | |
# | |  |                                    |  |-@  /-- Ctenophora_516519
# | |  |                                    |  | |  |
# | |  |                                    |  | |  |-- Tanyptera_2108371
# | |  |                                    |  | |  |
# | |  |                                    \--Tipuloideaictenidia_2108369
# | |  |                                       |    |
# | |  |                                       |    |-- Prionocera_1690388
# | |  |                                       |    |
# | |  |                                       |    \-- Tipula_41043
# | |  |                                       |
# | |  |                                       |------- Antocha_454619
# | |  |                                       |
# | |  |                                       |------- Limonia_52743
# | |  |                                       |
# Diptera                                      |------- Gnophomyia_700845
# | |  |                                       |
# | |  |                                       |------- Metalimnobia_700851
# | |  |                                       |
# | |  |                                       \------- Dactylolabis_560717
# | |  |
# | |  |                                            /-- Ptychoptera_209691
# | |  |                               /------------@
# | |  |                               |            \-- Bittacomorpha_79307
# | |  |                               |
# | |  |                               |            /-- Liponeura_446516
# | |  |                               |       /----@
# | |  |                               |       |    \-- Blepharicera_547808
# | |  |                               |       |
# | |  |                               |       |    /-- Mischoderus_560267
# | |  |                               |       |    |
# | |  |                               |  /----@ /--@-- Araucoderus_1549737
# | |  |                               |  |    | |  |
# | |  |                               |  |    | |  \-- Protoplasa_560776
# | |  |                               |  |    | |
# | |  |                               |  |    | |  /-- Trichomyia_560271
# | |  |                               |  |    \-@  |
# | |  |                               |  |      |  |-- Maruina_1144738
# | |  | /-----------------------------@  |      |  |
# | |  | |                             |  |      |  |-- Clogmia_85119
# | |  | |                             |  |      |  |
# | |  | |                             |  |      |  |-- Lutzomyia_7199
# | |  | |                             |  |      \--@
# | |  | |                             |  |         |-- Pericoma_1148481
# | |  | |                             |  |         |
# \-first_split                        |  |         |-- Psychoda_7201
#   |  | |                             |  |         |
#   |  | |                             |  |         |-- Phlebotomus_13203
#   |  | |                             |  |         |
#   |  | |                             |  |         \-- Sycorax_114592
#   |  | |                             |  |
#   |  | |                             |  |    /------- Dixa_79309
#   |  | |                             |  |    |
#   |  | |                             |  |    |    /-- Mochlonyx_1577622
#   |  | |                             \--@ /--Culicoidea
#   |  | |                                | |  | |  \-- Chaoborus_41812
#   |  | |                                | |  | |
#   |  | |                                | |  \-@  /-- Anopheles_7164
#   |  | |                                | |    |  |
#   |  | |                                | |    |  |-- Culex_7174
#   |  | |                                | |    \--Culicidae
#   |  | |                                | |       |-- Aedes_7158
#   |  | |                                | |       |
#   |  | |                                | |       \-- Culiseta_174825
#   |  | |                                | |
#   |  | |                                | |       /-- Sphaeromias_1874311
#   |  | |                                | |       |
#   |  | |                                | |       |-- Palpomyia_1525500
#   |  | |                                | |       |
#   |  | |                                | |       |-- Austroconops_209696
#   |  | |                                | |       |
#   |  | |                                | |       |-- Culicoides_41820
#   |  | |                                | |    /--Ceratopogonidae
#   |  | |                                | |    |  |-- Serromyia_209716
#   |  | |                                | |    |  |
#   |  | |                                | |    |  |-- Forcipomyia_209700
#   |  | |                                | |    |  |
#   |  | |                                | |    |  |-- Dasyhelea_41822
#   |  | |                                \-Culicomorpha
#   |  | |                                  |    |  \-- Atrichopogon_209702
#   |  | |                                  |    |
#   |  | |                                  |    |  /-- Ainuyusurika_1165747
#   |  | |                                  |    |  |
#   |  | |                                  |    |  |-- Pentaneura_891922
#   |  | |                                  |    |  |
#   |  | |                                  |  /-@  |-- Metriocnemus_137497
#   |  | |                                  |  | |  |
#   |  | |                                  |  | |  |-- Eukiefferiella_288843
#   |  | |                                  |  | |  |
#   |  | |                                  |  | |  |-- Parochlus_315560
#   |  | |                                  |  | |  |
#   |  | |                                  |  | |  |-- Pseudosmittia_611382
#   |  | |                                  |  | |  |
#   |  | |                                  |  | |  |-- Tvetenia_611398
#   |  | |                                  |  | |  |
#   |  | |                                  |  | |  |-- Paucispinigera_903463
#   |  | |                                  |  | |  |
#   |  | |                                  |  | |  |-- Paraborniella_903459
#   |  | |                                  |  | \--Chironomidae
#   |  | |                                  |  |    |-- Smittia_315559
#   |  | |                                  |  |    |
#   |  | |                                  |  |    |-- Monodiamesa_891905
#   |  | |                                  |  |    |
#   \--@ |                                  \--@    |-- Chironomus_7150
#      | |                                     |    |
#      | |                                     |    |-- Clunio_315556
#      | |                                     |    |
#      | |                                     |    |-- Aphroteniella_646259
#      | |                                     |    |
#      | |                                     |    |-- Gymnometriocnemus_611353
#      | |                                     |    |
#      | |                                     |    |-- Corynoneura_611344
#      | |                                     |    |
#      | |                                     |    |-- Ablabesmyia_46216
#      | |                                     |    |
#      | |                                     |    \-- Psectrotanypus_903467
#      | |                                     |
#      | |                                     |    /-- Androprosopa_41815
#      | |                                     |    |
#      | |                                     | /--@-- Austrothaumalea_1085085
#      | |                                     | |  |
#      | |                                     \-@  \-- Thaumalea_61068
#      | |                                       |
#      | |                                       \----- Simulium_7191
#      | |
#      | |                                          /-- Scatopse_1520324
#      | |                           /--------------@
#      | |                           |              \-- Coboldia_170624
#      | |                           |
#      | |                           | /--------------- Axymyia_560715
#      | |                           | |
#      | |                           | |            /-- Dilophus_52733
#      | |                           | |            |
#      | |                           | |         /--@-- Plecia_1260898
#      | |                           | |         |  |
#      | |                           | |  /------@  \-- Bibio_189978
#      | |                           | |  |      |
#      | |                           | |  |      |  /-- Pachyneura_1588165
#      | |                           | |  |      \--@
#      | |                           | |  |         \-- Cramptonomyia_209688
#      | |                           |-@  |
#      | |                           | |  | /---------- Diadocidia_560721
#      | |                           | |  | |
#      | |                           | |  | |       /-- Orfelia_270890
#      | |                           | |  | |  /----Keroplatidae
#      | |                           | |  | |  |    \-- Macrocera_608727
#      | |                           | |  | |  |
#      | |                           | |  | |  |    /-- Sciara_82677
#      | |                           | |  | |  |    |
#      | |                           | |  | |  | /--Sciaridaeoptera_1260849
#      | |                           | |  | |--@ |  |
#      | |                           | |  | |  | |  \-- Bradysia_35571
#      | |                           | \--@ |  | |
#      | |                           |    | |  | |  /-- Cecidomyia_1543682
#      | |                           |    | |  | |  |
#      | |                           |    | |  | |  |-- Aphidoletes_95971
#      | |                           |    | |  \-@  |
#      | |                           |    | |    |  |-- Piceacecis_2597495
#      | |                           |    | |    |  |
#      | |                           |    | |    |  |-- Lasioptera_201413
#      | |                           |    | |    |  |
#      | |                           |    | |    |  |-- Peromyia_1914937
#      | |                           |    | |    |  |
#      | |                           |    | |    \--Cecidomyiidaea_2338641
#      | |  /------------------------Bibionomorpha  |
#      | |  |                        |    | |       |-- Asphondylia_153012
#      | |  |                        |    | |       |
#      | |  |                        |    | |       |-- Aprionus_1819779
#      | |  |                        |    | |       |
#      | |  |                        |    | |       |-- Dasineura_240745
#      | |  |                        |    \-Sciaroidea
#      | |  |                        |      |       |-- Sitodiplosis_263139
#      | |  |                        |      |       |
#      | |  |                        |      |       \-- Contarinia_153220
#      | |  |                        |      |
#      | |  |                        |      |       /-- Brachypeza_2326774
#      | |  |                        |      |       |
#      | |  |                        |      |       |-- Trichonta_397122
#      | |  |                        |      |       |
#      | |  |                        |      |       |-- Mycetophila_397146
#      | |  |                        |      |       |
#      | |  |                        |      |       |-- Neoempheria_608686
#      | |  |                        |      |       |
#      | |  |                        |      |       |-- Symmerus_560780
#      | |  |                        |      |       |
#      | |  |                        |      |-------Mycetophilidae8706
#      | |  |                        |      |       |
#      | |  |                        |      |       |-- Sciophila_1085959
#      | |  |                        |      |       |
#      | |  |                        |      |       |-- Phronia_397119
#      | |  |                        |      |       |
#      | |  |                        |      |       |-- Exechia_397139
#      | |  |                        |      |       |
#      | |  |                        |      |       |-- Epicypta_397117
#      | |  |                        |      |       |
#      | |  |                        |      |       \-- Leptomorphus_560729
#      | |  |                        |      |
#      | |  |                        |      |---------- Bolitophila_52718
#      | |  |                        |      |
#      | |  |                        |      \---------- Ditomyia_1520322
#      | |  |                        |
#      | |  |                        |----------------- Penthetria_560770
#      | |  |                        |
#      | |  |                        \----------------- Hesperinus_1086788
#      | |  |
#      | |  |                             /------------ Pantophthalmus_124295
#      | |  |                             |
#      | |  |                             |         /-- Exeretonevra_560723
#      | |  |                             |         |
#      \-@  |                             | /-------Xylophagidaeus_219493
#        |  |                             | |       |
#        |  |                             | |       \-- Coenomyia_124305
#        |  | /---------------------------@ |
#        |  | |                           | |  /------- Vermileo_124333
#        |  | |                           | |  |
#        |  | |                           | |  | /----- Glutops_124309
#        |  | |                           | |  |-@
#        |  | |                           | |  | |  /-- Oreoleptis_1262318
#        |  | |                           | |  | \--@
#        |  | |                           | |  |    \-- Atherix_124299
#        |  | |                           \-@  |
#        |  | |                             |  |    /-- Esenbeckia_124297
#        |  | |                             |  |    |
#        |  | |                             |  |    |-- Hybomitra_124690
#        |  | |                             |  |    |
#        |  | |                             |  |    |-- Fidena_1334907
#        |  | |                             |  |    |
#        |  | |                             |  |    |-- Apatolestes_428062
#        |  | |                             |  |    |
#        |  | |                             |  |    |-- Catachlorops_1547373
#        |  | |                             |  |    |
#        |  | |                             |  |    |-- Silvius_415257
#        |  | |                             \--Tabanomorpha
#        |  | |                                |    |-- Atylotus_1310336
#        |  | |                                |----Tabanidae
#        |  | |                                |    |-- Haematopota_124311
#        |  | |                                |    |
#        |  | |                                |    |-- Stenotabanus_1547430
#        |  | |                                |    |
#        |  | |                                |    |-- Leucotabanus_1969939
#        |  | |                                |    |
#        |  | |                                |    |-- Chrysops_27458
#        |  | |                                |    |
#        |  | |                                |    |-- Tabanus_7206
#        |  | |                                |    |
#        |  | |                                |    |-- Bolbodimyia_1547386
#        |  | |                                |    |
#        |  | |                                |    \-- Goniops_428065
#        |  | |                                |
#        |  | |                                |------- Rhagio_124327
#        |  | |                                |
#        |  | |                                \------- Ptiolina_124325
#        |  | |
#        |  | |  /------------------------------------- Apiocera_160270
#        |  | |  |
#        |  | |  |                                  /-- Paraplatypeza_192442
#        |  | |  |                                  |
#        |  | |  |                                  |-- Bertamyia_1445832
#        |  | |  |                                  |
#        |  | |  |                                  |-- Callomyia_712098
#        |  | |  |                                  |
#        |  | |  | /--------------------------------Platypezidaeyia_1445844
#        |  | |  | |                                |
#        |  | |  | |                                |-- Agathomyia_226141
#        |  | |  | |                                |
#        |  | |  | |                                |-- Polyporivora_1445854
#        |  | |  | |                                |
#        |  | |  | |                                \-- Platypeza_289241
#        |  | |--@ |
#        |  | |  | |                                /-- Pipunculus_240898
#        |  | |  | |                                |
#        |  | |  | |                                |-- Chalarus_115250
#        |  | |  | |  /-----------------------------Pipunculidae
#        |  | |  | |  |                             |-- Nephrocerus_115303
#        |  | |  | |  |                             |
#        |  | |  | |  |                             \-- Verrallia_115333
#        |  | |  | |  |
#        |  | |  | |  |                             /-- Chamaemyia_305621
#        |  | |  | |  |                             |
#        |  | |  | |  |                     /-------@-- Leucopis_1728826
#        |  | |  | |  |                     |       |
#        |  | |  | |  |                     |       \-- Parochthiphila_1262282
#        |  | |  | |  |                     |
#        |  | |  \-@  |                     |       /-- Coelopa_169466
#        |  | |    |  |                     |  /----@
#        |  | |    |  |                     |  |    \-- Helcomyza_169476
#        |  | |    |  |                     |  |
#        |  | |    |  |                     |  |    /-- Homoneura_1692452
#        |  | |    |  |                     |  |    |
#        |  | |    |  |                     |  | /--@-- Tricholauxania_192459
#        |  | |    |  |                     |--@ |  |
#        |  | |    |  |                     |  | |  \-- Aulogastromyia_1824990
#        |  | |    |  |                     |  | |
#        |  | |    |  |                     |  | |  /-- Pteromicra_1226622
#        |  | |    |  |                     |  | |  |
#        |  | |    |  |                     |  | |  |-- Dictya_1096051
#        |  | |    |  |                     |  | |  |
#        |  | |    |  |                     |  \-@  |-- Elgiva_320938
#        |  | |    |  |                     |    |  |
#        |  | |    |  | /-------------------LauxanioideaSepedon_320954
#        |  | |    |  | |                   |    |  |
#        |  | |    |  | |                   |    |  |-- Neolimnia_1262312
#        |  | |    |  | |                   |    |  |
#        |  | |    |  | |                   |    |  |-- Sciomyza_320936
#        |  | |    |  | |                   |    |  |
#        |  | |    \--@ |                   |    \--Sciomyzidae1096072
#        |  | |       | |                   |       |
#        |  | |       | |                   |       |-- Psacadina_1096078
#        |  | |       | |                   |       |
#        |  | |       | |                   |       |-- Tetanocera_320959
#        |  | |       | |                   |       |
#        |  | |       | |                   |       |-- Hedria_320941
#        |  | |       | |                   |       |
#        |  | |       | |                   |       |-- Coremacera_1226614
#        |  | |       | |                   |       |
#        |  | |       | |                   |       |-- Anticheta_1096047
#        |  | |       | |                   |       |
#        |  | |       | |                   |       \-- Pelidnoptera_1096074
#        |  | |       | |                   |
#        |  | |       | |                   |       /-- Celyphus_1979294
#        |  | |       | |                   \-------Celyphidae
#        |  | |       | |                           \-- Spaniocelyphus_1262326
#        |  | |       | |
#        |  | |       | |                           /-- Copromyza_1217530
#        |  | |       | |  /------------------------@
#        |  | |       | |  |                        \-- Leptocera_1614654
#        |  | |       | |  |
#        |  | |       | |  |                        /-- Mimegralla_115300
#        |  | |       | |  |                        |
#        |  | |       | |  |                        |-- Compsobata_286452
#        |  | |       | |  |                     /--Micropezidae
#        |  | |       | |  |                     |  |-- Calobata_1820059
#        |  | |       | |  |                     |  |
#        |  | |       | |  |              /------@  \-- Micropeza_1572561
#        |  | |       | |  |              |      |
#        |  | |       | |  |              |      |  /-- Telostylinus_1262347
#        |  | |       | |  |              |      \--Neriidae
#        |  | |       | |  |              |         \-- Odontoloxozus_588320
#        |  | |       \-@  |              |
#        |  | |         |  |              |         /-- Lasiopiophila_1790233
#        |  | |         |  |              |         |
#        |  | |         |  |              |         |-- Piophila_53709
#        |  | |         |  |              |    /----Piophilidae
#        |  | |         |  |              |    |    |-- Centrophlebomyia_1603419
#        |  | |         |  |              |    |    |
#        |  | |         |  |              |    |    \-- Liopiophila_1603421
#        |  | |         |  |              |    |
#        |  | |         |  |              |    |    /-- Delphinia_43369
#        |  | |         |  |              |    |    |
#        |  | |         |  |              |    |    |-- Chaetopsis_240871
#        |  | |         |  |              |    | /--Ulidiidae
#        |  | |         |  |              |    | |  |-- Tetanops_454640
#        |  | |         |  |              |    | |  |
#        |  | |         |  |              |    | |  \-- Euxesta_286468
#        |  | |         |  |              |    | |
#        |  | |         |  |              |    | |  /-- Eurosta_28593
#        |  | |         |  |              |    | |  |
#        |  | |         |  |              |    | |  |-- Anastrepha_28585
#        |  | |         |  |              |    | |  |
#        |  | |         |  |              |    | |  |-- Euleia_28591
#        |  | |         |  |              |    | |  |
#        |  | |         |  |              |    |-@  |-- Terellia_28615
#        |  | |         |  |              |    | |  |
#        |  | |         |  |              |    | |  |-- Paracantha_164885
#        |  | |         |  | /------------@    | |  |
#        |  | |         |  | |            |    | |  |-- Tephritis_43386
#        |  | |         |  | |            |    | |  |
#        |  | |         |  | |            |    | |  |-- Urophora_28620
#        |  | |         |  | |            |    | |  |
#        |  | |         |  | |            |    | |  |-- Gymnocarena_28597
#        |  | |         |  | |            |    | |  |
#        |  | |         |  | |            |    | |  |-- Jamesomyia_28601
#        |  | |         |  | |            |    | \--@
#        |  | |         |  | |            |    |    |-- Oxyna_381365
#        |  | |         |  | |            | /--Tephritoidea
#        |  | |         |  | |            | |  |    |-- Trupanea_30060
#        |  | |         |  | |            | |  |    |
#        |  | |         |  | |            | |  |    |-- Rhagoletis_28609
#        |  | |         \--@ |            | |  |    |
#        |  | |            | |            | |  |    |-- Noeeta_381362
#        |  | |            | |            | |  |    |
#        \--@ |            | |            | |  |    |-- Ceratitis_7212
#           | |            | |            | |  |    |
#           | |            | |            | |  |    |-- Zonosemata_28622
#           | |            | |            | |  |    |
#           | |            | |            | |  |    |-- Bactrocera_27456
#           | |            | |            | |  |    |
#           | |            | |            | |  |    |-- Xyphosia_381372
#           | |            | |            | |  |    |
#           | |            | |            | |  |    \-- Icterica_28599
#           | |            | |            | |  |
#           | |            | |            | |  |    /-- Lamprolonchaea_907706
#           | |            | |            | |  |    |
#           | |            | |            | |  |    |-- Lonchaea_198649
#           | |            | |            | |  |----Lonchaeidae
#           | |            | |            \-@  |    |-- Dasiops_286456
#           | |            | |              |  |    |
#           | |            | |              |  |    \-- Silba_198646
#           | |            | |              |  |
#           | |            | |              |  |    /-- Rivellia_28633
#           | |            | |              |  |    |
#           | |            | |              |  |----Platystomatidae286504
#           | |            | |              |  |    |
#           | |            | |              |  |    \-- Scholastes_1902237
#           | |            | |              |  |
#           | |            | |              |  |------- Palloptera_286498
#           | |            | |              |  |
#           | |            | |              |  \------- Ctenostylidae
#           | |            | |              |
#           | |            | |              |       /-- Opomyza_716643
#           | |            | |              |    /--@
#           | |            | |              |    |  \-- Geomyza_305619
#           | |            | |              |  /-@
#           | |            | |              |  | |  /-- Psila_305548
#           | |            | |              |  | |  |
#           | |            | |              |  | \--Psilidaecera_34684
#           | |            | |              \--@    |
#           | |            | |                 |    \-- Chyliza_716634
#           | |            | |                 |
#           | |            | |                 |    /-- Sepsis_137507
#           | |            | |                 \----Sepsidae
#           | |            | |                      \-- Themira_292396
#           | |            | |
#           | |            | |                      /-- Diasemopsis_139652
#           | |            | |                      |
#           | |            | |                 /----@-- Sphyracephala_139674
#           | |            | |                 |    |
#           | |            | |                 |    \-- Diopsis_139667
#           | |            | |  /--------------@
#           | |            | |  |              | /----- Procanace_1262322
#           | |            | |  |              | |
#           | |            | |  |              \-@  /-- Stiphrosoma_500293
#           | |            \-@  |                |  |
#           | |              |  |                \--Anthomyzidaemyza_500298
#           | |              |  |                   |
#           | |              |  |                   \-- Quametopia_1603285
#           | |              |  |
#           | |              |  |                   /-- Thaumatomyia_333800
#           | |              |  |                   |
#           | |              |  |                   |-- Hippelates_540866
#           | |              |  |                   |
#           | |              |  |                   |-- Cetema_540891
#           | |              |  |                   |
#           | |              |  |                   |-- Gaurax_540862
#           | |              |  |                   |
#           | |              |  |                   |-- Lipara_540870
#           | |              |  |                   |
#           | |              |  |                   |-- Tricimba_540889
#           | |              |  |                   |
#           | |              |  |         /---------Chloropidaetera_540858
#           | |              |  |         |         |
#           | |              |  |         |         |-- Incertella_540867
#           | |              |  |         |         |
#           | |              |  |         |         |-- Aphanotrigonum_540849
#           | |              |  |         |         |
#           | |              |  |         |         |-- Calamoncosis_540852
#           | |              |  |         |         |
#           | |              |  |         |         |-- Chlorops_540892
#           | |              |  |         |         |
#           | |              |  | /-------@         |-- Cryptonevra_1616778
#           | |              |  | |       |         |
#           | |              |  | |       |         \-- Epichlorops_540897
#           | |              |  | |       |
#           | |              |  | |       |         /-- Stenomicra_716630
#           | |              |  | |       | /-------@
#           | |              |  | |       | |       \-- Periscelis_716628
#           | |              |  | |       | |
#           | |              |  | |       | |  /------- Fergusonina_156411
#           | |              |  | |       | |  |
#           | |              |  | |       \-@  |    /-- Liriomyza_127403
#           | |              |  | |         |  |    |
#           | |              |  | |         |  |    |-- Melanagromyza_286470
#           | |              |  | |         |  |    |
#           | |              |  | |         |  |    |-- Phytobia_414304
#           | |              |  | |         \--@    |
#           | |              |  | |            |    |-- Cerodontha_127401
#           | |              |  | |            |    |
#           | |              |  | |            | /--@-- Ophiomyia_341050
#           | |              |  | |            | |  |
#           | |              |  | |            | |  |-- Japanagromyza_414298
#           | |              |  | |            | |  |
#           | |              |  | |            | |  |-- Agromyza_414290
#           | |              |  | |            \-@  |
#           | |              |  | |              |  |-- Calycomyza_414293
#           | |              |  | |              |  |
#           | |              |  | |              |  \-- Phytomyza_132616
#           | |              |  | |              |
#           | |              |  | |              \----- Odinia_414302
#           | |              |  | |
#           | |              |  | |                 /-- Crataerina_452743
#           | |              |  | |                 |
#           | |              |  | |                 |-- Olfersia_1333310
#           | |              |  | |                 |
#           | |              |  | |                 |-- Melophagus_452748
#           | |              |  | |                 |
#           | |              |  | |              /--Hippoboscidaeila_1497392
#           | |              |  | |              |  |
#           | |              |  | |              |  |-- Hippobosca_452745
#           | |              |  | |              |  |
#           | |              |  | |              |  |-- Icosta_402409
#           | |              \--@ |              |  |
#           | |                 | |    /---------Hippoboscoideana_170902
#           | |                 | |    |         |
#           | |                 | |    |         |----- Glossina_7393
#           | |                 | |    |         |
#           | |                 | |    |         |  /-- Basilia_170889
#           | |                 | |    |         |  |
#           | |                 | |    |         \--Nycteribiidaedia_81721
#           | |                 | |    |            |
#           | |                 | |    |            \-- Nycteribia_633884
#           | |                 | |    |
#           | |                 | |    |            /-- Muscina_57892
#           | |                 | |    |            |
#           | |                 | |    |            |-- Phaonia_253431
#           | |                 | |    |            |
#           | |                 | |    |            |-- Hebecnema_559682
#           | |                 | |    |            |
#           | |                 | |    |            |-- Potamia_559704
#           | |                 | |    |            |
#           | |                 | |    |            |-- Atherigona_305597
#           | |                 | |    |            |
#           | |                 | |    |            |-- Musca_7369
#           | |                 | |    |            |
#           | |                 | |    |            |-- Passeromyia_1511687
#           | |                 | |    |            |
#           | |                 | |    |            |-- Myospila_520040
#           | |                 | |    |            |
#           | |                 | |    |  /---------Muscidaeatobosca_559680
#           | |                 | |    |  |         |
#           | |                 | |    |  |         |-- Neomyia_305607
#           | |                 | |    |  |         |
#           | |                 | |    |  |         |-- Mesembrina_116147
#           | |                 | |    |  |         |
#           | |                 | |    |  |         |-- Graphomya_1072499
#           | |                 | |    |  |         |
#           | |                 | |    |  |         |-- Morellia_253340
#           | |                 | |    |  |         |
#           | |                 | |    |  |         |-- Philornis_253427
#           | |                 | |    |  |         |
#           | |                 | |    |  |         |-- Polietes_559702
#           | |                 | |    |  |         |
#           | |                 | |    |  |         |-- Eginia_1511678
#           | |                 | |    |  |         |
#           | |                 | |    |  |         \-- Limnophora_307207
#           | |                 | |    |  |
#           | |                 | |    |  |         /-- Scathophaga_95462
#           | |                 | |    |  |         |
#           | |                 | |    |  |         |-- Hydromyza_113174
#           | |                 | |    |  |         |
#           | |                 | |    |  |         |-- Norellia_113119
#           | |                 | |    |  | /-------Scathophagidae
#           | |                 | |    |  | |       |-- Cordilura_113132
#           | |                 | |    |  | |       |
#           | |                 | |    |  | |       |-- Cleigastra_113167
#           | |                 | |    |  | |       |
#           | |                 | |    |  | |       \-- Orthacheta_113181
#           | |                 | |    |  | |
#           | |                 | |    |  | |       /-- Sphecapatoclea_2021595
#           | |                 | |    |  | |       |
#           | |                 | |    |--@ |       |-- Sphecapatodes_2021536
#           | |                 | |    |  | |       |
#           | |                 | |    |  | |       |-- Miltogramma_670602
#           | |                 | |    |  | |       |
#           | |                 | |    |  | |  /----Sarcophagidaeha_128953
#           | |                 | |    |  | |  |    |
#           | |                 | |    |  | |  |    |-- Craticulina_2021509
#           | |                 | |    |  | |  |    |
#           | |                 | |    |  | |  |    |-- Sarcophaga_7384
#           | |                 | |    |  | |  |    |
#           | |                 | |    |  | |  |    \-- Wohlfahrtia_128961
#           | |                 | |    |  | |  |
#           | |                 | |    |  | |  |    /-- Ectophasia_569037
#           | |                 | |    |  | |  |    |
#           | |                 \-@    |  | |  |    |-- Sturmia_569089
#           | |                   |    |  | |  |    |
#           | |                   |    |  | |  |    |-- Phytomyptera_179785
#           | |                   |    |  | |  |    |
#           | |                   |    |  | |  |    |-- Nemoraea_170911
#           | |                   |    |  | |  |    |
#           | |                   |    |  | |  |    |-- Billaea_701468
#           | |                   |    |  | |  |    |
#           | |                   |    |  | |  |    |-- Ateloglossa_1890907
#           | |                   |    |  | |  |    |
#           | |                   |    |  | |  |    |-- Senotainia_179787
#           | |                   |    |  | |  |    |
# ...
#             |                                     |
#             |                                     |-- Scaeva_219538
#             |                                     |
#             |                                     |-- Eumerus_224220
#             |                                     |
#             |                                     |-- Syrphus_224255
#             |                                     |
#             |                                     |-- Ornidia_994473
#             |                                     |
#             |                                     |-- Volucella_226148
#             |                                     |
#             |                                     |-- Melangyna_414825
#             |                                     |
#             |                                     |-- Syritta_34681
#             |                                     |
#             |                                     |-- Ocyptamus_369855
#             |                                     |
#             |-------------------------------------Syrphidaeosia_173981
#             |                                     |
#             |                                     |-- Chrysogaster_224248
#             |                                     |
#             |                                     |-- Microdon_115291
#             |                                     |
#             |                                     |-- Toxomerus_115327
#             |                                     |
#             |                                     |-- Sphaerophoria_226179
#             |                                     |
#             |                                     |-- Merodon_224226
#             |                                     |
#             |                                     |-- Pipiza_221788
#             |                                     |
#             |                                     |-- Epistrophe_414810
#             |                                     |
#             |                                     |-- Temnostoma_226164
#             |                                     |
#             |                                     |-- Eriozona_414724
#             |                                     |
#             |                                     |-- Myolepta_1473716
#             |                                     |
#             |                                     |-- Neoascia_224222
#             |                                     |
#             |                                     |-- Callicera_228567
#             |                                     |
#             |                                     |-- Eristalis_198633
#             |                                     |
#             |                                     \-- Xanthogramma_414873
#             |
#             |                                     /-- Dolichopus_192427
#             |                                     |
#             |                                     |-- Medetera_377527
#             |                                     |
#             |                                     |-- Rhaphium_377528
#             |                                     |
#             |                                     |-- Rhamphomyia_192612
#             |                                     |
#             |                                     |-- Neoplasta_192640
#             |-------------------------------------Dolichopodidae
#             |                                     |-- Phyllodromia_1209097
#             |                                     |
#             |                                     |-- Chelifera_369889
#             |                                     |
#             |                                     |-- Wiedemannia_240904
#             |                                     |
#             |                                     |-- Clinocera_192484
#             |                                     |
#             |                                     \-- Metachela_369884
#             |
#             |                                     /-- Philonicus_247567
#             |                                     |
#             |                                     |-- Dioctria_468720
#             |                                     |
#             |                                     |-- Promachus_247552
#             |                                     |
#             |                                     |-- Machimus_247604
#             |-------------------------------------Asilidae
#             |                                     |-- Lasiopogon_219536
#             |                                     |
#             |                                     |-- Pamponerus_1717601
#             |                                     |
#             |                                     |-- Laphria_50683
#             |                                     |
#             |                                     \-- Mallophora_270862
#             |
#             |                                     /-- Ocnaea_210271
#             |                                     |
#             |                                     |-- Ogcodes_188257
#             |                                     |
#             |                                     |-- Eulonchus_210230
#             |                                     |
#             |-------------------------------------Acroceridaea_210245
#             |                                     |
#             |                                     |-- Astomella_210239
#             |                                     |
#             |                                     |-- Exetasis_1932988
#             |                                     |
#             |                                     \-- Pterodontia_210267
#             |
#             |                                     /-- Systoechus_1690390
#             |                                     |
#             |                                     |-- Bombylius_219362
#             |-------------------------------------Bombyliidae
#             |                                     |-- Anthrax_117078
#             |                                     |
#             |                                     \-- Ligyra_117088
#             |
#             |                                     /-- Desmometopa_305587
#             |                                     |
#             |                                     |-- Leptometopa_1720790
#             |-------------------------------------Milichiidae
#             |                                     |-- Pholeomyia_1720804
#             |                                     |
#             |                                     \-- Milichiella_1890919
#             |
#             |                                     /-- Physocephala_198643
#             |                                     |
#             |                                     |-- Thecophora_305546
#             |-------------------------------------Conopidae
#             |                                     |-- Sicus_1219203
#             |                                     |
#             |                                     \-- Zodion_768804
#             |
#             |                                     /-- Sobarocephala_574054
#             |                                     |
#             |-------------------------------------Clusiidaea_574057
#             |                                     |
#             |                                     \-- Clusiodes_500306
#             |
#             |---------------------------------------- Mydas_186100
#             |
#             |---------------------------------------- Hypocera_940227
#             |
#             |---------------------------------------- Sciadocera_192453
#             |
#             |---------------------------------------- Hermetia_343581
#             |
#             |---------------------------------------- Heterocheila_169481
#             |
#             |---------------------------------------- Borophaga_712093
#             |
#             |---------------------------------------- Ptecticus_343648
#             |
#             |---------------------------------------- Dryomyza_169444
#             |
#             |---------------------------------------- Oxycera_860348
#             |
#             |---------------------------------------- Chloromyia_343649
#             |
#             |---------------------------------------- Neorhynchocephalus_259248
#             |
#             |---------------------------------------- Neurochaeta_716624
#             |
#             |---------------------------------------- Berkshiria_2061012
#             |
#             |---------------------------------------- Nemotelus_343582
#             |
#             |---------------------------------------- Anevrina_92526
#             |
#             |---------------------------------------- Lonchoptera_92595
#             |
#             |---------------------------------------- Microchrysa_931517
#             |
#             |---------------------------------------- Scenopinus_247599
#             |
#             |---------------------------------------- Neopachygaster_1692469
#             |
#             |---------------------------------------- Diplonevra_92534
#             |
#             |---------------------------------------- Apocephalus_117252
#             |
#             |---------------------------------------- Scoliocentra_1823605
#             |
#             |---------------------------------------- Sargus_343647
#             |
#             |---------------------------------------- Teratomyzidae
#             |
#             |---------------------------------------- Hirmoneura_388531
#             |
#             |---------------------------------------- Neossos_2268121
#             |
#             |---------------------------------------- Pachygaster_124321
#             |
#             |---------------------------------------- Tanypeza_1692486
#             |
#             |---------------------------------------- Stratiomys_219520
#             |
#             |---------------------------------------- Odontomyia_343652
#             |
#             |---------------------------------------- Zabrachia_1891525
#             |
#             |---------------------------------------- Thereva_95078
#             |
#             |---------------------------------------- Helosciomyzidae
#             |
#             |---------------------------------------- Triphleba_92553
#             |
#             |---------------------------------------- Oedoparena_1262316
#             |
#             |---------------------------------------- Megaselia_36165
#             |
#             \---------------------------------------- Oplodontha_446504

# %% [markdown]
# ### Save BEAST xml statements
#
# Since we have already an XML file, here we will just generate constraint statements to manually add to it. All nodes in our tree will be constraints, following these rules:
#
# 1. If the node is annotated as a hard constraint, it will be a monophyletic constraint for the children of the node
# 2. If the node is not annotated as a hard constraint, it will be a soft constraint: we will include all children of the node as the constraint, and we will look for parent nodes until we find a hard constraint. We will then include the ancestors from this node as rogues, so they can float freely within the hard constraint (unless a less inclusive hard constraint excludes them).
#
# We will skip the root node since we have manually input that one using beauti.

# %%
node_lab_idx = 0
tr.seed_node.label = 'Diptera'
constraint_statements = []
log_statements = []

rogues = dict()

for node in tr.preorder_internal_node_iter():
    if node == tr.seed_node: continue
    included_taxa = [leaf.taxon.label for leaf in node.leaf_nodes()]
    constraint_lines = []
    
    if not node.label:
        node.label = f'Node_{node_lab_idx}' 
        node_lab_idx += 1
        
    
    log_statements.append(f'            <log idref="{node.label}.prior"/>')   
    
    
    if not node.annotations.get_value("constraint_type") == "hard": #soft constraint
        parent = node.parent_node
        while True:
            if parent.annotations.get_value("constraint_type") == "hard" or parent == tr.seed_node:
                break
            else:
                parent = parent.parent_node
                
        rogues = set([leaf.taxon.label for leaf in parent.leaf_nodes()]) - set(included_taxa)
                
        constraint_lines.append(f'                <distribution id="{node.label}.prior" spec="beastlabs.math.distributions.MRCAPriorWithRogues" monophyletic="true" tree="@Tree.t:mito_nonprotcoding">')
        constraint_lines.append(f'                    <taxonset id="{node.label}" spec="TaxonSet">')
        for tx in included_taxa:
            constraint_lines.append(f'                        <taxon idref="{tx}" spec="Taxon"/>')
        constraint_lines.append(f'                    </taxonset>')
           
            
        constraint_lines.append(f'                    <rogues id="{node.label}_rogues" spec="TaxonSet">')
        for rogue_tx in rogues:
            constraint_lines.append(f'                        <taxon idref="{rogue_tx}" spec="Taxon"/>')
        constraint_lines.append(f'                    </rogues>')
        
         
    else: #hard constraint
        constraint_lines = []
        constraint_lines.append(f'                 <distribution id="{node.label}.prior" spec="beast.base.evolution.tree.MRCAPrior" monophyletic="true" tree="@Tree.t:mito_nonprotcoding">' )
        constraint_lines.append(f'                    <taxonset id="{node.label}" spec="TaxonSet">')
        for tx in included_taxa:
            constraint_lines.append(f'                        <taxon idref="{tx}" spec="Taxon"/>')
        constraint_lines.append(f'                    </taxonset>')
        
    constraint_lines.append(f'                </distribution>')
        
        
    constraint_statements.append('\n'.join(constraint_lines))

# %% [markdown]
# Let's now print these statements so we can copy and paste to the xml file:

# %% [markdown]
# ##### Log statements

# %%
print('\n'.join(log_statements))
# Out:
#             <log idref="first_split.prior"/>
#             <log idref="Node_0.prior"/>
#             <log idref="Tipulomorpha.prior"/>
#             <log idref="Tipuloidea.prior"/>
#             <log idref="Node_1.prior"/>
#             <log idref="Node_2.prior"/>
#             <log idref="Node_3.prior"/>
#             <log idref="Node_4.prior"/>
#             <log idref="Node_5.prior"/>
#             <log idref="Node_6.prior"/>
#             <log idref="Node_7.prior"/>
#             <log idref="Node_8.prior"/>
#             <log idref="Node_9.prior"/>
#             <log idref="Node_10.prior"/>
#             <log idref="Node_11.prior"/>
#             <log idref="Node_12.prior"/>
#             <log idref="Node_13.prior"/>
#             <log idref="Culicomorpha.prior"/>
#             <log idref="Culicoidea.prior"/>
#             <log idref="Node_14.prior"/>
#             <log idref="Node_15.prior"/>
#             <log idref="Culicidae.prior"/>
#             <log idref="Node_16.prior"/>
#             <log idref="Node_17.prior"/>
#             <log idref="Ceratopogonidae.prior"/>
#             <log idref="Chironomidae.prior"/>
#             <log idref="Node_18.prior"/>
#             <log idref="Node_19.prior"/>
#             <log idref="Node_20.prior"/>
#             <log idref="Bibionomorpha.prior"/>
#             <log idref="Node_21.prior"/>
#             <log idref="Node_22.prior"/>
#             <log idref="Node_23.prior"/>
#             <log idref="Node_24.prior"/>
#             <log idref="Node_25.prior"/>
#             <log idref="Node_26.prior"/>
#             <log idref="Sciaroidea.prior"/>
#             <log idref="Node_27.prior"/>
#             <log idref="Keroplatidae.prior"/>
#             <log idref="Node_28.prior"/>
#             <log idref="Sciaridae.prior"/>
#             <log idref="Cecidomyiidae.prior"/>
#             <log idref="Mycetophilidae.prior"/>
#             <log idref="Brachycera.prior"/>
#             <log idref="Node_29.prior"/>
#             <log idref="Node_30.prior"/>
#             <log idref="Xylophagidae.prior"/>
#             <log idref="Tabanomorpha.prior"/>
#             <log idref="Node_31.prior"/>
#             <log idref="Node_32.prior"/>
#             <log idref="Tabanidae.prior"/>
#             <log idref="Node_33.prior"/>
#             <log idref="Node_34.prior"/>
#             <log idref="Platypezidae.prior"/>
#             <log idref="Node_35.prior"/>
#             <log idref="Pipunculidae.prior"/>
#             <log idref="Node_36.prior"/>
#             <log idref="Lauxanioidea.prior"/>
#             <log idref="Node_37.prior"/>
#             <log idref="Node_38.prior"/>
#             <log idref="Node_39.prior"/>
#             <log idref="Node_40.prior"/>
#             <log idref="Node_41.prior"/>
#             <log idref="Sciomyzidae.prior"/>
#             <log idref="Celyphidae.prior"/>
#             <log idref="Node_42.prior"/>
#             <log idref="Node_43.prior"/>
#             <log idref="Node_44.prior"/>
#             <log idref="Node_45.prior"/>
#             <log idref="Node_46.prior"/>
#             <log idref="Micropezidae.prior"/>
#             <log idref="Neriidae.prior"/>
#             <log idref="Node_47.prior"/>
#             <log idref="Tephritoidea.prior"/>
#             <log idref="Piophilidae.prior"/>
#             <log idref="Node_48.prior"/>
#             <log idref="Ulidiidae.prior"/>
#             <log idref="Node_49.prior"/>
#             <log idref="Lonchaeidae.prior"/>
#             <log idref="Platystomatidae.prior"/>
#             <log idref="Node_50.prior"/>
#             <log idref="Node_51.prior"/>
#             <log idref="Node_52.prior"/>
#             <log idref="Psilidae.prior"/>
#             <log idref="Sepsidae.prior"/>
#             <log idref="Node_53.prior"/>
#             <log idref="Node_54.prior"/>
#             <log idref="Node_55.prior"/>
#             <log idref="Node_56.prior"/>
#             <log idref="Anthomyzidae.prior"/>
#             <log idref="Node_57.prior"/>
#             <log idref="Node_58.prior"/>
#             <log idref="Chloropidae.prior"/>
#             <log idref="Node_59.prior"/>
#             <log idref="Node_60.prior"/>
#             <log idref="Node_61.prior"/>
#             <log idref="Node_62.prior"/>
#             <log idref="Node_63.prior"/>
#             <log idref="Ephydroidea_Calyptratae.prior"/>
#             <log idref="Calyptratae.prior"/>
#             <log idref="Hippoboscoidea.prior"/>
#             <log idref="Hippoboscidae.prior"/>
#             <log idref="Nycteribiidae.prior"/>
#             <log idref="Node_64.prior"/>
#             <log idref="Muscidae.prior"/>
#             <log idref="Node_65.prior"/>
#             <log idref="Scathophagidae.prior"/>
#             <log idref="Oestroidea.prior"/>
#             <log idref="Sarcophagidae.prior"/>
#             <log idref="Node_66.prior"/>
#             <log idref="Tachinidae.prior"/>
#             <log idref="Rhinophoridae.prior"/>
#             <log idref="Mesembrinellidae.prior"/>
#             <log idref="Rhiniidae.prior"/>
#             <log idref="Anthomyiidae.prior"/>
#             <log idref="Fanniidae.prior"/>
#             <log idref="Ephydroidea.prior"/>
#             <log idref="Ephydridae.prior"/>
#             <log idref="Syrphidae.prior"/>
#             <log idref="Dolichopodidae.prior"/>
#             <log idref="Asilidae.prior"/>
#             <log idref="Acroceridae.prior"/>
#             <log idref="Bombyliidae.prior"/>
#             <log idref="Milichiidae.prior"/>
#             <log idref="Conopidae.prior"/>
#             <log idref="Clusiidae.prior"/>

# %% [markdown]
# ##### Constraint statements

# %%
print('\n'.join(constraint_statements))
# Out:
#                  <distribution id="first_split.prior" spec="beast.base.evolution.tree.MRCAPrior" monophyletic="true" tree="@Tree.t:mito_nonprotcoding">
#                     <taxonset id="first_split" spec="TaxonSet">
#                         <taxon idref="Nymphomyia_560766" spec="Taxon"/>
#                         <taxon idref="Trichocera_52759" spec="Taxon"/>
#                         <taxon idref="Dicranota_700836" spec="Taxon"/>
#                         <taxon idref="Pedicia_472374" spec="Taxon"/>
#                         <taxon idref="Liogma_560731" spec="Taxon"/>
#                         <taxon idref="Phalacrocera_2203737" spec="Taxon"/>
#                         <taxon idref="Cylindrotoma_700834" spec="Taxon"/>
#                         <taxon idref="Ctenophora_516519" spec="Taxon"/>
#                         <taxon idref="Tanyptera_2108371" spec="Taxon"/>
#                         <taxon idref="Dictenidia_2108369" spec="Taxon"/>
#                         <taxon idref="Prionocera_1690388" spec="Taxon"/>
#                         <taxon idref="Tipula_41043" spec="Taxon"/>
#                         <taxon idref="Antocha_454619" spec="Taxon"/>
#                         <taxon idref="Limonia_52743" spec="Taxon"/>
#                         <taxon idref="Gnophomyia_700845" spec="Taxon"/>
#                         <taxon idref="Metalimnobia_700851" spec="Taxon"/>
#                         <taxon idref="Dactylolabis_560717" spec="Taxon"/>
#                         <taxon idref="Ptychoptera_209691" spec="Taxon"/>
#                         <taxon idref="Bittacomorpha_79307" spec="Taxon"/>
#                         <taxon idref="Liponeura_446516" spec="Taxon"/>
#                         <taxon idref="Blepharicera_547808" spec="Taxon"/>
#                         <taxon idref="Mischoderus_560267" spec="Taxon"/>
#                         <taxon idref="Araucoderus_1549737" spec="Taxon"/>
#                         <taxon idref="Protoplasa_560776" spec="Taxon"/>
#                         <taxon idref="Trichomyia_560271" spec="Taxon"/>
#                         <taxon idref="Maruina_1144738" spec="Taxon"/>
#                         <taxon idref="Clogmia_85119" spec="Taxon"/>
#                         <taxon idref="Lutzomyia_7199" spec="Taxon"/>
#                         <taxon idref="Pericoma_1148481" spec="Taxon"/>
#                         <taxon idref="Psychoda_7201" spec="Taxon"/>
#                         <taxon idref="Phlebotomus_13203" spec="Taxon"/>
#                         <taxon idref="Sycorax_114592" spec="Taxon"/>
#                         <taxon idref="Dixa_79309" spec="Taxon"/>
#                         <taxon idref="Mochlonyx_1577622" spec="Taxon"/>
#                         <taxon idref="Chaoborus_41812" spec="Taxon"/>
#                         <taxon idref="Anopheles_7164" spec="Taxon"/>
#                         <taxon idref="Culex_7174" spec="Taxon"/>
#                         <taxon idref="Aedes_7158" spec="Taxon"/>
#                         <taxon idref="Culiseta_174825" spec="Taxon"/>
#                         <taxon idref="Sphaeromias_1874311" spec="Taxon"/>
#                         <taxon idref="Palpomyia_1525500" spec="Taxon"/>
#                         <taxon idref="Austroconops_209696" spec="Taxon"/>
#                         <taxon idref="Culicoides_41820" spec="Taxon"/>
#                         <taxon idref="Serromyia_209716" spec="Taxon"/>
#                         <taxon idref="Forcipomyia_209700" spec="Taxon"/>
#                         <taxon idref="Dasyhelea_41822" spec="Taxon"/>
#                         <taxon idref="Atrichopogon_209702" spec="Taxon"/>
#                         <taxon idref="Ainuyusurika_1165747" spec="Taxon"/>
#                         <taxon idref="Pentaneura_891922" spec="Taxon"/>
#                         <taxon idref="Metriocnemus_137497" spec="Taxon"/>
#                         <taxon idref="Eukiefferiella_288843" spec="Taxon"/>
#                         <taxon idref="Parochlus_315560" spec="Taxon"/>
#                         <taxon idref="Pseudosmittia_611382" spec="Taxon"/>
#                         <taxon idref="Tvetenia_611398" spec="Taxon"/>
#                         <taxon idref="Paucispinigera_903463" spec="Taxon"/>
#                         <taxon idref="Paraborniella_903459" spec="Taxon"/>
#                         <taxon idref="Smittia_315559" spec="Taxon"/>
#                         <taxon idref="Monodiamesa_891905" spec="Taxon"/>
#                         <taxon idref="Chironomus_7150" spec="Taxon"/>
#                         <taxon idref="Clunio_315556" spec="Taxon"/>
#                         <taxon idref="Aphroteniella_646259" spec="Taxon"/>
#                         <taxon idref="Gymnometriocnemus_611353" spec="Taxon"/>
#                         <taxon idref="Corynoneura_611344" spec="Taxon"/>
#                         <taxon idref="Ablabesmyia_46216" spec="Taxon"/>
#                         <taxon idref="Psectrotanypus_903467" spec="Taxon"/>
#                         <taxon idref="Androprosopa_41815" spec="Taxon"/>
#                         <taxon idref="Austrothaumalea_1085085" spec="Taxon"/>
#                         <taxon idref="Thaumalea_61068" spec="Taxon"/>
#                         <taxon idref="Simulium_7191" spec="Taxon"/>
#                         <taxon idref="Scatopse_1520324" spec="Taxon"/>
#                         <taxon idref="Coboldia_170624" spec="Taxon"/>
#                         <taxon idref="Axymyia_560715" spec="Taxon"/>
#                         <taxon idref="Dilophus_52733" spec="Taxon"/>
#                         <taxon idref="Plecia_1260898" spec="Taxon"/>
#                         <taxon idref="Bibio_189978" spec="Taxon"/>
#                         <taxon idref="Pachyneura_1588165" spec="Taxon"/>
#                         <taxon idref="Cramptonomyia_209688" spec="Taxon"/>
#                         <taxon idref="Diadocidia_560721" spec="Taxon"/>
#                         <taxon idref="Orfelia_270890" spec="Taxon"/>
#                         <taxon idref="Macrocera_608727" spec="Taxon"/>
#                         <taxon idref="Sciara_82677" spec="Taxon"/>
#                         <taxon idref="Corynoptera_1260849" spec="Taxon"/>
#                         <taxon idref="Bradysia_35571" spec="Taxon"/>
#                         <taxon idref="Cecidomyia_1543682" spec="Taxon"/>
#                         <taxon idref="Aphidoletes_95971" spec="Taxon"/>
#                         <taxon idref="Piceacecis_2597495" spec="Taxon"/>
#                         <taxon idref="Lasioptera_201413" spec="Taxon"/>
#                         <taxon idref="Peromyia_1914937" spec="Taxon"/>
#                         <taxon idref="Winnertzia_2338641" spec="Taxon"/>
#                         <taxon idref="Asphondylia_153012" spec="Taxon"/>
#                         <taxon idref="Aprionus_1819779" spec="Taxon"/>
#                         <taxon idref="Dasineura_240745" spec="Taxon"/>
#                         <taxon idref="Sitodiplosis_263139" spec="Taxon"/>
#                         <taxon idref="Contarinia_153220" spec="Taxon"/>
#                         <taxon idref="Brachypeza_2326774" spec="Taxon"/>
#                         <taxon idref="Trichonta_397122" spec="Taxon"/>
#                         <taxon idref="Mycetophila_397146" spec="Taxon"/>
#                         <taxon idref="Neoempheria_608686" spec="Taxon"/>
#                         <taxon idref="Symmerus_560780" spec="Taxon"/>
#                         <taxon idref="Mycomya_608706" spec="Taxon"/>
#                         <taxon idref="Sciophila_1085959" spec="Taxon"/>
#                         <taxon idref="Phronia_397119" spec="Taxon"/>
#                         <taxon idref="Exechia_397139" spec="Taxon"/>
#                         <taxon idref="Epicypta_397117" spec="Taxon"/>
#                         <taxon idref="Leptomorphus_560729" spec="Taxon"/>
#                         <taxon idref="Bolitophila_52718" spec="Taxon"/>
#                         <taxon idref="Ditomyia_1520322" spec="Taxon"/>
#                         <taxon idref="Penthetria_560770" spec="Taxon"/>
#                         <taxon idref="Hesperinus_1086788" spec="Taxon"/>
#                         <taxon idref="Pantophthalmus_124295" spec="Taxon"/>
#                         <taxon idref="Exeretonevra_560723" spec="Taxon"/>
#                         <taxon idref="Xylophagus_219493" spec="Taxon"/>
#                         <taxon idref="Coenomyia_124305" spec="Taxon"/>
#                         <taxon idref="Vermileo_124333" spec="Taxon"/>
#                         <taxon idref="Glutops_124309" spec="Taxon"/>
#                         <taxon idref="Oreoleptis_1262318" spec="Taxon"/>
#                         <taxon idref="Atherix_124299" spec="Taxon"/>
#                         <taxon idref="Esenbeckia_124297" spec="Taxon"/>
#                         <taxon idref="Hybomitra_124690" spec="Taxon"/>
#                         <taxon idref="Fidena_1334907" spec="Taxon"/>
#                         <taxon idref="Apatolestes_428062" spec="Taxon"/>
#                         <taxon idref="Catachlorops_1547373" spec="Taxon"/>
#                         <taxon idref="Silvius_415257" spec="Taxon"/>
#                         <taxon idref="Atylotus_1310336" spec="Taxon"/>
#                         <taxon idref="Haematopota_124311" spec="Taxon"/>
#                         <taxon idref="Stenotabanus_1547430" spec="Taxon"/>
#                         <taxon idref="Leucotabanus_1969939" spec="Taxon"/>
#                         <taxon idref="Chrysops_27458" spec="Taxon"/>
#                         <taxon idref="Tabanus_7206" spec="Taxon"/>
#                         <taxon idref="Bolbodimyia_1547386" spec="Taxon"/>
#                         <taxon idref="Goniops_428065" spec="Taxon"/>
#                         <taxon idref="Rhagio_124327" spec="Taxon"/>
#                         <taxon idref="Ptiolina_124325" spec="Taxon"/>
#                         <taxon idref="Apiocera_160270" spec="Taxon"/>
#                         <taxon idref="Paraplatypeza_192442" spec="Taxon"/>
#                         <taxon idref="Bertamyia_1445832" spec="Taxon"/>
#                         <taxon idref="Callomyia_712098" spec="Taxon"/>
#                         <taxon idref="Kesselimyia_1445844" spec="Taxon"/>
#                         <taxon idref="Agathomyia_226141" spec="Taxon"/>
#                         <taxon idref="Polyporivora_1445854" spec="Taxon"/>
#                         <taxon idref="Platypeza_289241" spec="Taxon"/>
#                         <taxon idref="Pipunculus_240898" spec="Taxon"/>
#                         <taxon idref="Chalarus_115250" spec="Taxon"/>
#                         <taxon idref="Nephrocerus_115303" spec="Taxon"/>
#                         <taxon idref="Verrallia_115333" spec="Taxon"/>
#                         <taxon idref="Chamaemyia_305621" spec="Taxon"/>
#                         <taxon idref="Leucopis_1728826" spec="Taxon"/>
#                         <taxon idref="Parochthiphila_1262282" spec="Taxon"/>
#                         <taxon idref="Coelopa_169466" spec="Taxon"/>
#                         <taxon idref="Helcomyza_169476" spec="Taxon"/>
#                         <taxon idref="Homoneura_1692452" spec="Taxon"/>
#                         <taxon idref="Tricholauxania_192459" spec="Taxon"/>
#                         <taxon idref="Aulogastromyia_1824990" spec="Taxon"/>
#                         <taxon idref="Pteromicra_1226622" spec="Taxon"/>
#                         <taxon idref="Dictya_1096051" spec="Taxon"/>
#                         <taxon idref="Elgiva_320938" spec="Taxon"/>
#                         <taxon idref="Sepedon_320954" spec="Taxon"/>
#                         <taxon idref="Neolimnia_1262312" spec="Taxon"/>
#                         <taxon idref="Sciomyza_320936" spec="Taxon"/>
#                         <taxon idref="Ilione_1096072" spec="Taxon"/>
#                         <taxon idref="Psacadina_1096078" spec="Taxon"/>
#                         <taxon idref="Tetanocera_320959" spec="Taxon"/>
#                         <taxon idref="Hedria_320941" spec="Taxon"/>
#                         <taxon idref="Coremacera_1226614" spec="Taxon"/>
#                         <taxon idref="Anticheta_1096047" spec="Taxon"/>
#                         <taxon idref="Pelidnoptera_1096074" spec="Taxon"/>
#                         <taxon idref="Celyphus_1979294" spec="Taxon"/>
#                         <taxon idref="Spaniocelyphus_1262326" spec="Taxon"/>
#                         <taxon idref="Copromyza_1217530" spec="Taxon"/>
#                         <taxon idref="Leptocera_1614654" spec="Taxon"/>
#                         <taxon idref="Mimegralla_115300" spec="Taxon"/>
#                         <taxon idref="Compsobata_286452" spec="Taxon"/>
#                         <taxon idref="Calobata_1820059" spec="Taxon"/>
#                         <taxon idref="Micropeza_1572561" spec="Taxon"/>
#                         <taxon idref="Telostylinus_1262347" spec="Taxon"/>
#                         <taxon idref="Odontoloxozus_588320" spec="Taxon"/>
#                         <taxon idref="Lasiopiophila_1790233" spec="Taxon"/>
#                         <taxon idref="Piophila_53709" spec="Taxon"/>
#                         <taxon idref="Centrophlebomyia_1603419" spec="Taxon"/>
#                         <taxon idref="Liopiophila_1603421" spec="Taxon"/>
#                         <taxon idref="Delphinia_43369" spec="Taxon"/>
#                         <taxon idref="Chaetopsis_240871" spec="Taxon"/>
#                         <taxon idref="Tetanops_454640" spec="Taxon"/>
#                         <taxon idref="Euxesta_286468" spec="Taxon"/>
#                         <taxon idref="Eurosta_28593" spec="Taxon"/>
#                         <taxon idref="Anastrepha_28585" spec="Taxon"/>
#                         <taxon idref="Euleia_28591" spec="Taxon"/>
#                         <taxon idref="Terellia_28615" spec="Taxon"/>
#                         <taxon idref="Paracantha_164885" spec="Taxon"/>
#                         <taxon idref="Tephritis_43386" spec="Taxon"/>
#                         <taxon idref="Urophora_28620" spec="Taxon"/>
#                         <taxon idref="Gymnocarena_28597" spec="Taxon"/>
#                         <taxon idref="Jamesomyia_28601" spec="Taxon"/>
#                         <taxon idref="Oxyna_381365" spec="Taxon"/>
#                         <taxon idref="Trupanea_30060" spec="Taxon"/>
#                         <taxon idref="Rhagoletis_28609" spec="Taxon"/>
#                         <taxon idref="Noeeta_381362" spec="Taxon"/>
#                         <taxon idref="Ceratitis_7212" spec="Taxon"/>
#                         <taxon idref="Zonosemata_28622" spec="Taxon"/>
#                         <taxon idref="Bactrocera_27456" spec="Taxon"/>
#                         <taxon idref="Xyphosia_381372" spec="Taxon"/>
#                         <taxon idref="Icterica_28599" spec="Taxon"/>
#                         <taxon idref="Lamprolonchaea_907706" spec="Taxon"/>
#                         <taxon idref="Lonchaea_198649" spec="Taxon"/>
#                         <taxon idref="Dasiops_286456" spec="Taxon"/>
#                         <taxon idref="Silba_198646" spec="Taxon"/>
#                         <taxon idref="Rivellia_28633" spec="Taxon"/>
#                         <taxon idref="Platystoma_286504" spec="Taxon"/>
#                         <taxon idref="Scholastes_1902237" spec="Taxon"/>
#                         <taxon idref="Palloptera_286498" spec="Taxon"/>
#                         <taxon idref="Ctenostylidae" spec="Taxon"/>
#                         <taxon idref="Opomyza_716643" spec="Taxon"/>
#                         <taxon idref="Geomyza_305619" spec="Taxon"/>
#                         <taxon idref="Psila_305548" spec="Taxon"/>
#                         <taxon idref="Loxocera_34684" spec="Taxon"/>
#                         <taxon idref="Chyliza_716634" spec="Taxon"/>
#                         <taxon idref="Sepsis_137507" spec="Taxon"/>
#                         <taxon idref="Themira_292396" spec="Taxon"/>
#                         <taxon idref="Diasemopsis_139652" spec="Taxon"/>
#                         <taxon idref="Sphyracephala_139674" spec="Taxon"/>
#                         <taxon idref="Diopsis_139667" spec="Taxon"/>
#                         <taxon idref="Procanace_1262322" spec="Taxon"/>
#                         <taxon idref="Stiphrosoma_500293" spec="Taxon"/>
#                         <taxon idref="Paranthomyza_500298" spec="Taxon"/>
#                         <taxon idref="Quametopia_1603285" spec="Taxon"/>
#                         <taxon idref="Thaumatomyia_333800" spec="Taxon"/>
#                         <taxon idref="Hippelates_540866" spec="Taxon"/>
#                         <taxon idref="Cetema_540891" spec="Taxon"/>
#                         <taxon idref="Gaurax_540862" spec="Taxon"/>
#                         <taxon idref="Lipara_540870" spec="Taxon"/>
#                         <taxon idref="Tricimba_540889" spec="Taxon"/>
#                         <taxon idref="Elachiptera_540858" spec="Taxon"/>
#                         <taxon idref="Incertella_540867" spec="Taxon"/>
#                         <taxon idref="Aphanotrigonum_540849" spec="Taxon"/>
#                         <taxon idref="Calamoncosis_540852" spec="Taxon"/>
#                         <taxon idref="Chlorops_540892" spec="Taxon"/>
#                         <taxon idref="Cryptonevra_1616778" spec="Taxon"/>
#                         <taxon idref="Epichlorops_540897" spec="Taxon"/>
#                         <taxon idref="Stenomicra_716630" spec="Taxon"/>
#                         <taxon idref="Periscelis_716628" spec="Taxon"/>
#                         <taxon idref="Fergusonina_156411" spec="Taxon"/>
#                         <taxon idref="Liriomyza_127403" spec="Taxon"/>
#                         <taxon idref="Melanagromyza_286470" spec="Taxon"/>
#                         <taxon idref="Phytobia_414304" spec="Taxon"/>
#                         <taxon idref="Cerodontha_127401" spec="Taxon"/>
#                         <taxon idref="Ophiomyia_341050" spec="Taxon"/>
#                         <taxon idref="Japanagromyza_414298" spec="Taxon"/>
#                         <taxon idref="Agromyza_414290" spec="Taxon"/>
#                         <taxon idref="Calycomyza_414293" spec="Taxon"/>
#                         <taxon idref="Phytomyza_132616" spec="Taxon"/>
#                         <taxon idref="Odinia_414302" spec="Taxon"/>
#                         <taxon idref="Crataerina_452743" spec="Taxon"/>
#                         <taxon idref="Olfersia_1333310" spec="Taxon"/>
#                         <taxon idref="Melophagus_452748" spec="Taxon"/>
#                         <taxon idref="Ornithophila_1497392" spec="Taxon"/>
#                         <taxon idref="Hippobosca_452745" spec="Taxon"/>
#                         <taxon idref="Icosta_402409" spec="Taxon"/>
#                         <taxon idref="Lipoptena_170902" spec="Taxon"/>
#                         <taxon idref="Glossina_7393" spec="Taxon"/>
#                         <taxon idref="Basilia_170889" spec="Taxon"/>
#                         <taxon idref="Penicillidia_81721" spec="Taxon"/>
#                         <taxon idref="Nycteribia_633884" spec="Taxon"/>
#                         <taxon idref="Muscina_57892" spec="Taxon"/>
#                         <taxon idref="Phaonia_253431" spec="Taxon"/>
#                         <taxon idref="Hebecnema_559682" spec="Taxon"/>
#                         <taxon idref="Potamia_559704" spec="Taxon"/>
#                         <taxon idref="Atherigona_305597" spec="Taxon"/>
#                         <taxon idref="Musca_7369" spec="Taxon"/>
#                         <taxon idref="Passeromyia_1511687" spec="Taxon"/>
#                         <taxon idref="Myospila_520040" spec="Taxon"/>
#                         <taxon idref="Haematobosca_559680" spec="Taxon"/>
#                         <taxon idref="Neomyia_305607" spec="Taxon"/>
#                         <taxon idref="Mesembrina_116147" spec="Taxon"/>
#                         <taxon idref="Graphomya_1072499" spec="Taxon"/>
#                         <taxon idref="Morellia_253340" spec="Taxon"/>
#                         <taxon idref="Philornis_253427" spec="Taxon"/>
#                         <taxon idref="Polietes_559702" spec="Taxon"/>
#                         <taxon idref="Eginia_1511678" spec="Taxon"/>
#                         <taxon idref="Limnophora_307207" spec="Taxon"/>
#                         <taxon idref="Scathophaga_95462" spec="Taxon"/>
#                         <taxon idref="Hydromyza_113174" spec="Taxon"/>
#                         <taxon idref="Norellia_113119" spec="Taxon"/>
#                         <taxon idref="Cordilura_113132" spec="Taxon"/>
#                         <taxon idref="Cleigastra_113167" spec="Taxon"/>
#                         <taxon idref="Orthacheta_113181" spec="Taxon"/>
#                         <taxon idref="Sphecapatoclea_2021595" spec="Taxon"/>
#                         <taxon idref="Sphecapatodes_2021536" spec="Taxon"/>
#                         <taxon idref="Miltogramma_670602" spec="Taxon"/>
#                         <taxon idref="Blaesoxipha_128953" spec="Taxon"/>
#                         <taxon idref="Craticulina_2021509" spec="Taxon"/>
#                         <taxon idref="Sarcophaga_7384" spec="Taxon"/>
#                         <taxon idref="Wohlfahrtia_128961" spec="Taxon"/>
#                         <taxon idref="Ectophasia_569037" spec="Taxon"/>
#                         <taxon idref="Sturmia_569089" spec="Taxon"/>
#                         <taxon idref="Phytomyptera_179785" spec="Taxon"/>
#                         <taxon idref="Nemoraea_170911" spec="Taxon"/>
#                         <taxon idref="Billaea_701468" spec="Taxon"/>
#                         <taxon idref="Ateloglossa_1890907" spec="Taxon"/>
#                         <taxon idref="Senotainia_179787" spec="Taxon"/>
#                         <taxon idref="Elomyia_1562792" spec="Taxon"/>
#                         <taxon idref="Blondelia_179437" spec="Taxon"/>
#                         <taxon idref="Prosena_1918293" spec="Taxon"/>
#                         <taxon idref="Glaurocara_2027854" spec="Taxon"/>
#                         <taxon idref="Drino_179459" spec="Taxon"/>
#                         <taxon idref="Phryxe_569079" spec="Taxon"/>
#                         <taxon idref="Acemya_1677647" spec="Taxon"/>
#                         <taxon idref="Blepharomyia_179434" spec="Taxon"/>
#                         <taxon idref="Cleonice_1918224" spec="Taxon"/>
#                         <taxon idref="Cyrtophleba_991141" spec="Taxon"/>
#                         <taxon idref="Dinera_569035" spec="Taxon"/>
#                         <taxon idref="Anthomyiopsis_1918198" spec="Taxon"/>
#                         <taxon idref="Neaera_695903" spec="Taxon"/>
#                         <taxon idref="Parasetigena_380521" spec="Taxon"/>
#                         <taxon idref="Mintho_1918277" spec="Taxon"/>
#                         <taxon idref="Lydella_283929" spec="Taxon"/>
#                         <taxon idref="Clausicella_1718822" spec="Taxon"/>
#                         <taxon idref="Archytas_198637" spec="Taxon"/>
#                         <taxon idref="Dexia_569033" spec="Taxon"/>
#                         <taxon idref="Pseudoperichaeta_283931" spec="Taxon"/>
#                         <taxon idref="Estheria_1918238" spec="Taxon"/>
#                         <taxon idref="Exorista_113238" spec="Taxon"/>
#                         <taxon idref="Leschenaultia_179486" spec="Taxon"/>
#                         <taxon idref="Vibrissina_179525" spec="Taxon"/>
#                         <taxon idref="Zaira_179789" spec="Taxon"/>
#                         <taxon idref="Macquartia_1918266" spec="Taxon"/>
#                         <taxon idref="Stevenia_670627" spec="Taxon"/>
#                         <taxon idref="Rhinophora_670625" spec="Taxon"/>
#                         <taxon idref="Tricogena_1606792" spec="Taxon"/>
#                         <taxon idref="Phyto_1262320" spec="Taxon"/>
#                         <taxon idref="Paykullia_559695" spec="Taxon"/>
#                         <taxon idref="Melanophora_1606787" spec="Taxon"/>
#                         <taxon idref="Laneella_1658054" spec="Taxon"/>
#                         <taxon idref="Eumesembrinella_672472" spec="Taxon"/>
#                         <taxon idref="Mesembrinella_460529" spec="Taxon"/>
#                         <taxon idref="Huascaromusca_1609532" spec="Taxon"/>
#                         <taxon idref="Rhyncomya_670621" spec="Taxon"/>
#                         <taxon idref="Idiella_1902146" spec="Taxon"/>
#                         <taxon idref="Paralucilia_1042205" spec="Taxon"/>
#                         <taxon idref="Hypoderma_7388" spec="Taxon"/>
#                         <taxon idref="Dermatobia_115426" spec="Taxon"/>
#                         <taxon idref="Compsomyiops_142897" spec="Taxon"/>
#                         <taxon idref="Hemilucilia_416848" spec="Taxon"/>
#                         <taxon idref="Przhevalskiana_123746" spec="Taxon"/>
#                         <taxon idref="Rhinoestrus_204922" spec="Taxon"/>
#                         <taxon idref="Oestrus_123736" spec="Taxon"/>
#                         <taxon idref="Oestromyia_170913" spec="Taxon"/>
#                         <taxon idref="Calliphora_7372" spec="Taxon"/>
#                         <taxon idref="Lucilia_7374" spec="Taxon"/>
#                         <taxon idref="Mystacinobia_81694" spec="Taxon"/>
#                         <taxon idref="Pollenia_229639" spec="Taxon"/>
#                         <taxon idref="Hemigymnochaeta_1240433" spec="Taxon"/>
#                         <taxon idref="Chrysomya_45449" spec="Taxon"/>
#                         <taxon idref="Trypocalliphora_1042207" spec="Taxon"/>
#                         <taxon idref="Cordylobia_226131" spec="Taxon"/>
#                         <taxon idref="Sarconesia_670650" spec="Taxon"/>
#                         <taxon idref="Amenia_2086281" spec="Taxon"/>
#                         <taxon idref="Auchmeromyia_226129" spec="Taxon"/>
#                         <taxon idref="Melinda_170907" spec="Taxon"/>
#                         <taxon idref="Protocalliphora_142901" spec="Taxon"/>
#                         <taxon idref="Cuterebra_170896" spec="Taxon"/>
#                         <taxon idref="Cephenemyia_170894" spec="Taxon"/>
#                         <taxon idref="Phorbia_1993534" spec="Taxon"/>
#                         <taxon idref="Egle_411076" spec="Taxon"/>
#                         <taxon idref="Lasiomma_95464" spec="Taxon"/>
#                         <taxon idref="Alliopsis_1692454" spec="Taxon"/>
#                         <taxon idref="Fucellia_205683" spec="Taxon"/>
#                         <taxon idref="Pegomya_559697" spec="Taxon"/>
#                         <taxon idref="Paregle_559693" spec="Taxon"/>
#                         <taxon idref="Chiastocheta_129251" spec="Taxon"/>
#                         <taxon idref="Chirosia_392044" spec="Taxon"/>
#                         <taxon idref="Pegohylemyia_1887308" spec="Taxon"/>
#                         <taxon idref="Delia_30063" spec="Taxon"/>
#                         <taxon idref="Hylemya_253328" spec="Taxon"/>
#                         <taxon idref="Anthomyia_259845" spec="Taxon"/>
#                         <taxon idref="Fannia_95468" spec="Taxon"/>
#                         <taxon idref="Euryomma_1650677" spec="Taxon"/>
#                         <taxon idref="Curtonotum_1262296" spec="Taxon"/>
#                         <taxon idref="Cryptochetum_1262333" spec="Taxon"/>
#                         <taxon idref="Hydrellia_92591" spec="Taxon"/>
#                         <taxon idref="Nostima_1473719" spec="Taxon"/>
#                         <taxon idref="Scatophila_1763968" spec="Taxon"/>
#                         <taxon idref="Pelina_1086796" spec="Taxon"/>
#                         <taxon idref="Ephydra_504564" spec="Taxon"/>
#                         <taxon idref="Scatella_305595" spec="Taxon"/>
#                         <taxon idref="Stegana_188292" spec="Taxon"/>
#                         <taxon idref="Drosophila_7215" spec="Taxon"/>
#                         <taxon idref="Zygothrica_504731" spec="Taxon"/>
#                         <taxon idref="Scaptomyza_7298" spec="Taxon"/>
#                         <taxon idref="Acletoxenus_462271" spec="Taxon"/>
#                         <taxon idref="Leucophenga_7329" spec="Taxon"/>
#                         <taxon idref="Chymomyza_7292" spec="Taxon"/>
#                         <taxon idref="Zaprionus_7296" spec="Taxon"/>
#                         <taxon idref="Scaptodrosophila_7354" spec="Taxon"/>
#                         <taxon idref="Cacoxenus_462273" spec="Taxon"/>
#                         <taxon idref="Hammerschmidtia_226171" spec="Taxon"/>
#                         <taxon idref="Paragus_115308" spec="Taxon"/>
#                         <taxon idref="Brachyopa_1637464" spec="Taxon"/>
#                         <taxon idref="Eupeodes_290403" spec="Taxon"/>
#                         <taxon idref="Blera_226146" spec="Taxon"/>
#                         <taxon idref="Copestylum_511142" spec="Taxon"/>
#                         <taxon idref="Scaeva_219538" spec="Taxon"/>
#                         <taxon idref="Eumerus_224220" spec="Taxon"/>
#                         <taxon idref="Syrphus_224255" spec="Taxon"/>
#                         <taxon idref="Ornidia_994473" spec="Taxon"/>
#                         <taxon idref="Volucella_226148" spec="Taxon"/>
#                         <taxon idref="Melangyna_414825" spec="Taxon"/>
#                         <taxon idref="Syritta_34681" spec="Taxon"/>
#                         <taxon idref="Ocyptamus_369855" spec="Taxon"/>
#                         <taxon idref="Cheilosia_173981" spec="Taxon"/>
#                         <taxon idref="Chrysogaster_224248" spec="Taxon"/>
#                         <taxon idref="Microdon_115291" spec="Taxon"/>
#                         <taxon idref="Toxomerus_115327" spec="Taxon"/>
#                         <taxon idref="Sphaerophoria_226179" spec="Taxon"/>
#                         <taxon idref="Merodon_224226" spec="Taxon"/>
#                         <taxon idref="Pipiza_221788" spec="Taxon"/>
#                         <taxon idref="Epistrophe_414810" spec="Taxon"/>
#                         <taxon idref="Temnostoma_226164" spec="Taxon"/>
#                         <taxon idref="Eriozona_414724" spec="Taxon"/>
#                         <taxon idref="Myolepta_1473716" spec="Taxon"/>
#                         <taxon idref="Neoascia_224222" spec="Taxon"/>
#                         <taxon idref="Callicera_228567" spec="Taxon"/>
#                         <taxon idref="Eristalis_198633" spec="Taxon"/>
#                         <taxon idref="Xanthogramma_414873" spec="Taxon"/>
#                         <taxon idref="Dolichopus_192427" spec="Taxon"/>
#                         <taxon idref="Medetera_377527" spec="Taxon"/>
#                         <taxon idref="Rhaphium_377528" spec="Taxon"/>
#                         <taxon idref="Rhamphomyia_192612" spec="Taxon"/>
#                         <taxon idref="Neoplasta_192640" spec="Taxon"/>
#                         <taxon idref="Phyllodromia_1209097" spec="Taxon"/>
#                         <taxon idref="Chelifera_369889" spec="Taxon"/>
#                         <taxon idref="Wiedemannia_240904" spec="Taxon"/>
#                         <taxon idref="Clinocera_192484" spec="Taxon"/>
#                         <taxon idref="Metachela_369884" spec="Taxon"/>
#                         <taxon idref="Philonicus_247567" spec="Taxon"/>
#                         <taxon idref="Dioctria_468720" spec="Taxon"/>
#                         <taxon idref="Promachus_247552" spec="Taxon"/>
#                         <taxon idref="Machimus_247604" spec="Taxon"/>
#                         <taxon idref="Lasiopogon_219536" spec="Taxon"/>
#                         <taxon idref="Pamponerus_1717601" spec="Taxon"/>
#                         <taxon idref="Laphria_50683" spec="Taxon"/>
#                         <taxon idref="Mallophora_270862" spec="Taxon"/>
#                         <taxon idref="Ocnaea_210271" spec="Taxon"/>
#                         <taxon idref="Ogcodes_188257" spec="Taxon"/>
#                         <taxon idref="Eulonchus_210230" spec="Taxon"/>
#                         <taxon idref="Acrocera_210245" spec="Taxon"/>
#                         <taxon idref="Astomella_210239" spec="Taxon"/>
#                         <taxon idref="Exetasis_1932988" spec="Taxon"/>
#                         <taxon idref="Pterodontia_210267" spec="Taxon"/>
#                         <taxon idref="Systoechus_1690390" spec="Taxon"/>
#                         <taxon idref="Bombylius_219362" spec="Taxon"/>
#                         <taxon idref="Anthrax_117078" spec="Taxon"/>
#                         <taxon idref="Ligyra_117088" spec="Taxon"/>
#                         <taxon idref="Desmometopa_305587" spec="Taxon"/>
#                         <taxon idref="Leptometopa_1720790" spec="Taxon"/>
#                         <taxon idref="Pholeomyia_1720804" spec="Taxon"/>
#                         <taxon idref="Milichiella_1890919" spec="Taxon"/>
#                         <taxon idref="Physocephala_198643" spec="Taxon"/>
#                         <taxon idref="Thecophora_305546" spec="Taxon"/>
#                         <taxon idref="Sicus_1219203" spec="Taxon"/>
#                         <taxon idref="Zodion_768804" spec="Taxon"/>
#                         <taxon idref="Sobarocephala_574054" spec="Taxon"/>
#                         <taxon idref="Clusia_574057" spec="Taxon"/>
#                         <taxon idref="Clusiodes_500306" spec="Taxon"/>
#                         <taxon idref="Mydas_186100" spec="Taxon"/>
#                         <taxon idref="Hypocera_940227" spec="Taxon"/>
#                         <taxon idref="Sciadocera_192453" spec="Taxon"/>
#                         <taxon idref="Hermetia_343581" spec="Taxon"/>
#                         <taxon idref="Heterocheila_169481" spec="Taxon"/>
#                         <taxon idref="Borophaga_712093" spec="Taxon"/>
#                         <taxon idref="Ptecticus_343648" spec="Taxon"/>
#                         <taxon idref="Dryomyza_169444" spec="Taxon"/>
#                         <taxon idref="Oxycera_860348" spec="Taxon"/>
#                         <taxon idref="Chloromyia_343649" spec="Taxon"/>
#                         <taxon idref="Neorhynchocephalus_259248" spec="Taxon"/>
#                         <taxon idref="Neurochaeta_716624" spec="Taxon"/>
#                         <taxon idref="Berkshiria_2061012" spec="Taxon"/>
#                         <taxon idref="Nemotelus_343582" spec="Taxon"/>
#                         <taxon idref="Anevrina_92526" spec="Taxon"/>
#                         <taxon idref="Lonchoptera_92595" spec="Taxon"/>
#                         <taxon idref="Microchrysa_931517" spec="Taxon"/>
#                         <taxon idref="Scenopinus_247599" spec="Taxon"/>
#                         <taxon idref="Neopachygaster_1692469" spec="Taxon"/>
#                         <taxon idref="Diplonevra_92534" spec="Taxon"/>
#                         <taxon idref="Apocephalus_117252" spec="Taxon"/>
#                         <taxon idref="Scoliocentra_1823605" spec="Taxon"/>
#                         <taxon idref="Sargus_343647" spec="Taxon"/>
#                         <taxon idref="Teratomyzidae" spec="Taxon"/>
#                         <taxon idref="Hirmoneura_388531" spec="Taxon"/>
#                         <taxon idref="Neossos_2268121" spec="Taxon"/>
#                         <taxon idref="Pachygaster_124321" spec="Taxon"/>
#                         <taxon idref="Tanypeza_1692486" spec="Taxon"/>
#                         <taxon idref="Stratiomys_219520" spec="Taxon"/>
#                         <taxon idref="Odontomyia_343652" spec="Taxon"/>
#                         <taxon idref="Zabrachia_1891525" spec="Taxon"/>
#                         <taxon idref="Thereva_95078" spec="Taxon"/>
#                         <taxon idref="Helosciomyzidae" spec="Taxon"/>
#                         <taxon idref="Triphleba_92553" spec="Taxon"/>
#                         <taxon idref="Oedoparena_1262316" spec="Taxon"/>
#                         <taxon idref="Megaselia_36165" spec="Taxon"/>
#                         <taxon idref="Oplodontha_446504" spec="Taxon"/>
#                     </taxonset>
#                 </distribution>
#                 <distribution id="Node_0.prior" spec="beastlabs.math.distributions.MRCAPriorWithRogues" monophyletic="true" tree="@Tree.t:mito_nonprotcoding">
#                     <taxonset id="Node_0" spec="TaxonSet">
#                         <taxon idref="Trichocera_52759" spec="Taxon"/>
#                         <taxon idref="Dicranota_700836" spec="Taxon"/>
#                         <taxon idref="Pedicia_472374" spec="Taxon"/>
#                         <taxon idref="Liogma_560731" spec="Taxon"/>
#                         <taxon idref="Phalacrocera_2203737" spec="Taxon"/>
#                         <taxon idref="Cylindrotoma_700834" spec="Taxon"/>
#                         <taxon idref="Ctenophora_516519" spec="Taxon"/>
#                         <taxon idref="Tanyptera_2108371" spec="Taxon"/>
#                         <taxon idref="Dictenidia_2108369" spec="Taxon"/>
#                         <taxon idref="Prionocera_1690388" spec="Taxon"/>
#                         <taxon idref="Tipula_41043" spec="Taxon"/>
#                         <taxon idref="Antocha_454619" spec="Taxon"/>
#                         <taxon idref="Limonia_52743" spec="Taxon"/>
#                         <taxon idref="Gnophomyia_700845" spec="Taxon"/>
#                         <taxon idref="Metalimnobia_700851" spec="Taxon"/>
#                         <taxon idref="Dactylolabis_560717" spec="Taxon"/>
#                         <taxon idref="Ptychoptera_209691" spec="Taxon"/>
#                         <taxon idref="Bittacomorpha_79307" spec="Taxon"/>
#                         <taxon idref="Liponeura_446516" spec="Taxon"/>
#                         <taxon idref="Blepharicera_547808" spec="Taxon"/>
#                         <taxon idref="Mischoderus_560267" spec="Taxon"/>
#                         <taxon idref="Araucoderus_1549737" spec="Taxon"/>
#                         <taxon idref="Protoplasa_560776" spec="Taxon"/>
#                         <taxon idref="Trichomyia_560271" spec="Taxon"/>
#                         <taxon idref="Maruina_1144738" spec="Taxon"/>
#                         <taxon idref="Clogmia_85119" spec="Taxon"/>
#                         <taxon idref="Lutzomyia_7199" spec="Taxon"/>
#                         <taxon idref="Pericoma_1148481" spec="Taxon"/>
#                         <taxon idref="Psychoda_7201" spec="Taxon"/>
#                         <taxon idref="Phlebotomus_13203" spec="Taxon"/>
#                         <taxon idref="Sycorax_114592" spec="Taxon"/>
#                         <taxon idref="Dixa_79309" spec="Taxon"/>
#                         <taxon idref="Mochlonyx_1577622" spec="Taxon"/>
#                         <taxon idref="Chaoborus_41812" spec="Taxon"/>
#                         <taxon idref="Anopheles_7164" spec="Taxon"/>
#                         <taxon idref="Culex_7174" spec="Taxon"/>
#                         <taxon idref="Aedes_7158" spec="Taxon"/>
#                         <taxon idref="Culiseta_174825" spec="Taxon"/>
#                         <taxon idref="Sphaeromias_1874311" spec="Taxon"/>
#                         <taxon idref="Palpomyia_1525500" spec="Taxon"/>
#                         <taxon idref="Austroconops_209696" spec="Taxon"/>
#                         <taxon idref="Culicoides_41820" spec="Taxon"/>
#                         <taxon idref="Serromyia_209716" spec="Taxon"/>
#                         <taxon idref="Forcipomyia_209700" spec="Taxon"/>
#                         <taxon idref="Dasyhelea_41822" spec="Taxon"/>
#                         <taxon idref="Atrichopogon_209702" spec="Taxon"/>
#                         <taxon idref="Ainuyusurika_1165747" spec="Taxon"/>
#                         <taxon idref="Pentaneura_891922" spec="Taxon"/>
#                         <taxon idref="Metriocnemus_137497" spec="Taxon"/>
#                         <taxon idref="Eukiefferiella_288843" spec="Taxon"/>
#                         <taxon idref="Parochlus_315560" spec="Taxon"/>
#                         <taxon idref="Pseudosmittia_611382" spec="Taxon"/>
#                         <taxon idref="Tvetenia_611398" spec="Taxon"/>
#                         <taxon idref="Paucispinigera_903463" spec="Taxon"/>
#                         <taxon idref="Paraborniella_903459" spec="Taxon"/>
#                         <taxon idref="Smittia_315559" spec="Taxon"/>
#                         <taxon idref="Monodiamesa_891905" spec="Taxon"/>
#                         <taxon idref="Chironomus_7150" spec="Taxon"/>
#                         <taxon idref="Clunio_315556" spec="Taxon"/>
#                         <taxon idref="Aphroteniella_646259" spec="Taxon"/>
#                         <taxon idref="Gymnometriocnemus_611353" spec="Taxon"/>
#                         <taxon idref="Corynoneura_611344" spec="Taxon"/>
#                         <taxon idref="Ablabesmyia_46216" spec="Taxon"/>
#                         <taxon idref="Psectrotanypus_903467" spec="Taxon"/>
#                         <taxon idref="Androprosopa_41815" spec="Taxon"/>
#                         <taxon idref="Austrothaumalea_1085085" spec="Taxon"/>
#                         <taxon idref="Thaumalea_61068" spec="Taxon"/>
#                         <taxon idref="Simulium_7191" spec="Taxon"/>
#                         <taxon idref="Scatopse_1520324" spec="Taxon"/>
#                         <taxon idref="Coboldia_170624" spec="Taxon"/>
#                         <taxon idref="Axymyia_560715" spec="Taxon"/>
#                         <taxon idref="Dilophus_52733" spec="Taxon"/>
#                         <taxon idref="Plecia_1260898" spec="Taxon"/>
#                         <taxon idref="Bibio_189978" spec="Taxon"/>
#                         <taxon idref="Pachyneura_1588165" spec="Taxon"/>
#                         <taxon idref="Cramptonomyia_209688" spec="Taxon"/>
#                         <taxon idref="Diadocidia_560721" spec="Taxon"/>
#                         <taxon idref="Orfelia_270890" spec="Taxon"/>
#                         <taxon idref="Macrocera_608727" spec="Taxon"/>
#                         <taxon idref="Sciara_82677" spec="Taxon"/>
#                         <taxon idref="Corynoptera_1260849" spec="Taxon"/>
#                         <taxon idref="Bradysia_35571" spec="Taxon"/>
#                         <taxon idref="Cecidomyia_1543682" spec="Taxon"/>
#                         <taxon idref="Aphidoletes_95971" spec="Taxon"/>
#                         <taxon idref="Piceacecis_2597495" spec="Taxon"/>
#                         <taxon idref="Lasioptera_201413" spec="Taxon"/>
#                         <taxon idref="Peromyia_1914937" spec="Taxon"/>
#                         <taxon idref="Winnertzia_2338641" spec="Taxon"/>
#                         <taxon idref="Asphondylia_153012" spec="Taxon"/>
#                         <taxon idref="Aprionus_1819779" spec="Taxon"/>
#                         <taxon idref="Dasineura_240745" spec="Taxon"/>
#                         <taxon idref="Sitodiplosis_263139" spec="Taxon"/>
#                         <taxon idref="Contarinia_153220" spec="Taxon"/>
#                         <taxon idref="Brachypeza_2326774" spec="Taxon"/>
#                         <taxon idref="Trichonta_397122" spec="Taxon"/>
#                         <taxon idref="Mycetophila_397146" spec="Taxon"/>
#                         <taxon idref="Neoempheria_608686" spec="Taxon"/>
#                         <taxon idref="Symmerus_560780" spec="Taxon"/>
#                         <taxon idref="Mycomya_608706" spec="Taxon"/>
#                         <taxon idref="Sciophila_1085959" spec="Taxon"/>
#                         <taxon idref="Phronia_397119" spec="Taxon"/>
#                         <taxon idref="Exechia_397139" spec="Taxon"/>
#                         <taxon idref="Epicypta_397117" spec="Taxon"/>
#                         <taxon idref="Leptomorphus_560729" spec="Taxon"/>
#                         <taxon idref="Bolitophila_52718" spec="Taxon"/>
#                         <taxon idref="Ditomyia_1520322" spec="Taxon"/>
#                         <taxon idref="Penthetria_560770" spec="Taxon"/>
#                         <taxon idref="Hesperinus_1086788" spec="Taxon"/>
#                         <taxon idref="Pantophthalmus_124295" spec="Taxon"/>
#                         <taxon idref="Exeretonevra_560723" spec="Taxon"/>
#                         <taxon idref="Xylophagus_219493" spec="Taxon"/>
#                         <taxon idref="Coenomyia_124305" spec="Taxon"/>
#                         <taxon idref="Vermileo_124333" spec="Taxon"/>
#                         <taxon idref="Glutops_124309" spec="Taxon"/>
#                         <taxon idref="Oreoleptis_1262318" spec="Taxon"/>
#                         <taxon idref="Atherix_124299" spec="Taxon"/>
#                         <taxon idref="Esenbeckia_124297" spec="Taxon"/>
#                         <taxon idref="Hybomitra_124690" spec="Taxon"/>
#                         <taxon idref="Fidena_1334907" spec="Taxon"/>
#                         <taxon idref="Apatolestes_428062" spec="Taxon"/>
#                         <taxon idref="Catachlorops_1547373" spec="Taxon"/>
#                         <taxon idref="Silvius_415257" spec="Taxon"/>
#                         <taxon idref="Atylotus_1310336" spec="Taxon"/>
#                         <taxon idref="Haematopota_124311" spec="Taxon"/>
#                         <taxon idref="Stenotabanus_1547430" spec="Taxon"/>
#                         <taxon idref="Leucotabanus_1969939" spec="Taxon"/>
#                         <taxon idref="Chrysops_27458" spec="Taxon"/>
#                         <taxon idref="Tabanus_7206" spec="Taxon"/>
#                         <taxon idref="Bolbodimyia_1547386" spec="Taxon"/>
#                         <taxon idref="Goniops_428065" spec="Taxon"/>
#                         <taxon idref="Rhagio_124327" spec="Taxon"/>
#                         <taxon idref="Ptiolina_124325" spec="Taxon"/>
#                         <taxon idref="Apiocera_160270" spec="Taxon"/>
#                         <taxon idref="Paraplatypeza_192442" spec="Taxon"/>
#                         <taxon idref="Bertamyia_1445832" spec="Taxon"/>
#                         <taxon idref="Callomyia_712098" spec="Taxon"/>
#                         <taxon idref="Kesselimyia_1445844" spec="Taxon"/>
#                         <taxon idref="Agathomyia_226141" spec="Taxon"/>
#                         <taxon idref="Polyporivora_1445854" spec="Taxon"/>
#                         <taxon idref="Platypeza_289241" spec="Taxon"/>
#                         <taxon idref="Pipunculus_240898" spec="Taxon"/>
#                         <taxon idref="Chalarus_115250" spec="Taxon"/>
#                         <taxon idref="Nephrocerus_115303" spec="Taxon"/>
#                         <taxon idref="Verrallia_115333" spec="Taxon"/>
#                         <taxon idref="Chamaemyia_305621" spec="Taxon"/>
#                         <taxon idref="Leucopis_1728826" spec="Taxon"/>
#                         <taxon idref="Parochthiphila_1262282" spec="Taxon"/>
#                         <taxon idref="Coelopa_169466" spec="Taxon"/>
#                         <taxon idref="Helcomyza_169476" spec="Taxon"/>
#                         <taxon idref="Homoneura_1692452" spec="Taxon"/>
#                         <taxon idref="Tricholauxania_192459" spec="Taxon"/>
#                         <taxon idref="Aulogastromyia_1824990" spec="Taxon"/>
#                         <taxon idref="Pteromicra_1226622" spec="Taxon"/>
#                         <taxon idref="Dictya_1096051" spec="Taxon"/>
#                         <taxon idref="Elgiva_320938" spec="Taxon"/>
#                         <taxon idref="Sepedon_320954" spec="Taxon"/>
#                         <taxon idref="Neolimnia_1262312" spec="Taxon"/>
#                         <taxon idref="Sciomyza_320936" spec="Taxon"/>
#                         <taxon idref="Ilione_1096072" spec="Taxon"/>
#                         <taxon idref="Psacadina_1096078" spec="Taxon"/>
#                         <taxon idref="Tetanocera_320959" spec="Taxon"/>
#                         <taxon idref="Hedria_320941" spec="Taxon"/>
#                         <taxon idref="Coremacera_1226614" spec="Taxon"/>
#                         <taxon idref="Anticheta_1096047" spec="Taxon"/>
#                         <taxon idref="Pelidnoptera_1096074" spec="Taxon"/>
# ...
#                         <taxon idref="Melinda_170907" spec="Taxon"/>
#                         <taxon idref="Mesembrinella_460529" spec="Taxon"/>
#                         <taxon idref="Protocalliphora_142901" spec="Taxon"/>
#                         <taxon idref="Cuterebra_170896" spec="Taxon"/>
#                         <taxon idref="Blaesoxipha_128953" spec="Taxon"/>
#                         <taxon idref="Cephenemyia_170894" spec="Taxon"/>
#                         <taxon idref="Sphecapatodes_2021536" spec="Taxon"/>
#                         <taxon idref="Idiella_1902146" spec="Taxon"/>
#                     </rogues>
#                 </distribution>
#                  <distribution id="Tachinidae.prior" spec="beast.base.evolution.tree.MRCAPrior" monophyletic="true" tree="@Tree.t:mito_nonprotcoding">
#                     <taxonset id="Tachinidae" spec="TaxonSet">
#                         <taxon idref="Ectophasia_569037" spec="Taxon"/>
#                         <taxon idref="Sturmia_569089" spec="Taxon"/>
#                         <taxon idref="Phytomyptera_179785" spec="Taxon"/>
#                         <taxon idref="Nemoraea_170911" spec="Taxon"/>
#                         <taxon idref="Billaea_701468" spec="Taxon"/>
#                         <taxon idref="Ateloglossa_1890907" spec="Taxon"/>
#                         <taxon idref="Senotainia_179787" spec="Taxon"/>
#                         <taxon idref="Elomyia_1562792" spec="Taxon"/>
#                         <taxon idref="Blondelia_179437" spec="Taxon"/>
#                         <taxon idref="Prosena_1918293" spec="Taxon"/>
#                         <taxon idref="Glaurocara_2027854" spec="Taxon"/>
#                         <taxon idref="Drino_179459" spec="Taxon"/>
#                         <taxon idref="Phryxe_569079" spec="Taxon"/>
#                         <taxon idref="Acemya_1677647" spec="Taxon"/>
#                         <taxon idref="Blepharomyia_179434" spec="Taxon"/>
#                         <taxon idref="Cleonice_1918224" spec="Taxon"/>
#                         <taxon idref="Cyrtophleba_991141" spec="Taxon"/>
#                         <taxon idref="Dinera_569035" spec="Taxon"/>
#                         <taxon idref="Anthomyiopsis_1918198" spec="Taxon"/>
#                         <taxon idref="Neaera_695903" spec="Taxon"/>
#                         <taxon idref="Parasetigena_380521" spec="Taxon"/>
#                         <taxon idref="Mintho_1918277" spec="Taxon"/>
#                         <taxon idref="Lydella_283929" spec="Taxon"/>
#                         <taxon idref="Clausicella_1718822" spec="Taxon"/>
#                         <taxon idref="Archytas_198637" spec="Taxon"/>
#                         <taxon idref="Dexia_569033" spec="Taxon"/>
#                         <taxon idref="Pseudoperichaeta_283931" spec="Taxon"/>
#                         <taxon idref="Estheria_1918238" spec="Taxon"/>
#                         <taxon idref="Exorista_113238" spec="Taxon"/>
#                         <taxon idref="Leschenaultia_179486" spec="Taxon"/>
#                         <taxon idref="Vibrissina_179525" spec="Taxon"/>
#                         <taxon idref="Zaira_179789" spec="Taxon"/>
#                         <taxon idref="Macquartia_1918266" spec="Taxon"/>
#                     </taxonset>
#                 </distribution>
#                  <distribution id="Rhinophoridae.prior" spec="beast.base.evolution.tree.MRCAPrior" monophyletic="true" tree="@Tree.t:mito_nonprotcoding">
#                     <taxonset id="Rhinophoridae" spec="TaxonSet">
#                         <taxon idref="Stevenia_670627" spec="Taxon"/>
#                         <taxon idref="Rhinophora_670625" spec="Taxon"/>
#                         <taxon idref="Tricogena_1606792" spec="Taxon"/>
#                         <taxon idref="Phyto_1262320" spec="Taxon"/>
#                         <taxon idref="Paykullia_559695" spec="Taxon"/>
#                         <taxon idref="Melanophora_1606787" spec="Taxon"/>
#                     </taxonset>
#                 </distribution>
#                  <distribution id="Mesembrinellidae.prior" spec="beast.base.evolution.tree.MRCAPrior" monophyletic="true" tree="@Tree.t:mito_nonprotcoding">
#                     <taxonset id="Mesembrinellidae" spec="TaxonSet">
#                         <taxon idref="Laneella_1658054" spec="Taxon"/>
#                         <taxon idref="Eumesembrinella_672472" spec="Taxon"/>
#                         <taxon idref="Mesembrinella_460529" spec="Taxon"/>
#                         <taxon idref="Huascaromusca_1609532" spec="Taxon"/>
#                     </taxonset>
#                 </distribution>
#                  <distribution id="Rhiniidae.prior" spec="beast.base.evolution.tree.MRCAPrior" monophyletic="true" tree="@Tree.t:mito_nonprotcoding">
#                     <taxonset id="Rhiniidae" spec="TaxonSet">
#                         <taxon idref="Rhyncomya_670621" spec="Taxon"/>
#                         <taxon idref="Idiella_1902146" spec="Taxon"/>
#                     </taxonset>
#                 </distribution>
#                  <distribution id="Anthomyiidae.prior" spec="beast.base.evolution.tree.MRCAPrior" monophyletic="true" tree="@Tree.t:mito_nonprotcoding">
#                     <taxonset id="Anthomyiidae" spec="TaxonSet">
#                         <taxon idref="Phorbia_1993534" spec="Taxon"/>
#                         <taxon idref="Egle_411076" spec="Taxon"/>
#                         <taxon idref="Lasiomma_95464" spec="Taxon"/>
#                         <taxon idref="Alliopsis_1692454" spec="Taxon"/>
#                         <taxon idref="Fucellia_205683" spec="Taxon"/>
#                         <taxon idref="Pegomya_559697" spec="Taxon"/>
#                         <taxon idref="Paregle_559693" spec="Taxon"/>
#                         <taxon idref="Chiastocheta_129251" spec="Taxon"/>
#                         <taxon idref="Chirosia_392044" spec="Taxon"/>
#                         <taxon idref="Pegohylemyia_1887308" spec="Taxon"/>
#                         <taxon idref="Delia_30063" spec="Taxon"/>
#                         <taxon idref="Hylemya_253328" spec="Taxon"/>
#                         <taxon idref="Anthomyia_259845" spec="Taxon"/>
#                     </taxonset>
#                 </distribution>
#                  <distribution id="Fanniidae.prior" spec="beast.base.evolution.tree.MRCAPrior" monophyletic="true" tree="@Tree.t:mito_nonprotcoding">
#                     <taxonset id="Fanniidae" spec="TaxonSet">
#                         <taxon idref="Fannia_95468" spec="Taxon"/>
#                         <taxon idref="Euryomma_1650677" spec="Taxon"/>
#                     </taxonset>
#                 </distribution>
#                  <distribution id="Ephydroidea.prior" spec="beast.base.evolution.tree.MRCAPrior" monophyletic="true" tree="@Tree.t:mito_nonprotcoding">
#                     <taxonset id="Ephydroidea" spec="TaxonSet">
#                         <taxon idref="Curtonotum_1262296" spec="Taxon"/>
#                         <taxon idref="Cryptochetum_1262333" spec="Taxon"/>
#                         <taxon idref="Hydrellia_92591" spec="Taxon"/>
#                         <taxon idref="Nostima_1473719" spec="Taxon"/>
#                         <taxon idref="Scatophila_1763968" spec="Taxon"/>
#                         <taxon idref="Pelina_1086796" spec="Taxon"/>
#                         <taxon idref="Ephydra_504564" spec="Taxon"/>
#                         <taxon idref="Scatella_305595" spec="Taxon"/>
#                         <taxon idref="Stegana_188292" spec="Taxon"/>
#                         <taxon idref="Drosophila_7215" spec="Taxon"/>
#                         <taxon idref="Zygothrica_504731" spec="Taxon"/>
#                         <taxon idref="Scaptomyza_7298" spec="Taxon"/>
#                         <taxon idref="Acletoxenus_462271" spec="Taxon"/>
#                         <taxon idref="Leucophenga_7329" spec="Taxon"/>
#                         <taxon idref="Chymomyza_7292" spec="Taxon"/>
#                         <taxon idref="Zaprionus_7296" spec="Taxon"/>
#                         <taxon idref="Scaptodrosophila_7354" spec="Taxon"/>
#                         <taxon idref="Cacoxenus_462273" spec="Taxon"/>
#                     </taxonset>
#                 </distribution>
#                  <distribution id="Ephydridae.prior" spec="beast.base.evolution.tree.MRCAPrior" monophyletic="true" tree="@Tree.t:mito_nonprotcoding">
#                     <taxonset id="Ephydridae" spec="TaxonSet">
#                         <taxon idref="Hydrellia_92591" spec="Taxon"/>
#                         <taxon idref="Nostima_1473719" spec="Taxon"/>
#                         <taxon idref="Scatophila_1763968" spec="Taxon"/>
#                         <taxon idref="Pelina_1086796" spec="Taxon"/>
#                         <taxon idref="Ephydra_504564" spec="Taxon"/>
#                         <taxon idref="Scatella_305595" spec="Taxon"/>
#                     </taxonset>
#                 </distribution>
#                  <distribution id="Syrphidae.prior" spec="beast.base.evolution.tree.MRCAPrior" monophyletic="true" tree="@Tree.t:mito_nonprotcoding">
#                     <taxonset id="Syrphidae" spec="TaxonSet">
#                         <taxon idref="Hammerschmidtia_226171" spec="Taxon"/>
#                         <taxon idref="Paragus_115308" spec="Taxon"/>
#                         <taxon idref="Brachyopa_1637464" spec="Taxon"/>
#                         <taxon idref="Eupeodes_290403" spec="Taxon"/>
#                         <taxon idref="Blera_226146" spec="Taxon"/>
#                         <taxon idref="Copestylum_511142" spec="Taxon"/>
#                         <taxon idref="Scaeva_219538" spec="Taxon"/>
#                         <taxon idref="Eumerus_224220" spec="Taxon"/>
#                         <taxon idref="Syrphus_224255" spec="Taxon"/>
#                         <taxon idref="Ornidia_994473" spec="Taxon"/>
#                         <taxon idref="Volucella_226148" spec="Taxon"/>
#                         <taxon idref="Melangyna_414825" spec="Taxon"/>
#                         <taxon idref="Syritta_34681" spec="Taxon"/>
#                         <taxon idref="Ocyptamus_369855" spec="Taxon"/>
#                         <taxon idref="Cheilosia_173981" spec="Taxon"/>
#                         <taxon idref="Chrysogaster_224248" spec="Taxon"/>
#                         <taxon idref="Microdon_115291" spec="Taxon"/>
#                         <taxon idref="Toxomerus_115327" spec="Taxon"/>
#                         <taxon idref="Sphaerophoria_226179" spec="Taxon"/>
#                         <taxon idref="Merodon_224226" spec="Taxon"/>
#                         <taxon idref="Pipiza_221788" spec="Taxon"/>
#                         <taxon idref="Epistrophe_414810" spec="Taxon"/>
#                         <taxon idref="Temnostoma_226164" spec="Taxon"/>
#                         <taxon idref="Eriozona_414724" spec="Taxon"/>
#                         <taxon idref="Myolepta_1473716" spec="Taxon"/>
#                         <taxon idref="Neoascia_224222" spec="Taxon"/>
#                         <taxon idref="Callicera_228567" spec="Taxon"/>
#                         <taxon idref="Eristalis_198633" spec="Taxon"/>
#                         <taxon idref="Xanthogramma_414873" spec="Taxon"/>
#                     </taxonset>
#                 </distribution>
#                  <distribution id="Dolichopodidae.prior" spec="beast.base.evolution.tree.MRCAPrior" monophyletic="true" tree="@Tree.t:mito_nonprotcoding">
#                     <taxonset id="Dolichopodidae" spec="TaxonSet">
#                         <taxon idref="Dolichopus_192427" spec="Taxon"/>
#                         <taxon idref="Medetera_377527" spec="Taxon"/>
#                         <taxon idref="Rhaphium_377528" spec="Taxon"/>
#                         <taxon idref="Rhamphomyia_192612" spec="Taxon"/>
#                         <taxon idref="Neoplasta_192640" spec="Taxon"/>
#                         <taxon idref="Phyllodromia_1209097" spec="Taxon"/>
#                         <taxon idref="Chelifera_369889" spec="Taxon"/>
#                         <taxon idref="Wiedemannia_240904" spec="Taxon"/>
#                         <taxon idref="Clinocera_192484" spec="Taxon"/>
#                         <taxon idref="Metachela_369884" spec="Taxon"/>
#                     </taxonset>
#                 </distribution>
#                  <distribution id="Asilidae.prior" spec="beast.base.evolution.tree.MRCAPrior" monophyletic="true" tree="@Tree.t:mito_nonprotcoding">
#                     <taxonset id="Asilidae" spec="TaxonSet">
#                         <taxon idref="Philonicus_247567" spec="Taxon"/>
#                         <taxon idref="Dioctria_468720" spec="Taxon"/>
#                         <taxon idref="Promachus_247552" spec="Taxon"/>
#                         <taxon idref="Machimus_247604" spec="Taxon"/>
#                         <taxon idref="Lasiopogon_219536" spec="Taxon"/>
#                         <taxon idref="Pamponerus_1717601" spec="Taxon"/>
#                         <taxon idref="Laphria_50683" spec="Taxon"/>
#                         <taxon idref="Mallophora_270862" spec="Taxon"/>
#                     </taxonset>
#                 </distribution>
#                  <distribution id="Acroceridae.prior" spec="beast.base.evolution.tree.MRCAPrior" monophyletic="true" tree="@Tree.t:mito_nonprotcoding">
#                     <taxonset id="Acroceridae" spec="TaxonSet">
#                         <taxon idref="Ocnaea_210271" spec="Taxon"/>
#                         <taxon idref="Ogcodes_188257" spec="Taxon"/>
#                         <taxon idref="Eulonchus_210230" spec="Taxon"/>
#                         <taxon idref="Acrocera_210245" spec="Taxon"/>
#                         <taxon idref="Astomella_210239" spec="Taxon"/>
#                         <taxon idref="Exetasis_1932988" spec="Taxon"/>
#                         <taxon idref="Pterodontia_210267" spec="Taxon"/>
#                     </taxonset>
#                 </distribution>
#                  <distribution id="Bombyliidae.prior" spec="beast.base.evolution.tree.MRCAPrior" monophyletic="true" tree="@Tree.t:mito_nonprotcoding">
#                     <taxonset id="Bombyliidae" spec="TaxonSet">
#                         <taxon idref="Systoechus_1690390" spec="Taxon"/>
#                         <taxon idref="Bombylius_219362" spec="Taxon"/>
#                         <taxon idref="Anthrax_117078" spec="Taxon"/>
#                         <taxon idref="Ligyra_117088" spec="Taxon"/>
#                     </taxonset>
#                 </distribution>
#                  <distribution id="Milichiidae.prior" spec="beast.base.evolution.tree.MRCAPrior" monophyletic="true" tree="@Tree.t:mito_nonprotcoding">
#                     <taxonset id="Milichiidae" spec="TaxonSet">
#                         <taxon idref="Desmometopa_305587" spec="Taxon"/>
#                         <taxon idref="Leptometopa_1720790" spec="Taxon"/>
#                         <taxon idref="Pholeomyia_1720804" spec="Taxon"/>
#                         <taxon idref="Milichiella_1890919" spec="Taxon"/>
#                     </taxonset>
#                 </distribution>
#                  <distribution id="Conopidae.prior" spec="beast.base.evolution.tree.MRCAPrior" monophyletic="true" tree="@Tree.t:mito_nonprotcoding">
#                     <taxonset id="Conopidae" spec="TaxonSet">
#                         <taxon idref="Physocephala_198643" spec="Taxon"/>
#                         <taxon idref="Thecophora_305546" spec="Taxon"/>
#                         <taxon idref="Sicus_1219203" spec="Taxon"/>
#                         <taxon idref="Zodion_768804" spec="Taxon"/>
#                     </taxonset>
#                 </distribution>
#                  <distribution id="Clusiidae.prior" spec="beast.base.evolution.tree.MRCAPrior" monophyletic="true" tree="@Tree.t:mito_nonprotcoding">
#                     <taxonset id="Clusiidae" spec="TaxonSet">
#                         <taxon idref="Sobarocephala_574054" spec="Taxon"/>
#                         <taxon idref="Clusia_574057" spec="Taxon"/>
#                         <taxon idref="Clusiodes_500306" spec="Taxon"/>
#                     </taxonset>
#                 </distribution>
